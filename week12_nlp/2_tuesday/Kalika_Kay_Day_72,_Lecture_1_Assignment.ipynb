# %% [markdown]
# # Text Data Cleaning and Preprocessing Assignment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
from nltk import sent_tokenize
from nltk import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %% [markdown]
# ### Read the O'Reilly RSS plain text file articles into a corpus using the NLTK's PlaintextCorpusReader.

# %%
PATH = 'drive/MyDrive/content/rss/'

DOC_PATTERN = r'.*\.txt'
corpus = PlaintextCorpusReader(PATH, DOC_PATTERN)

# %% [markdown]
# ### Iterate through the fileids in the corpus, extract the raw text of each document, and store them in a list.

# %%
docs = [corpus.raw(fileid) for fileid in corpus.fileids()]

# %% [markdown]
# ### Sentence tokenize each document in the list of documents.

# %%
# sentence tokenization
sents = [sent_tokenize(doc) for doc in docs ]
print(sents)
# Out:
# [['2020 has been a year of great challenges for so many, but it’s not all negative.', 'Around the world, organizations and their workforces have risen to the occasion, recognizing the importance of expanding their knowledge, taking on new tasks, and bettering themselves both personally and professionally.', 'With the uptick in virtual conferencing, remote work, and, [&#8230;]'], ['It has long seemed to me that functional programming is, essentially, programming viewed as mathematics.', 'Many ideas in functional programming came from Alonzo Church&#8217;s Lambda Calculus, which significantly predates anything that looks remotely like a modern computer.', 'Though the actual history of computing runs differently: in the early days of computing, Von Neumann’s ideas were [&#8230;]'], ['Advanced System on a Chip Lecture Notes (2016) &#8212; Topics: 1.', 'Basic Processor &#38; Memory hierarchy; 2.', 'Advanced Out-of-Order Processor; 3.', 'Data-parallel processors; 4.', 'Micro-controller introduction; 5.', 'Multicore; 6.', 'RISC-V core; 7.', 'Advanced Multicore; 8.', 'Multicore programming; 9.', 'Graphics Processing Unit (GPU); 10.', 'Heterogeneous SoC; 11.', 'GPU Programming; 12.', 'Application-Specific Instruction-Set Processor (ASIP); 13 PULP: [&#8230;]'], ['The programming world used to be split into functional languages, object-oriented languages, and everything else (mostly procedural languages).', 'One &#8220;was&#8221; a functional programmer (at least as a hobby) writing Lisp, Haskell, or Erlang; or one &#8220;was&#8221; an OO programmer (at least professionally), writing code in Java or C++.', '(One never called oneself a “procedural programmer”; [&#8230;]'], ['Hypothesis as Liability &#8212; Would the mental focus on a specific hypothesis prevent us from making a discovery?', 'To test this, we made up a dataset and asked students to analyze it.', '[&#8230;] The most notable “discovery” in the dataset was that if you simply plotted the number of steps versus the BMI, you would [&#8230;]'], ['Dealing with Security Holes in Chips &#8212; system security starts at the hardware layer.', 'Ubooquity &#8212; free home server for your comics and ebooks library.', '&#8220;Like plex for books.&#8221; Noisepage &#8212; a relational database management system developed by the Carnegie Mellon Database Group.', 'The research goal of the NoisePage project is to develop high-performance system [&#8230;]'], ['The AI Who Mistook a Bald Head for a Football &#8212; Second-tier Scottish football club Inverness Caledonian Thistle doesn’t have a camera operator for matches at their stadium so the club uses an AI-controlled camera that’s programmed to follow the ball for their broadcasts.', 'But in a recent match against Ayr United, the AI controller [&#8230;]'], ['Perhaps the most important event this month isn’t technical, but the start of the US Justice Dept.’s lawsuit against Google.', 'That will certainly play out over years rather than months, but it’s significance is less about this particular case than the idea that legal and regulatory systems will play a large role in the evolution [&#8230;]'], ['Mutation Testing &#8212; in this paper, we semi-automatically learn error-inducing patterns from a corpus of common Java coding errors and from changes that caused operational anomalies at Facebook specifically.', 'We combine the mutations with instrumentation that measures which tests exactly visited the mutated piece of code.', 'Results on more than 15,000 generated mutants show that [&#8230;]'], ['Phantom of the ADAS &#8212; In this paper, we investigate &#8220;split-second phantom attacks,&#8221; a scientific gap that causes two commercial advanced driver-assistance systems (ADASs), Telsa Model X (HW 2.5 and HW 3) and Mobileye 630, to treat a depthless object that appears for a few milliseconds as a real obstacle/object.', 'Turns out neural networks can [&#8230;]'], ['&#8220;On peut interroger n&#8217;importe qui, dans n&#8217;importe quel ét ...

# %% [markdown]
# ### Word tokenize each sentence within each document.
#
# You should end up with a nested list structure where the outer list contains all the sentences in each document and the inner list contains the tokenized sentences.

# %%
sents[0][0]
# Out:
# '2020 has been a year of great challenges for so many, but it’s not all negative.'

# %%
len(sents)
# Out:
# 60

# %%
i = 0
tokenized = []
for i in range(len(docs)-1):
  tokenized += [word_tokenize(sent) for sent in sents[i]]
print(tokenized)
# Out:
# [['2020', 'has', 'been', 'a', 'year', 'of', 'great', 'challenges', 'for', 'so', 'many', ',', 'but', 'it', '’', 's', 'not', 'all', 'negative', '.'], ['Around', 'the', 'world', ',', 'organizations', 'and', 'their', 'workforces', 'have', 'risen', 'to', 'the', 'occasion', ',', 'recognizing', 'the', 'importance', 'of', 'expanding', 'their', 'knowledge', ',', 'taking', 'on', 'new', 'tasks', ',', 'and', 'bettering', 'themselves', 'both', 'personally', 'and', 'professionally', '.'], ['With', 'the', 'uptick', 'in', 'virtual', 'conferencing', ',', 'remote', 'work', ',', 'and', ',', '[', '&', '#', '8230', ';', ']'], ['It', 'has', 'long', 'seemed', 'to', 'me', 'that', 'functional', 'programming', 'is', ',', 'essentially', ',', 'programming', 'viewed', 'as', 'mathematics', '.'], ['Many', 'ideas', 'in', 'functional', 'programming', 'came', 'from', 'Alonzo', 'Church', '&', '#', '8217', ';', 's', 'Lambda', 'Calculus', ',', 'which', 'significantly', 'predates', 'anything', 'that', 'looks', 'remotely', 'like', 'a', 'modern', 'computer', '.'], ['Though', 'the', 'actual', 'history', 'of', 'computing', 'runs', 'differently', ':', 'in', 'the', 'early', 'days', 'of', 'computing', ',', 'Von', 'Neumann', '’', 's', 'ideas', 'were', '[', '&', '#', '8230', ';', ']'], ['Advanced', 'System', 'on', 'a', 'Chip', 'Lecture', 'Notes', '(', '2016', ')', '&', '#', '8212', ';', 'Topics', ':', '1', '.'], ['Basic', 'Processor', '&', '#', '38', ';', 'Memory', 'hierarchy', ';', '2', '.'], ['Advanced', 'Out-of-Order', 'Processor', ';', '3', '.'], ['Data-parallel', 'processors', ';', '4', '.'], ['Micro-controller', 'introduction', ';', '5', '.'], ['Multicore', ';', '6', '.'], ['RISC-V', 'core', ';', '7', '.'], ['Advanced', 'Multicore', ';', '8', '.'], ['Multicore', 'programming', ';', '9', '.'], ['Graphics', 'Processing', 'Unit', '(', 'GPU', ')', ';', '10', '.'], ['Heterogeneous', 'SoC', ';', '11', '.'], ['GPU', 'Programming', ';', '12', '.'], ['Application-Specific', 'Instruction-Set', 'Processor', '(', 'ASIP', ')', ';', '13', 'PULP', ':', '[', '&', '#', '8230', ';', ']'], ['The', 'programming', 'world', 'used', 'to', 'be', 'split', 'into', 'functional', 'languages', ',', 'object-oriented', 'languages', ',', 'and', 'everything', 'else', '(', 'mostly', 'procedural', 'languages', ')', '.'], ['One', '&', '#', '8220', ';', 'was', '&', '#', '8221', ';', 'a', 'functional', 'programmer', '(', 'at', 'least', 'as', 'a', 'hobby', ')', 'writing', 'Lisp', ',', 'Haskell', ',', 'or', 'Erlang', ';', 'or', 'one', '&', '#', '8220', ';', 'was', '&', '#', '8221', ';', 'an', 'OO', 'programmer', '(', 'at', 'least', 'professionally', ')', ',', 'writing', 'code', 'in', 'Java', 'or', 'C++', '.'], ['(', 'One', 'never', 'called', 'oneself', 'a', '“', 'procedural', 'programmer', '”', ';', '[', '&', '#', '8230', ';', ']'], ['Hypothesis', 'as', 'Liability', '&', '#', '8212', ';', 'Would', 'the', 'mental', 'focus', 'on', 'a', 'specific', 'hypothesis', 'prevent', 'us', 'from', 'making', 'a', 'discovery', '?'], ['To', 'test', 'this', ',', 'we', 'made', 'up', 'a', 'dataset', 'and', 'asked', 'students', 'to', 'analyze', 'it', '.'], ['[', '&', '#', '8230', ';', ']', 'The', 'most', 'notable', '“', 'discovery', '”', 'in', 'the', 'dataset', 'was', 'that', 'if', 'you', 'simply', 'plotted', 'the', 'number', 'of', 'steps', 'versus', 'the', 'BMI', ',', 'you', 'would', '[', '&', '#', '8230', ';', ']'], ['Dealing', 'with', 'Security', 'Holes', 'in', 'Chips', '&', '#', '8212', ';', 'system', 'security', 'starts', 'at', 'the', 'hardware', 'layer', '.'], ['Ubooquity', '&', '#', '8212', ';', 'free', 'home', 'server', 'for', 'your', 'comics', 'and', 'ebooks', 'library', '.'], ['&', '#', '8220', ';', 'Like', 'plex', 'for', 'books.', '&', '#', '8221', ';', 'Noisepage', '&', '#', '8212', ';', 'a', 'relational', 'database', 'management', 'system', 'developed', 'by', 'the', 'Carnegie', 'Mellon', 'Database', 'Group', '.'], ['The', 'research', 'goal', 'of', 'the', 'NoisePage', 'project', 'is', 'to', 'develop', 'high-perform ...

# %% [markdown]
# ### Tag each token with its part of speech.

# %%
tags = [pos_tag(token) for token in tokenized]
print(tags)
# Out:
# [[('2020', 'CD'), ('has', 'VBZ'), ('been', 'VBN'), ('a', 'DT'), ('year', 'NN'), ('of', 'IN'), ('great', 'JJ'), ('challenges', 'NNS'), ('for', 'IN'), ('so', 'RB'), ('many', 'JJ'), (',', ','), ('but', 'CC'), ('it', 'PRP'), ('’', 'NNP'), ('s', 'VBZ'), ('not', 'RB'), ('all', 'DT'), ('negative', 'JJ'), ('.', '.')], [('Around', 'IN'), ('the', 'DT'), ('world', 'NN'), (',', ','), ('organizations', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('workforces', 'NNS'), ('have', 'VBP'), ('risen', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('occasion', 'NN'), (',', ','), ('recognizing', 'VBG'), ('the', 'DT'), ('importance', 'NN'), ('of', 'IN'), ('expanding', 'VBG'), ('their', 'PRP$'), ('knowledge', 'NN'), (',', ','), ('taking', 'VBG'), ('on', 'IN'), ('new', 'JJ'), ('tasks', 'NNS'), (',', ','), ('and', 'CC'), ('bettering', 'VBG'), ('themselves', 'PRP'), ('both', 'DT'), ('personally', 'RB'), ('and', 'CC'), ('professionally', 'RB'), ('.', '.')], [('With', 'IN'), ('the', 'DT'), ('uptick', 'NN'), ('in', 'IN'), ('virtual', 'JJ'), ('conferencing', 'NN'), (',', ','), ('remote', 'JJ'), ('work', 'NN'), (',', ','), ('and', 'CC'), (',', ','), ('[', 'NNP'), ('&', 'CC'), ('#', '#'), ('8230', 'CD'), (';', ':'), (']', 'CC')], [('It', 'PRP'), ('has', 'VBZ'), ('long', 'RB'), ('seemed', 'VBN'), ('to', 'TO'), ('me', 'PRP'), ('that', 'IN'), ('functional', 'JJ'), ('programming', 'NN'), ('is', 'VBZ'), (',', ','), ('essentially', 'RB'), (',', ','), ('programming', 'VBG'), ('viewed', 'VBN'), ('as', 'IN'), ('mathematics', 'NNS'), ('.', '.')], [('Many', 'JJ'), ('ideas', 'NNS'), ('in', 'IN'), ('functional', 'JJ'), ('programming', 'NN'), ('came', 'VBD'), ('from', 'IN'), ('Alonzo', 'NNP'), ('Church', 'NNP'), ('&', 'CC'), ('#', '#'), ('8217', 'CD'), (';', ':'), ('s', 'CC'), ('Lambda', 'NNP'), ('Calculus', 'NNP'), (',', ','), ('which', 'WDT'), ('significantly', 'RB'), ('predates', 'VBZ'), ('anything', 'NN'), ('that', 'WDT'), ('looks', 'VBZ'), ('remotely', 'RB'), ('like', 'IN'), ('a', 'DT'), ('modern', 'JJ'), ('computer', 'NN'), ('.', '.')], [('Though', 'IN'), ('the', 'DT'), ('actual', 'JJ'), ('history', 'NN'), ('of', 'IN'), ('computing', 'VBG'), ('runs', 'NNS'), ('differently', 'RB'), (':', ':'), ('in', 'IN'), ('the', 'DT'), ('early', 'JJ'), ('days', 'NNS'), ('of', 'IN'), ('computing', 'NN'), (',', ','), ('Von', 'NNP'), ('Neumann', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('ideas', 'NNS'), ('were', 'VBD'), ('[', 'NNP'), ('&', 'CC'), ('#', '#'), ('8230', 'CD'), (';', ':'), (']', 'CC')], [('Advanced', 'NNP'), ('System', 'NNP'), ('on', 'IN'), ('a', 'DT'), ('Chip', 'JJ'), ('Lecture', 'NN'), ('Notes', 'NNS'), ('(', '('), ('2016', 'CD'), (')', ')'), ('&', 'CC'), ('#', '#'), ('8212', 'CD'), (';', ':'), ('Topics', 'NNS'), (':', ':'), ('1', 'CD'), ('.', '.')], [('Basic', 'NNP'), ('Processor', 'NNP'), ('&', 'CC'), ('#', '#'), ('38', 'CD'), (';', ':'), ('Memory', 'NNP'), ('hierarchy', 'NN'), (';', ':'), ('2', 'CD'), ('.', '.')], [('Advanced', 'NNP'), ('Out-of-Order', 'NNP'), ('Processor', 'NNP'), (';', ':'), ('3', 'CD'), ('.', '.')], [('Data-parallel', 'JJ'), ('processors', 'NNS'), (';', ':'), ('4', 'CD'), ('.', '.')], [('Micro-controller', 'NNP'), ('introduction', 'NN'), (';', ':'), ('5', 'CD'), ('.', '.')], [('Multicore', 'RB'), (';', ':'), ('6', 'CD'), ('.', '.')], [('RISC-V', 'NNP'), ('core', 'NN'), (';', ':'), ('7', 'CD'), ('.', '.')], [('Advanced', 'NNP'), ('Multicore', 'NNP'), (';', ':'), ('8', 'CD'), ('.', '.')], [('Multicore', 'RB'), ('programming', 'NN'), (';', ':'), ('9', 'CD'), ('.', '.')], [('Graphics', 'NNS'), ('Processing', 'VBG'), ('Unit', 'NNP'), ('(', '('), ('GPU', 'NNP'), (')', ')'), (';', ':'), ('10', 'CD'), ('.', '.')], [('Heterogeneous', 'JJ'), ('SoC', 'NNP'), (';', ':'), ('11', 'CD'), ('.', '.')], [('GPU', 'NNP'), ('Programming', 'NNP'), (';', ':'), ('12', 'CD'), ('.', '.')], [('Application-Specific', 'JJ'), ('Instruction-Set', 'NNP'), ('Processor', 'NNP'), ('(', '('), ('ASIP', 'NNP'), (')', ')'), (';', ':'), ('13', 'CD'), ('PULP', 'NN'), (':', ':'), ('[', 'NN'), ('&', 'CC') ...

# %% [markdown]
# ### Word tokenize the raw text of each document and remove stop words.

# %%
doc_tokens = [word_tokenize(doc) for doc in docs]
print(doc_tokens)
# Out:
# [['2020', 'has', 'been', 'a', 'year', 'of', 'great', 'challenges', 'for', 'so', 'many', ',', 'but', 'it', '’', 's', 'not', 'all', 'negative', '.', 'Around', 'the', 'world', ',', 'organizations', 'and', 'their', 'workforces', 'have', 'risen', 'to', 'the', 'occasion', ',', 'recognizing', 'the', 'importance', 'of', 'expanding', 'their', 'knowledge', ',', 'taking', 'on', 'new', 'tasks', ',', 'and', 'bettering', 'themselves', 'both', 'personally', 'and', 'professionally', '.', 'With', 'the', 'uptick', 'in', 'virtual', 'conferencing', ',', 'remote', 'work', ',', 'and', ',', '[', '&', '#', '8230', ';', ']'], ['It', 'has', 'long', 'seemed', 'to', 'me', 'that', 'functional', 'programming', 'is', ',', 'essentially', ',', 'programming', 'viewed', 'as', 'mathematics', '.', 'Many', 'ideas', 'in', 'functional', 'programming', 'came', 'from', 'Alonzo', 'Church', '&', '#', '8217', ';', 's', 'Lambda', 'Calculus', ',', 'which', 'significantly', 'predates', 'anything', 'that', 'looks', 'remotely', 'like', 'a', 'modern', 'computer', '.', 'Though', 'the', 'actual', 'history', 'of', 'computing', 'runs', 'differently', ':', 'in', 'the', 'early', 'days', 'of', 'computing', ',', 'Von', 'Neumann', '’', 's', 'ideas', 'were', '[', '&', '#', '8230', ';', ']'], ['Advanced', 'System', 'on', 'a', 'Chip', 'Lecture', 'Notes', '(', '2016', ')', '&', '#', '8212', ';', 'Topics', ':', '1', '.', 'Basic', 'Processor', '&', '#', '38', ';', 'Memory', 'hierarchy', ';', '2', '.', 'Advanced', 'Out-of-Order', 'Processor', ';', '3', '.', 'Data-parallel', 'processors', ';', '4', '.', 'Micro-controller', 'introduction', ';', '5', '.', 'Multicore', ';', '6', '.', 'RISC-V', 'core', ';', '7', '.', 'Advanced', 'Multicore', ';', '8', '.', 'Multicore', 'programming', ';', '9', '.', 'Graphics', 'Processing', 'Unit', '(', 'GPU', ')', ';', '10', '.', 'Heterogeneous', 'SoC', ';', '11', '.', 'GPU', 'Programming', ';', '12', '.', 'Application-Specific', 'Instruction-Set', 'Processor', '(', 'ASIP', ')', ';', '13', 'PULP', ':', '[', '&', '#', '8230', ';', ']'], ['The', 'programming', 'world', 'used', 'to', 'be', 'split', 'into', 'functional', 'languages', ',', 'object-oriented', 'languages', ',', 'and', 'everything', 'else', '(', 'mostly', 'procedural', 'languages', ')', '.', 'One', '&', '#', '8220', ';', 'was', '&', '#', '8221', ';', 'a', 'functional', 'programmer', '(', 'at', 'least', 'as', 'a', 'hobby', ')', 'writing', 'Lisp', ',', 'Haskell', ',', 'or', 'Erlang', ';', 'or', 'one', '&', '#', '8220', ';', 'was', '&', '#', '8221', ';', 'an', 'OO', 'programmer', '(', 'at', 'least', 'professionally', ')', ',', 'writing', 'code', 'in', 'Java', 'or', 'C++', '.', '(', 'One', 'never', 'called', 'oneself', 'a', '“', 'procedural', 'programmer', '”', ';', '[', '&', '#', '8230', ';', ']'], ['Hypothesis', 'as', 'Liability', '&', '#', '8212', ';', 'Would', 'the', 'mental', 'focus', 'on', 'a', 'specific', 'hypothesis', 'prevent', 'us', 'from', 'making', 'a', 'discovery', '?', 'To', 'test', 'this', ',', 'we', 'made', 'up', 'a', 'dataset', 'and', 'asked', 'students', 'to', 'analyze', 'it', '.', '[', '&', '#', '8230', ';', ']', 'The', 'most', 'notable', '“', 'discovery', '”', 'in', 'the', 'dataset', 'was', 'that', 'if', 'you', 'simply', 'plotted', 'the', 'number', 'of', 'steps', 'versus', 'the', 'BMI', ',', 'you', 'would', '[', '&', '#', '8230', ';', ']'], ['Dealing', 'with', 'Security', 'Holes', 'in', 'Chips', '&', '#', '8212', ';', 'system', 'security', 'starts', 'at', 'the', 'hardware', 'layer', '.', 'Ubooquity', '&', '#', '8212', ';', 'free', 'home', 'server', 'for', 'your', 'comics', 'and', 'ebooks', 'library', '.', '&', '#', '8220', ';', 'Like', 'plex', 'for', 'books.', '&', '#', '8221', ';', 'Noisepage', '&', '#', '8212', ';', 'a', 'relational', 'database', 'management', 'system', 'developed', 'by', 'the', 'Carnegie', 'Mellon', 'Database', 'Group', '.', 'The', 'research', 'goal', 'of', 'the', 'NoisePage', 'project', 'is', 'to', 'develop', 'high-performance', 'system', '[', '&', '#', '8230', ';', ' ...

# %%
i = 0
no_stopwords = []
for i in range(len(doc_tokens)-1):
  no_stopwords += [token.lower() for token in doc_tokens[i] 
                if token.lower() not in stopwords.words('english')]
print(no_stopwords)
# Out:
# ['2020', 'year', 'great', 'challenges', 'many', ',', '’', 'negative', '.', 'around', 'world', ',', 'organizations', 'workforces', 'risen', 'occasion', ',', 'recognizing', 'importance', 'expanding', 'knowledge', ',', 'taking', 'new', 'tasks', ',', 'bettering', 'personally', 'professionally', '.', 'uptick', 'virtual', 'conferencing', ',', 'remote', 'work', ',', ',', '[', '&', '#', '8230', ';', ']', 'long', 'seemed', 'functional', 'programming', ',', 'essentially', ',', 'programming', 'viewed', 'mathematics', '.', 'many', 'ideas', 'functional', 'programming', 'came', 'alonzo', 'church', '&', '#', '8217', ';', 'lambda', 'calculus', ',', 'significantly', 'predates', 'anything', 'looks', 'remotely', 'like', 'modern', 'computer', '.', 'though', 'actual', 'history', 'computing', 'runs', 'differently', ':', 'early', 'days', 'computing', ',', 'von', 'neumann', '’', 'ideas', '[', '&', '#', '8230', ';', ']', 'advanced', 'system', 'chip', 'lecture', 'notes', '(', '2016', ')', '&', '#', '8212', ';', 'topics', ':', '1', '.', 'basic', 'processor', '&', '#', '38', ';', 'memory', 'hierarchy', ';', '2', '.', 'advanced', 'out-of-order', 'processor', ';', '3', '.', 'data-parallel', 'processors', ';', '4', '.', 'micro-controller', 'introduction', ';', '5', '.', 'multicore', ';', '6', '.', 'risc-v', 'core', ';', '7', '.', 'advanced', 'multicore', ';', '8', '.', 'multicore', 'programming', ';', '9', '.', 'graphics', 'processing', 'unit', '(', 'gpu', ')', ';', '10', '.', 'heterogeneous', 'soc', ';', '11', '.', 'gpu', 'programming', ';', '12', '.', 'application-specific', 'instruction-set', 'processor', '(', 'asip', ')', ';', '13', 'pulp', ':', '[', '&', '#', '8230', ';', ']', 'programming', 'world', 'used', 'split', 'functional', 'languages', ',', 'object-oriented', 'languages', ',', 'everything', 'else', '(', 'mostly', 'procedural', 'languages', ')', '.', 'one', '&', '#', '8220', ';', '&', '#', '8221', ';', 'functional', 'programmer', '(', 'least', 'hobby', ')', 'writing', 'lisp', ',', 'haskell', ',', 'erlang', ';', 'one', '&', '#', '8220', ';', '&', '#', '8221', ';', 'oo', 'programmer', '(', 'least', 'professionally', ')', ',', 'writing', 'code', 'java', 'c++', '.', '(', 'one', 'never', 'called', 'oneself', '“', 'procedural', 'programmer', '”', ';', '[', '&', '#', '8230', ';', ']', 'hypothesis', 'liability', '&', '#', '8212', ';', 'would', 'mental', 'focus', 'specific', 'hypothesis', 'prevent', 'us', 'making', 'discovery', '?', 'test', ',', 'made', 'dataset', 'asked', 'students', 'analyze', '.', '[', '&', '#', '8230', ';', ']', 'notable', '“', 'discovery', '”', 'dataset', 'simply', 'plotted', 'number', 'steps', 'versus', 'bmi', ',', 'would', '[', '&', '#', '8230', ';', ']', 'dealing', 'security', 'holes', 'chips', '&', '#', '8212', ';', 'system', 'security', 'starts', 'hardware', 'layer', '.', 'ubooquity', '&', '#', '8212', ';', 'free', 'home', 'server', 'comics', 'ebooks', 'library', '.', '&', '#', '8220', ';', 'like', 'plex', 'books.', '&', '#', '8221', ';', 'noisepage', '&', '#', '8212', ';', 'relational', 'database', 'management', 'system', 'developed', 'carnegie', 'mellon', 'database', 'group', '.', 'research', 'goal', 'noisepage', 'project', 'develop', 'high-performance', 'system', '[', '&', '#', '8230', ';', ']', 'ai', 'mistook', 'bald', 'head', 'football', '&', '#', '8212', ';', 'second-tier', 'scottish', 'football', 'club', 'inverness', 'caledonian', 'thistle', '’', 'camera', 'operator', 'matches', 'stadium', 'club', 'uses', 'ai-controlled', 'camera', '’', 'programmed', 'follow', 'ball', 'broadcasts', '.', 'recent', 'match', 'ayr', 'united', ',', 'ai', 'controller', '[', '&', '#', '8230', ';', ']', 'perhaps', 'important', 'event', 'month', '’', 'technical', ',', 'start', 'us', 'justice', 'dept.', '’', 'lawsuit', 'google', '.', 'certainly', 'play', 'years', 'rather', 'months', ',', '’', 'significance', 'less', 'particular', 'case', 'idea', 'legal', 'regulatory', 'systems', 'play', 'large', 'role', 'evolution', '[', '&', '#', '8230', ';', ']' ...

# %% [markdown]
# ### For every document, stem all the words in the document.

# %%
# stemming
stemmer = SnowballStemmer('english')
stemmed = []
for i in range(len(docs)-1):
  stemmed += [stemmer.stem(token.lower()) for token in word_tokenize(docs[i])]

print(stemmed)
# Out:
# ['2020', 'has', 'been', 'a', 'year', 'of', 'great', 'challeng', 'for', 'so', 'mani', ',', 'but', 'it', '’', 's', 'not', 'all', 'negat', '.', 'around', 'the', 'world', ',', 'organ', 'and', 'their', 'workforc', 'have', 'risen', 'to', 'the', 'occas', ',', 'recogn', 'the', 'import', 'of', 'expand', 'their', 'knowledg', ',', 'take', 'on', 'new', 'task', ',', 'and', 'better', 'themselv', 'both', 'person', 'and', 'profession', '.', 'with', 'the', 'uptick', 'in', 'virtual', 'conferenc', ',', 'remot', 'work', ',', 'and', ',', '[', '&', '#', '8230', ';', ']', 'it', 'has', 'long', 'seem', 'to', 'me', 'that', 'function', 'program', 'is', ',', 'essenti', ',', 'program', 'view', 'as', 'mathemat', '.', 'mani', 'idea', 'in', 'function', 'program', 'came', 'from', 'alonzo', 'church', '&', '#', '8217', ';', 's', 'lambda', 'calculus', ',', 'which', 'signific', 'predat', 'anyth', 'that', 'look', 'remot', 'like', 'a', 'modern', 'comput', '.', 'though', 'the', 'actual', 'histori', 'of', 'comput', 'run', 'differ', ':', 'in', 'the', 'earli', 'day', 'of', 'comput', ',', 'von', 'neumann', '’', 's', 'idea', 'were', '[', '&', '#', '8230', ';', ']', 'advanc', 'system', 'on', 'a', 'chip', 'lectur', 'note', '(', '2016', ')', '&', '#', '8212', ';', 'topic', ':', '1', '.', 'basic', 'processor', '&', '#', '38', ';', 'memori', 'hierarchi', ';', '2', '.', 'advanc', 'out-of-ord', 'processor', ';', '3', '.', 'data-parallel', 'processor', ';', '4', '.', 'micro-control', 'introduct', ';', '5', '.', 'multicor', ';', '6', '.', 'risc-v', 'core', ';', '7', '.', 'advanc', 'multicor', ';', '8', '.', 'multicor', 'program', ';', '9', '.', 'graphic', 'process', 'unit', '(', 'gpu', ')', ';', '10', '.', 'heterogen', 'soc', ';', '11', '.', 'gpu', 'program', ';', '12', '.', 'application-specif', 'instruction-set', 'processor', '(', 'asip', ')', ';', '13', 'pulp', ':', '[', '&', '#', '8230', ';', ']', 'the', 'program', 'world', 'use', 'to', 'be', 'split', 'into', 'function', 'languag', ',', 'object-ori', 'languag', ',', 'and', 'everyth', 'els', '(', 'most', 'procedur', 'languag', ')', '.', 'one', '&', '#', '8220', ';', 'was', '&', '#', '8221', ';', 'a', 'function', 'programm', '(', 'at', 'least', 'as', 'a', 'hobbi', ')', 'write', 'lisp', ',', 'haskel', ',', 'or', 'erlang', ';', 'or', 'one', '&', '#', '8220', ';', 'was', '&', '#', '8221', ';', 'an', 'oo', 'programm', '(', 'at', 'least', 'profession', ')', ',', 'write', 'code', 'in', 'java', 'or', 'c++', '.', '(', 'one', 'never', 'call', 'oneself', 'a', '“', 'procedur', 'programm', '”', ';', '[', '&', '#', '8230', ';', ']', 'hypothesi', 'as', 'liabil', '&', '#', '8212', ';', 'would', 'the', 'mental', 'focus', 'on', 'a', 'specif', 'hypothesi', 'prevent', 'us', 'from', 'make', 'a', 'discoveri', '?', 'to', 'test', 'this', ',', 'we', 'made', 'up', 'a', 'dataset', 'and', 'ask', 'student', 'to', 'analyz', 'it', '.', '[', '&', '#', '8230', ';', ']', 'the', 'most', 'notabl', '“', 'discoveri', '”', 'in', 'the', 'dataset', 'was', 'that', 'if', 'you', 'simpli', 'plot', 'the', 'number', 'of', 'step', 'versus', 'the', 'bmi', ',', 'you', 'would', '[', '&', '#', '8230', ';', ']', 'deal', 'with', 'secur', 'hole', 'in', 'chip', '&', '#', '8212', ';', 'system', 'secur', 'start', 'at', 'the', 'hardwar', 'layer', '.', 'ubooqu', '&', '#', '8212', ';', 'free', 'home', 'server', 'for', 'your', 'comic', 'and', 'ebook', 'librari', '.', '&', '#', '8220', ';', 'like', 'plex', 'for', 'books.', '&', '#', '8221', ';', 'noisepag', '&', '#', '8212', ';', 'a', 'relat', 'databas', 'manag', 'system', 'develop', 'by', 'the', 'carnegi', 'mellon', 'databas', 'group', '.', 'the', 'research', 'goal', 'of', 'the', 'noisepag', 'project', 'is', 'to', 'develop', 'high-perform', 'system', '[', '&', '#', '8230', ';', ']', 'the', 'ai', 'who', 'mistook', 'a', 'bald', 'head', 'for', 'a', 'footbal', '&', '#', '8212', ';', 'second-ti', 'scottish', 'footbal', 'club', 'inver', 'caledonian', 'thistl', 'doesn', '’', 't', 'have', 'a', 'camera', 'oper', 'for', 'match', 'at', 'their', 'st ...

# %% [markdown]
# ### Iterate through each document, computing and printing the following document statistics for each.
#
# - Number of sentences
# - Average words per sentence
# - Vocabulary
# - Lexical Diversity

# %%
# document statistics
def stats(doc, title):
  sents = sent_tokenize(doc)
  tokenized = word_tokenize(doc)
  sentences = len(sents)
  avg_words_sent = sum([len(sent) for sent in tokenized]) / sentences
  vocab = len(set([word.lower() for word in word_tokenize(doc)]))
  lex_div = vocab / len(word_tokenize(doc))

  print(title)
  print('Number of Sentences: ', sentences)
  print('Avg. words per sentence: ', avg_words_sent)
  print('Unique words (vocabulary): ', vocab)
  print('Lexical Diversity: ', lex_div)
  print('---')

# %%
for doc in docs:
  stats(doc, doc[0:3])
# Out:
# 202
# Number of Sentences:  3
# Avg. words per sentence:  104.66666666666667
# Unique words (vocabulary):  57
# Lexical Diversity:  0.7808219178082192
# ---
# It
# Number of Sentences:  3
# Avg. words per sentence:  113.66666666666667
# Unique words (vocabulary):  58
# Lexical Diversity:  0.7733333333333333
# ---
# Adv
# Number of Sentences:  13
# Avg. words per sentence:  29.615384615384617
# Unique words (vocabulary):  57
# Lexical Diversity:  0.5757575757575758
# ---
# The
# Number of Sentences:  3
# Avg. words per sentence:  117.0
# Unique words (vocabulary):  53
# Lexical Diversity:  0.5578947368421052
# ---
# Hyp
# Number of Sentences:  3
# Avg. words per sentence:  90.0
# Unique words (vocabulary):  53
# Lexical Diversity:  0.7066666666666667
# ---
# Dea
# Number of Sentences:  4
# Avg. words per sentence:  84.75
# Unique words (vocabulary):  53
# Lexical Diversity:  0.654320987654321
# ---
# The
# Number of Sentences:  2
# Avg. words per sentence:  146.0
# Unique words (vocabulary):  53
# Lexical Diversity:  0.7571428571428571
# ---
# Per
# Number of Sentences:  2
# Avg. words per sentence:  142.0
# Unique words (vocabulary):  56
# Lexical Diversity:  0.8
# ---
# Mut
# Number of Sentences:  3
# Avg. words per sentence:  112.33333333333333
# Unique words (vocabulary):  57
# Lexical Diversity:  0.8507462686567164
# ---
# Pha
# Number of Sentences:  2
# Avg. words per sentence:  157.5
# Unique words (vocabulary):  60
# Lexical Diversity:  0.7407407407407407
# ---
# &#8
# Number of Sentences:  1
# Avg. words per sentence:  358.0
# Unique words (vocabulary):  61
# Lexical Diversity:  0.5495495495495496
# ---
# Jus
# Number of Sentences:  4
# Avg. words per sentence:  96.5
# Unique words (vocabulary):  59
# Lexical Diversity:  0.7662337662337663
# ---
# NAN
# Number of Sentences:  3
# Avg. words per sentence:  105.33333333333333
# Unique words (vocabulary):  59
# Lexical Diversity:  0.7195121951219512
# ---
# Aut
# Number of Sentences:  4
# Avg. words per sentence:  84.75
# Unique words (vocabulary):  58
# Lexical Diversity:  0.6666666666666666
# ---
# Dat
# Number of Sentences:  2
# Avg. words per sentence:  156.0
# Unique words (vocabulary):  57
# Lexical Diversity:  0.8028169014084507
# ---
# The
# Number of Sentences:  3
# Avg. words per sentence:  97.33333333333333
# Unique words (vocabulary):  47
# Lexical Diversity:  0.7121212121212122
# ---
# T-S
# Number of Sentences:  2
# Avg. words per sentence:  145.5
# Unique words (vocabulary):  52
# Lexical Diversity:  0.7536231884057971
# ---
# The
# Number of Sentences:  2
# Avg. words per sentence:  158.0
# Unique words (vocabulary):  56
# Lexical Diversity:  0.6153846153846154
# ---
# Alg
# Number of Sentences:  3
# Avg. words per sentence:  121.66666666666667
# Unique words (vocabulary):  54
# Lexical Diversity:  0.7714285714285715
# ---
# Sin
# Number of Sentences:  2
# Avg. words per sentence:  138.0
# Unique words (vocabulary):  54
# Lexical Diversity:  0.7397260273972602
# ---
# Thi
# Number of Sentences:  4
# Avg. words per sentence:  70.5
# Unique words (vocabulary):  52
# Lexical Diversity:  0.7536231884057971
# ---
# Whe
# Number of Sentences:  4
# Avg. words per sentence:  80.5
# Unique words (vocabulary):  60
# Lexical Diversity:  0.8108108108108109
# ---
# Ada
# Number of Sentences:  3
# Avg. words per sentence:  120.0
# Unique words (vocabulary):  54
# Lexical Diversity:  0.72
# ---
# Alp
# Number of Sentences:  3
# Avg. words per sentence:  100.0
# Unique words (vocabulary):  59
# Lexical Diversity:  0.7763157894736842
# ---
# CS3
# Number of Sentences:  2
# Avg. words per sentence:  178.0
# Unique words (vocabulary):  54
# Lexical Diversity:  0.7012987012987013
# ---
# A C
# Number of Sentences:  3
# Avg. words per sentence:  104.0
# Unique words (vocabulary):  58
# Lexical Diversity:  0.8055555555555556
# ---
# AI
# Number of Sentences:  3
# Avg. words per sentence:  98.66666666666667
# Unique words (vocabulary):  51
# Lexical Diversity:  0.75
# ---
# Acc
# Number of Sentences:  4
# Avg. words per sentence:  76.5
# Unique words (vocabulary):  56
# Lexical Diversity:  0.6363636363636364
# ---
# Thi
# Number of Sentences:  2
# Avg. words per sentence:  141.5
# Unique words (vocabulary):  56
# Lexical Diversity:  0.6829268292682927
# ---
# In
# Number of Sentences:  4
# Avg. words per sentence:  79.5
# Unique words (vocabulary):  52
# Lexical Diversity:  0.7647058823529411
# ---
# Ins
# Number of Sentences:  3
# Avg. words per sentence:  102.66666666666667
# Unique words (vocabulary):  50
# Lexical Diversity:  0.6329113924050633
# ---
# VSC
# Number of Sentences:  5
# Avg. words per sentence:  66.4
# Unique words (vocabulary):  56
# Lexical Diversity:  0.7272727272727273
# ---
# Com
# Number of Sentences:  4
# Avg. words per sentence:  76.75
# Unique words (vocabulary):  57
# Lexical Diversity:  0.7702702702702703
# ---
# Act
# Number of Sentences:  4
# Avg. words per sentence:  85.75
# Unique words (vocabulary):  61
# Lexical Diversity:  0.7093023255813954
# ---
# Thi
# Number of Sentences:  4
# Avg. words per sentence:  74.75
# Unique words (vocabulary):  56
# Lexical Diversity:  0.7368421052631579
# ---
# The
# Number of Sentences:  1
# Avg. words per sentence:  314.0
# Unique words (vocabulary):  59
# Lexical Diversity:  0.6629213483146067
# ---
# Woo
# Number of Sentences:  4
# Avg. words per sentence:  82.25
# Unique words (vocabulary):  57
# Lexical Diversity:  0.6785714285714286
# ---
# The
# Number of Sentences:  4
# Avg. words per sentence:  77.5
# Unique words (vocabulary):  50
# Lexical Diversity:  0.6410256410256411
# ---
# The
# Number of Sentences:  1
# Avg. words per sentence:  351.0
# Unique words (vocabulary):  55
# Lexical Diversity:  0.6962025316455697
# ---
# So
# Number of Sentences:  3
# Avg. words per sentence:  100.33333333333333
# Unique words (vocabulary):  58
# Lexical Diversity:  0.6904761904761905
# ---
# Sin
# Number of Sentences:  3
# Avg. words per sentence:  108.66666666666667
# Unique words (vocabulary):  51
# Lexical Diversity:  0.7285714285714285
# ---
# Sta
# Number of Sentences:  3
# Avg. words per sentence:  107.0
# Unique words (vocabulary):  60
# Lexical Diversity:  0.6818181818181818
# ---
# Imm
# Number of Sentences:  5
# Avg. words per sentence:  71.8
# Unique words (vocabulary):  56
# Lexical Diversity:  0.7
# ---
# Sur
# Number of Sentences:  3
# Avg. words per sentence:  93.0
# Unique words (vocabulary):  53
# Lexical Diversity:  0.7681159420289855
# ---
# Tal
# Number of Sentences:  4
# Avg. words per sentence:  80.25
# Unique words (vocabulary):  57
# Lexical Diversity:  0.7307692307692307
# ---
# Bri
# Number of Sentences:  3
# Avg. words per sentence:  99.66666666666667
# Unique words (vocabulary):  55
# Lexical Diversity:  0.5851063829787234
# ---
# I t
# Number of Sentences:  4
# Avg. words per sentence:  68.25
# Unique words (vocabulary):  59
# Lexical Diversity:  0.7468354430379747
# ---
# Mig
# Number of Sentences:  3
# Avg. words per sentence:  93.33333333333333
# Unique words (vocabulary):  59
# Lexical Diversity:  0.7564102564102564
# ---
# Tur
# Number of Sentences:  4
# Avg. words per sentence:  81.75
# Unique words (vocabulary):  52
# Lexical Diversity:  0.6265060240963856
# ---
# The
# Number of Sentences:  4
# Avg. words per sentence:  67.25
# Unique words (vocabulary):  51
# Lexical Diversity:  0.6891891891891891
# ---
# The
# Number of Sentences:  3
# Avg. words per sentence:  104.66666666666667
# Unique words (vocabulary):  45
# Lexical Diversity:  0.6521739130434783
# ---
# A r
# Number of Sentences:  3
# Avg. words per sentence:  107.0
# Unique words (vocabulary):  55
# Lexical Diversity:  0.6790123456790124
# ---
# Tec
# Number of Sentences:  3
# Avg. words per sentence:  85.33333333333333
# Unique words (vocabulary):  54
# Lexical Diversity:  0.7297297297297297
# ---
# How
# Number of Sentences:  2
# Avg. words per sentence:  170.5
# Unique words (vocabulary):  54
# Lexical Diversity:  0.7105263157894737
# ---
# As
# Number of Sentences:  3
# Avg. words per sentence:  89.0
# Unique words (vocabulary):  54
# Lexical Diversity:  0.7941176470588235
# ---
# wik
# Number of Sentences:  3
# Avg. words per sentence:  115.33333333333333
# Unique words (vocabulary):  58
# Lexical Diversity:  0.7532467532467533
# ---
# Ope
# Number of Sentences:  4
# Avg. words per sentence:  78.75
# Unique words (vocabulary):  58
# Lexical Diversity:  0.6987951807228916
# ---
# epr
# Number of Sentences:  5
# Avg. words per sentence:  66.2
# Unique words (vocabulary):  56
# Lexical Diversity:  0.6153846153846154
# ---
# If
# Number of Sentences:  4
# Avg. words per sentence:  65.75
# Unique words (vocabulary):  53
# Lexical Diversity:  0.7910447761194029
# ---
# NDS
# Number of Sentences:  2
# Avg. words per sentence:  162.0
# Unique words (vocabulary):  52
# Lexical Diversity:  0.7428571428571429
# ---
