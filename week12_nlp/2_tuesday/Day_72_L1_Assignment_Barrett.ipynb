# %% [markdown]
# # Text Data Cleaning and Preprocessing Assignment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
from nltk import sent_tokenize
from nltk import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# ### Read the O'Reilly RSS plain text file articles into a corpus using the NLTK's PlaintextCorpusReader.

# %%
PATH = '/content/drive/MyDrive/Thinkful/NLP/oreily_rss/'

DOC_PATTERN = r'.*\.txt'

corpus = PlaintextCorpusReader(PATH, DOC_PATTERN)

# %% [markdown]
# ### Iterate through the fileids in the corpus, extract the raw text of each document, and store them in a list.

# %%
docs = [corpus.raw(fileid) for fileid in corpus.fileids()]

# %% [markdown]
# ### Sentence tokenize each document in the list of documents.

# %%
doc_sents = [sent_tokenize(doc) for doc in docs]

# %%
doc_sents[0]
# Out:
# ['2020 has been a year of great challenges for so many, but it’s not all negative.',
#  'Around the world, organizations and their workforces have risen to the occasion, recognizing the importance of expanding their knowledge, taking on new tasks, and bettering themselves both personally and professionally.',
#  'With the uptick in virtual conferencing, remote work, and, for some, reentering the job market, new technology adoption was accelerated, driving the workforce to build new skills.',
#  'While 2020 was the year of the global COVID-19 pandemic, it will also be commemorated as the year online learning prevailed.',
#  'As vaccine development persists and life gets back to normal, with it will come a more future-proof workforce ready to share their new knowledge with the world.',
#  'Since the onset of the pandemic, online courses and programs have seen dramatic spikes in consumption and enrollment, and O’Reilly has been no different.',
#  'A big contributor to O’Reilly’s continued success during these unprecedented times has been its live virtual training courses.',
#  'This year, more than 900,000 users have registered for live events through O’Reilly online learning—a 96% increase from last year.',
#  'This functionality also allowed O’Reilly to introduce its Superstream Series, a new lineup of virtual conferences featuring expert speakers delivering talks and training sessions on the most important topics and emerging trends in technology.',
#  'So what are the trends driving this uptick in learning?',
#  'Companies are increasingly interested in understanding how to successfully adjust to remote work and effectively manage time.',
#  'And individual O’Reilly members are looking to build and expand on their technical skills in everything from software architecture and microservices to AI and programming languages.',
#  'But which topics are the brightest minds in technology most focused on?',
#  'We’ve compiled the top 20 live online training courses of 2020 to shed some light on what those in the know want to know.',
#  'Top 20 live online training courses of 2020 For a more in-depth analysis of the hot technology topics of 2020, based on data from O’Reilly online learning, stay tuned for our upcoming report, Wrapping Up 2020 (and What to Expect for 2021): Trends on O’Reilly online learning.']

# %%
doc = docs[0]

# %%
print(doc)
# Out:
# 2020 has been a year of great challenges for so many, but it’s not all negative. Around the world, organizations and their workforces have risen to the occasion, recognizing the importance of expanding their knowledge, taking on new tasks, and bettering themselves both personally and professionally. With the uptick in virtual conferencing, remote work, and, for some, reentering the job market, new technology adoption was accelerated, driving the workforce to build new skills. While 2020 was the year of the global COVID-19 pandemic, it will also be commemorated as the year online learning prevailed. As vaccine development persists and life gets back to normal, with it will come a more future-proof workforce ready to share their new knowledge with the world.  Since the onset of the pandemic, online courses and programs have seen dramatic spikes in consumption and enrollment, and O’Reilly has been no different. A big contributor to O’Reilly’s continued success during these unprecedented times has been its live virtual training courses. This year, more than 900,000 users have registered for live events through O’Reilly online learning—a 96% increase from last year. This functionality also allowed O’Reilly to introduce its Superstream Series, a new lineup of virtual conferences featuring expert speakers delivering talks and training sessions on the most important topics and emerging trends in technology.  So what are the trends driving this uptick in learning? Companies are increasingly interested in understanding how to successfully adjust to remote work and effectively manage time. And individual O’Reilly members are looking to build and expand on their technical skills in everything from software architecture and microservices to AI and programming languages. But which topics are the brightest minds in technology most focused on? We’ve compiled the top 20 live online training courses of 2020 to shed some light on what those in the know want to know. Top 20 live online training courses of 2020 For a more in-depth analysis of the hot technology topics of 2020, based on data from O’Reilly online learning, stay tuned for our upcoming report, Wrapping Up 2020 (and What to Expect for 2021): Trends on O’Reilly online learning.

# %%
sents = sent_tokenize(doc)
sents
# Out:
# ['2020 has been a year of great challenges for so many, but it’s not all negative.',
#  'Around the world, organizations and their workforces have risen to the occasion, recognizing the importance of expanding their knowledge, taking on new tasks, and bettering themselves both personally and professionally.',
#  'With the uptick in virtual conferencing, remote work, and, for some, reentering the job market, new technology adoption was accelerated, driving the workforce to build new skills.',
#  'While 2020 was the year of the global COVID-19 pandemic, it will also be commemorated as the year online learning prevailed.',
#  'As vaccine development persists and life gets back to normal, with it will come a more future-proof workforce ready to share their new knowledge with the world.',
#  'Since the onset of the pandemic, online courses and programs have seen dramatic spikes in consumption and enrollment, and O’Reilly has been no different.',
#  'A big contributor to O’Reilly’s continued success during these unprecedented times has been its live virtual training courses.',
#  'This year, more than 900,000 users have registered for live events through O’Reilly online learning—a 96% increase from last year.',
#  'This functionality also allowed O’Reilly to introduce its Superstream Series, a new lineup of virtual conferences featuring expert speakers delivering talks and training sessions on the most important topics and emerging trends in technology.',
#  'So what are the trends driving this uptick in learning?',
#  'Companies are increasingly interested in understanding how to successfully adjust to remote work and effectively manage time.',
#  'And individual O’Reilly members are looking to build and expand on their technical skills in everything from software architecture and microservices to AI and programming languages.',
#  'But which topics are the brightest minds in technology most focused on?',
#  'We’ve compiled the top 20 live online training courses of 2020 to shed some light on what those in the know want to know.',
#  'Top 20 live online training courses of 2020 For a more in-depth analysis of the hot technology topics of 2020, based on data from O’Reilly online learning, stay tuned for our upcoming report, Wrapping Up 2020 (and What to Expect for 2021): Trends on O’Reilly online learning.']

# %% [markdown]
# ### Word tokenize each sentence within each document.
#
# You should end up with a nested list structure where the outer list contains all the sentences in each document and the inner list contains the tokenized sentences.

# %%
tokened = [[word_tokenize(sent) for sent in doc] for doc in doc_sents]
print(tokened)
# Out:
# [[['2020', 'has', 'been', 'a', 'year', 'of', 'great', 'challenges', 'for', 'so', 'many', ',', 'but', 'it', '’', 's', 'not', 'all', 'negative', '.'], ['Around', 'the', 'world', ',', 'organizations', 'and', 'their', 'workforces', 'have', 'risen', 'to', 'the', 'occasion', ',', 'recognizing', 'the', 'importance', 'of', 'expanding', 'their', 'knowledge', ',', 'taking', 'on', 'new', 'tasks', ',', 'and', 'bettering', 'themselves', 'both', 'personally', 'and', 'professionally', '.'], ['With', 'the', 'uptick', 'in', 'virtual', 'conferencing', ',', 'remote', 'work', ',', 'and', ',', 'for', 'some', ',', 'reentering', 'the', 'job', 'market', ',', 'new', 'technology', 'adoption', 'was', 'accelerated', ',', 'driving', 'the', 'workforce', 'to', 'build', 'new', 'skills', '.'], ['While', '2020', 'was', 'the', 'year', 'of', 'the', 'global', 'COVID-19', 'pandemic', ',', 'it', 'will', 'also', 'be', 'commemorated', 'as', 'the', 'year', 'online', 'learning', 'prevailed', '.'], ['As', 'vaccine', 'development', 'persists', 'and', 'life', 'gets', 'back', 'to', 'normal', ',', 'with', 'it', 'will', 'come', 'a', 'more', 'future-proof', 'workforce', 'ready', 'to', 'share', 'their', 'new', 'knowledge', 'with', 'the', 'world', '.'], ['Since', 'the', 'onset', 'of', 'the', 'pandemic', ',', 'online', 'courses', 'and', 'programs', 'have', 'seen', 'dramatic', 'spikes', 'in', 'consumption', 'and', 'enrollment', ',', 'and', 'O', '’', 'Reilly', 'has', 'been', 'no', 'different', '.'], ['A', 'big', 'contributor', 'to', 'O', '’', 'Reilly', '’', 's', 'continued', 'success', 'during', 'these', 'unprecedented', 'times', 'has', 'been', 'its', 'live', 'virtual', 'training', 'courses', '.'], ['This', 'year', ',', 'more', 'than', '900,000', 'users', 'have', 'registered', 'for', 'live', 'events', 'through', 'O', '’', 'Reilly', 'online', 'learning—a', '96', '%', 'increase', 'from', 'last', 'year', '.'], ['This', 'functionality', 'also', 'allowed', 'O', '’', 'Reilly', 'to', 'introduce', 'its', 'Superstream', 'Series', ',', 'a', 'new', 'lineup', 'of', 'virtual', 'conferences', 'featuring', 'expert', 'speakers', 'delivering', 'talks', 'and', 'training', 'sessions', 'on', 'the', 'most', 'important', 'topics', 'and', 'emerging', 'trends', 'in', 'technology', '.'], ['So', 'what', 'are', 'the', 'trends', 'driving', 'this', 'uptick', 'in', 'learning', '?'], ['Companies', 'are', 'increasingly', 'interested', 'in', 'understanding', 'how', 'to', 'successfully', 'adjust', 'to', 'remote', 'work', 'and', 'effectively', 'manage', 'time', '.'], ['And', 'individual', 'O', '’', 'Reilly', 'members', 'are', 'looking', 'to', 'build', 'and', 'expand', 'on', 'their', 'technical', 'skills', 'in', 'everything', 'from', 'software', 'architecture', 'and', 'microservices', 'to', 'AI', 'and', 'programming', 'languages', '.'], ['But', 'which', 'topics', 'are', 'the', 'brightest', 'minds', 'in', 'technology', 'most', 'focused', 'on', '?'], ['We', '’', 've', 'compiled', 'the', 'top', '20', 'live', 'online', 'training', 'courses', 'of', '2020', 'to', 'shed', 'some', 'light', 'on', 'what', 'those', 'in', 'the', 'know', 'want', 'to', 'know', '.'], ['Top', '20', 'live', 'online', 'training', 'courses', 'of', '2020', 'For', 'a', 'more', 'in-depth', 'analysis', 'of', 'the', 'hot', 'technology', 'topics', 'of', '2020', ',', 'based', 'on', 'data', 'from', 'O', '’', 'Reilly', 'online', 'learning', ',', 'stay', 'tuned', 'for', 'our', 'upcoming', 'report', ',', 'Wrapping', 'Up', '2020', '(', 'and', 'What', 'to', 'Expect', 'for', '2021', ')', ':', 'Trends', 'on', 'O', '’', 'Reilly', 'online', 'learning', '.']], [['It', 'has', 'long', 'seemed', 'to', 'me', 'that', 'functional', 'programming', 'is', ',', 'essentially', ',', 'programming', 'viewed', 'as', 'mathematics', '.'], ['Many', 'ideas', 'in', 'functional', 'programming', 'came', 'from', 'Alonzo', 'Church', '’', 's', 'Lambda', 'Calculus', ',', 'which', 'significantly', 'predates', 'anything', 'that', 'looks', 'remotely', 'like', 'a', 'modern', 'computer', '.'], ['Tho ...

# %% [markdown]
# ### Tag each token with its part of speech.

# %%
part_of_speech = [[pos_tag(sent) for sent in doc] for doc in tokened]
print(part_of_speech)
# Out:
# [[[('2020', 'CD'), ('has', 'VBZ'), ('been', 'VBN'), ('a', 'DT'), ('year', 'NN'), ('of', 'IN'), ('great', 'JJ'), ('challenges', 'NNS'), ('for', 'IN'), ('so', 'RB'), ('many', 'JJ'), (',', ','), ('but', 'CC'), ('it', 'PRP'), ('’', 'NNP'), ('s', 'VBZ'), ('not', 'RB'), ('all', 'DT'), ('negative', 'JJ'), ('.', '.')], [('Around', 'IN'), ('the', 'DT'), ('world', 'NN'), (',', ','), ('organizations', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('workforces', 'NNS'), ('have', 'VBP'), ('risen', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('occasion', 'NN'), (',', ','), ('recognizing', 'VBG'), ('the', 'DT'), ('importance', 'NN'), ('of', 'IN'), ('expanding', 'VBG'), ('their', 'PRP$'), ('knowledge', 'NN'), (',', ','), ('taking', 'VBG'), ('on', 'IN'), ('new', 'JJ'), ('tasks', 'NNS'), (',', ','), ('and', 'CC'), ('bettering', 'VBG'), ('themselves', 'PRP'), ('both', 'DT'), ('personally', 'RB'), ('and', 'CC'), ('professionally', 'RB'), ('.', '.')], [('With', 'IN'), ('the', 'DT'), ('uptick', 'NN'), ('in', 'IN'), ('virtual', 'JJ'), ('conferencing', 'NN'), (',', ','), ('remote', 'JJ'), ('work', 'NN'), (',', ','), ('and', 'CC'), (',', ','), ('for', 'IN'), ('some', 'DT'), (',', ','), ('reentering', 'VBG'), ('the', 'DT'), ('job', 'NN'), ('market', 'NN'), (',', ','), ('new', 'JJ'), ('technology', 'NN'), ('adoption', 'NN'), ('was', 'VBD'), ('accelerated', 'VBN'), (',', ','), ('driving', 'VBG'), ('the', 'DT'), ('workforce', 'NN'), ('to', 'TO'), ('build', 'VB'), ('new', 'JJ'), ('skills', 'NNS'), ('.', '.')], [('While', 'IN'), ('2020', 'CD'), ('was', 'VBD'), ('the', 'DT'), ('year', 'NN'), ('of', 'IN'), ('the', 'DT'), ('global', 'JJ'), ('COVID-19', 'NNP'), ('pandemic', 'NN'), (',', ','), ('it', 'PRP'), ('will', 'MD'), ('also', 'RB'), ('be', 'VB'), ('commemorated', 'VBN'), ('as', 'IN'), ('the', 'DT'), ('year', 'NN'), ('online', 'NN'), ('learning', 'NN'), ('prevailed', 'VBD'), ('.', '.')], [('As', 'IN'), ('vaccine', 'NN'), ('development', 'NN'), ('persists', 'NNS'), ('and', 'CC'), ('life', 'NN'), ('gets', 'VBZ'), ('back', 'RB'), ('to', 'TO'), ('normal', 'JJ'), (',', ','), ('with', 'IN'), ('it', 'PRP'), ('will', 'MD'), ('come', 'VB'), ('a', 'DT'), ('more', 'RBR'), ('future-proof', 'JJ'), ('workforce', 'NN'), ('ready', 'NN'), ('to', 'TO'), ('share', 'NN'), ('their', 'PRP$'), ('new', 'JJ'), ('knowledge', 'NN'), ('with', 'IN'), ('the', 'DT'), ('world', 'NN'), ('.', '.')], [('Since', 'IN'), ('the', 'DT'), ('onset', 'NN'), ('of', 'IN'), ('the', 'DT'), ('pandemic', 'JJ'), (',', ','), ('online', 'JJ'), ('courses', 'NNS'), ('and', 'CC'), ('programs', 'NNS'), ('have', 'VBP'), ('seen', 'VBN'), ('dramatic', 'JJ'), ('spikes', 'NNS'), ('in', 'IN'), ('consumption', 'NN'), ('and', 'CC'), ('enrollment', 'NN'), (',', ','), ('and', 'CC'), ('O', 'NNP'), ('’', 'NNP'), ('Reilly', 'NNP'), ('has', 'VBZ'), ('been', 'VBN'), ('no', 'DT'), ('different', 'JJ'), ('.', '.')], [('A', 'DT'), ('big', 'JJ'), ('contributor', 'NN'), ('to', 'TO'), ('O', 'NNP'), ('’', 'NNP'), ('Reilly', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('continued', 'JJ'), ('success', 'NN'), ('during', 'IN'), ('these', 'DT'), ('unprecedented', 'JJ'), ('times', 'NNS'), ('has', 'VBZ'), ('been', 'VBN'), ('its', 'PRP$'), ('live', 'JJ'), ('virtual', 'JJ'), ('training', 'NN'), ('courses', 'NNS'), ('.', '.')], [('This', 'DT'), ('year', 'NN'), (',', ','), ('more', 'JJR'), ('than', 'IN'), ('900,000', 'CD'), ('users', 'NNS'), ('have', 'VBP'), ('registered', 'VBN'), ('for', 'IN'), ('live', 'JJ'), ('events', 'NNS'), ('through', 'IN'), ('O', 'NNP'), ('’', 'NNP'), ('Reilly', 'NNP'), ('online', 'VBP'), ('learning—a', 'JJ'), ('96', 'CD'), ('%', 'NN'), ('increase', 'NN'), ('from', 'IN'), ('last', 'JJ'), ('year', 'NN'), ('.', '.')], [('This', 'DT'), ('functionality', 'NN'), ('also', 'RB'), ('allowed', 'VBD'), ('O', 'NNP'), ('’', 'NNP'), ('Reilly', 'NNP'), ('to', 'TO'), ('introduce', 'VB'), ('its', 'PRP$'), ('Superstream', 'NNP'), ('Series', 'NNP'), (',', ','), ('a', 'DT'), ('new', 'JJ'), ('lineup', 'NN'), ('of', 'IN'), ('virtual', 'JJ'), ('conferences', ' ...

# %% [markdown]
# ### Word tokenize the raw text of each document and remove stop words.

# %%
no_stopwords = [[token.lower() for token in word_tokenize(doc) if token.lower() not in stopwords.words('english')] for doc in docs]

# %%
print(no_stopwords)
# Out:
# [['2020', 'year', 'great', 'challenges', 'many', ',', '’', 'negative', '.', 'around', 'world', ',', 'organizations', 'workforces', 'risen', 'occasion', ',', 'recognizing', 'importance', 'expanding', 'knowledge', ',', 'taking', 'new', 'tasks', ',', 'bettering', 'personally', 'professionally', '.', 'uptick', 'virtual', 'conferencing', ',', 'remote', 'work', ',', ',', ',', 'reentering', 'job', 'market', ',', 'new', 'technology', 'adoption', 'accelerated', ',', 'driving', 'workforce', 'build', 'new', 'skills', '.', '2020', 'year', 'global', 'covid-19', 'pandemic', ',', 'also', 'commemorated', 'year', 'online', 'learning', 'prevailed', '.', 'vaccine', 'development', 'persists', 'life', 'gets', 'back', 'normal', ',', 'come', 'future-proof', 'workforce', 'ready', 'share', 'new', 'knowledge', 'world', '.', 'since', 'onset', 'pandemic', ',', 'online', 'courses', 'programs', 'seen', 'dramatic', 'spikes', 'consumption', 'enrollment', ',', '’', 'reilly', 'different', '.', 'big', 'contributor', '’', 'reilly', '’', 'continued', 'success', 'unprecedented', 'times', 'live', 'virtual', 'training', 'courses', '.', 'year', ',', '900,000', 'users', 'registered', 'live', 'events', '’', 'reilly', 'online', 'learning—a', '96', '%', 'increase', 'last', 'year', '.', 'functionality', 'also', 'allowed', '’', 'reilly', 'introduce', 'superstream', 'series', ',', 'new', 'lineup', 'virtual', 'conferences', 'featuring', 'expert', 'speakers', 'delivering', 'talks', 'training', 'sessions', 'important', 'topics', 'emerging', 'trends', 'technology', '.', 'trends', 'driving', 'uptick', 'learning', '?', 'companies', 'increasingly', 'interested', 'understanding', 'successfully', 'adjust', 'remote', 'work', 'effectively', 'manage', 'time', '.', 'individual', '’', 'reilly', 'members', 'looking', 'build', 'expand', 'technical', 'skills', 'everything', 'software', 'architecture', 'microservices', 'ai', 'programming', 'languages', '.', 'topics', 'brightest', 'minds', 'technology', 'focused', '?', '’', 'compiled', 'top', '20', 'live', 'online', 'training', 'courses', '2020', 'shed', 'light', 'know', 'want', 'know', '.', 'top', '20', 'live', 'online', 'training', 'courses', '2020', 'in-depth', 'analysis', 'hot', 'technology', 'topics', '2020', ',', 'based', 'data', '’', 'reilly', 'online', 'learning', ',', 'stay', 'tuned', 'upcoming', 'report', ',', 'wrapping', '2020', '(', 'expect', '2021', ')', ':', 'trends', '’', 'reilly', 'online', 'learning', '.'], ['long', 'seemed', 'functional', 'programming', ',', 'essentially', ',', 'programming', 'viewed', 'mathematics', '.', 'many', 'ideas', 'functional', 'programming', 'came', 'alonzo', 'church', '’', 'lambda', 'calculus', ',', 'significantly', 'predates', 'anything', 'looks', 'remotely', 'like', 'modern', 'computer', '.', 'though', 'actual', 'history', 'computing', 'runs', 'differently', ':', 'early', 'days', 'computing', ',', 'von', 'neumann', '’', 'ideas', 'important', 'church', '’', ',', 'tremendous', 'influence', 'design', 'early', 'computers—an', 'influence', 'continues', 'present', '.', 'von', 'neumann', '’', 'thinking', 'essentially', 'imperative', ':', 'program', 'list', 'commands', 'run', 'machine', 'designed', 'execute', 'commands', '.', ',', 'mean', 'say', 'functional', 'programming', 'programming', '“', 'viewed', 'mathematics', '”', '?', 'von', 'neumann', '“', 'mathematician', ',', '”', 'programming', 'kinds', 'found', 'first', 'home', 'mathematics', 'departments', '.', ',', 'functional', 'programming', 'mathematical', ',', 'mean', '?', 'kind', 'math', '?', '’', 'thinking', 'specific', 'branch', 'mathematics', '.', 'yes', ',', 'lambda', 'calculus', 'significant', 'ties', 'set', 'theory', ',', 'logic', ',', 'category', 'theory', ',', 'many', 'branches', 'mathematics', '.', 'let', '’', 'start', 'grade', 'school', 'mathematics', 'assignment', 'statements', ';', '’', 'basic', 'programming', 'language', '.', '’', 'familiar', 'code', 'like', ':', 'mathematically', ',', 'nonsense', '.', 'equation', 'statement', 'relation ...

# %% [markdown]
# ### For every document, stem all the words in the document.

# %%
stemmer = SnowballStemmer('english')
stemmed = [[stemmer.stem(token) for token in word_tokenize(doc)] for doc in docs]
print(stemmed)
# Out:
# [['2020', 'has', 'been', 'a', 'year', 'of', 'great', 'challeng', 'for', 'so', 'mani', ',', 'but', 'it', '’', 's', 'not', 'all', 'negat', '.', 'around', 'the', 'world', ',', 'organ', 'and', 'their', 'workforc', 'have', 'risen', 'to', 'the', 'occas', ',', 'recogn', 'the', 'import', 'of', 'expand', 'their', 'knowledg', ',', 'take', 'on', 'new', 'task', ',', 'and', 'better', 'themselv', 'both', 'person', 'and', 'profession', '.', 'with', 'the', 'uptick', 'in', 'virtual', 'conferenc', ',', 'remot', 'work', ',', 'and', ',', 'for', 'some', ',', 'reenter', 'the', 'job', 'market', ',', 'new', 'technolog', 'adopt', 'was', 'acceler', ',', 'drive', 'the', 'workforc', 'to', 'build', 'new', 'skill', '.', 'while', '2020', 'was', 'the', 'year', 'of', 'the', 'global', 'covid-19', 'pandem', ',', 'it', 'will', 'also', 'be', 'commemor', 'as', 'the', 'year', 'onlin', 'learn', 'prevail', '.', 'as', 'vaccin', 'develop', 'persist', 'and', 'life', 'get', 'back', 'to', 'normal', ',', 'with', 'it', 'will', 'come', 'a', 'more', 'future-proof', 'workforc', 'readi', 'to', 'share', 'their', 'new', 'knowledg', 'with', 'the', 'world', '.', 'sinc', 'the', 'onset', 'of', 'the', 'pandem', ',', 'onlin', 'cours', 'and', 'program', 'have', 'seen', 'dramat', 'spike', 'in', 'consumpt', 'and', 'enrol', ',', 'and', 'o', '’', 'reilli', 'has', 'been', 'no', 'differ', '.', 'a', 'big', 'contributor', 'to', 'o', '’', 'reilli', '’', 's', 'continu', 'success', 'dure', 'these', 'unpreced', 'time', 'has', 'been', 'it', 'live', 'virtual', 'train', 'cours', '.', 'this', 'year', ',', 'more', 'than', '900,000', 'user', 'have', 'regist', 'for', 'live', 'event', 'through', 'o', '’', 'reilli', 'onlin', 'learning—a', '96', '%', 'increas', 'from', 'last', 'year', '.', 'this', 'function', 'also', 'allow', 'o', '’', 'reilli', 'to', 'introduc', 'it', 'superstream', 'seri', ',', 'a', 'new', 'lineup', 'of', 'virtual', 'confer', 'featur', 'expert', 'speaker', 'deliv', 'talk', 'and', 'train', 'session', 'on', 'the', 'most', 'import', 'topic', 'and', 'emerg', 'trend', 'in', 'technolog', '.', 'so', 'what', 'are', 'the', 'trend', 'drive', 'this', 'uptick', 'in', 'learn', '?', 'compani', 'are', 'increas', 'interest', 'in', 'understand', 'how', 'to', 'success', 'adjust', 'to', 'remot', 'work', 'and', 'effect', 'manag', 'time', '.', 'and', 'individu', 'o', '’', 'reilli', 'member', 'are', 'look', 'to', 'build', 'and', 'expand', 'on', 'their', 'technic', 'skill', 'in', 'everyth', 'from', 'softwar', 'architectur', 'and', 'microservic', 'to', 'ai', 'and', 'program', 'languag', '.', 'but', 'which', 'topic', 'are', 'the', 'brightest', 'mind', 'in', 'technolog', 'most', 'focus', 'on', '?', 'we', '’', 've', 'compil', 'the', 'top', '20', 'live', 'onlin', 'train', 'cours', 'of', '2020', 'to', 'shed', 'some', 'light', 'on', 'what', 'those', 'in', 'the', 'know', 'want', 'to', 'know', '.', 'top', '20', 'live', 'onlin', 'train', 'cours', 'of', '2020', 'for', 'a', 'more', 'in-depth', 'analysi', 'of', 'the', 'hot', 'technolog', 'topic', 'of', '2020', ',', 'base', 'on', 'data', 'from', 'o', '’', 'reilli', 'onlin', 'learn', ',', 'stay', 'tune', 'for', 'our', 'upcom', 'report', ',', 'wrap', 'up', '2020', '(', 'and', 'what', 'to', 'expect', 'for', '2021', ')', ':', 'trend', 'on', 'o', '’', 'reilli', 'onlin', 'learn', '.'], ['it', 'has', 'long', 'seem', 'to', 'me', 'that', 'function', 'program', 'is', ',', 'essenti', ',', 'program', 'view', 'as', 'mathemat', '.', 'mani', 'idea', 'in', 'function', 'program', 'came', 'from', 'alonzo', 'church', '’', 's', 'lambda', 'calculus', ',', 'which', 'signific', 'predat', 'anyth', 'that', 'look', 'remot', 'like', 'a', 'modern', 'comput', '.', 'though', 'the', 'actual', 'histori', 'of', 'comput', 'run', 'differ', ':', 'in', 'the', 'earli', 'day', 'of', 'comput', ',', 'von', 'neumann', '’', 's', 'idea', 'were', 'more', 'import', 'than', 'church', '’', 's', ',', 'and', 'had', 'a', 'tremend', 'influenc', 'on', 'the', 'design', 'of', 'earli', 'computers—an', 'influenc', 'that', 'continu' ...

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

lemmatizer = WordNetLemmatizer()
lemmatized = [[lemmatizer.lemmatize(token.lower(), get_wordnet_pos(token)) for token in word_tokenize(doc)] for doc in docs]
print(lemmatized)
# Out:
# [['2020', 'have', 'be', 'a', 'year', 'of', 'great', 'challenge', 'for', 'so', 'many', ',', 'but', 'it', '’', 's', 'not', 'all', 'negative', '.', 'around', 'the', 'world', ',', 'organization', 'and', 'their', 'workforce', 'have', 'risen', 'to', 'the', 'occasion', ',', 'recognize', 'the', 'importance', 'of', 'expand', 'their', 'knowledge', ',', 'take', 'on', 'new', 'task', ',', 'and', 'bettering', 'themselves', 'both', 'personally', 'and', 'professionally', '.', 'with', 'the', 'uptick', 'in', 'virtual', 'conferencing', ',', 'remote', 'work', ',', 'and', ',', 'for', 'some', ',', 'reentering', 'the', 'job', 'market', ',', 'new', 'technology', 'adoption', 'be', 'accelerate', ',', 'drive', 'the', 'workforce', 'to', 'build', 'new', 'skill', '.', 'while', '2020', 'be', 'the', 'year', 'of', 'the', 'global', 'covid-19', 'pandemic', ',', 'it', 'will', 'also', 'be', 'commemorate', 'a', 'the', 'year', 'online', 'learn', 'prevail', '.', 'a', 'vaccine', 'development', 'persists', 'and', 'life', 'get', 'back', 'to', 'normal', ',', 'with', 'it', 'will', 'come', 'a', 'more', 'future-proof', 'workforce', 'ready', 'to', 'share', 'their', 'new', 'knowledge', 'with', 'the', 'world', '.', 'since', 'the', 'onset', 'of', 'the', 'pandemic', ',', 'online', 'course', 'and', 'program', 'have', 'see', 'dramatic', 'spike', 'in', 'consumption', 'and', 'enrollment', ',', 'and', 'o', '’', 'reilly', 'have', 'be', 'no', 'different', '.', 'a', 'big', 'contributor', 'to', 'o', '’', 'reilly', '’', 's', 'continued', 'success', 'during', 'these', 'unprecedented', 'time', 'have', 'be', 'it', 'live', 'virtual', 'training', 'course', '.', 'this', 'year', ',', 'more', 'than', '900,000', 'user', 'have', 'register', 'for', 'live', 'event', 'through', 'o', '’', 'reilly', 'online', 'learning—a', '96', '%', 'increase', 'from', 'last', 'year', '.', 'this', 'functionality', 'also', 'allow', 'o', '’', 'reilly', 'to', 'introduce', 'it', 'superstream', 'series', ',', 'a', 'new', 'lineup', 'of', 'virtual', 'conference', 'feature', 'expert', 'speaker', 'deliver', 'talk', 'and', 'training', 'session', 'on', 'the', 'most', 'important', 'topic', 'and', 'emerge', 'trend', 'in', 'technology', '.', 'so', 'what', 'be', 'the', 'trend', 'drive', 'this', 'uptick', 'in', 'learn', '?', 'company', 'be', 'increasingly', 'interested', 'in', 'understand', 'how', 'to', 'successfully', 'adjust', 'to', 'remote', 'work', 'and', 'effectively', 'manage', 'time', '.', 'and', 'individual', 'o', '’', 'reilly', 'member', 'be', 'look', 'to', 'build', 'and', 'expand', 'on', 'their', 'technical', 'skill', 'in', 'everything', 'from', 'software', 'architecture', 'and', 'microservices', 'to', 'ai', 'and', 'program', 'language', '.', 'but', 'which', 'topic', 'be', 'the', 'brightest', 'mind', 'in', 'technology', 'most', 'focus', 'on', '?', 'we', '’', 've', 'compile', 'the', 'top', '20', 'live', 'online', 'training', 'course', 'of', '2020', 'to', 'shed', 'some', 'light', 'on', 'what', 'those', 'in', 'the', 'know', 'want', 'to', 'know', '.', 'top', '20', 'live', 'online', 'training', 'course', 'of', '2020', 'for', 'a', 'more', 'in-depth', 'analysis', 'of', 'the', 'hot', 'technology', 'topic', 'of', '2020', ',', 'base', 'on', 'data', 'from', 'o', '’', 'reilly', 'online', 'learn', ',', 'stay', 'tune', 'for', 'our', 'upcoming', 'report', ',', 'wrap', 'up', '2020', '(', 'and', 'what', 'to', 'expect', 'for', '2021', ')', ':', 'trend', 'on', 'o', '’', 'reilly', 'online', 'learn', '.'], ['it', 'have', 'long', 'seem', 'to', 'me', 'that', 'functional', 'program', 'be', ',', 'essentially', ',', 'program', 'view', 'a', 'mathematics', '.', 'many', 'idea', 'in', 'functional', 'program', 'come', 'from', 'alonzo', 'church', '’', 's', 'lambda', 'calculus', ',', 'which', 'significantly', 'predates', 'anything', 'that', 'look', 'remotely', 'like', 'a', 'modern', 'computer', '.', 'though', 'the', 'actual', 'history', 'of', 'compute', 'run', 'differently', ':', 'in', 'the', 'early', 'day', 'of', 'compute', ',', 'von', 'neumann', '’', 's' ...

# %% [markdown]
# ### Iterate through each document, computing and printing the following document statistics for each.
#
# - Number of sentences
# - Average words per sentence
# - Vocabulary
# - Lexical Diversity

# %%
def doc_stats(doc):
  sents = sent_tokenize(doc)
  tokenized = [word_tokenize(sent) for sent in sents]
  total_sents = len(sents)
  avg_words_sent = sum([len(sent) for sent in tokenized])/total_sents
  vocab = len(set([word.lower() for word in word_tokenize(doc)]))
  lexicon_diversity = vocab / len(word_tokenize(doc))
  print(f'Number of sentences: {total_sents}')
  print(f'Avg. number of words per sentence: {avg_words_sent}')
  print(f'Unique word count (vocab): {vocab}')
  print(f'Lexicon diversity: {lexicon_diversity}')

# %%
for i,doc in enumerate(docs):
  print(f'Stats for document {i+1}')
  doc_stats(doc)
  print('---------')
# Out:
# Stats for document 1
# Number of sentences: 15
# Avg. number of words per sentence: 27.466666666666665
# Unique word count (vocab): 198
# Lexicon diversity: 0.48058252427184467
# ---------
# Stats for document 2
# Number of sentences: 77
# Avg. number of words per sentence: 24.25974025974026
# Unique word count (vocab): 555
# Lexicon diversity: 0.29710920770877947
# ---------
# Stats for document 3
# Number of sentences: 21
# Avg. number of words per sentence: 14.476190476190476
# Unique word count (vocab): 183
# Lexicon diversity: 0.6019736842105263
# ---------
# Stats for document 4
# Number of sentences: 42
# Avg. number of words per sentence: 23.595238095238095
# Unique word count (vocab): 380
# Lexicon diversity: 0.3834510595358224
# ---------
# Stats for document 5
# Number of sentences: 7
# Avg. number of words per sentence: 19.571428571428573
# Unique word count (vocab): 91
# Lexicon diversity: 0.6642335766423357
# ---------
# Stats for document 6
# Number of sentences: 2
# Avg. number of words per sentence: 27.0
# Unique word count (vocab): 45
# Lexicon diversity: 0.8333333333333334
# ---------
# Stats for document 7
# Number of sentences: 10
# Avg. number of words per sentence: 26.3
# Unique word count (vocab): 161
# Lexicon diversity: 0.6121673003802282
# ---------
# Stats for document 8
# Number of sentences: 4
# Avg. number of words per sentence: 29.25
# Unique word count (vocab): 74
# Lexicon diversity: 0.6324786324786325
# ---------
# Stats for document 9
# Number of sentences: 11
# Avg. number of words per sentence: 20.636363636363637
# Unique word count (vocab): 139
# Lexicon diversity: 0.6123348017621145
# ---------
# Stats for document 10
# Number of sentences: 11
# Avg. number of words per sentence: 14.545454545454545
# Unique word count (vocab): 117
# Lexicon diversity: 0.73125
# ---------
# Stats for document 11
# Number of sentences: 205
# Avg. number of words per sentence: 23.619512195121953
# Unique word count (vocab): 1147
# Lexicon diversity: 0.23688558446922758
# ---------
# Stats for document 12
# Number of sentences: 5
# Avg. number of words per sentence: 23.2
# Unique word count (vocab): 88
# Lexicon diversity: 0.7586206896551724
# ---------
# Stats for document 13
# Number of sentences: 9
# Avg. number of words per sentence: 25.0
# Unique word count (vocab): 145
# Lexicon diversity: 0.6444444444444445
# ---------
# Stats for document 14
# Number of sentences: 7
# Avg. number of words per sentence: 22.714285714285715
# Unique word count (vocab): 101
# Lexicon diversity: 0.6352201257861635
# ---------
# Stats for document 15
# Number of sentences: 8
# Avg. number of words per sentence: 36.25
# Unique word count (vocab): 173
# Lexicon diversity: 0.596551724137931
# ---------
# Stats for document 16
# Number of sentences: 111
# Avg. number of words per sentence: 29.486486486486488
# Unique word count (vocab): 950
# Lexicon diversity: 0.2902535899786129
# ---------
# Stats for document 17
# Number of sentences: 11
# Avg. number of words per sentence: 21.636363636363637
# Unique word count (vocab): 134
# Lexicon diversity: 0.5630252100840336
# ---------
# Stats for document 18
# Number of sentences: 57
# Avg. number of words per sentence: 22.92982456140351
# Unique word count (vocab): 446
# Lexicon diversity: 0.34123947972456004
# ---------
# Stats for document 19
# Number of sentences: 8
# Avg. number of words per sentence: 29.25
# Unique word count (vocab): 143
# Lexicon diversity: 0.6111111111111112
# ---------
# Stats for document 20
# Number of sentences: 1
# Avg. number of words per sentence: 70.0
# Unique word count (vocab): 51
# Lexicon diversity: 0.7285714285714285
# ---------
# Stats for document 21
# Number of sentences: 6
# Avg. number of words per sentence: 19.166666666666668
# Unique word count (vocab): 71
# Lexicon diversity: 0.6173913043478261
# ---------
# Stats for document 22
# Number of sentences: 8
# Avg. number of words per sentence: 17.0
# Unique word count (vocab): 102
# Lexicon diversity: 0.75
# ---------
# Stats for document 23
# Number of sentences: 5
# Avg. number of words per sentence: 22.4
# Unique word count (vocab): 78
# Lexicon diversity: 0.6964285714285714
# ---------
# Stats for document 24
# Number of sentences: 21
# Avg. number of words per sentence: 21.476190476190474
# Unique word count (vocab): 220
# Lexicon diversity: 0.4878048780487805
# ---------
# Stats for document 25
# Number of sentences: 8
# Avg. number of words per sentence: 31.75
# Unique word count (vocab): 147
# Lexicon diversity: 0.5787401574803149
# ---------
# Stats for document 26
# Number of sentences: 9
# Avg. number of words per sentence: 28.77777777777778
# Unique word count (vocab): 145
# Lexicon diversity: 0.5598455598455598
# ---------
# Stats for document 27
# Number of sentences: 60
# Avg. number of words per sentence: 29.7
# Unique word count (vocab): 600
# Lexicon diversity: 0.3367003367003367
# ---------
# Stats for document 28
# Number of sentences: 1
# Avg. number of words per sentence: 40.0
# Unique word count (vocab): 30
# Lexicon diversity: 0.75
# ---------
# Stats for document 29
# Number of sentences: 3
# Avg. number of words per sentence: 41.333333333333336
# Unique word count (vocab): 84
# Lexicon diversity: 0.6774193548387096
# ---------
# Stats for document 30
# Number of sentences: 42
# Avg. number of words per sentence: 23.357142857142858
# Unique word count (vocab): 378
# Lexicon diversity: 0.3853211009174312
# ---------
# Stats for document 31
# Number of sentences: 3
# Avg. number of words per sentence: 16.0
# Unique word count (vocab): 46
# Lexicon diversity: 0.9583333333333334
# ---------
# Stats for document 32
# Number of sentences: 6
# Avg. number of words per sentence: 19.666666666666668
# Unique word count (vocab): 84
# Lexicon diversity: 0.711864406779661
# ---------
# Stats for document 33
# Number of sentences: 6
# Avg. number of words per sentence: 21.333333333333332
# Unique word count (vocab): 91
# Lexicon diversity: 0.7109375
# ---------
# Stats for document 34
# Number of sentences: 6
# Avg. number of words per sentence: 24.166666666666668
# Unique word count (vocab): 104
# Lexicon diversity: 0.7172413793103448
# ---------
# Stats for document 35
# Number of sentences: 4
# Avg. number of words per sentence: 23.0
# Unique word count (vocab): 68
# Lexicon diversity: 0.7391304347826086
# ---------
# Stats for document 36
# Number of sentences: 209
# Avg. number of words per sentence: 24.124401913875598
# Unique word count (vocab): 1417
# Lexicon diversity: 0.2810392701309004
# ---------
# Stats for document 37
# Number of sentences: 12
# Avg. number of words per sentence: 17.333333333333332
# Unique word count (vocab): 123
# Lexicon diversity: 0.5913461538461539
# ---------
# Stats for document 38
# Number of sentences: 3
# Avg. number of words per sentence: 19.0
# Unique word count (vocab): 45
# Lexicon diversity: 0.7894736842105263
# ---------
# Stats for document 39
# Number of sentences: 4
# Avg. number of words per sentence: 29.75
# Unique word count (vocab): 85
# Lexicon diversity: 0.7142857142857143
# ---------
# Stats for document 40
# Number of sentences: 68
# Avg. number of words per sentence: 22.955882352941178
# Unique word count (vocab): 555
# Lexicon diversity: 0.3555413196668802
# ---------
# Stats for document 41
# Number of sentences: 9
# Avg. number of words per sentence: 20.444444444444443
# Unique word count (vocab): 115
# Lexicon diversity: 0.625
# ---------
# Stats for document 42
# Number of sentences: 37
# Avg. number of words per sentence: 23.10810810810811
# Unique word count (vocab): 331
# Lexicon diversity: 0.3871345029239766
# ---------
# Stats for document 43
# Number of sentences: 7
# Avg. number of words per sentence: 21.0
# Unique word count (vocab): 105
# Lexicon diversity: 0.7142857142857143
# ---------
# Stats for document 44
# Number of sentences: 10
# Avg. number of words per sentence: 20.8
# Unique word count (vocab): 126
# Lexicon diversity: 0.6057692307692307
# ---------
# Stats for document 45
# Number of sentences: 1
# Avg. number of words per sentence: 39.0
# Unique word count (vocab): 34
# Lexicon diversity: 0.8717948717948718
# ---------
# Stats for document 46
# Number of sentences: 8
# Avg. number of words per sentence: 30.375
# Unique word count (vocab): 131
# Lexicon diversity: 0.5390946502057613
# ---------
# Stats for document 47
# Number of sentences: 5
# Avg. number of words per sentence: 18.2
# Unique word count (vocab): 64
# Lexicon diversity: 0.7032967032967034
# ---------
# Stats for document 48
# Number of sentences: 6
# Avg. number of words per sentence: 34.666666666666664
# Unique word count (vocab): 140
# Lexicon diversity: 0.6730769230769231
# ---------
# Stats for document 49
# Number of sentences: 11
# Avg. number of words per sentence: 25.181818181818183
# Unique word count (vocab): 147
# Lexicon diversity: 0.5306859205776173
# ---------
# Stats for document 50
# Number of sentences: 2
# Avg. number of words per sentence: 23.0
# Unique word count (vocab): 40
# Lexicon diversity: 0.8695652173913043
# ---------
# Stats for document 51
# Number of sentences: 209
# Avg. number of words per sentence: 25.803827751196174
# Unique word count (vocab): 1295
# Lexicon diversity: 0.2401260893751159
# ---------
# Stats for document 52
# Number of sentences: 86
# Avg. number of words per sentence: 22.058139534883722
# Unique word count (vocab): 573
# Lexicon diversity: 0.30205587770163417
# ---------
# Stats for document 53
# Number of sentences: 7
# Avg. number of words per sentence: 28.142857142857142
# Unique word count (vocab): 132
# Lexicon diversity: 0.6700507614213198
# ---------
# Stats for document 54
# Number of sentences: 5
# Avg. number of words per sentence: 44.0
# Unique word count (vocab): 142
# Lexicon diversity: 0.6454545454545455
# ---------
# Stats for document 55
# Number of sentences: 11
# Avg. number of words per sentence: 30.09090909090909
# Unique word count (vocab): 194
# Lexicon diversity: 0.5861027190332326
# ---------
# Stats for document 56
# Number of sentences: 5
# Avg. number of words per sentence: 29.6
# Unique word count (vocab): 104
# Lexicon diversity: 0.7027027027027027
# ---------
# Stats for document 57
# Number of sentences: 13
# Avg. number of words per sentence: 25.923076923076923
# Unique word count (vocab): 219
# Lexicon diversity: 0.6498516320474778
# ---------
# Stats for document 58
# Number of sentences: 3
# Avg. number of words per sentence: 33.0
# Unique word count (vocab): 76
# Lexicon diversity: 0.7676767676767676
# ---------
# Stats for document 59
# Number of sentences: 73
# Avg. number of words per sentence: 22.315068493150687
# Unique word count (vocab): 548
# Lexicon diversity: 0.336402701043585
# ---------
# Stats for document 60
# Number of sentences: 5
# Avg. number of words per sentence: 19.4
# Unique word count (vocab): 64
# Lexicon diversity: 0.6597938144329897
# ---------

# %% [markdown]
# #Lecture Notes

# %%
PATH = '/content/drive/MyDrive/Thinkful/NLP/cnn_articles/'

DOC_PATTERN = r'.*\.txt'

corpus = PlaintextCorpusReader(PATH, DOC_PATTERN)

# %%
corpus.fileids()
# Out:
# ['article_0.txt',
#  'article_1.txt',
#  'article_10.txt',
#  'article_11.txt',
#  'article_12.txt',
#  'article_13.txt',
#  'article_2.txt',
#  'article_3.txt',
#  'article_4.txt',
#  'article_5.txt',
#  'article_6.txt',
#  'article_7.txt',
#  'article_8.txt',
#  'article_9.txt']

# %%
docs = [corpus.raw(fileid) for fileid in corpus.fileids()]

# %%
doc = docs[0]

# %%
sents = sent_tokenize(doc)
sents
# Out:
# ['Pink taking a break to focus on familyUpdated 10:18 AM ET, Thu November 14, 2019(CNN) - Pink has been working pretty hard and it sounds like she will be taking a step back in 2020.Speaking with "Entertainment Tonight" on the Country Music Association Awards red carpet, the singer was joined by her husband, Carey Hart, and their kids Willow, 8, and Jameson, 2.Pink was there to perform her song "Love Me Anyway" with country star Chris Stapleton, and she  talked about how hectic things have been.',
#  '"We did two and a half years of [music] and Willow\'s back in school now, Jameson\'s going to start pre-school soon," Pink said.',
#  '"It\'s kind of the year of the family.',
#  '"The star also praised her husband, with whom she will celebrate 14 years of marriage in January.',
#  '"Carey has a lot going on as well," she said of Hart, who went from being a professional motocross competitor to racing off-road trucks.',
#  '"He\'s super supportive, he follows me around the world and now it\'s his turn.',
#  '"According to Billboard, Pink\'s Beautiful Trauma Tour ranks as the 10th highest-grossing tour of all time, earning more than $397 million.']

# %%
tokenized = word_tokenize(sents[0])
tokenized
# Out:
# ['Pink',
#  'taking',
#  'a',
#  'break',
#  'to',
#  'focus',
#  'on',
#  'familyUpdated',
#  '10:18',
#  'AM',
#  'ET',
#  ',',
#  'Thu',
#  'November',
#  '14',
#  ',',
#  '2019',
#  '(',
#  'CNN',
#  ')',
#  '-',
#  'Pink',
#  'has',
#  'been',
#  'working',
#  'pretty',
#  'hard',
#  'and',
#  'it',
#  'sounds',
#  'like',
#  'she',
#  'will',
#  'be',
#  'taking',
#  'a',
#  'step',
#  'back',
#  'in',
#  '2020.Speaking',
#  'with',
#  '``',
#  'Entertainment',
#  'Tonight',
#  "''",
#  'on',
#  'the',
#  'Country',
#  'Music',
#  'Association',
#  'Awards',
#  'red',
#  'carpet',
#  ',',
#  'the',
#  'singer',
#  'was',
#  'joined',
#  'by',
#  'her',
#  'husband',
#  ',',
#  'Carey',
#  'Hart',
#  ',',
#  'and',
#  'their',
#  'kids',
#  'Willow',
#  ',',
#  '8',
#  ',',
#  'and',
#  'Jameson',
#  ',',
#  '2.Pink',
#  'was',
#  'there',
#  'to',
#  'perform',
#  'her',
#  'song',
#  '``',
#  'Love',
#  'Me',
#  'Anyway',
#  "''",
#  'with',
#  'country',
#  'star',
#  'Chris',
#  'Stapleton',
#  ',',
#  'and',
#  'she',
#  'talked',
#  'about',
#  'how',
#  'hectic',
#  'things',
#  'have',
#  'been',
#  '.']

# %%
word_tokenize(doc)
# Out:
# ['Pink',
#  'taking',
#  'a',
#  'break',
#  'to',
#  'focus',
#  'on',
#  'familyUpdated',
#  '10:18',
#  'AM',
#  'ET',
#  ',',
#  'Thu',
#  'November',
#  '14',
#  ',',
#  '2019',
#  '(',
#  'CNN',
#  ')',
#  '-',
#  'Pink',
#  'has',
#  'been',
#  'working',
#  'pretty',
#  'hard',
#  'and',
#  'it',
#  'sounds',
#  'like',
#  'she',
#  'will',
#  'be',
#  'taking',
#  'a',
#  'step',
#  'back',
#  'in',
#  '2020.Speaking',
#  'with',
#  '``',
#  'Entertainment',
#  'Tonight',
#  "''",
#  'on',
#  'the',
#  'Country',
#  'Music',
#  'Association',
#  'Awards',
#  'red',
#  'carpet',
#  ',',
#  'the',
#  'singer',
#  'was',
#  'joined',
#  'by',
#  'her',
#  'husband',
#  ',',
#  'Carey',
#  'Hart',
#  ',',
#  'and',
#  'their',
#  'kids',
#  'Willow',
#  ',',
#  '8',
#  ',',
#  'and',
#  'Jameson',
#  ',',
#  '2.Pink',
#  'was',
#  'there',
#  'to',
#  'perform',
#  'her',
#  'song',
#  '``',
#  'Love',
#  'Me',
#  'Anyway',
#  "''",
#  'with',
#  'country',
#  'star',
#  'Chris',
#  'Stapleton',
#  ',',
#  'and',
#  'she',
#  'talked',
#  'about',
#  'how',
#  'hectic',
#  'things',
#  'have',
#  'been',
#  '.',
#  '``',
#  'We',
#  'did',
#  'two',
#  'and',
#  'a',
#  'half',
#  'years',
#  'of',
#  '[',
#  'music',
#  ']',
#  'and',
#  'Willow',
#  "'s",
#  'back',
#  'in',
#  'school',
#  'now',
#  ',',
#  'Jameson',
#  "'s",
#  'going',
#  'to',
#  'start',
#  'pre-school',
#  'soon',
#  ',',
#  "''",
#  'Pink',
#  'said',
#  '.',
#  '``',
#  'It',
#  "'s",
#  'kind',
#  'of',
#  'the',
#  'year',
#  'of',
#  'the',
#  'family',
#  '.',
#  '``',
#  'The',
#  'star',
#  'also',
#  'praised',
#  'her',
#  'husband',
#  ',',
#  'with',
#  'whom',
#  'she',
#  'will',
#  'celebrate',
#  '14',
#  'years',
#  'of',
#  'marriage',
#  'in',
#  'January',
#  '.',
#  '``',
#  'Carey',
#  'has',
#  'a',
#  'lot',
#  'going',
#  'on',
#  'as',
#  'well',
#  ',',
#  "''",
#  'she',
#  'said',
#  'of',
#  'Hart',
#  ',',
#  'who',
#  'went',
#  'from',
#  'being',
#  'a',
#  'professional',
#  'motocross',
#  'competitor',
#  'to',
#  'racing',
#  'off-road',
#  'trucks',
#  '.',
#  '``',
#  'He',
#  "'s",
#  'super',
#  'supportive',
#  ',',
#  'he',
#  'follows',
#  'me',
#  'around',
#  'the',
#  'world',
#  'and',
#  'now',
#  'it',
#  "'s",
#  'his',
#  'turn',
#  '.',
#  '``',
#  'According',
#  'to',
#  'Billboard',
#  ',',
#  'Pink',
#  "'s",
#  'Beautiful',
#  'Trauma',
#  'Tour',
#  'ranks',
#  'as',
#  'the',
#  '10th',
#  'highest-grossing',
#  'tour',
#  'of',
#  'all',
#  'time',
#  ',',
#  'earning',
#  'more',
#  'than',
#  '$',
#  '397',
#  'million',
#  '.']

# %%
pos_tag(tokenized)
# Out:
# [('Pink', 'NNP'),
#  ('taking', 'VBG'),
#  ('a', 'DT'),
#  ('break', 'NN'),
#  ('to', 'TO'),
#  ('focus', 'VB'),
#  ('on', 'IN'),
#  ('familyUpdated', 'JJ'),
#  ('10:18', 'CD'),
#  ('AM', 'NNP'),
#  ('ET', 'NNP'),
#  (',', ','),
#  ('Thu', 'NNP'),
#  ('November', 'NNP'),
#  ('14', 'CD'),
#  (',', ','),
#  ('2019', 'CD'),
#  ('(', '('),
#  ('CNN', 'NNP'),
#  (')', ')'),
#  ('-', ':'),
#  ('Pink', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('working', 'VBG'),
#  ('pretty', 'RB'),
#  ('hard', 'JJ'),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('sounds', 'VBZ'),
#  ('like', 'IN'),
#  ('she', 'PRP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('taking', 'VBG'),
#  ('a', 'DT'),
#  ('step', 'NN'),
#  ('back', 'RB'),
#  ('in', 'IN'),
#  ('2020.Speaking', 'VBG'),
#  ('with', 'IN'),
#  ('``', '``'),
#  ('Entertainment', 'JJ'),
#  ('Tonight', 'NNP'),
#  ("''", "''"),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('Country', 'NNP'),
#  ('Music', 'NNP'),
#  ('Association', 'NNP'),
#  ('Awards', 'NNP'),
#  ('red', 'JJ'),
#  ('carpet', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('singer', 'NN'),
#  ('was', 'VBD'),
#  ('joined', 'VBN'),
#  ('by', 'IN'),
#  ('her', 'PRP$'),
#  ('husband', 'NN'),
#  (',', ','),
#  ('Carey', 'NNP'),
#  ('Hart', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('their', 'PRP$'),
#  ('kids', 'NNS'),
#  ('Willow', 'NNP'),
#  (',', ','),
#  ('8', 'CD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Jameson', 'NNP'),
#  (',', ','),
#  ('2.Pink', 'CD'),
#  ('was', 'VBD'),
#  ('there', 'RB'),
#  ('to', 'TO'),
#  ('perform', 'VB'),
#  ('her', 'PRP$'),
#  ('song', 'NN'),
#  ('``', '``'),
#  ('Love', 'VB'),
#  ('Me', 'NNP'),
#  ('Anyway', 'NNP'),
#  ("''", "''"),
#  ('with', 'IN'),
#  ('country', 'NN'),
#  ('star', 'NN'),
#  ('Chris', 'NNP'),
#  ('Stapleton', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('she', 'PRP'),
#  ('talked', 'VBD'),
#  ('about', 'IN'),
#  ('how', 'WRB'),
#  ('hectic', 'JJ'),
#  ('things', 'NNS'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('.', '.')]

# %%
sents = sent_tokenize(doc)
tokenized = [word_tokenize(sent) for sent in sents]

# %%
tagged = [pos_tag(tokens) for tokens in tokenized]

# %%
print(tagged)
# Out:
# [[('Pink', 'NNP'), ('taking', 'VBG'), ('a', 'DT'), ('break', 'NN'), ('to', 'TO'), ('focus', 'VB'), ('on', 'IN'), ('familyUpdated', 'JJ'), ('10:18', 'CD'), ('AM', 'NNP'), ('ET', 'NNP'), (',', ','), ('Thu', 'NNP'), ('November', 'NNP'), ('14', 'CD'), (',', ','), ('2019', 'CD'), ('(', '('), ('CNN', 'NNP'), (')', ')'), ('-', ':'), ('Pink', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('working', 'VBG'), ('pretty', 'RB'), ('hard', 'JJ'), ('and', 'CC'), ('it', 'PRP'), ('sounds', 'VBZ'), ('like', 'IN'), ('she', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('taking', 'VBG'), ('a', 'DT'), ('step', 'NN'), ('back', 'RB'), ('in', 'IN'), ('2020.Speaking', 'VBG'), ('with', 'IN'), ('``', '``'), ('Entertainment', 'JJ'), ('Tonight', 'NNP'), ("''", "''"), ('on', 'IN'), ('the', 'DT'), ('Country', 'NNP'), ('Music', 'NNP'), ('Association', 'NNP'), ('Awards', 'NNP'), ('red', 'JJ'), ('carpet', 'NN'), (',', ','), ('the', 'DT'), ('singer', 'NN'), ('was', 'VBD'), ('joined', 'VBN'), ('by', 'IN'), ('her', 'PRP$'), ('husband', 'NN'), (',', ','), ('Carey', 'NNP'), ('Hart', 'NNP'), (',', ','), ('and', 'CC'), ('their', 'PRP$'), ('kids', 'NNS'), ('Willow', 'NNP'), (',', ','), ('8', 'CD'), (',', ','), ('and', 'CC'), ('Jameson', 'NNP'), (',', ','), ('2.Pink', 'CD'), ('was', 'VBD'), ('there', 'RB'), ('to', 'TO'), ('perform', 'VB'), ('her', 'PRP$'), ('song', 'NN'), ('``', '``'), ('Love', 'VB'), ('Me', 'NNP'), ('Anyway', 'NNP'), ("''", "''"), ('with', 'IN'), ('country', 'NN'), ('star', 'NN'), ('Chris', 'NNP'), ('Stapleton', 'NNP'), (',', ','), ('and', 'CC'), ('she', 'PRP'), ('talked', 'VBD'), ('about', 'IN'), ('how', 'WRB'), ('hectic', 'JJ'), ('things', 'NNS'), ('have', 'VBP'), ('been', 'VBN'), ('.', '.')], [('``', '``'), ('We', 'PRP'), ('did', 'VBD'), ('two', 'CD'), ('and', 'CC'), ('a', 'DT'), ('half', 'JJ'), ('years', 'NNS'), ('of', 'IN'), ('[', 'JJ'), ('music', 'NN'), (']', 'NN'), ('and', 'CC'), ('Willow', 'NNP'), ("'s", 'POS'), ('back', 'NN'), ('in', 'IN'), ('school', 'NN'), ('now', 'RB'), (',', ','), ('Jameson', 'NNP'), ("'s", 'POS'), ('going', 'VBG'), ('to', 'TO'), ('start', 'VB'), ('pre-school', 'JJ'), ('soon', 'RB'), (',', ','), ("''", "''"), ('Pink', 'NNP'), ('said', 'VBD'), ('.', '.')], [('``', '``'), ('It', 'PRP'), ("'s", 'VBZ'), ('kind', 'NN'), ('of', 'IN'), ('the', 'DT'), ('year', 'NN'), ('of', 'IN'), ('the', 'DT'), ('family', 'NN'), ('.', '.')], [('``', '``'), ('The', 'DT'), ('star', 'NN'), ('also', 'RB'), ('praised', 'VBD'), ('her', 'PRP'), ('husband', 'NN'), (',', ','), ('with', 'IN'), ('whom', 'WP'), ('she', 'PRP'), ('will', 'MD'), ('celebrate', 'VB'), ('14', 'CD'), ('years', 'NNS'), ('of', 'IN'), ('marriage', 'NN'), ('in', 'IN'), ('January', 'NNP'), ('.', '.')], [('``', '``'), ('Carey', 'NNP'), ('has', 'VBZ'), ('a', 'DT'), ('lot', 'NN'), ('going', 'VBG'), ('on', 'IN'), ('as', 'RB'), ('well', 'RB'), (',', ','), ("''", "''"), ('she', 'PRP'), ('said', 'VBD'), ('of', 'IN'), ('Hart', 'NNP'), (',', ','), ('who', 'WP'), ('went', 'VBD'), ('from', 'IN'), ('being', 'VBG'), ('a', 'DT'), ('professional', 'JJ'), ('motocross', 'NN'), ('competitor', 'NN'), ('to', 'TO'), ('racing', 'VBG'), ('off-road', 'JJ'), ('trucks', 'NNS'), ('.', '.')], [('``', '``'), ('He', 'PRP'), ("'s", 'VBZ'), ('super', 'JJ'), ('supportive', 'NN'), (',', ','), ('he', 'PRP'), ('follows', 'VBZ'), ('me', 'PRP'), ('around', 'IN'), ('the', 'DT'), ('world', 'NN'), ('and', 'CC'), ('now', 'RB'), ('it', 'PRP'), ("'s", 'VBZ'), ('his', 'PRP$'), ('turn', 'NN'), ('.', '.')], [('``', '``'), ('According', 'VBG'), ('to', 'TO'), ('Billboard', 'NNP'), (',', ','), ('Pink', 'NNP'), ("'s", 'POS'), ('Beautiful', 'NNP'), ('Trauma', 'NNP'), ('Tour', 'NNP'), ('ranks', 'VBZ'), ('as', 'IN'), ('the', 'DT'), ('10th', 'CD'), ('highest-grossing', 'JJ'), ('tour', 'NN'), ('of', 'IN'), ('all', 'DT'), ('time', 'NN'), (',', ','), ('earning', 'VBG'), ('more', 'JJR'), ('than', 'IN'), ('$', '$'), ('397', 'CD'), ('million', 'CD'), ('.', '.')]]

# %%
lowercase = [token.lower() for token in tokenized[0]]
print(lowercase)
# Out:
# ['pink', 'taking', 'a', 'break', 'to', 'focus', 'on', 'familyupdated', '10:18', 'am', 'et', ',', 'thu', 'november', '14', ',', '2019', '(', 'cnn', ')', '-', 'pink', 'has', 'been', 'working', 'pretty', 'hard', 'and', 'it', 'sounds', 'like', 'she', 'will', 'be', 'taking', 'a', 'step', 'back', 'in', '2020.speaking', 'with', '``', 'entertainment', 'tonight', "''", 'on', 'the', 'country', 'music', 'association', 'awards', 'red', 'carpet', ',', 'the', 'singer', 'was', 'joined', 'by', 'her', 'husband', ',', 'carey', 'hart', ',', 'and', 'their', 'kids', 'willow', ',', '8', ',', 'and', 'jameson', ',', '2.pink', 'was', 'there', 'to', 'perform', 'her', 'song', '``', 'love', 'me', 'anyway', "''", 'with', 'country', 'star', 'chris', 'stapleton', ',', 'and', 'she', 'talked', 'about', 'how', 'hectic', 'things', 'have', 'been', '.']

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
no_stopwords = [token.lower() for token in word_tokenize(doc) 
                if token.lower() not in stopwords.words('english')]

# %%
print(no_stopwords)
# Out:
# ['pink', 'taking', 'break', 'focus', 'familyupdated', '10:18', 'et', ',', 'thu', 'november', '14', ',', '2019', '(', 'cnn', ')', '-', 'pink', 'working', 'pretty', 'hard', 'sounds', 'like', 'taking', 'step', 'back', '2020.speaking', '``', 'entertainment', 'tonight', "''", 'country', 'music', 'association', 'awards', 'red', 'carpet', ',', 'singer', 'joined', 'husband', ',', 'carey', 'hart', ',', 'kids', 'willow', ',', '8', ',', 'jameson', ',', '2.pink', 'perform', 'song', '``', 'love', 'anyway', "''", 'country', 'star', 'chris', 'stapleton', ',', 'talked', 'hectic', 'things', '.', '``', 'two', 'half', 'years', '[', 'music', ']', 'willow', "'s", 'back', 'school', ',', 'jameson', "'s", 'going', 'start', 'pre-school', 'soon', ',', "''", 'pink', 'said', '.', '``', "'s", 'kind', 'year', 'family', '.', '``', 'star', 'also', 'praised', 'husband', ',', 'celebrate', '14', 'years', 'marriage', 'january', '.', '``', 'carey', 'lot', 'going', 'well', ',', "''", 'said', 'hart', ',', 'went', 'professional', 'motocross', 'competitor', 'racing', 'off-road', 'trucks', '.', '``', "'s", 'super', 'supportive', ',', 'follows', 'around', 'world', "'s", 'turn', '.', '``', 'according', 'billboard', ',', 'pink', "'s", 'beautiful', 'trauma', 'tour', 'ranks', '10th', 'highest-grossing', 'tour', 'time', ',', 'earning', '$', '397', 'million', '.']

# %%
len(no_stopwords)
# Out:
# 158

# %%
len(word_tokenize(doc))
# Out:
# 241

# %%
no_punct = [token.lower() for token in word_tokenize(doc)
            if token.isalpha() == True]

# %%
print(no_punct)
# Out:
# ['pink', 'taking', 'a', 'break', 'to', 'focus', 'on', 'familyupdated', 'am', 'et', 'thu', 'november', 'cnn', 'pink', 'has', 'been', 'working', 'pretty', 'hard', 'and', 'it', 'sounds', 'like', 'she', 'will', 'be', 'taking', 'a', 'step', 'back', 'in', 'with', 'entertainment', 'tonight', 'on', 'the', 'country', 'music', 'association', 'awards', 'red', 'carpet', 'the', 'singer', 'was', 'joined', 'by', 'her', 'husband', 'carey', 'hart', 'and', 'their', 'kids', 'willow', 'and', 'jameson', 'was', 'there', 'to', 'perform', 'her', 'song', 'love', 'me', 'anyway', 'with', 'country', 'star', 'chris', 'stapleton', 'and', 'she', 'talked', 'about', 'how', 'hectic', 'things', 'have', 'been', 'we', 'did', 'two', 'and', 'a', 'half', 'years', 'of', 'music', 'and', 'willow', 'back', 'in', 'school', 'now', 'jameson', 'going', 'to', 'start', 'soon', 'pink', 'said', 'it', 'kind', 'of', 'the', 'year', 'of', 'the', 'family', 'the', 'star', 'also', 'praised', 'her', 'husband', 'with', 'whom', 'she', 'will', 'celebrate', 'years', 'of', 'marriage', 'in', 'january', 'carey', 'has', 'a', 'lot', 'going', 'on', 'as', 'well', 'she', 'said', 'of', 'hart', 'who', 'went', 'from', 'being', 'a', 'professional', 'motocross', 'competitor', 'to', 'racing', 'trucks', 'he', 'super', 'supportive', 'he', 'follows', 'me', 'around', 'the', 'world', 'and', 'now', 'it', 'his', 'turn', 'according', 'to', 'billboard', 'pink', 'beautiful', 'trauma', 'tour', 'ranks', 'as', 'the', 'tour', 'of', 'all', 'time', 'earning', 'more', 'than', 'million']

# %%
len(no_punct)
# Out:
# 181

# %%
no_punct_stop = [token.lower() for token in no_stopwords
            if token.isalpha() == True]

# %%
len(no_punct_stop)
# Out:
# 98

# %%
stemmer = SnowballStemmer('english')
stemmed = [stemmer.stem(token) for token in word_tokenize(doc)]
print(stemmed)
# Out:
# ['pink', 'take', 'a', 'break', 'to', 'focus', 'on', 'familyupd', '10:18', 'am', 'et', ',', 'thu', 'novemb', '14', ',', '2019', '(', 'cnn', ')', '-', 'pink', 'has', 'been', 'work', 'pretti', 'hard', 'and', 'it', 'sound', 'like', 'she', 'will', 'be', 'take', 'a', 'step', 'back', 'in', '2020.speak', 'with', '``', 'entertain', 'tonight', "''", 'on', 'the', 'countri', 'music', 'associ', 'award', 'red', 'carpet', ',', 'the', 'singer', 'was', 'join', 'by', 'her', 'husband', ',', 'carey', 'hart', ',', 'and', 'their', 'kid', 'willow', ',', '8', ',', 'and', 'jameson', ',', '2.pink', 'was', 'there', 'to', 'perform', 'her', 'song', '``', 'love', 'me', 'anyway', "''", 'with', 'countri', 'star', 'chris', 'stapleton', ',', 'and', 'she', 'talk', 'about', 'how', 'hectic', 'thing', 'have', 'been', '.', '``', 'we', 'did', 'two', 'and', 'a', 'half', 'year', 'of', '[', 'music', ']', 'and', 'willow', "'s", 'back', 'in', 'school', 'now', ',', 'jameson', "'s", 'go', 'to', 'start', 'pre-school', 'soon', ',', "''", 'pink', 'said', '.', '``', 'it', "'s", 'kind', 'of', 'the', 'year', 'of', 'the', 'famili', '.', '``', 'the', 'star', 'also', 'prais', 'her', 'husband', ',', 'with', 'whom', 'she', 'will', 'celebr', '14', 'year', 'of', 'marriag', 'in', 'januari', '.', '``', 'carey', 'has', 'a', 'lot', 'go', 'on', 'as', 'well', ',', "''", 'she', 'said', 'of', 'hart', ',', 'who', 'went', 'from', 'be', 'a', 'profession', 'motocross', 'competitor', 'to', 'race', 'off-road', 'truck', '.', '``', 'he', "'s", 'super', 'support', ',', 'he', 'follow', 'me', 'around', 'the', 'world', 'and', 'now', 'it', "'s", 'his', 'turn', '.', '``', 'accord', 'to', 'billboard', ',', 'pink', "'s", 'beauti', 'trauma', 'tour', 'rank', 'as', 'the', '10th', 'highest-gross', 'tour', 'of', 'all', 'time', ',', 'earn', 'more', 'than', '$', '397', 'million', '.']

# %%
len(stemmed)
# Out:
# 241

# %%
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(token.lower()) for token in word_tokenize(doc)]
print(lemmatized)
# Out:
# ['pink', 'taking', 'a', 'break', 'to', 'focus', 'on', 'familyupdated', '10:18', 'am', 'et', ',', 'thu', 'november', '14', ',', '2019', '(', 'cnn', ')', '-', 'pink', 'ha', 'been', 'working', 'pretty', 'hard', 'and', 'it', 'sound', 'like', 'she', 'will', 'be', 'taking', 'a', 'step', 'back', 'in', '2020.speaking', 'with', '``', 'entertainment', 'tonight', "''", 'on', 'the', 'country', 'music', 'association', 'award', 'red', 'carpet', ',', 'the', 'singer', 'wa', 'joined', 'by', 'her', 'husband', ',', 'carey', 'hart', ',', 'and', 'their', 'kid', 'willow', ',', '8', ',', 'and', 'jameson', ',', '2.pink', 'wa', 'there', 'to', 'perform', 'her', 'song', '``', 'love', 'me', 'anyway', "''", 'with', 'country', 'star', 'chris', 'stapleton', ',', 'and', 'she', 'talked', 'about', 'how', 'hectic', 'thing', 'have', 'been', '.', '``', 'we', 'did', 'two', 'and', 'a', 'half', 'year', 'of', '[', 'music', ']', 'and', 'willow', "'s", 'back', 'in', 'school', 'now', ',', 'jameson', "'s", 'going', 'to', 'start', 'pre-school', 'soon', ',', "''", 'pink', 'said', '.', '``', 'it', "'s", 'kind', 'of', 'the', 'year', 'of', 'the', 'family', '.', '``', 'the', 'star', 'also', 'praised', 'her', 'husband', ',', 'with', 'whom', 'she', 'will', 'celebrate', '14', 'year', 'of', 'marriage', 'in', 'january', '.', '``', 'carey', 'ha', 'a', 'lot', 'going', 'on', 'a', 'well', ',', "''", 'she', 'said', 'of', 'hart', ',', 'who', 'went', 'from', 'being', 'a', 'professional', 'motocross', 'competitor', 'to', 'racing', 'off-road', 'truck', '.', '``', 'he', "'s", 'super', 'supportive', ',', 'he', 'follows', 'me', 'around', 'the', 'world', 'and', 'now', 'it', "'s", 'his', 'turn', '.', '``', 'according', 'to', 'billboard', ',', 'pink', "'s", 'beautiful', 'trauma', 'tour', 'rank', 'a', 'the', '10th', 'highest-grossing', 'tour', 'of', 'all', 'time', ',', 'earning', 'more', 'than', '$', '397', 'million', '.']

# %%
len(lemmatized)
# Out:
# 241

# %%
len(word_tokenize(doc))
# Out:
# 241

# %%
lemmatizer = WordNetLemmatizer()
[lemmatizer.lemmatize(word) for word in ['taking', 'take']]
# Out:
# ['taking', 'take']

# %%
sents = sent_tokenize(doc)
tokenized = [word_tokenize(sent) for sent in sents]

# %%
total_sents = len(sents)
total_sents
# Out:
# 7

# %%
avg_words_sent = sum([len(sent) for sent in tokenized])/total_sents
avg_words_sent
# Out:
# 34.42857142857143

# %%
vocab = len(set([word.lower() for word in word_tokenize(doc)])) #filter first (isalpha and stopwords)
vocab
# Out:
# 140

# %%
lexicon_diversity = vocab / len(word_tokenize(doc))
lexicon_diversity
# Out:
# 0.5809128630705395

# %%
def doc_stats(doc):
  sents = sent_tokenize(doc)
  tokenized = [word_tokenize(sent) for sent in sents]
  total_sents = len(sents)
  avg_words_sent = sum([len(sent) for sent in tokenized])/total_sents
  vocab = len(set([word.lower() for word in word_tokenize(doc)]))
  lexicon_diversity = vocab / len(word_tokenize(doc))
  print(f'Number of sentences: {total_sents}')
  print(f'Avg. number of words per sentence: {avg_words_sent}')
  print(f'Unique word count (vocab): {vocab}')
  print(f'Lexicon diversity: {lexicon_diversity}')

# %%
doc_stats(doc)
# Out:
# Number of sentences: 7
# Avg. number of words per sentence: 34.42857142857143
# Unique word count (vocab): 140
# Lexicon diversity: 0.5809128630705395

# %%
wnl = WordNetLemmatizer()
print(wnl.lemmatize('feet'))
# Out:
# foot

# %%
lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
word = 'feet'
print(lemmatizer.lemmatize(word, get_wordnet_pos(word)))
# Out:
# foot

# %%
sentence = "The striped bats are hanging on their feet for best"
print([lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(sentence)])
# Out:
# ['The', 'strip', 'bat', 'be', 'hang', 'on', 'their', 'foot', 'for', 'best']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(token.lower(), get_wordnet_pos(token)) for token in word_tokenize(doc)]
print(lemmatized)
# Out:
# ['pink', 'take', 'a', 'break', 'to', 'focus', 'on', 'familyupdated', '10:18', 'am', 'et', ',', 'thu', 'november', '14', ',', '2019', '(', 'cnn', ')', '-', 'pink', 'have', 'be', 'work', 'pretty', 'hard', 'and', 'it', 'sound', 'like', 'she', 'will', 'be', 'take', 'a', 'step', 'back', 'in', '2020.speaking', 'with', '``', 'entertainment', 'tonight', "''", 'on', 'the', 'country', 'music', 'association', 'award', 'red', 'carpet', ',', 'the', 'singer', 'be', 'join', 'by', 'her', 'husband', ',', 'carey', 'hart', ',', 'and', 'their', 'kid', 'willow', ',', '8', ',', 'and', 'jameson', ',', '2.pink', 'be', 'there', 'to', 'perform', 'her', 'song', '``', 'love', 'me', 'anyway', "''", 'with', 'country', 'star', 'chris', 'stapleton', ',', 'and', 'she', 'talk', 'about', 'how', 'hectic', 'thing', 'have', 'be', '.', '``', 'we', 'do', 'two', 'and', 'a', 'half', 'year', 'of', '[', 'music', ']', 'and', 'willow', "'s", 'back', 'in', 'school', 'now', ',', 'jameson', "'s", 'go', 'to', 'start', 'pre-school', 'soon', ',', "''", 'pink', 'say', '.', '``', 'it', "'s", 'kind', 'of', 'the', 'year', 'of', 'the', 'family', '.', '``', 'the', 'star', 'also', 'praise', 'her', 'husband', ',', 'with', 'whom', 'she', 'will', 'celebrate', '14', 'year', 'of', 'marriage', 'in', 'january', '.', '``', 'carey', 'have', 'a', 'lot', 'go', 'on', 'a', 'well', ',', "''", 'she', 'say', 'of', 'hart', ',', 'who', 'go', 'from', 'be', 'a', 'professional', 'motocross', 'competitor', 'to', 'race', 'off-road', 'truck', '.', '``', 'he', "'s", 'super', 'supportive', ',', 'he', 'follow', 'me', 'around', 'the', 'world', 'and', 'now', 'it', "'s", 'his', 'turn', '.', '``', 'accord', 'to', 'billboard', ',', 'pink', "'s", 'beautiful', 'trauma', 'tour', 'rank', 'a', 'the', '10th', 'highest-grossing', 'tour', 'of', 'all', 'time', ',', 'earn', 'more', 'than', '$', '397', 'million', '.']

# %%
from nltk.corpus import wordnet

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(token.lower(), get_wordnet_pos(token)) for token in word_tokenize(doc)]
print(lemmatized)
# Out:
# ['pink', 'take', 'a', 'break', 'to', 'focus', 'on', 'familyupdated', '10:18', 'am', 'et', ',', 'thu', 'november', '14', ',', '2019', '(', 'cnn', ')', '-', 'pink', 'have', 'be', 'work', 'pretty', 'hard', 'and', 'it', 'sound', 'like', 'she', 'will', 'be', 'take', 'a', 'step', 'back', 'in', '2020.speaking', 'with', '``', 'entertainment', 'tonight', "''", 'on', 'the', 'country', 'music', 'association', 'award', 'red', 'carpet', ',', 'the', 'singer', 'be', 'join', 'by', 'her', 'husband', ',', 'carey', 'hart', ',', 'and', 'their', 'kid', 'willow', ',', '8', ',', 'and', 'jameson', ',', '2.pink', 'be', 'there', 'to', 'perform', 'her', 'song', '``', 'love', 'me', 'anyway', "''", 'with', 'country', 'star', 'chris', 'stapleton', ',', 'and', 'she', 'talk', 'about', 'how', 'hectic', 'thing', 'have', 'be', '.', '``', 'we', 'do', 'two', 'and', 'a', 'half', 'year', 'of', '[', 'music', ']', 'and', 'willow', "'s", 'back', 'in', 'school', 'now', ',', 'jameson', "'s", 'go', 'to', 'start', 'pre-school', 'soon', ',', "''", 'pink', 'say', '.', '``', 'it', "'s", 'kind', 'of', 'the', 'year', 'of', 'the', 'family', '.', '``', 'the', 'star', 'also', 'praise', 'her', 'husband', ',', 'with', 'whom', 'she', 'will', 'celebrate', '14', 'year', 'of', 'marriage', 'in', 'january', '.', '``', 'carey', 'have', 'a', 'lot', 'go', 'on', 'a', 'well', ',', "''", 'she', 'say', 'of', 'hart', ',', 'who', 'go', 'from', 'be', 'a', 'professional', 'motocross', 'competitor', 'to', 'race', 'off-road', 'truck', '.', '``', 'he', "'s", 'super', 'supportive', ',', 'he', 'follow', 'me', 'around', 'the', 'world', 'and', 'now', 'it', "'s", 'his', 'turn', '.', '``', 'accord', 'to', 'billboard', ',', 'pink', "'s", 'beautiful', 'trauma', 'tour', 'rank', 'a', 'the', '10th', 'highest-grossing', 'tour', 'of', 'all', 'time', ',', 'earn', 'more', 'than', '$', '397', 'million', '.']
