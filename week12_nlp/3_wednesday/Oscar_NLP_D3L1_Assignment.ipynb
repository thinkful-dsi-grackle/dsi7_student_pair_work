# %% [markdown]
# # Extracting Information from Text Data Assignment

# %%
# !pip install textacy --quiet
# !pip install rake_nltk --quiet

# %%
import spacy
import string
import textacy
import itertools
from nltk import pos_tag
from rake_nltk import Rake
from nltk import sent_tokenize
from nltk import word_tokenize
from nltk import tree2conlltags
from gensim.summarization import keywords
from nltk.chunk.regexp import RegexpParser
from nltk.corpus.reader.plaintext import PlaintextCorpusReader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Read the CNN Lite plain text file articles into a corpus using the NLTK's PlaintextCorpusReader.

# %%
PATH = '/content/drive/MyDrive/python_for_data_scientists/DSI07/DataSets/cnn_lite'

DOC_PATTERN = r'.*\.txt'

corpus = PlaintextCorpusReader(PATH, DOC_PATTERN)

# %% [markdown]
# ### Iterate through the fileids in the corpus, extract the raw text of each document, and store them in a list.

# %%
docs = [corpus.raw(fileid) for fileid in corpus.fileids()]

# %% [markdown]
# ### Extract the top 5 keywords from every document in the corpus. Print them and compare the differences in keywords among the documents.

# %%
top5_keywords = [keywords(doc, words=5, lemmatize=True).split('\n') for doc in docs]
top5_keywords
# Out:
# [['sanders', 'campaign', 'news', 'democrats', 'recent'],
#  ['courts', 'trump', 'states', 'general', 'businesses'],
#  ['politically', 'news', 'people', 'america', 'trump'],
#  ['erdogan', 'said', 'trump', 'meet', 'turkish'],
#  ['laurent', 'said', 'news', 'age', 'student'],
#  ['schools', 'high', 'gun', 'town', 'clarita'],
#  ['politically', 'people', 'american', 'guns', 'news'],
#  ['trump', 'november', 'border', 'facts', 'said'],
#  ['politically', 'presidents', 'likely', 'community', 'american'],
#  ['visitors', 'park', 'national', 'african', 'giraffes'],
#  ['livingstone', 'christmas', 'clarke', 'said', 'wham'],
#  ['trump', 'taylor', 'president', 'news', 'republican'],
#  ['bevin', 'general', 'kentucky', 'thursday', 'cnn'],
#  ['gaynor', 'hurricane', 'carper', 'changes', 'said'],
#  ['trump', 'democratic', 'republicans', 'presidency', 'news'],
#  ['rehaag', 'room', 'media', 'woman', 'later'],
#  ['snacks', 'hostess', 'twinkies', 'cereals', 'cnn'],
#  ['kushner', 'trump', 'news', 'department', 'impeachment'],
#  ['political', 'watches', 'people', 'positive', 'news'],
#  ['horvat', 'dorian', 'away', 'banks', 'cnn'],
#  ['republican', 'taylor', 'presidents', 'rep', 'ukraine'],
#  ['tail', 'narwhal', 'puppy', 'unicorn', 'dogs'],
#  ['news', 'said', 'trump', 'republican', 'media'],
#  ['momoa', 'cnn', 'said', 'reserved', 'hero'],
#  ['crows', 'cnn', 'american', 'old'],
#  ['said', 'architects', 'philippe', 'restoration', 'georgelin'],
#  ['keys', 'grammys', 'award', 'wanna', 'reserved'],
#  ['trump', 'hotels', 'office', 'profit', 'owned'],
#  ['protester', 'chinese', 'news', 'police', 'said'],
#  ['lambert', 'women', 'brooks', 'cnn', 'award'],
#  ['trump', 'democratic', 'news', 'taylor', 'house'],
#  ['govern', 'chinese', 'kong', 'authorities', 'protester'],
#  ['times', 'screens', 'digitally', 'kids'],
#  ['pollution', 'flood', 'ciambetti', 'region', 'parties'],
#  ['senator', 'espy', 'hyde', 'jobs'],
#  ['bart', 'cooper', 'court', 'news', 'answers'],
#  ['brown', 'police', 'jones', 'high', 'said'],
#  ['trump', 'emolument', 'foreigners', 'governments', 'said'],
#  ['feathered', 'dinosaur', 'polar', 'said', 'likely'],
#  ['muslimness', 'people', 'skin', 'white', 'religion'],
#  ['democrat', 'security', 'ukraine', 'assistant', 'trump'],
#  ['high school', 'year', 'kill'],
#  ['americans', 'republican', 'ukrainians', 'investigate', 'impeachable'],
#  ['states', 'democrats', 'news', 'bloomberg', 'told'],
#  ['democrat', 'ryan', 'trump', 'candidates', 'biden'],
#  ['taylor', 'diplomatic', 'deeply', 'trump', 'republicans'],
#  ['rep', 'hearings', 'president', 'taylor', 'said'],
#  ['cnn', 'lochhead', 'seen', 'later', 'video'],
#  ['patrick', 'primary', 'news', 'cnn', 'democrats'],
#  ['adults', 'tobacco', 'cigarettes', 'cnn', 'recorded'],
#  ['pink', 'carey', 'tour', 'cnn', 'reserved'],
#  ['house', 'ukraine', 'zelensky', 'aides', 'trump'],
#  ['said', 'trump', 'news', 'like', 'wisconsin'],
#  ['cnn', 'reserved', 'county', 'angeles', 'morning'],
#  ['trump', 'foreign', 'hotels', 'rooms', 'investor'],
#  ['reserved', 'news', 'turner', 'cnn'],
#  ['reserved', 'turner', 'news', 'cnn']]

# %% [markdown]
# ### Extract the top 3 keyphrases from each document, print them, and compare the differences.

# %%
for doc in docs:
  r = Rake()
  r.extract_keywords_from_text(doc)
  print(r.get_ranked_phrases_with_scores()[:3])
  print('-------------------')
# Out:
# [(64.35555555555555, 'win ," campaign manager faiz shakir told cnn last month'), (52.0, 'billionaire former new york city mayor michael bloomberg'), (33.0, 'former vice president joe biden came')]
# -------------------
# [(43.25, 'attorneys general offices could gather financial information'), (25.25, 'attorney general brian frosh called'), (25.0, '© 2019 cable news network')]
# -------------------
# [(26.015151515151516, 'america ," cnn opinion invited readers'), (23.0, '© 2019 cable news network'), (23.0, 'seen increasingly vast gaps develop')]
# -------------------
# [(29.42820512820513, 'senior administration official said trump first raised'), (29.2, 'turkish president recep tayyip erdoğan pulled'), (25.0, '© 2019 cable news network')]
# -------------------
# [(25.0, '© 2019 cable news network'), (20.625, 'unusual ," said sjoerd hulshof'), (14.8, 'discover new things ."')]
# -------------------
# [(82.4, 'make quick judgments ," saugus high student lèan aguilar said'), (25.0, '© 2019 cable news network'), (24.0, 'santa clarita valley signal reported')]
# -------------------
# [(29.333333333333332, 'climate change might affect us ")'), (23.0, '© 2019 cable news network'), (23.0, 'almost three times less accurate')]
# -------------------
# [(62.371794871794876, 'mexican defense minister luis cresencio sandoval said last week'), (47.03846153846154, 'additional testimony sondland submitted last monday effectively conceded'), (42.25, 'issues went far beyond trivial administrative transgressions')]
# -------------------
# [(33.0, 'racist tweets targeting four women lawmakers'), (28.916666666666664, 'creating vast global communities across generations'), (25.0, 'ucla professor matthew lieberman wrote')]
# -------------------
# [(25.0, '© 2019 cable news network'), (23.0, 'oncoming tourist rental vehicle driven'), (19.666666666666664, 'giraffe held 13 visitors passing')]
# -------------------
# [(25.0, '© 2019 cable news network'), (19.666666666666664, 'director paul feig told thr'), (14.0, 'producer david livingstone talked')]
# -------------------
# [(52.02777777777778, '• taylor aide david holmes testifies behind closed doors'), (45.266666666666666, 'ukrainian president volodymyr zelensky despite president donald trump'), (32.5, 'senate majority leader mitch mcconnell probably')]
# -------------------
# [(39.666666666666664, 'trailing democratic state attorney general andy beshear'), (39.06666666666666, 'accurate ," bevin told cnn affiliate wkyt'), (25.0, '© 2019 cable news network')]
# -------------------
# [(43.5, 'federal emergency management agency repeatedly said thursday'), (25.0, '© 2019 cable news network'), (22.416666666666668, 'good answer ," carper told')]
# -------------------
# [(33.5, 'polarized differences still allowed dispassionate debate'), (30.875, 'turkish strongman president recep tayyip erdoğan'), (23.666666666666668, '© 2019 cable news network')]
# -------------------
# [(23.5, '© 2019 cable news network'), (16.0, '450 euros ($ 330'), (15.0, 'pregnant social media star')]
# -------------------
# [(31.6, 'consumer loyalty among hostess brands ."'), (25.0, '© 2019 cable news network'), (24.1, 'smaller headcount called hostess brands')]
# -------------------
# [(55.095238095238095, 'state department spokeswoman morgan ortagus flank ivanka trump'), (47.37857142857143, 'festivities feting trump jr ., including republican reps'), (37.0, 'former treasury department spokesman tony sayegh')]
# -------------------
# [(39.83333333333333, 'social media may make things worse rather'), (24.0, '© 2019 cable news network'), (24.0, 'minded citizens simply reiterate familiar')]
# -------------------
# [(25.0, '© 2019 cable news network'), (21.75, 'discovered around four miles away'), (21.0, 'cape lookout national seashore park')]
# -------------------
# [(69.0, 'money ," tweeted white house press secretary stephanie grisham'), (67.33333333333333, 'former white house homeland security adviser tom bossert summed'), (63.416666666666664, 'former national security council russia expert fiona hill said')]
# -------------------
# [(28.166666666666668, 'little magical furry unicorn ," according'), (25.0, '© 2019 cable news network'), (18.5, 'dog rescue nonprofit organization mac')]
# -------------------
# [(78.26923076923076, 'others made jokes — christian whiton said witnesses bill taylor'), (46.333333333333336, 'heard white house press secretary stephanie grisham say'), (34.33333333333333, 'house intelligence committee chair adam schiff')]
# -------------------
# [(25.0, '© 2019 cable news network'), (20.5, 'like whether aquaman knows ariel'), (16.0, 'like daughter river blackstock')]
# -------------------
# [(29.0, 'may contain outdated cultural depictions ."'), (25.0, '© 2019 cable news network'), (16.0, 'director tim burton chose')]
# -------------------
# [(32.0, 'french prime minister édouard philippe announced'), (25.0, '© 2019 cable news network'), (22.0, 'restoration expert frédéric létoffé said')]
# -------------------
# [(23.5, '© 2019 cable news network'), (20.833333333333336, 'host ," keys told billboard'), (18.666666666666668, 'current alicia keys discussing hosting')]
# -------------------
# [(30.03333333333333, '," said committee chairman peter defazio'), (23.5, '© 2019 cable news network'), (23.5, 'wall street journal first reported')]
# -------------------
# [(31.5, 'fall semester around two weeks early'), (31.177777777777777, 'senior chinese official shen chunyao said'), (29.833333333333336, 'three tunnels connecting hong kong island')]
# -------------------
# [(29.5, '53rd annual country music association awards'), (25.0, '© 2019 cable news network'), (16.0, 'fellow superstars dolly parton')]
# -------------------
# [(39.55, 'senior state department official overseeing ukraine policy'), (30.03333333333333, 'investigate former vice president joe biden'), (28.266666666666666, 'trump telling top us diplomats working')]
# -------------------
# [(28.083333333333332, 'hong kong hospital authority spokesperson confirmed'), (25.0, '© 2019 cable news network'), (21.666666666666664, 'staunchly support hk judicial bodies')]
# -------------------
# [(40.0, 'spend 15 minutes every evening watching videos'), (25.0, '© 2019 cable news network'), (22.0, 'taint every single activity done')]
# -------------------
# [(34.0, 'local paper giornale di vicenza :.'), (32.8, 'mayor luigi brugnaro blamed climate change'), (29.45, 'democratic party councilor andrea zanoni said')]
# -------------------
# [(51.833333333333336, 'makes statements supporting voter suppression ," espy said'), (36.00000000000001, 'mississippi democrat whose heated special senate runoff'), (25.0, '© 2019 cable news network')]
# -------------------
# [(35.5, 'daily digital show streaming live around'), (25.5, 'horrific videos show rising tensions'), (25.0, '© 2019 cable news network')]
# -------------------
# [(29.675, 'roanoke police chief tim jones said brown'), (25.0, '© 2019 cable news network'), (23.925, 'navigationally savvy ," jones said')]
# -------------------
# [(33.0, 'washington university law professor kathleen clark'), (23.0, '© 2019 cable news network'), (23.0, 'story originally ran may 3')]
# -------------------
# [(79.75, 'polar darkness every year ," said study author benjamin kear'), (43.5, 'ancient polar habitats ," said martin kundrat'), (25.0, '© 2019 cable news network')]
# -------------------
# [(25.0, '© 2019 cable news network'), (16.0, 'protesters stormed john f'), (16.0, 'executive order banning entry')]
# -------------------
# [(40.5, 'told lawmakers behind closed doors last month'), (28.75, 'ukraine security assistance initiative funding appropriated'), (24.0, 'congressional watchdog group announced earlier')]
# -------------------
# [(39.79722222222222, 'old duane morrison takes six female students hostage'), (34.13055555555555, 'old dylan klebold kill 12 fellow students'), (32.57142857142857, 'serving three life sentences plus 140 years')]
# -------------------
# [(32.6, 'house intelligence committee chair adam schiff'), (27.916666666666664, 'republicans like jim jordan threw angrily'), (23.75, 'courts also prohibit witness speculation')]
# -------------------
# [(37.58333333333333, 'former new york mayor michael bloomberg made'), (29.0, '2016 democratic nominee playfully tweeted back'), (25.0, '© 2019 cable news network')]
# -------------------
# [(27.416666666666668, 'win swing states president donald trump'), (25.0, '© 2019 cable news network'), (19.666666666666668, 'tim ryan endorsed joe biden')]
# -------------------
# [(32.0, 'house intelligence committee chairman adam schiff'), (25.0, '© 2019 cable news network'), (22.666666666666664, 'behavior toward top ukrainian officials')]
# -------------------
# [(52.66666666666667, 'unfair (" 93 days since adam schiff learned'), (40.94444444444444, 'hearing featuring two relatively unknown senior diplomats'), (34.52777777777777, 'big ," one house republican aide told cnn')]
# -------------------
# [(25.833333333333332, 'video ," santa cruz county sheriff'), (25.0, '© 2019 cable news network'), (24.666666666666668, 'newly released surveillance video shows')]
# -------------------
# [(94.33333333333333, 'former new york city mayor michael bloomberg stepped forward last week'), (30.291666666666664, 'patrick could seize upon potential advantages'), (30.0, 'elections process would ultimately splash back')]
# -------------------
# [(26.333333333333336, 'cigarette smoking among us adults fell'), (25.0, '© 2019 cable news network'), (24.0, 'vaping among young adults 18')]
# -------------------
# [(32.5, 'country music association awards red carpet'), (25.0, '© 2019 cable news network'), (17.5, 'school soon ," pink said')]
# -------------------
# [(121.19696969696969, 'intelligence community inspector general michael atkinson notifies house intelligence chairman adam schiff'), (54.70833333333333, 'could damage former vice president joe biden heading'), (36.1686507936508, 'president donald trump used us tax dollars')]
# -------------------
# [(36.0, 'moral compass among elected officials within'), (33.5, 'complex diplomatic dealings involving military aid'), (25.0, '© 2019 cable news network')]
# -------------------
# [(25.0, '© 2019 cable news network'), (16.0, 'los angeles county sheriff'), (14.0, 'department said thursday morning')]
# -------------------
# [(33.0, 'whose ceo jeff bezos also owns'), (23.0, '© 2019 cable news network'), (22.0, 'area ," said dan hawkins')]
# -------------------

# %% [markdown]
# ### Identify and extract the named entities in each document, filtering out the numeric types. Print them and compare the differences between documents.

# %%
nlp = spacy.load('en_core_web_sm')
spacy_docs = [nlp(doc) for doc in docs]

# %%
numeric = ['CARDINAL', 'DATE', 'TIME', 'ORDINAL', 'PERCENT', 'MONEY', 'QUANTITY']

entities = [[[entity.text, entity.label_] for entity in spacy_doc.ents 
             if entity.label_ not in numeric] 
            for spacy_doc in spacy_docs]

# %%
entities
# Out:
# [[['Des Moines', 'GPE'],
#   ['Iowa', 'GPE'],
#   ['CNN', 'ORG'],
#   ['Alexandria Ocasio-Cortez', 'PERSON'],
#   ['Iowa', 'GPE'],
#   ['Bernie Sanders', 'PERSON'],
#   ['Vermont', 'GPE'],
#   ['Council Bluffs', 'ORG'],
#   ['Sanders', 'ORG'],
#   ['Democratic', 'NORP'],
#   ['Las Vegas', 'GPE'],
#   ['Sanders', 'ORG'],
#   ['New Hampshire', 'GPE'],
#   ['Iowa', 'GPE'],
#   ['New York', 'GPE'],
#   ['Minnesota', 'GPE'],
#   ['Sanders', 'ORG'],
#   ['Des Moines', 'GPE'],
#   ['Drake University', 'ORG'],
#   ['Ocasio-Cortez', 'ORG'],
#   ['Ilhan Omar', 'PERSON'],
#   ['Rashida Tlaib', 'PERSON'],
#   ['Ohio', 'GPE'],
#   ['Sanders', 'ORG'],
#   ['Democratic', 'NORP'],
#   ['Sanders', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Democrats', 'NORP'],
#   ['New Hampshire', 'GPE'],
#   ["Elizabeth Warren's", 'PERSON'],
#   ['Joe Biden', 'PERSON'],
#   ['South Bend', 'GPE'],
#   ['Indiana', 'GPE'],
#   ['Pete Buttigieg', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Iowa', 'GPE'],
#   ['Bernie', 'PERSON'],
#   ['the White House', 'ORG'],
#   ['Democratic', 'NORP'],
#   ['the better party of', 'ORG'],
#   ['Hillary Clinton', 'PERSON'],
#   ['Democratic', 'NORP'],
#   ['Sanders', 'NORP'],
#   ['Texas', 'GPE'],
#   ["Beto O'Rourke", 'PERSON'],
#   ['Elizabeth Warren', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Clinton', 'PERSON'],
#   ['Iowa', 'GPE'],
#   ["O'Rourke", 'ORG'],
#   ['Warren', 'PERSON'],
#   ['Clinton', 'PERSON'],
#   ['Biden', 'PERSON'],
#   ['South Bend', 'GPE'],
#   ['Indiana', 'GPE'],
#   ['Pete Buttigieg', 'PERSON'],
#   ['Bernie', 'ORG'],
#   ['Sanders', 'ORG'],
#   ['Iowa', 'GPE'],
#   ['Burlington', 'GPE'],
#   ['Vermont', 'GPE'],
#   ['Sanders', 'ORG'],
#   ['Ohio', 'GPE'],
#   ['New York', 'GPE'],
#   ['Ocasio-Cortez', 'ORG'],
#   ['Sanders', 'ORG'],
#   ['Detroit', 'GPE'],
#   ['Tlaib', 'NORP'],
#   ['Sanders', 'NORP'],
#   ['Donald Trump', 'PERSON'],
#   ['Sanders', 'ORG'],
#   ['Donald Trump', 'PERSON'],
#   ['Faiz Shakir', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Sanders', 'ORG'],
#   ['Sanders', 'NORP'],
#   ['Washington, DC', 'GPE'],
#   ['Sanders', 'ORG'],
#   ['Sanders', 'ORG'],
#   ['CNN', 'ORG'],
#   ['New York City', 'GPE'],
#   ['Michael Bloomberg', 'PERSON'],
#   ['Sanders', 'ORG'],
#   ['Drake University', 'ORG'],
#   ['Sanders', 'ORG'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Washington', 'GPE'],
#   ['CNN', 'ORG'],
#   ['Donald Trump', 'PERSON'],
#   ['the Trump Organization', 'ORG'],
#   ['the District of Columbia', 'GPE'],
#   ['Maryland', 'GPE'],
#   ['the Trump International Hotel', 'FAC'],
#   ['4th US Circuit Court of Appeals', 'ORG'],
#   ['Richmond', 'GPE'],
#   ['Virginia', 'GPE'],
#   ['The District of Columbia', 'GPE'],
#   ['Maryland', 'GPE'],
#   ['the Trump International Hotel', 'FAC'],
#   ['Washington', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['the Trump Organization', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Twitter', 'PERSON'],
#   ['the Deep State', 'LOC'],
#   ['Democrat', 'NORP'],
#   ['Witch Hunt', 'PERSON'],
#   ['Trump', 'LOC'],
#   ['Circuit', 'ORG'],
#   ['Karl Racine', 'PERSON'],
#   ['Maryland', 'GPE'],
#   ['Brian Frosh', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Constitution', 'LAW'],
#   ['Trump', 'PRODUCT'],
#   ['the Emoluments Clause of the Constitution', 'FAC'],
#   ['New York', 'GPE'],
#   ['Washington, DC', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Fractured States of America', 'WORK_OF_ART'],
#   ['CNN Opinion', 'WORK_OF_ART'],
#   ['Americans', 'NORP'],
#   ['Teresina Adams', 'PERSON'],
#   ['Las Vegas', 'GPE'],
#   ['Kenja Purkey', 'PERSON'],
#   ['Amarillo', 'GPE'],
#   ['Texas', 'GPE'],
#   ['America', 'GPE'],
#   ['Phil L.', 'PERSON'],
#   ['Pennsylvania', 'GPE'],
#   ['post-2016', 'ORG'],
#   ['Eve', 'PERSON'],
#   ['Rexford', 'GPE'],
#   ['New York', 'GPE'],
#   ['Chinese', 'NORP'],
#   ['Eve', 'PERSON'],
#   ['Eve', 'PERSON'],
#   ['America', 'GPE'],
#   ['Jason R.', 'PERSON'],
#   ['Ohio', 'GPE'],
#   ['America', 'GPE'],
#   ['Clinton W.', 'PERSON'],
#   ['Portland', 'GPE'],
#   ['Oregon', 'GPE'],
#   ['Rich G.', 'PERSON'],
#   ['Tampa', 'GPE'],
#   ['Florida', 'GPE'],
#   ['Americans', 'NORP'],
#   ['Rich', 'PERSON'],
#   ['Christian', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Christian', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Bible', 'WORK_OF_ART'],
#   ['Democrat', 'NORP'],
#   ['Americans', 'NORP'],
#   ['Teresina Adams', 'PERSON'],
#   ['Las Vegas', 'GPE'],
#   ['Nevada', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Democrat', 'NORP'],
#   ['Hillary', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['America', 'GPE'],
#   ['Ronda', 'GPE'],
#   ['Delaware County', 'GPE'],
#   ['New York', 'GPE'],
#   ['New Orleans', 'GPE'],
#   ['Pensacola', 'GPE'],
#   ['Florida', 'GPE'],
#   ['Phil Goddard', 'PERSON'],
#   ['Pensacola', 'GPE'],
#   ['Florida', 'GPE'],
#   ['America', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Americans', 'NORP'],
#   ['America', 'GPE'],
#   ['Susie D.', 'PERSON'],
#   ['Virginia Beach', 'GPE'],
#   ['Virginia', 'GPE'],
#   ['Nazi', 'NORP'],
#   ["Veterans' Day", 'GPE'],
#   ['America', 'GPE'],
#   ['New York', 'GPE'],
#   ['Ellis Island', 'LOC'],
#   ['America', 'GPE'],
#   ['Nazi', 'NORP'],
#   ['America', 'GPE'],
#   ['US', 'GPE'],
#   ['Nazism', 'NORP'],
#   ['Carol', 'GPE'],
#   ['South Dakota', 'GPE'],
#   ['America', 'GPE'],
#   ['Beth A.', 'PERSON'],
#   ['North Carolina', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Navy', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Brian Barrios', 'PERSON'],
#   ['Warren', 'GPE'],
#   ['Ohio', 'GPE'],
#   ['Democrat', 'NORP'],
#   ['Republican', 'NORP'],
#   ['Republican', 'NORP'],
#   ['America', 'GPE'],
#   ['Joanne C.', 'PERSON'],
#   ['Arizona', 'GPE'],
#   ["Adam Schiff's", 'GPE'],
#   ['L.A.', 'GPE'],
#   ['Michigan', 'GPE'],
#   ['California', 'GPE'],
#   ['Texas', 'GPE'],
#   ['Michael Peterson', 'PERSON'],
#   ['Los Angeles', 'GPE'],
#   ['California', 'GPE'],
#   ['Democrat', 'NORP'],
#   ['Hillary Clinton', 'PERSON'],
#   ['Donald Trump', 'PERSON'],
#   ['Bernie', 'PERSON'],
#   ['Obama', 'LOC'],
#   ['Obamacare', 'PERSON'],
#   ['Trumper', 'PRODUCT'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'LOC'],
#   ['Lynn Root', 'PERSON'],
#   ['Covington', 'GPE'],
#   ['Washington', 'GPE'],
#   ['America', 'GPE'],
#   ['America', 'GPE'],
#   ['America', 'GPE'],
#   ['America', 'GPE'],
#   ['Clinton', 'PERSON'],
#   ['America', 'GPE'],
#   ["Barack Obama's", 'PERSON'],
#   ['the Patriot Act', 'LAW'],
#   ["Martin Luther King Jr's", 'PERSON'],
#   ['America', 'GPE'],
#   ['Jason R.', 'PERSON'],
#   ['Ohio', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Texas', 'GPE'],
#   ['Republican', 'NORP'],
#   ['Clintons', 'PERSON'],
#   ['the Tea Party', 'ORG'],
#   ['the Republican Party', 'ORG'],
#   ['Confederate', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['THEY', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'PRODUCT'],
#   ['Better Angels', 'ORG'],
#   ['Kenja Purkey', 'PERSON'],
#   ['Amarillo', 'GPE'],
#   ['Texas', 'GPE'],
#   ['Contract with America', 'WORK_OF_ART'],
#   ['America', 'GPE'],
#   ['Kathi Ghannam', 'PERSON'],
#   ['Virginia', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'PRODUCT'],
#   ['Muslims', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Akiko Bergeron', 'GPE'],
#   ['Clearwater', 'GPE'],
#   ['Florida', 'GPE'],
#   ['Michael L.', 'PERSON'],
#   ['Maine', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Washington', 'GPE'],
#   ['CNN', 'ORG'],
#   ['the Oval Office', 'ORG'],
#   ['Turkish', 'NORP'],
#   ['Recep Tayyip Erdoğan', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Donald Trump', 'PERSON'],
#   ['Kurds', 'NORP'],
#   ['GOP', 'ORG'],
#   ['Axios', 'ORG'],
#   ['Lindsey Graham', 'PERSON'],
#   ['Jim Risch', 'PERSON'],
#   ['Ted Cruz', 'PERSON'],
#   ['Joni Ernst', 'PERSON'],
#   ['Rick Scott', 'PERSON'],
#   ['Erdogan', 'PERSON'],
#   ['Russian', 'NORP'],
#   ['Turkey', 'GPE'],
#   ['Turkey', 'GPE'],
#   ['Kurds', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['GOP', 'ORG'],
#   ['Turkey', 'GPE'],
#   ['US', 'GPE'],
#   ['Russian', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Turkey', 'GPE'],
#   ['Erdoğan', 'ORG'],
#   ['Erdoğan', 'PERSON'],
#   ['Erdoğan', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Senate', 'ORG'],
#   ['Turkey', 'GPE'],
#   ['Erdoğan', 'PERSON'],
#   ['Senate', 'ORG'],
#   ["Robert O'Brien", 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Senate', 'ORG'],
#   ['Republican', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Erdoğan', 'ORG'],
#   ['Turkey', 'GPE'],
#   ['Republican', 'NORP'],
#   ['Erdoğan', 'ORG'],
#   ['Graham', 'PERSON'],
#   ['Turkey', 'GPE'],
#   ['Syria', 'GPE'],
#   ['Erdoğan', 'PERSON'],
#   ['US', 'GPE'],
#   ['Kurdish', 'NORP'],
#   ['Graham', 'PERSON'],
#   ['Syria', 'GPE'],
#   ['Scott', 'PERSON'],
#   ['Turkey', 'GPE'],
#   ['NATO', 'ORG'],
#   ['Russia', 'GPE'],
#   ['Cruz', 'PERSON'],
#   ['Erdoğan', 'PERSON'],
#   ['Kurds', 'NORP'],
#   ['Turkey', 'GPE'],
#   ['the White House', 'FAC'],
#   ['Erdoğan', 'PERSON'],
#   ['Turkish', 'NORP'],
#   ['Kurds', 'NORP'],
#   ['Turkish', 'NORP'],
#   ['US', 'GPE'],
#   ['Turkey', 'GPE'],
#   ['Turkey', 'GPE'],
#   ['Russia', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Erdoğan', 'PERSON'],
#   ['US', 'GPE'],
#   ['Trump', 'LOC'],
#   ['Erdoğan', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Erdoğan', 'PERSON'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Belgium', 'GPE'],
#   ['the Eindhoven University of Technology', 'ORG'],
#   ['PhD', 'WORK_OF_ART'],
#   ['CNN', 'ORG'],
#   ['Lydia', 'GPE'],
#   ['Alexander Simons', 'PERSON'],
#   ['Laurent', 'ORG'],
#   ['Lydia', 'GPE'],
#   ['Alexander', 'PERSON'],
#   ['Lydia', 'GPE'],
#   ['TUE', 'PRODUCT'],
#   ['Sjoerd Hulshof', 'PERSON'],
#   ['TUE', 'PRODUCT'],
#   ['Electrical Engineering', 'ORG'],
#   ['Hulshof', 'PERSON'],
#   ['Laurent', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Laurent', 'ORG'],
#   ['Laurent', 'ORG'],
#   ['Alexander', 'PERSON'],
#   ['Sammy', 'PERSON'],
#   ['Laurent', 'ORG'],
#   ['Japan', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Saugus High School', 'ORG'],
#   ['Santa Clarita', 'GPE'],
#   ['Marjory', 'WORK_OF_ART'],
#   ['Douglas High School', 'PERSON'],
#   ['Florida', 'GPE'],
#   ['Saugus High', 'GPE'],
#   ['the Santa Clarita Valley Signal', 'ORG'],
#   ['Lèan Aguilar', 'PERSON'],
#   ['California', 'GPE'],
#   ['Katie Hill', 'PERSON'],
#   ['Saugus High School', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Daniel Yudkin', 'PERSON'],
#   ['the University of Pennsylvania', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Americans', 'NORP'],
#   ['American', 'NORP'],
#   ['Americans', 'NORP'],
#   ['Americans', 'NORP'],
#   ['Americans', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['American', 'NORP'],
#   ['Americans', 'NORP'],
#   ['New England', 'LOC'],
#   ['Kansas', 'GPE'],
#   ['American', 'NORP'],
#   ['US', 'GPE'],
#   ['American', 'NORP'],
#   ['Americans', 'NORP'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Washington', 'GPE'],
#   ['CNN', 'ORG'],
#   ['Donald Trump', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Trump', 'PRODUCT'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['the Washington Post', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['William Barr', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Post', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Post', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Louisiana', 'GPE'],
#   ['Hackberry', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Obama', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Louisiana', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['the Republican Party', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Gallup', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Ukraine', 'GPE'],
#   ['Marine One', 'ORG'],
#   ['Air Force One', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['Alexander Vindman', 'PERSON'],
#   ['Tim Morrison', 'PERSON'],
#   ["the White House's", 'ORG'],
#   ['National Security Council', 'ORG'],
#   ['Jennifer Williams', 'PERSON'],
#   ['Mike Pence', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Air Force One', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Russian', 'NORP'],
#   ['Trump', 'PERSON'],
#   ["Gordon Sondland's", 'PERSON'],
#   ['Gordon Sondland', 'PERSON'],
#   ['Marine One', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Sondland', 'PERSON'],
#   ['the European Union', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Sondland', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Sondland', 'PERSON'],
#   ["Adam Schiff's", 'PERSON'],
#   ['WKYT', 'ORG'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['House Intelligence Committee', 'ORG'],
#   ['Schiff', 'ORG'],
#   ['Trump', 'LOC'],
#   ['Trump', 'PERSON'],
#   ['Schiff', 'ORG'],
#   ['Schiff', 'ORG'],
#   ["The Washington Post's", 'ORG'],
#   ['Barr', 'PERSON'],
#   ['Fake News CNN', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['AG Barr', 'ORG'],
#   ['Ukraine', 'GPE'],
#   ['Bill Barr', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Fake Washington Post', 'ORG'],
#   ['Washington Post', 'ORG'],
#   ['Bill Barr', 'PERSON'],
#   ['John', 'PERSON'],
#   ['Marine One', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Washington Post', 'ORG'],
#   ['CNN', 'ORG'],
#   ['the New York Times', 'ORG'],
#   ['Post', 'ORG'],
#   ['Marty Baron', 'PERSON'],
#   ['Post', 'ORG'],
#   ['Post', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Black Voices', 'EVENT'],
#   ['Trump', 'LOC'],
#   ['Hillary Clinton', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['NASDAQ', 'ORG'],
#   ['Kentucky', 'GPE'],
#   ['Matt Bevin', 'PERSON'],
#   ['Kentucky', 'GPE'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Bevin', 'PERSON'],
#   ['Kentucky', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Jack Mazurak', 'PERSON'],
#   ['the Kentucky Cabinet for Economic Development', 'ORG'],
#   ['Mazurak', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Russell Wheeler', 'PERSON'],
#   ['the Brookings Institution', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'LOC'],
#   ['Russell Wheeler', 'PERSON'],
#   ['the Brookings Institution', 'ORG'],
#   ["Jimmy Carter's", 'PERSON'],
#   ['Wheeler', 'ORG'],
#   ['Senate', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Wheeler', 'PERSON'],
#   ['Carter', 'PERSON'],
#   ['Richard Nixon', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['John F. Kennedy', 'PERSON'],
#   ['Wheeler', 'ORG'],
#   ['The Trump Foundation', 'ORG'],
#   ['New York', 'GPE'],
#   ['the Trump Foundation', 'ORG'],
#   ['New York', 'GPE'],
#   ['the Trump Foundation', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Foundation', 'ORG'],
#   ['Foundation', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Foundation', 'ORG'],
#   ['Foundation', 'ORG'],
#   ['Trump', 'LOC'],
#   ['Foundation', 'ORG'],
#   ['Trump', 'LOC'],
#   ['Foundation', 'ORG'],
#   ['Foundation', 'ORG'],
#   ['Pam Bondi', 'PERSON'],
#   ['Florida', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Foundation', 'ORG'],
#   ['Foundation', 'ORG'],
#   ['Saliann Scarpulla', 'PERSON'],
#   ['Foundation', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Des Moines', 'GPE'],
#   ['Iowa', 'GPE'],
#   ['Iowa', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Fundraiser', 'PRODUCT'],
#   ['Foundation', 'ORG'],
#   ['Fundraiser', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Scarpulla', 'PERSON'],
#   ['Andy Beshear', 'PERSON'],
#   ['Beshear', 'PERSON'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Beshear', 'PERSON'],
#   ['Kentucky', 'GPE'],
#   ['Beshear', 'PERSON'],
#   ['Barack Obama', 'PERSON'],
#   ['Clean Power Plan', 'PRODUCT'],
#   ['Beshear', 'PERSON'],
#   ['Beshear', 'PERSON'],
#   ['Kentucky', 'GPE'],
#   ['Beshear', 'PERSON'],
#   ['Beshear', 'PRODUCT'],
#   ['Republican', 'NORP'],
#   ['Matt Bevin', 'PERSON'],
#   ['Bevin', 'PERSON'],
#   ['The Wall Street Journal', 'ORG'],
#   ['Beshear', 'PERSON'],
#   ['Kentucky', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Bevin', 'PERSON'],
#   ['Amy McGrath', 'PERSON'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Amy McGrath', 'PERSON'],
#   ['Democratic', 'NORP'],
#   ['Senate', 'ORG'],
#   ['Kentucky', 'GPE'],
#   ['McGrath', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['McGrath', 'PERSON'],
#   ['Louisville', 'GPE'],
#   ['the United States', 'GPE'],
#   ['Monroe', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['the United States', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Alabama', 'GPE'],
#   ['Alabama', 'GPE'],
#   ['Marine One', 'ORG'],
#   ['ABC', 'ORG'],
#   ['Birmingham', 'GPE'],
#   ['Alabama', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Alabama', 'GPE'],
#   ["Hillary Clinton's", 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Biden', 'PERSON'],
#   ['Joe Biden', 'PERSON'],
#   ['Marine One', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Biden', 'LOC'],
#   ['Council on Foreign Relations', 'ORG'],
#   ['Biden', 'NORP'],
#   ['Ukraine', 'GPE'],
#   ['Ukrainian', 'NORP'],
#   ['Viktor Shokin', 'PERSON'],
#   ['US', 'GPE'],
#   ['European', 'NORP'],
#   ['Biden', 'LOC'],
#   ['the Supreme Court', 'ORG'],
#   ['Monroe', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Schiff', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Schiff', 'ORG'],
#   ['Schiff', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Schiff', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Schiff', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Bradley Moss', 'PERSON'],
#   ['Mark Zaid', 'PERSON'],
#   ['European', 'NORP'],
#   ['Ukraine', 'GPE'],
#   ['Germany', 'GPE'],
#   ['France', 'GPE'],
#   ['the United Kingdom', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['European', 'NORP'],
#   ['Ukraine', 'GPE'],
#   ['Russia', 'GPE'],
#   ['Zelensky', 'ORG'],
#   ['European', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['the United Nations', 'FAC'],
#   ['European', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['WKYT', 'ORG'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Marine One', 'ORG'],
#   ['Fox 5 Atlanta', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Marine One', 'ORG'],
#   ['Trump', 'LOC'],
#   ['Louisiana', 'GPE'],
#   ['Moon Griffon', 'PERSON'],
#   ['Monroe', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Insure.com', 'ORG'],
#   ['Louisiana news', 'ORG'],
#   ['Michigan', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Insure.com', 'ORG'],
#   ['Michigan', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['American', 'NORP'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['US', 'GPE'],
#   ['Trump', 'LOC'],
#   ['American', 'NORP'],
#   ['US', 'GPE'],
#   ['Energy Information Administration', 'ORG'],
#   ['US', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Louisiana', 'GPE'],
#   ['Hackberry', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Monroe', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Obama', 'PERSON'],
#   ['The Federal Energy Regulatory Commission', 'ORG'],
#   ['Cameron LNG', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Democrats', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Washington Post', 'ORG'],
#   ['Mexican', 'NORP'],
#   ['Mexican', 'NORP'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Mexico', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['US', 'GPE'],
#   ['CNN', 'ORG'],
#   ['Mexico', 'GPE'],
#   ['Mexican', 'NORP'],
#   ['Defense', 'ORG'],
#   ['Luis Cresencio Sandoval', 'PERSON'],
#   ['US Customs', 'ORG'],
#   ['Border Protection', 'ORG'],
#   ['Mark Morgan', 'PERSON'],
#   ['Mexico', 'GPE'],
#   ['Democrats', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Democrats', 'NORP'],
#   ['Mexico', 'GPE'],
#   ['Monroe', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Democratic', 'NORP'],
#   ['Massachusetts', 'GPE'],
#   ['Elizabeth Warren', 'PERSON'],
#   ['Housing and Urban Development', 'ORG'],
#   ['Julián Castro', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['a Rolls-Royce', 'ORG'],
#   ['Donald Trump', 'PERSON'],
#   ['Rolls-Royces', 'ORG'],
#   ['Black Voices', 'EVENT'],
#   ['Trump', 'LOC'],
#   ['Arizona', 'GPE'],
#   ['Democrats', 'NORP'],
#   ['Rolls-Royce', 'ORG'],
#   ['Nevada', 'GPE'],
#   ['Democrats', 'NORP'],
#   ['a Rolls-Royce', 'ORG'],
#   ['Nevada', 'GPE'],
#   ['Arizona', 'GPE'],
#   ['a Rolls-Royce?', 'ORG'],
#   ['China', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['China', 'GPE'],
#   ['China', 'GPE'],
#   ['Marine One', 'ORG'],
#   ['China', 'GPE'],
#   ['China', 'GPE'],
#   ['Black Voices', 'EVENT'],
#   ['Trump', 'LOC'],
#   ['ABC', 'ORG'],
#   ['Birmingham', 'GPE'],
#   ['Alabama', 'GPE'],
#   ['Americans', 'NORP'],
#   ['Americans', 'NORP'],
#   ['China', 'GPE'],
#   ['China', 'GPE'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['America', 'GPE'],
#   ['China', 'GPE'],
#   ['Monroe', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['China', 'GPE'],
#   ['China', 'GPE'],
#   ['China', 'GPE'],
#   ['Air Force One', 'PRODUCT'],
#   ['Americans', 'NORP'],
#   ['Treasury', 'ORG'],
#   ['China', 'GPE'],
#   ['US', 'GPE'],
#   ['China', 'GPE'],
#   ['US', 'GPE'],
#   ['the U.S. International Trade Commission DataWeb', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['China', 'GPE'],
#   ['US', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['US', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['China', 'GPE'],
#   ['Customs', 'ORG'],
#   ['Border Protection', 'ORG'],
#   ['China', 'GPE'],
#   ['China', 'GPE'],
#   ['American', 'NORP'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['China', 'GPE'],
#   ['China', 'GPE'],
#   ['Monroe', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['China', 'GPE'],
#   ['Air Force One', 'PRODUCT'],
#   ['China', 'GPE'],
#   ['ABC', 'ORG'],
#   ['Birmingham', 'GPE'],
#   ['Alabama', 'GPE'],
#   ['China', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Trump', 'PRODUCT'],
#   ['the Republican Party', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Ipsos', 'ORG'],
#   ['Reuters', 'ORG'],
#   ['Monmouth University', 'ORG'],
#   ['Republicans', 'NORP'],
#   ['Washington Post-ABC News', 'ORG'],
#   ['Republicans', 'NORP'],
#   ['Gallup', 'ORG'],
#   ['North Carolina', 'GPE'],
#   ['North Carolina', 'GPE'],
#   ['House', 'ORG'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['North Carolina', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['9th District', 'LOC'],
#   ['the 3rd District', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Republican', 'NORP'],
#   ['Greg Murphy', 'PERSON'],
#   ['Choice', 'PERSON'],
#   ['Moon Griffon', 'PERSON'],
#   ['Barack Obama', 'PERSON'],
#   ['Choice', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['the VA MISSION Act', 'LAW'],
#   ['Choice', 'ORG'],
#   ['Obama', 'PERSON'],
#   ['Mitch', 'ORG'],
#   ['Rand', 'PERSON'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Black Voices', 'EVENT'],
#   ['Trump', 'LOC'],
#   ['Russell Wheeler', 'PERSON'],
#   ['the Brookings Institution', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['the Supreme Court', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Wheeler', 'ORG'],
#   ['Obama', 'GPE'],
#   ['George W. Bush', 'PERSON'],
#   ['Bill Clinton', 'PERSON'],
#   ['Medicare', 'ORG'],
#   ['Lexington', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Monroe', 'GPE'],
#   ['Louisiana', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Obamacare', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Republican', 'NORP'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['SE Cupp Unfiltered', 'WORK_OF_ART'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Americans', 'NORP'],
#   ['Jonah Goldberg', 'PERSON'],
#   ['Amy Chua', 'PERSON'],
#   ['Steve Kornacki', 'PERSON'],
#   ['Stevan E. Hobfoll', 'PERSON'],
#   ['Sarah Rose Cavanagh', 'PERSON'],
#   ['America', 'GPE'],
#   ['Democratic', 'NORP'],
#   ['Hillary Clinton', 'PERSON'],
#   ['NRA', 'ORG'],
#   ['Iranians', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Democratic', 'NORP'],
#   ['Joe Biden', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Elizabeth Warren', 'PERSON'],
#   ['Bernie Sanders', 'PERSON'],
#   ['Donald Trump', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['American', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['UCLA', 'ORG'],
#   ['Matthew Lieberman', 'PERSON'],
#   ['"Social: Why Our Brains Are Wired to Connect,"', 'WORK_OF_ART'],
#   ['Tribalism', 'WORK_OF_ART'],
#   ['Christianity', 'ORG'],
#   ['Jesus', 'PERSON'],
#   ['Messiah', 'PERSON'],
#   ['the New York Yankees', 'ORG'],
#   ['the Boston Red Sox', 'ORG'],
#   ['Americans', 'NORP'],
#   ['American', 'NORP'],
#   ['American', 'NORP'],
#   ['the American Journal of Political Science', 'ORG'],
#   ['Peter Hatemi', 'PERSON'],
#   ['American', 'NORP'],
#   ['Barack Obama', 'PERSON'],
#   ['Franklin D. Roosevelt', 'PERSON'],
#   ['John F. Kennedy', 'PERSON'],
#   ['Lyndon B. Johnson', 'PERSON'],
#   ['George W. Bush', 'PERSON'],
#   ['George Washington', 'PERSON'],
#   ['Thomas Fleming', 'PERSON'],
#   ['The Intimate Lives of the Founding Fathers', 'WORK_OF_ART'],
#   ['Washington', 'GPE'],
#   ["George Will's", 'PERSON'],
#   ['"The Conservative Sensibility', 'WORK_OF_ART'],
#   ['Bill Clinton', 'PERSON'],
#   ['George H. W. Bush', 'PERSON'],
#   ['Ross Perot', 'PERSON'],
#   ['American', 'NORP'],
#   ['Republican', 'NORP'],
#   ['Democrat', 'NORP'],
#   ['Aaron Sorkin', 'PERSON'],
#   ['Donald Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['America', 'GPE'],
#   ['Max Roser', 'PERSON'],
#   ['Oxford University', 'ORG'],
#   ['The Short History of Global Living Conditions and Why It Matters That We Know It',
#    'WORK_OF_ART'],
#   ['the United States', 'GPE'],
#   ['the United States', 'GPE'],
#   ['Washington', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['House', 'ORG'],
#   ['Nancy Pelosi', 'PERSON'],
#   ['America', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['South African', 'NORP'],
#   ['Kruger National Park', 'FAC'],
#   ['Swiss', 'NORP'],
#   ['Giraffes', 'PERSON'],
#   ['South African', 'NORP'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Wham', 'PERSON'],
#   ['Paul Feig', 'PERSON'],
#   ['David Livingstone', 'PERSON'],
#   ['Hollywood', 'GPE'],
#   ['Emilia Clarke', 'PERSON'],
#   ['Henry Golding', 'PERSON'],
#   ['Kate', 'PERSON'],
#   ['Golding', 'PERSON'],
#   ['Tom', 'PERSON'],
#   ['Livingstone', 'PERSON'],
#   ['UK', 'GPE'],
#   ["George Michael's", 'PERSON'],
#   ['Stevie Wonder', 'ORG'],
#   ['George Michael', 'PERSON'],
#   ['Wham', 'PERSON'],
#   ['Last Christmas', 'WORK_OF_ART'],
#   ['Livingstone', 'ORG'],
#   ['Michael', 'PERSON'],
#   ['Emma Thompson', 'PERSON'],
#   ['Livingstone', 'ORG'],
#   ['Michael', 'PERSON'],
#   ['Thompson', 'ORG'],
#   ['Livingstone', 'ORG'],
#   ['Thompson', 'ORG'],
#   ['Emma', 'ORG'],
#   ['Golding', 'PERSON'],
#   ['Tom', 'PERSON'],
#   ['Clarke', 'PERSON'],
#   ['Kate', 'PERSON'],
#   ['Paul Feig', 'PERSON'],
#   ['Feig', 'ORG'],
#   ['Vulture', 'ORG'],
#   ['Emma Thompson', 'PERSON'],
#   ['Emilia', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Impeachment Watch', 'ORG'],
#   ['Bill Taylor', 'PERSON'],
#   ['Vietnam', 'GPE'],
#   ['Congress', 'ORG'],
#   ['Robert Mueller', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['the US Embassy', 'ORG'],
#   ['Ukraine', 'GPE'],
#   ['State Department', 'ORG'],
#   ['George Kent', 'PERSON'],
#   ['Mueller', 'PERSON'],
#   ['Russia', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['US', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['US', 'GPE'],
#   ['the European Union Gordon Sondland', 'ORG'],
#   ['Ukrainians', 'NORP'],
#   ['US', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['George W. Bush', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Kent', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Jim Jordan', 'PERSON'],
#   ['Ohio', 'GPE'],
#   ['Republicans', 'NORP'],
#   ['Impeachment Watch', 'ORG'],
#   ['David Chalian', 'PERSON'],
#   ['Carrie Cordero', 'PERSON'],
#   ['Molly Ball', 'PERSON'],
#   ['Chris Cillizza', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Kevin Liptak', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Jordan', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Kent', 'PERSON'],
#   ['White House', 'ORG'],
#   ['Ukrainian', 'NORP'],
#   ['Volodymyr Zelensky', 'PERSON'],
#   ['Donald Trump', 'PERSON'],
#   ['White House', 'ORG'],
#   ['Jordan', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Russia', 'GPE'],
#   ['Jordan', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'LOC'],
#   ['Ukraine', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Congress', 'ORG'],
#   ['Taylor', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['CNN', 'ORG'],
#   ['Zelensky', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Sondland', 'ORG'],
#   ['White House', 'ORG'],
#   ['Turkish', 'NORP'],
#   ['Recep Tayyip Erdogan', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Sondland', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Senate', 'ORG'],
#   ['House', 'ORG'],
#   ['Senate', 'ORG'],
#   ['House', 'ORG'],
#   ['Juleanna Glover', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Politico', 'PRODUCT'],
#   ['Capitol Hill', 'ORG'],
#   ['Republican', 'NORP'],
#   ['Trump', 'LOC'],
#   ['Glover', 'ORG'],
#   ['Senate', 'ORG'],
#   ['Mitch McConnell', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['White House', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['Marie Yovanovitch', 'PERSON'],
#   ['US', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['David Holmes', 'PERSON'],
#   ['Mark Sandy', 'PERSON'],
#   ['Office of Management and Budget', 'ORG'],
#   ['US', 'GPE'],
#   ['Democrats', 'NORP'],
#   ['American', 'NORP'],
#   ['US', 'GPE'],
#   ['US', 'GPE'],
#   ['CNN', 'ORG'],
#   ['Impeachment Tracker', 'PERSON'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Kentucky', 'GPE'],
#   ['Republican', 'NORP'],
#   ['Matt Bevin', 'PERSON'],
#   ['Democratic', 'NORP'],
#   ['Andy Beshear', 'PERSON'],
#   ['Beshear', 'PERSON'],
#   ['Lillie Ruschell', 'PERSON'],
#   ['Kentucky', 'GPE'],
#   ['Kentucky', 'GPE'],
#   ['Bevin', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['WKYT', 'ORG'],
#   ['Beshear', 'PRODUCT'],
#   ['Bevin', 'PERSON'],
#   ['General Assembly', 'ORG'],
#   ['Assembly', 'ORG'],
#   ['Bevin', 'PERSON'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Washington', 'GPE'],
#   ['CNN', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['the Federal Emergency Management Agency', 'ORG'],
#   ['Pete Gaynor', 'PERSON'],
#   ['FEMA', 'ORG'],
#   ['Tom Carper', 'PERSON'],
#   ['Democrat', 'NORP'],
#   ['Delaware', 'GPE'],
#   ['Carper', 'PERSON'],
#   ['Carper', 'PERSON'],
#   ['Hurricane Dorian', 'NORP'],
#   ['Bahamas', 'GPE'],
#   ['FEMA', 'ORG'],
#   ['US', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Washington', 'GPE'],
#   ['CNN', 'ORG'],
#   ['House', 'ORG'],
#   ['Donald Trump', 'PERSON'],
#   ['America', 'GPE'],
#   ['Trump', 'LOC'],
#   ['Ukraine', 'GPE'],
#   ['Democrats', 'NORP'],
#   ['US', 'GPE'],
#   ['Adam Schiff', 'PERSON'],
#   ['California', 'GPE'],
#   ['Democrat', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['US', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Bill Taylor', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['US', 'GPE'],
#   ['the European Union Gordon Sondland', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Sondland', 'ORG'],
#   ['Joe Biden', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['Volodymyr Zelensky', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'WORK_OF_ART'],
#   ['the White House', 'FAC'],
#   ['Republican', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Biden', 'LOC'],
#   ['Trump', 'PERSON'],
#   ['Sondland', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Sondland', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['George Kent', 'PERSON'],
#   ['European', 'NORP'],
#   ['Eurasian Affairs', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Biden', 'LOC'],
#   ['Trump', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Democratic', 'NORP'],
#   ['GOP', 'ORG'],
#   ['Democrats', 'NORP'],
#   ['Trump', 'PERSON'],
#   ["Robert Mueller's", 'PERSON'],
#   ['Russia', 'GPE'],
#   ['Democrats', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['GOP', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'LOC'],
#   ['Republican', 'NORP'],
#   ['Richard Nixon', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Fox News', 'ORG'],
#   ['GOP', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Washington', 'GPE'],
#   ['Republican', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['House', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Ohio', 'GPE'],
#   ['Jim Jordan', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['the United States', 'GPE'],
#   ['GOP', 'ORG'],
#   ['Republican', 'NORP'],
#   ['Stephen Castor', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ["Rudy Giuliani's", 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Washington', 'GPE'],
#   ['Maricopa County', 'GPE'],
#   ['Arizona', 'GPE'],
#   ['the Republican Party', 'ORG'],
#   ['Trump', 'LOC'],
#   ["Boyce O'Brien", 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Phoenix', 'GPE'],
#   ['GOP', 'ORG'],
#   ['Christian', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['CNN', 'ORG'],
#   ['Kyung Lah', 'PERSON'],
#   ['Kent Jeffers', 'PERSON'],
#   ['Wisconsinite', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Mueller', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ["Biden'", 'ORG'],
#   ['Ukraine', 'GPE'],
#   ['Democratic', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['America', 'GPE'],
#   ['Russian', 'NORP'],
#   ['US', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Sondland', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Biden', 'LOC'],
#   ['Ukraine', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Kent', 'PERSON'],
#   ['the Foreign Service', 'ORG'],
#   ['House', 'ORG'],
#   ['Vietnam War', 'EVENT'],
#   ['Kiev', 'PERSON'],
#   ['Marie "Masha" Yovanovitch, Taylor', 'PERSON'],
#   ['Kent', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['World War II', 'EVENT'],
#   ['America', 'GPE'],
#   ['Europe', 'LOC'],
#   ['Kent', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['"America First"', 'WORK_OF_ART'],
#   ['Devin Nunes', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Americans', 'NORP'],
#   ['California', 'GPE'],
#   ['Republican', 'NORP'],
#   ['America', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Turkish', 'NORP'],
#   ['Recep Tayyip Erdoğan', 'PERSON'],
#   ['Erdoğan', 'ORG'],
#   ['America', 'GPE'],
#   ['Kurdish', 'NORP'],
#   ['Syria', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['US', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Erdoğan', 'ORG'],
#   ['Turkey', 'GPE'],
#   ['Schiff', 'ORG'],
#   ['Trump', 'LOC'],
#   ['the United States', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['German', 'NORP'],
#   ['Instagram', 'NORP'],
#   ['Michael Rehaag', 'PERSON'],
#   ['Bochum', 'GPE'],
#   ['CNN', 'ORG'],
#   ['German', 'NORP'],
#   ['Instagram', 'NORP'],
#   ['Rehaag', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Rehaag', 'WORK_OF_ART'],
#   ['hygiene ordinance', 'PERSON'],
#   ['Rehaag', 'PERSON'],
#   ['Bochum', 'NORP'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['New York', 'GPE'],
#   ['CNN Busines', 'ORG'],
#   ['Twinkies', 'ORG'],
#   ['the United States', 'GPE'],
#   ['Hostess', 'PERSON'],
#   ['Twinkies Cereal', 'ORG'],
#   ['Josh Jans', 'PERSON'],
#   ['Post', 'ORG'],
#   ['Twinkies', 'ORG'],
#   ['the Great Depression', 'EVENT'],
#   ['Hostess', 'PERSON'],
#   ['Hostess Brands', 'ORG'],
#   ['Gores Group', 'ORG'],
#   ['Twinkies', 'ORG'],
#   ['Hostess', 'ORG'],
#   ['Hostess and Post', 'ORG'],
#   ['Hostess', 'ORG'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Washington', 'GPE'],
#   ['CNN', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Jared Kushner', 'PERSON'],
#   ['Donald Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Don Jr.', 'PERSON'],
#   ['The New York Times', 'ORG'],
#   ['the White House', 'FAC'],
#   ['Instagram', 'NORP'],
#   ['White House', 'ORG'],
#   ['Mick Mulvaney', 'PERSON'],
#   ['the White House', 'ORG'],
#   ['Florida', 'GPE'],
#   ['Pam Bondi', 'PERSON'],
#   ['Treasury Department', 'ORG'],
#   ['Tony Sayegh', 'PERSON'],
#   ['Bondi', 'GPE'],
#   ['State Department', 'ORG'],
#   ['Morgan Ortagus', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Ohio', 'GPE'],
#   ['Jim Jordan', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['US', 'GPE'],
#   ['Kiev', 'GPE'],
#   ['Bill Taylor', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump Jr.', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Kevin McCarthy', 'PERSON'],
#   ['Matt Gaetz', 'PERSON'],
#   ['Mark Meadows', 'PERSON'],
#   ['Sebastian Gorka', 'PERSON'],
#   ['Rand Paul', 'PERSON'],
#   ['Sean Spicer', 'PERSON'],
#   ['Jerry Falwell Jr.', 'PERSON'],
#   ['Linda McMahon', 'PERSON'],
#   ['Commerce', 'ORG'],
#   ['Wilbur Ross', 'PERSON'],
#   ['Kushner', 'PERSON'],
#   ['book,"(it', 'PERSON'],
#   ['Don', 'PERSON'],
#   ['Gorka', 'ORG'],
#   ['Falwell Jr. Trump Jr.', 'ORG'],
#   ['Kimberly Guilfoyle', 'PERSON'],
#   ['Kushner', 'PERSON'],
#   ['Washington', 'GPE'],
#   ['Ivanka', 'ORG'],
#   ['Washington', 'GPE'],
#   ['Kushner', 'PERSON'],
#   ['The New York Times', 'ORG'],
#   ['The New York Times Bestseller List', 'ORG'],
#   ['Don', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Julia A. Minson', 'PERSON'],
#   ['Harvard Kennedy School', 'ORG'],
#   ['Charles A. Dorison', 'PERSON'],
#   ['Todd Rogers', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Americans', 'NORP'],
#   ['Donald Trump', 'PERSON'],
#   ['Americans', 'NORP'],
#   ['Hillary Clinton', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Clinton', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Americans', 'NORP'],
#   ['Trump', 'LOC'],
#   ['conservatives', 'NORP'],
#   ['Ted Cruz', 'PERSON'],
#   ['Bernie Sanders', 'PERSON'],
#   ['Cruz', 'PERSON'],
#   ['Sanders', 'NORP'],
#   ['Fox News', 'ORG'],
#   ['NPR', 'ORG'],
#   ['Jeremy Frimer', 'PERSON'],
#   ['Linda Skitka', 'PERSON'],
#   ['Matt Motyl', 'PERSON'],
#   ['Cognition', 'PRODUCT'],
#   ['Trump', 'PRODUCT'],
#   ['Clinton', 'PERSON'],
#   ['Cruz', 'PERSON'],
#   ['Sanders', 'ORG'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Hurricane Dorian', 'NORP'],
#   ['Dorian', 'NORP'],
#   ['North Carolina', 'GPE'],
#   ['the Outer Banks', 'ORG'],
#   ['North Carolina', 'GPE'],
#   ['Cedar Island', 'LOC'],
#   ['Cape Lookout National Seashore park', 'FAC'],
#   ['Core Banks', 'ORG'],
#   ['B.G. Horvat', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Dorian', 'NORP'],
#   ['Horvat', 'ORG'],
#   ['Cedar Island', 'LOC'],
#   ['Horvat', 'WORK_OF_ART'],
#   ['CNN', 'ORG'],
#   ['Dorian', 'NORP'],
#   ['Horvat', 'ORG'],
#   ['the Core Banks', 'ORG'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['The House Intelligence Committee', 'ORG'],
#   ['Donald Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Joe Biden', 'PERSON'],
#   ['Adam Schiff', 'ORG'],
#   ['Intelligence Committee', 'ORG'],
#   ['Adam Schiff', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Constitution', 'LAW'],
#   ['American', 'NORP'],
#   ['Trump', 'PRODUCT'],
#   ['Congress', 'ORG'],
#   ['Schiff', 'ORG'],
#   ['Founders', 'PERSON'],
#   ['Schiff', 'PERSON'],
#   ['Americans', 'NORP'],
#   ['Constitution', 'LAW'],
#   ['Schiff', 'ORG'],
#   ['Founders', 'PERSON'],
#   ['Constitution three', 'LAW'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'PRODUCT'],
#   ['Schiff', 'PERSON'],
#   ['Schiff', 'ORG'],
#   ['Republicans', 'NORP'],
#   ['Devin Nunes', 'ORG'],
#   ['California', 'GPE'],
#   ['Devin Nunes', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['the Intelligence Committee', 'ORG'],
#   ['Democratic', 'NORP'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['Mueller', 'PERSON'],
#   ['Nunes', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Ukrainian', 'NORP'],
#   ['Volodymyr Zelensky', 'PERSON'],
#   ['House', 'ORG'],
#   ["Bill Taylor's", 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['US', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Rudy Giuliani', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['US', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['John Bolton', 'PERSON'],
#   ['US', 'GPE'],
#   ['the European Union Gordon Sondland', 'ORG'],
#   ['Ukrainian', 'NORP'],
#   ['US', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Burisma Holdings', 'ORG'],
#   ['Ukrainian', 'NORP'],
#   ['Hunter Biden', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Sondland', 'ORG'],
#   ['Taylor', 'PERSON'],
#   ['Zelensky', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Taylor', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Sondland', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Biden', 'LOC'],
#   ['Trump', 'LOC'],
#   ['Ukraine', 'GPE'],
#   ['Congress', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Bidens', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['George Kent', 'PERSON'],
#   ['State Department', 'ORG'],
#   ['Taylor', 'PERSON'],
#   ['Donbass', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['American', 'NORP'],
#   ['Russian', 'NORP'],
#   ['Kent', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['America', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Russia', 'GPE'],
#   ['Russia', 'GPE'],
#   ['Crimea', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Kent', 'PERSON'],
#   ['the White House', 'ORG'],
#   ['Ukraine', 'GPE'],
#   ["the United States'", 'GPE'],
#   ['Russia', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Bidens', 'NORP'],
#   ['Ukraine', 'GPE'],
#   ['American', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['White House', 'ORG'],
#   ['Mick Mulvaney', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['the White House', 'FAC'],
#   ['Taylor', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Democratic', 'NORP'],
#   ['Republican', 'NORP'],
#   ['Mulvaney', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Kent', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Nunes', 'PERSON'],
#   ['Ukrainians', 'NORP'],
#   ['Democratic', 'NORP'],
#   ["Hillary Clinton's", 'PERSON'],
#   ["Democratic National Committee's", 'ORG'],
#   ['Zelensky', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['US', 'GPE'],
#   ['Kent', 'PERSON'],
#   ['National Security Council', 'ORG'],
#   ['Russia', 'GPE'],
#   ['Fiona Hill', 'PERSON'],
#   ['House', 'ORG'],
#   ['White House', 'ORG'],
#   ['Tom Bossert', 'PERSON'],
#   ['ABC', 'ORG'],
#   ['George Stephanopoulos', 'PERSON'],
#   ['Giuliani', 'PERSON'],
#   ['George', 'PERSON'],
#   ['Devin Nunes', 'ORG'],
#   ['Republicans', 'NORP'],
#   ['Yawn', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['White House', 'ORG'],
#   ['Stephanie Grisham', 'PERSON'],
#   ['Snoozefest', 'PERSON'],
#   ['Eric Trump', 'PERSON'],
#   ['North Carolina', 'GPE'],
#   ['Mark Meadows', 'PERSON'],
#   ['White House', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Lauren Fox', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Jim Jordan', 'PERSON'],
#   ['House', 'ORG'],
#   ['Republicans', 'NORP'],
#   ['Ohio', 'GPE'],
#   ['Jim Jordan', 'PERSON'],
#   ['the Intelligence Committee', 'ORG'],
#   ['Jordan', 'PERSON'],
#   ['Jordan', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Jordan', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['GOP', 'ORG'],
#   ['Taylor', 'PERSON'],
#   ['Kent', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Bidens', 'GPE'],
#   ['Jordan', 'PERSON'],
#   ['Texas', 'GPE'],
#   ['John Ratcliffe', 'PERSON'],
#   ['New York', 'GPE'],
#   ['Elise Stefanik', 'PERSON'],
#   ['Congress', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['Jordan', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Missouri', 'GPE'],
#   ['Narwhal', 'PERSON'],
#   ['Narwhal the Little Magical Furry Unicorn', 'WORK_OF_ART'],
#   ['Mac', 'PERSON'],
#   ['Narwhal', 'PERSON'],
#   ["Mac's Mission", 'ORG'],
#   ['Narwhal', 'PERSON'],
#   ['Poppa Smurf', 'PERSON'],
#   ['a Daschund Terrier', 'PERSON'],
#   ['Narwhal', 'ORG'],
#   ['Daschund', 'PERSON'],
#   ['Mac', 'PERSON'],
#   ['CNN Narwhal', 'ORG'],
#   ['Missouri', 'GPE'],
#   ['Midwest', 'LOC'],
#   ['Mac', 'PERSON'],
#   ['Narwhal', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Narwhal', 'PERSON'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['New York', 'GPE'],
#   ['CNN Business', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Fox News', 'ORG'],
#   ['White House', 'ORG'],
#   ['Stephanie Grisham', 'PERSON'],
#   ['Donald Trump Jr.', 'PERSON'],
#   ['Jeff Sessions', 'PERSON'],
#   ['Fox', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Republican', 'NORP'],
#   ['Democrat', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Oliver Darcy', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Darcy', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Fox News', 'ORG'],
#   ['Tucker', 'PERSON'],
#   ['Tucker Carlson', 'PERSON'],
#   ["New Year's", 'EVENT'],
#   ['the Super Bowl', 'EVENT'],
#   ['Carlson', 'ORG'],
#   ['Grisham', 'PERSON'],
#   ['Christian Whiton', 'PERSON'],
#   ['Bill Taylor', 'PERSON'],
#   ['George Kent', 'PERSON'],
#   ['Grisham', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Carlson', 'ORG'],
#   ["Larry O'Connor", 'PERSON'],
#   ['America', 'GPE'],
#   ['Trish Regan', 'PERSON'],
#   ['the Fox Business Network', 'ORG'],
#   ['Regan', 'PERSON'],
#   ['Fox News', 'ORG'],
#   ['Carlson', 'ORG'],
#   ['Washington', 'GPE'],
#   ['D.C.', 'GPE'],
#   ['Sean Hannity', 'PERSON'],
#   ['THE WORST SHOW ON EARTH', 'WORK_OF_ART'],
#   ['Democrats', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['House Intelligence Committee', 'ORG'],
#   ['Adam Schiff', 'PERSON'],
#   ['Hannity', 'ORG'],
#   ['House', 'ORG'],
#   ['Democrats', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Hannity', 'WORK_OF_ART'],
#   ['Hannity', 'ORG'],
#   ['Mark Levin', 'PERSON'],
#   ['boob', 'PERSON'],
#   ['Donald Trump Jr.', 'PERSON'],
#   ['Steve Scalise', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Ed Henry', 'PERSON'],
#   ['Laura Ingraham', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Ingraham', 'ORG'],
#   ['Fox', 'ORG'],
#   ['Ed Henry', 'PERSON'],
#   ['Capitol Hill', 'ORG'],
#   ['Henry', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['THEY', 'ORG'],
#   ['Democrats', 'NORP'],
#   ['Henry', 'PERSON'],
#   ['Dem', 'NORP'],
#   ['the Washington Post', 'ORG'],
#   ['Ingraham', 'PERSON'],
#   ['Fox', 'ORG'],
#   ['DEMOCRATS', 'NORP'],
#   ["DEMS' IMPEACHMENT COLLAPSE", 'WORK_OF_ART'],
#   ['Ingraham', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Chris Stewart', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Gordon Sondland', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Fox', 'ORG'],
#   ['GOP', 'ORG'],
#   ['Mark Meadows', 'PERSON'],
#   ['Ingraham', 'ORG'],
#   ['Democrats', 'NORP'],
#   ['Ukraine', 'GPE'],
#   ['America', 'GPE'],
#   ['Fox', 'ORG'],
#   ['the "IMPEACHMENT STUNT WILL HAUNT', 'ORG'],
#   ['MSNBC', 'ORG'],
#   ['Republican', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Fox', 'PERSON'],
#   ['GOP', 'ORG'],
#   ['Dems', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Dems', 'NORP'],
#   ['Notes', 'PRODUCT'],
#   ['Fox', 'ORG'],
#   ['Fox News', 'WORK_OF_ART'],
#   ["Chris Wallace's", 'PERSON'],
#   ['William Taylor', 'PERSON'],
#   ['The Hill', 'WORK_OF_ART'],
#   ['Lou Dobbs', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Joe diGenova', 'PERSON'],
#   ['Victoria Toensing', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ["George Soros '", 'PERSON'],
#   ['the State Department', 'ORG'],
#   ['FBI', 'ORG'],
#   ['Republican', 'NORP'],
#   ['Americans', 'NORP'],
#   ['Susan Glasser', 'PERSON'],
#   ['New Yorker', 'PERSON'],
#   ['Frank Pallotta', 'PERSON'],
#   ['Jimmy Kimmel', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Darcy', 'PERSON'],
#   ['Oliver Darcy', 'PERSON'],
#   ['pro-Trump', 'PERSON'],
#   ['GOP', 'ORG'],
#   ['Jim Jordan', 'PERSON'],
#   ['Devin Nunes', 'ORG'],
#   ['Taylor', 'PERSON'],
#   ['Kent', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'LOC'],
#   ['Democrats', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ["Kelly Clarkson's", 'PERSON'],
#   ['Aquaman', 'WORK_OF_ART'],
#   ['Jason Momoa', 'PERSON'],
#   ['The Kelly Clarkson Show', 'WORK_OF_ART'],
#   ['Remington Blackstock', 'PERSON'],
#   ['River Blackstock', 'PERSON'],
# ...
#   ['Tom Carper', 'PERSON'],
#   ['Delaware', 'GPE'],
#   ['Bob Casey', 'PERSON'],
#   ['Pennsylvania', 'GPE'],
#   ['Doug Jones', 'PERSON'],
#   ['Alabama', 'GPE'],
#   ['Democratic', 'NORP'],
#   ['Lisa Blunt Rochester', 'PERSON'],
#   ['Delaware', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Bill Taylor', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Capitol Hill', 'ORG'],
#   ['Donald Trump', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['US', 'GPE'],
#   ['the European Union Gordon Sondland', 'ORG'],
#   ['Ukrainians', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Sondland', 'ORG'],
#   ['Joe', 'PERSON'],
#   ['Hunter Biden', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['House Intelligence Committee', 'ORG'],
#   ['Adam Schiff', 'PERSON'],
#   ['California', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['US', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'LOC'],
#   ['Rudy Giuliani', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['the United States', 'GPE'],
#   ['Republicans', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Trump', 'LOC'],
#   ['Ukraine', 'GPE'],
#   ['GOP', 'ORG'],
#   ['Ohio', 'GPE'],
#   ['Jim Jordan', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['the US Military Academy', 'ORG'],
#   ['West Point', 'LOC'],
#   ['Vietnam', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['House', 'ORG'],
#   ['Taylor', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Taylor', 'PERSON'],
#   ['Trump', 'LOC'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Washington', 'GPE'],
#   ['CNN', 'ORG'],
#   ['Bill Taylor', 'PERSON'],
#   ['US', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Donald Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['EU', 'ORG'],
#   ['Gordon Sondland', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['Volodymyr Zelensky', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Sondland', 'PERSON'],
#   ['Sondland', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Ukrainians', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Sondland', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Joe Biden', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Ukrainians', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Republicans', 'NORP'],
#   ['Capitol Hill', 'ORG'],
#   ['Democratic', 'NORP'],
#   ['Adam Schiff', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Devin Nunes', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Democratic', 'NORP'],
#   ['Republican', 'NORP'],
#   ['Republican', 'NORP'],
#   ['House', 'ORG'],
#   ['Democratic', 'NORP'],
#   ['Raja Krishnamoorthi', 'PERSON'],
#   ['Krishnamoorthi', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Adam Schiff', 'PERSON'],
#   ['Democrats', 'NORP'],
#   ['Schiff', 'ORG'],
#   ['Schiff', 'ORG'],
#   ['Taylor', 'PERSON'],
#   ['Democratic', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Peter Welch', 'PERSON'],
#   ['Donald Trump', 'PERSON'],
#   ['Republicans', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Chris Stewart', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Turkish', 'NORP'],
#   ['Recep Tayyip Erdoğan', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Jim Jordan', 'PERSON'],
#   ['GOP', 'ORG'],
#   ['Intelligence', 'ORG'],
#   ['Trump', 'LOC'],
#   ['Jordan', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Sondland', 'PERSON'],
#   ['Jordan', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Morrison', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Morrison', 'PERSON'],
#   ['Yermak', 'PERSON'],
#   ['Pence', 'PERSON'],
#   ['Warsaw', 'GPE'],
#   ['Zelensky', 'PERSON'],
#   ['Jordan', 'PERSON'],
#   ['Jordan', 'PERSON'],
#   ['House', 'ORG'],
#   ['Republican', 'NORP'],
#   ['CNN', 'ORG'],
#   ['Republican', 'NORP'],
#   ['Elise Stefanik', 'PERSON'],
#   ['GOP', 'ORG'],
#   ['Ukraine', 'GPE'],
#   ['Bidens', 'NORP'],
#   ['Capitol Hill', 'ORG'],
#   ['Republican', 'NORP'],
#   ['Chris Stewart', 'PERSON'],
#   ['Mike Quigley', 'PERSON'],
#   ['Democrat', 'NORP'],
#   ['American', 'NORP'],
#   ['Quigley', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Republicans', 'NORP'],
#   ['Washington', 'GPE'],
#   ['Adam Schiff', 'PERSON'],
#   ['Nancy Pelosi', 'PERSON'],
#   ['Steve Scalise', 'PERSON'],
#   ['Republican', 'NORP'],
#   ['Senate', 'ORG'],
#   ['Republicans', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['GOP', 'ORG'],
#   ['Senate', 'ORG'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['California', 'GPE'],
#   ['Tushar Atre', 'ORG'],
#   ["the Santa Cruz County Sheriff's Office", 'ORG'],
#   ['CNN', 'ORG'],
#   ['KPIX', 'ORG'],
#   ["Santa Cruz County Sheriff's", 'GPE'],
#   ['Facebook', 'ORG'],
#   ['BMW SUV', 'ORG'],
#   ['Atre', 'PERSON'],
#   ['KPIX', 'ORG'],
#   ['Christopher Lochhead', 'PERSON'],
#   ['Facebook', 'ORG'],
#   ['FBI', 'ORG'],
#   ['Tushar', 'GPE'],
#   ["Santa Cruz Sheriff's", 'GPE'],
#   ['BMW', 'ORG'],
#   ['Atre', 'PERSON'],
#   ['KPIX', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Lochhead', 'ORG'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Massachusetts', 'GPE'],
#   ['Deval Patrick', 'PERSON'],
#   ['flux', 'GPE'],
#   ['Patrick', 'PERSON'],
#   ['Democratic', 'NORP'],
#   ['New Hampshire', 'GPE'],
#   ['state', 'ORG'],
#   ['Patrick', 'PERSON'],
#   ['Patrick', 'PERSON'],
#   ['Alabama', 'GPE'],
#   ['Arkansas', 'GPE'],
#   ['New Hampshire', 'GPE'],
#   ['Patrick', 'PERSON'],
#   ['Massachusetts', 'GPE'],
#   ['New Hampshire', 'GPE'],
#   ['African American', 'NORP'],
#   ['South Carolina', 'GPE'],
#   ['Democratic', 'NORP'],
#   ['CNN', 'ORG'],
#   ['Patrick', 'PERSON'],
#   ["the Democratic Party's", 'ORG'],
#   ['New York City', 'GPE'],
#   ['Michael Bloomberg', 'PERSON'],
#   ['Patrick', 'PERSON'],
#   ['The New York Times', 'ORG'],
#   ['Patrick', 'PERSON'],
#   ['Boston', 'GPE'],
#   ['Barack Obama', 'PERSON'],
#   ['Diane', 'PERSON'],
#   ['Patrick', 'PERSON'],
#   ['WBUR', 'PERSON'],
#   ['Diane', 'PERSON'],
#   ['Thanksgiving', 'EVENT'],
#   ['Patrick', 'PERSON'],
#   ['Bain Capital', 'ORG'],
#   ['Boston', 'GPE'],
#   ['Republican', 'NORP'],
#   ['Mitt Romney', 'PERSON'],
#   ['Massachusetts', 'GPE'],
#   ['US', 'GPE'],
#   ['Utah', 'GPE'],
#   ['Patrick', 'PERSON'],
#   ['Romney', 'ORG'],
#   ['Democratic', 'NORP'],
#   ['Democrats', 'NORP'],
#   ['Patrick', 'PERSON'],
#   ['Bain Capital', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Patrick', 'PERSON'],
#   ['South Carolina', 'GPE'],
#   ['Texas', 'GPE'],
#   ['New Jersey', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['US', 'GPE'],
#   ['the US Centers for Disease Control and Prevention', 'ORG'],
#   ['CDC', 'ORG'],
#   ['Robert R. Redfield', 'PERSON'],
#   ['US', 'GPE'],
#   ['lesbian', 'GPE'],
#   ['Midwest', 'LOC'],
#   ['South', 'LOC'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Entertainment Tonight', 'WORK_OF_ART'],
#   ['the Country Music Association Awards', 'ORG'],
#   ['Carey Hart', 'PERSON'],
#   ['Willow', 'PERSON'],
#   ['Jameson', 'ORG'],
#   ['Love Me Anyway', 'WORK_OF_ART'],
#   ['Chris Stapleton', 'PERSON'],
#   ['Willow', 'PERSON'],
#   ['Jameson', 'ORG'],
#   ['Carey', 'PERSON'],
#   ['Hart', 'ORG'],
#   ['Billboard', 'PERSON'],
#   ['Pink', 'ORG'],
#   ['Beautiful Trauma Tour', 'ORG'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Donald Trump', 'PERSON'],
#   ['US', 'GPE'],
#   ['Ukrainian', 'NORP'],
#   ['Volodymyr Zelensky', 'PERSON'],
#   ['Joe Biden', 'PERSON'],
#   ['Democratic', 'NORP'],
#   ['Zelensky', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Zelensky', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Russian', 'NORP'],
#   ['US', 'GPE'],
#   ['Western', 'NORP'],
#   ['Zelensky', 'PERSON'],
#   ['US', 'GPE'],
#   ['Donald Trump', 'PERSON'],
#   ["Rudy Giuliani's", 'PERSON'],
#   ['The New York Times', 'ORG'],
#   ['Hunter Biden', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['Burisma', 'PRODUCT'],
#   ['US', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Rudy Giuliani', 'PERSON'],
#   ['Ukrainians', 'NORP'],
#   ['Ukrainian', 'NORP'],
#   ['Yuriy Lutsenko', 'PERSON'],
#   ['New York', 'GPE'],
#   ['Giuliani', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['White House', 'ORG'],
#   ['US', 'GPE'],
#   ['Ukrainian', 'GPE'],
#   ['Trump', 'PRODUCT'],
#   ['Zelensky', 'PERSON'],
#   ['White House', 'ORG'],
#   ['State Department', 'ORG'],
#   ['Ukrainian', 'NORP'],
#   ['White House', 'ORG'],
#   ['Mick Mulvaney', 'PERSON'],
#   ['Fiona Hill', 'PERSON'],
#   ['National Security Council', 'ORG'],
#   ['Russia', 'GPE'],
#   ['John Bolton', 'PERSON'],
#   ['National Security Council', 'ORG'],
#   ['Ukraine', 'GPE'],
#   ['Alexander Vindman', 'PERSON'],
#   ['the European Union Gordon Sondland', 'ORG'],
#   ['Ukraine', 'GPE'],
#   ['Mulvaney', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['the White House Office of Management and Budget', 'ORG'],
#   ['Congress', 'ORG'],
#   ['Ukraine', 'GPE'],
#   ['Laura Cooper', 'PERSON'],
#   ['Pentagon', 'ORG'],
#   ['Russia', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['the White House', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Zelensky', 'PERSON'],
#   ['Burisma', 'PRODUCT'],
#   ['Bidens', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Donald Trump', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['Ukraine', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['USA', 'GPE'],
#   ['the White House', 'ORG'],
#   ['Vindman', 'ORG'],
#   ['Zelensky', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['US', 'GPE'],
#   ['Ukraine Kurt Volker', 'PERSON'],
#   ['Sondland', 'NORP'],
#   ['Zelensky', 'GPE'],
#   ['Kiev', 'GPE'],
#   ['Zelensky', 'PERSON'],
#   ['Volker', 'PERSON'],
#   ['Sondland', 'ORG'],
#   ['Ukrainian', 'NORP'],
#   ['Trump', 'PRODUCT'],
#   ['Zelensky', 'GPE'],
#   ['Bill Taylor', 'PERSON'],
#   ['US', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Sondland', 'NORP'],
#   ['Trump', 'PRODUCT'],
#   ['Taylor', 'PERSON'],
#   ['Pentagon', 'ORG'],
#   ['Cooper', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Congress', 'ORG'],
#   ['Giuliani', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['Trump', 'LOC'],
#   ['Zelensky', 'GPE'],
#   ['Giuliani', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['Andriy Yermak', 'PERSON'],
#   ['Madrid', 'GPE'],
#   ['Giuliani', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Yermak', 'PERSON'],
#   ['Volker', 'PERSON'],
#   ['Politico', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Yermak', 'GPE'],
#   ['Mike Pence', 'PERSON'],
#   ['Zelensky', 'GPE'],
#   ['Warsaw', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['White House', 'ORG'],
#   ['Sondland', 'ORG'],
#   ['Taylor', 'PERSON'],
#   ['Trump', 'LOC'],
#   ['Ukrainians', 'NORP'],
#   ['Taylor', 'PERSON'],
#   ['Sondland', 'PERSON'],
#   ['Taylor', 'PERSON'],
#   ['Ukraine', 'GPE'],
#   ['Michael Atkinson', 'PERSON'],
#   ['House', 'ORG'],
#   ['Adam Schiff', 'PERSON'],
#   ['Devin Nunes', 'PERSON'],
#   ['Joseph Maguire', 'PERSON'],
#   ['Congress', 'ORG'],
#   ['House', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Giuliani', 'PERSON'],
#   ['Ukrainian', 'NORP'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['White House', 'ORG'],
#   ['Ukraine', 'GPE'],
#   ['The White House', 'ORG'],
#   ['Ukraine', 'GPE'],
#   ['Ukraine', 'GPE'],
#   ['Taylor', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['CNN', 'ORG'],
#   ['Fareed Zakaria', 'PERSON'],
#   ['House', 'ORG'],
#   ['Nancy Pelosi', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Zelensky', 'PERSON'],
#   ['House', 'ORG'],
#   ['Nancy Pelosi', 'PERSON'],
#   ['House', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Ukraine', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['CNN', 'ORG'],
#   ['The Lead', 'WORK_OF_ART'],
#   ['Jake Tapper', 'PERSON'],
#   ['Americans', 'NORP'],
#   ['House Intelligence', 'ORG'],
#   ['Adam Schiff', 'PERSON'],
#   ['Wisconsin', 'GPE'],
#   ['GOP', 'ORG'],
#   ['Jim Jordan', 'PERSON'],
#   ['Devin Nunes', 'ORG'],
#   ['Americans', 'NORP'],
#   ['Trump', 'PRODUCT'],
#   ['Kent Jeffers', 'PERSON'],
#   ['Cedar Grove', 'GPE'],
#   ['Wisconsin', 'GPE'],
#   ['Phoenix', 'GPE'],
#   ['Democratic', 'NORP'],
#   ['Americans', 'NORP'],
#   ['Donald Trump', 'PERSON'],
#   ['Mueller', 'PERSON'],
#   ['Jeffers', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Russia', 'GPE'],
#   ['Robert Mueller', 'PERSON'],
#   ["Boyce O'Brien", 'PERSON'],
#   ['Phoenix', 'GPE'],
#   ['GOP', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Christian', 'NORP'],
#   ['Republicans', 'NORP'],
#   ["O'Brien", 'PERSON'],
#   ['Trump', 'LOC'],
#   ['Ukraine', 'GPE'],
#   ['David Cronin', 'PERSON'],
#   ['Arizona', 'GPE'],
#   ['Democrat', 'NORP'],
#   ['Republican', 'NORP'],
#   ['Cronin', 'PERSON'],
#   ['American', 'NORP'],
#   ['Democrat', 'NORP'],
#   ['Republican', 'NORP'],
#   ['New Hampshire', 'GPE'],
#   ['American', 'NORP'],
#   ['Ralph Mecheau', 'PERSON'],
#   ['Bow', 'GPE'],
#   ['New Hampshire', 'GPE'],
#   ['Watergate', 'EVENT'],
#   ['Mecheau', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['America', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['Mecheau', 'PERSON'],
#   ['Elizabeth Warren', 'PERSON'],
#   ['Bernie', 'PERSON'],
#   ['Mecheau', 'PERSON'],
#   ['New York', 'GPE'],
#   ['Michael) Bloomberg', 'PERSON'],
#   ['Bernie', 'PERSON'],
#   ['Wisconsin', 'GPE'],
#   ['Randy', 'PERSON'],
#   ['Terri Burl', 'PERSON'],
#   ['Randy Burl', 'PERSON'],
#   ['the Forest County Wisconsin Republican Party', 'ORG'],
#   ['Terri Burl', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Trump', 'PRODUCT'],
#   ['George W. Bush', 'PERSON'],
#   ['Randy Burl', 'PERSON'],
#   ['Trump', 'LOC'],
#   ['Burl', 'PERSON'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['CNN', 'ORG'],
#   ['Southern California', 'LOC'],
#   ["the Los Angeles County Sheriff's Department", 'ORG'],
#   ['Saugus High School', 'ORG'],
#   ['Santa Clarita', 'GPE'],
#   ['Twitter', 'FAC'],
#   ['CNN', 'ORG'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']],
#  [['Washington', 'GPE'],
#   ['CNN', 'ORG'],
#   ['the Trump International Hotel', 'ORG'],
#   ['Washington', 'GPE'],
#   ['the Trump Organization', 'ORG'],
#   ['CNN', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['The Trump Organization', 'ORG'],
#   ['the Old Post Office', 'ORG'],
#   ['the White House', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'LOC'],
#   ['the US Constitution', 'EVENT'],
#   ['the Trump Organization', 'ORG'],
#   ['the US Treasury', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['The Trump Organization', 'ORG'],
#   ['CNN', 'ORG'],
#   ['JLL Hotels & Hospitality', 'ORG'],
#   ['Washington', 'GPE'],
#   ['JLL', 'ORG'],
#   ['the Trump Organization', 'ORG'],
#   ['the General Services Administration', 'ORG'],
#   ['the Trump Organization', 'ORG'],
#   ['the Old Post Office', 'ORG'],
#   ['Trump', 'PERSON'],
#   ['Eric Trump', 'PERSON'],
#   ['Trump', 'PERSON'],
#   ['Eric', 'PERSON'],
#   ['Don Jr', 'PERSON'],
#   ['the Wall Street Journal', 'ORG'],
#   ['Washington', 'GPE'],
#   ['the Rosewood Hotel', 'ORG'],
#   ['Georgetown', 'GPE'],
#   ['Washington', 'GPE'],
#   ['DC', 'GPE'],
#   ['Dan Hawkins', 'PERSON'],
#   ['Berkadia', 'GPE'],
#   ['GSA', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['GSA', 'ORG'],
#   ['Trump', 'PRODUCT'],
#   ['Trump', 'PERSON'],
#   ['Bobby Burchfield', 'PERSON'],
#   ['Washington', 'GPE'],
#   ['Trump', 'LOC'],
#   ['Trump', 'PERSON'],
#   ["the Trump Organization's", 'ORG'],
#   ['Washington', 'GPE'],
#   ['Saudi Arabia', 'GPE'],
#   ['Malaysia', 'GPE'],
#   ['Kuwait', 'GPE'],
#   ['Trump', 'PERSON'],
#   ['GOP', 'ORG'],
#   ['Romania', 'GPE'],
#   ['the Trump Organization', 'ORG'],
#   ['Amazon', 'ORG'],
#   ['Jeff Bezos', 'PERSON'],
#   ['the Washington Post', 'ORG'],
#   ['Amazon', 'ORG'],
#   ['Virginia', 'GPE'],
#   ['Amazon', 'ORG'],
#   ['Washington DC', 'GPE'],
#   ['Cable News Network', 'ORG'],
#   ['Turner Broadcasting System,', 'ORG'],
#   ['CNN', 'ORG'],
#   ['CNN', 'ORG']]]

# %% [markdown]
# ### For every document in the corpus, iterate over every sentence, extract any SVO triples, print them, and compare.

# %%
SVO_results = []

for doc in spacy_docs:
  temp = []
  for sent in doc.sents:
    svo = textacy.extract.subject_verb_object_triples(sent)
    temp += svo
  SVO_results.append(list(set(temp)))

# %%
SVO_results
# Out:
# [[(that, jarred, people),
#   (we, allow, to happen),
#   (Sanders, delivered, punchline),
#   (appeal wane, to play, foil),
#   (aide, told, CNN),
#   (we, tell, Trump),
#   (Sanders, invited, television cameras),
#   (We, don't watch, race),
#   (I, know, that),
#   (supporters, are saying, much),
#   (he, challenged, Clinton),
#   (me, say, it),
#   (I, 'm going, to tell),
#   (that, showed, him),
#   (Mayor Pete Buttigieg, has emerged, foe),
#   (staff, are saying, much),
#   (Iowa caucuses, kick, primary),
#   (we, tell, Trump),
#   (Sanders, decided, give),
#   (I, thank, you),
#   (Sanders, welcomed, news),
#   (nobody, would give, damn),
#   (surveys, show, group jockeying),
#   (I, want, to say),
#   (one, touched, digits),
#   (person, seems, different),
#   (Sanders, welcomed, run),
#   (Sanders, has charted, revival),
#   (backing, bolstered, argument),
#   (Sanders, is taking, source),
#   (South Bend, has emerged, foe),
#   (campaign, attracting, class coalition),
#   (Sanders, began, bid),
#   (manager Faiz Shakir, told, CNN),
#   (Biden, offers, contrast),
#   (pugilist, welcomed, run),
#   (candidate, entered, race),
#   (I, 've got, arteries),
#   (Sanders, injected, some),
#   (campaign, puts, it),
#   (I, use, profane word),
#   (that, has vaulted, him),
#   (Sanders, decided, to stick),
#   (pugilist, welcomed, news),
#   (he, fair, option),
#   (he, can grow, it),
#   (he, expand, base),
#   (CNN poll, showed, Sanders),
#   (others, began, to migrate),
#   (Sanders, invited, reporters),
#   (that, welcomed, him),
#   (he, 's taken, tone),
#   (Sanders, remains, front),
#   (me, say, it),
#   (Sanders, entered, primary),
#   (Cortez, capped, debut)],
#  [(which, could give, opponents),
#   (appeals court, revived, threat),
#   (District, claimed, businesses),
#   (offices, could gather, information),
#   (which, could give, access),
#   (judge panel, had dismissed, lawsuit),
#   (District, claimed, hotels),
#   (US Circuit Court, voted, to rehear),
#   (Trump, had applauded, victory),
#   (General Karl Racine, called, revival),
#   (General Karl Racine, called, significant),
#   (win, killed, lawsuit),
#   (General Brian Frosh, called, revival),
#   (General Brian Frosh, called, significant),
#   (District, claimed, Hotel),
#   (I, won, part)],
#  [(we, don't recognize, party),
#   (those, don't support, views),
#   (Focusing, will bring, us),
#   (Kenja Purkey, took, perspective),
#   (Americans, need, to consider),
#   (leaders, reflect, worst),
#   (I, watched, night),
#   (Nothing, pulled, ties),
#   (I, have had, battles),
#   (we, could afford, house),
#   (We, need, to start),
#   (we, started, talking),
#   (they, risked, lives),
#   (I, try, to ask),
#   (who, support, Trump),
#   (I, hate, liberals),
#   (who, were entering, country),
#   (We, 've had, fights),
#   (we, need, to stop),
#   (We, need, get),
#   (mourning, gave, way),
#   (I, voted, Democrat),
#   (we, need, take),
#   (those, don't support, rights),
#   (student, stopped, offering),
#   (we, don't recognize, party),
#   (I, fear, retaliation),
#   (Americans, to take, approach),
#   (we, are spending, time),
#   (that, scared, me),
#   (You, claim, to believe),
#   (Eve, recounted, dinner party),
#   (student, was struggling, get),
#   (classmate, prompted, student),
#   (we, need, to stop),
#   (We, 've ceased, attempts),
#   (I, questioned, student),
#   (they, put, hand),
#   (CNN Opinion, invited, readers),
#   (They, don't want, to hear),
#   (who, follow, Trump),
#   (Americans, can find, ways),
#   (experience, has introduced, me),
#   (everyone, has lost, minds),
#   (we, feel, left),
#   (I, lost, church),
#   (he, was declared, winner),
#   (I, had aligned, myself),
#   (I, left, church),
#   (It, hurts, to see),
#   (we, try, to find),
#   (I, recognized, Party),
#   (who, risked, life),
#   (they, need, to connect),
#   (I, tried, to work),
#   (I, fear, putting),
#   (I, have seen, colors),
#   (I, told, her),
#   (you, love, precedence),
#   (I, met, her),
#   (CNN Opinion, invited, to share),
#   (Voting, cost, friends),
#   (I, lost, friendships),
#   (we, hope, to use),
#   (I, travel, be),
#   (I, learned, lesson),
#   (I, left, church),
#   (I, began, to see),
#   (couple, began, walking),
#   (they, want, to win),
#   (nothing, will reintroduce, balance),
#   (I, started, to see),
#   (Americans, are doomed, to fail),
#   (children, are watching, bloodsport),
#   (that, would change, minds),
#   (words, colored, view),
#   (Voting, cost, me),
#   (style salute, reflects, hate),
#   (student, was struggling, immigrants),
#   (it, seems, right),
#   (She, 's driven, to make),
#   (I, have lost, friends),
#   (Rich G., offered, approach),
#   (America, intends, to mend),
#   (we, have researched, candidates),
#   (I, tried, to work),
#   (he, has established, politics zone),
#   (we, try, to find),
#   (some, seeing, him),
#   (People, seemed, to eat),
#   (I, won't be discussing, politics),
#   (which, divided, nation),
#   (We, need, to fix),
#   (that, paid, have),
#   (we, 've experienced, dynamics),
#   (I, was starting, to hate),
#   (I, decided, not talk),
#   (father, served, to stop),
#   (They, 'll inherit, America),
#   (you, want, to heal),
#   (I, approached, student),
#   (we, need, to hit),
#   (I, have forged, path),
#   (polarization, has threatened, to tear),
#   (We, need, to treat),
#   (Anger, gets, one),
#   (mother, hates, it),
#   (that, does not include, those),
#   (it, require, radical),
#   (who, believed, conspiracies),
#   (they, risked, for),
#   (that, have bound, us),
#   (Partisanship, infantilizes, voters),
#   (I, never wanted, to know),
#   (leaders, reflect, worst),
#   (everyone, would tone, hate),
#   (husband, ended, conversation),
#   (we, have researched, candidates),
#   (he, has done, good),
#   (She, blames, Obama),
#   (she, doesn't see, it),
#   (girlfriend, continued, to talk),
#   (surge, implied, time),
#   (we, are getting, it),
#   (husband, begged, to change),
#   (Hundreds, wrote, to offer),
#   (we, became, friends),
#   (They, became, people),
#   (I, was monitoring, students),
#   (I, was going, to work),
#   (One, can't make, omelet),
#   (student, replied, ones),
#   (We, seen, other),
#   (demographics, define, them),
#   (you, love, precedence),
#   (who, see, Trump),
#   (We, need, to reinvest),
#   (we, need, listen),
#   (you, name, it),
#   (I, left, party),
#   (You, described, leaving),
#   (I, keep, hearing),
#   (It, hurts, heart),
#   (I, will not tolerate, symbol),
#   (most, can't be designated, politics zone),
#   (we, 've crossed, threshold),
#   (I, started, divide),
#   (You, described, being alienated),
#   (we, can start, to rebuild),
#   (call, needs, to take),
#   (husband, begged, her),
#   (Some, took, issue),
#   (I, keep, hearing),
#   (we, want, to be treated),
#   (I, was starting, to hate),
#   (media, reflect, views)],
#  [(Trump, invited, senators),
#   (We, saw, it),
#   (Turkey, continues, deploy),
#   (Trump, invited, senators),
#   (Turkey, will face, US sanctions),
#   (Lindsey Graham, attended, candid),
#   (Trump, playing, traffic cop),
#   (Scott, raised, questions),
#   (lawmakers, raise, policy concerns),
#   (adviser Robert O'Brien, held, call),
#   (He, wanted, discussion),
#   (front, held, call),
#   (Trump, warned, Erdoğan),
#   (senators, delivered, criticisms),
#   (group, showed, Erdoğan),
#   (which, lasted, minutes),
#   (US, will not sell, jets),
#   (Senate, isn't going, to give),
#   (Trump, invited, knowing),
#   (Rick Scott, attended, candid),
#   (President Recep Tayyip Erdoğan, pulled, iPad),
#   (source, called, video),
#   (Erdoğan, understands, leverage),
#   (it, gave, Trump),
#   (he, made, clear),
#   (he, pushed, Erdoğan),
#   (it, gave, opportunity),
#   (I, described, Turkey),
#   (Erdoğan, understands, strength),
#   (Reporters, invited, to see),
#   (Jim Risch, attended, candid),
#   (lawmakers, to air, concerns),
#   (it, reverses, course),
#   (Trump, raised, possibility),
#   (Ted Cruz, attended, candid),
#   (Turkey, continues, to procure),
#   (Joni Ernst, attended, candid),
#   (Turkey, deploys, system)],
#  [(Laurent, was given, test),
#   (They, told, us),
#   (Laurent, to complete, course),
#   (Laurent, told, CNN),
#   (father, told, CNN),
#   (They, noticed, something),
#   (We, need, to find),
#   (teachers, tried, to work),
#   (we, help, students),
#   (him, enjoy, himself),
#   (he, going, to study),
#   (Laurent Simons, is studying, course),
#   (students, can arrange, schedule),
#   (he, enjoys, playing),
#   (Laurent Simons, is studying, engineering),
#   (he, enjoys, playing),
#   (institution, will play, host),
#   (I, ate, lot),
#   (he, wants, do),
#   (parents, not received, explanation),
#   (He, plans, to embark)],
#  [(it, was going, to be coming),
#   (gunman, opened, fire),
#   (students, joined, thousands),
#   (is, is having, conversation),
#   (Many, feared, day),
#   (They, held, town halls),
#   (Rep. Katie Hill, told, CNN),
#   (They, joined, March),
#   (there, had been fighting, end),
#   (school shooting, would strike, campus),
#   (few, hosted, hall),
#   (school, developed, safety plan)],
#  [(they, appear, have),
#   (who, post, content),
#   (they, are forced, to confront),
#   (research, revealed, facts),
#   (they, represent, fraction),
#   (Republicans, overestimate, proportion),
#   (This, leads, to stereotype),
#   (that, drives, counterparts),
#   (politicians, make, progress),
#   (who, consume, types),
#   (who, answered, question),
#   (We, call, this),
#   (We, call, majority),
#   (we, asked, participants),
#   (We, call, group),
#   (that, led, them),
#   (I, visited, family),
#   (We, call, perception gap),
#   (we, asked, to guess),
#   (climate change, might affect, us),
#   (This, leads, people),
#   (us, to compare, belief),
#   (people, are sorting, themselves),
#   (I, encountered, illustration),
#   (who, follow, news),
#   (Democrats, overestimate, proportion),
#   (Americans, overestimate, extremity),
#   (counterparts, subject, them)],
#  [(We, take, money),
#   (They, want, to give),
#   (they, 've got, to stop),
#   (Citizens, are allowed, to sponsor),
#   (President Trump, asked, to host),
#   (We, 've told, them),
#   (you, like, having),
#   (account, been proven, accurate),
#   (which, sought, to reduce),
#   (I, got, them),
#   (he, used, threat),
#   (They, 're having, year),
#   (Mexico, has deployed, troops),
#   (they, help, us),
#   (It, 's going, to be protected),
#   (He, continued, to joke),
#   (that, is seeking, to declare),
#   (Zelensky, acknowledged, help),
#   (duty breaches, included, allowing),
#   (witnesses, have had, knowledge),
#   (We, check, polls),
#   (Trump, tried, get),
#   (jobs count, does not include, retail),
#   (who, could become, citizen),
#   (they, 're paying, us),
#   (who, tracks, appointments),
#   (he, keeps, saying),
#   (You, can read, fact check),
#   (I, know, gentleman),
#   (he, had committed, crimes),
#   (Foundation, had made, donation),
#   (fact, check, hypothetical),
#   (they, misconstrued, it),
#   (we, 're taking, billions),
#   (They, 've devalued, currency),
#   (he, left, openings),
#   (he, has not issued, plan),
#   (jobs count, does not include, government sectors),
#   (they, tried, get),
#   (China, never paid, us),
#   (countries, putting, money),
#   (He, made, it),
#   (Schiff, delivered, account),
#   (CNN, reported, thing),
#   (US, became, producer),
#   (they, don't like, me),
#   (he, made, claim),
#   (race, was expected, to be won),
#   (Amy McGrath, wants, borders),
#   (Trump, took, office),
#   (we, protect, you),
#   (who, could become, citizens),
#   (service, plan, to create),
#   (they, ate, tariff),
#   (we, won, House seats),
#   (term, is not meant, to be used),
#   (Democrats, want, to give),
#   (China, looted, factories),
#   (Bill Barr, did not decline, request),
#   (president, supposed, do),
#   (Mr. Trump, breached, duty),
#   (they, make, it),
#   (you, don't want, do),
#   (he, had released, transcript),
#   (you, imagine, that),
#   (Who, is paying, tariffs),
#   (President Barack Obama, signed, Choice program),
#   (They, want, to give),
#   (They, 're paying, billions),
#   (jobs count, does not include, hospital),
#   (Kentucky, has created, jobs),
#   (facility, made, shipment),
#   (one, proved, untrue),
#   (Sondland, had not changed, testimony),
#   (we, don't need, help),
#   (she, declined, to order),
#   (who, advocate, decriminalization),
#   (number, exceeded, that),
#   (countries, have provided, millions),
#   (he, has added, years),
#   (Trump, may have been conflating, economy),
#   (he, reimbursed, Foundation),
#   (immigrant, could become, citizen),
#   (I, protect, Medicare),
#   (they, 've never given, us),
#   (They, wrote, story),
#   (they, shouldn't be having, hearings),
#   (US, had generated, billion),
#   (We, never got, anything),
#   (Schiff, made, comments),
#   (Treasury, has never received, cents),
#   (George W. Bush, took, office),
#   (company, tells, us),
#   (I, got, Choice),
#   (state, counting, announcements),
#   (Schiff, didn't use, word),
#   (You, can read, fact check),
#   (We, 've told, that),
#   (We, protect, patients),
#   (Democrats, want, borders),
#   (news outlets, followed, Post scoop),
#   (fact, checking, him),
#   (president, continues, to make),
#   (he, started, claiming),
#   (Federal Energy Regulatory Commission, authorized, project),
#   (We, check, hypothetical),
#   (they, 're eating, it),
#   (Trump, reimbursed, Foundation),
#   (presidents, to leave, vacancies),
#   (candidates, do not support, migration),
#   (You, can read, fact check),
#   (Foundation money, was used, to buy),
#   (she, prefers, reform package),
#   (we, 're taking, billions),
#   (he, didn't use, word),
#   (Justice Saliann Scarpulla, addressed, issue),
#   (I, got, them),
#   (Beshear, has claimed, victory),
#   (We, ended, war),
#   (we, protect, patients),
#   (Trump administration, put, bills),
#   (that, made, conversation),
#   (people, call, auto insurance),
#   (they, want, to give),
#   (US, generated, average),
#   (they, 've never given, billions),
#   (they, shouldn't be allowed, do),
#   (We, won't call, Trump),
#   (Trump, won, Alabama),
#   (China, wants, to make),
#   (media, did not misreport, comments),
#   (China, never paid, cents),
#   (we, hand, it),
#   (he, takes, step),
#   (it, did not achieve, status),
#   (Schiff, did not read, transcript),
#   (they, 've set, checkpoints),
#   (They, want, borders),
#   (race, considered, competitive),
#   (Kentucky, diversify, energy industry),
#   (they, wrote, story),
#   (President Obama, left, Rand),
#   (Mr. Beshear, carried, number),
#   (you, like, that),
#   (number, exceeded, that),
#   (campaign website, advocates, energy policy),
#   (you, tell, something),
#   (US, has had, tariffs),
#   (I, said, Let),
#   (he, hasn't changed, testimony),
#   (sector manufacturing, plan, to create),
#   (me, tell, you),
#   (we, secure, borders),
#   (we, will continue, do),
#   (I, got, them),
#   (Trump, referring, to does not show),
#   (who, filed, complaint),
#   (Senate, had confirmed, circuit judges),
#   (it, took, spot),
#   (commissioner Mark Morgan, has offered, numbers),
#   (They, want, to open),
#   (Trump, supporting, lawsuit),
#   (You, 're not supposed, to allow),
#   (McGrath, has called, stupid),
#   (President Obama, left, Mitch),
#   (Trump, released, transcript),
#   (they, supply, them),
#   (he, appeared, to be saying),
#   (residents, can sponsor, spouses),
#   (campaign, to orchestrate, Fundraiser),
#   (they, shouldn't be having, hearings),
#   (Trump, criticize, Schiff),
#   (jobs count, does not include, education),
#   (residents, can sponsor, children),
#   (They, rip, guts),
#   (they, get, Royces),
#   (who, seen, be),
#   (Democrats, want, give),
#   (that, never gave, cents),
#   (that, never gave, China),
#   (General William Barr, to hold, news conference),
#   (I, said, that),
#   (Americans, make, tariff payments),
#   (that, includes, coal technology),
#   (We, 're having, year),
#   (She, wants, borders),
#   (Foundation money, was used, to resolve),
#   (China, 's having, year),
#   (Obama, took, office),
#   (government, approved, facility),
#   (We, won't call, inaccurate),
#   (company, tells, us),
#   (Beshear, wants, to shut),
#   (Beshear, opposed, Plan),
#   (We, 're giving, hundreds),
#   (you, 'll see, corruption),
#   (we, 've got, markets),
#   (he, 's given, lot),
#   (You, can read, breakdown),
#   (they, write, whatever),
#   (What, constitutes, violation),
#   (people, call, it),
#   (we, ended, war),
#   (you, tell, press),
#   (US, become, energy producer),
#   (we, cut, ribbon),
#   (who, tracks, appointments),
#   (I, said, Let),
#   (jobs count, does not include, services),
#   (Trump, tweeted, words),
#   (that, met, you),
#   (who, tracks, appointments),
#   (we, want, have),
#   (Post, invented, sources),
#   (vote count, shows, Bevin),
#   (Republicans, put, bills),
#   (Trump, signed, bill),
#   (We, never got, anything),
#   (They, 're paying, us),
#   (They, 're having, year),
#   (It, makes, sense),
#   (they, 're paying, billions),
#   (Trump, made, claims),
#   (jobs count, does not include, profit),
#   (news outlets, reported, thing),
#   (that, attempt, to reduce),
#   (they, 're paying, billions),
#   (I, 'll tell, you),
#   (we, 're going, get),
#   (Bill Clinton, took, office),
#   (Trump, recited, one),
#   (immigrants, to sponsor, acquaintances),
#   (Royces, gets, Royce),
#   (Trump, has made, claims),
#   (he, says, that),
#   (Beshear, wants, to shut),
#   (Trump, made, clear),
#   (We, were supposed, to lose),
#   (We, remove, projects),
#   (she, does not support, migration),
#   (Trump, gave, speech),
#   (President Obama, left, me),
#   (fact, checking, claims),
#   (which, means, crime),
#   (Post, fabricated, existence),
#   (people, believe, it),
#   (immigrant, gets, Royce),
#   (tech companies, plan, to create),
#   (we, won, them),
#   (Trump, released, transcript),
#   (York state investigation, uncovered, issues),
#   (you, ignore, months),
#   (They, 're paying, billions),
#   (they, 're paying, billions),
#   (claim, ignores, hundreds),
#   (Trump, visited, facility),
#   (Washington Post, fabricated, sources),
#   (whistleblower, was shown, be),
#   (McGrath, told, Louisville),
#   (that, never gave, us),
#   (that, would weaken, protections),
#   (they, want, to pay),
#   (Americans, are bearing, majority),
#   (immigrants, to sponsor, relatives),
#   (Trump, did make, joke),
#   (They, 're having, people),
#   (jobs count, does not include, restaurant),
#   (We, 're taking, billions),
#   (that, exceeded, figure),
#   (We, 're giving, millions),
#   (York Times, reported, thing),
#   (We, 've never had, economy),
#   (he, tweets, claim),
#   (we, adjust, numbers),
#   (President Donald Trump, made, claims),
#   (I, got, them),
#   (we, need, support),
#   (that, includes, renewables)],
#  [(Trump, wasn't elected, solve),
#   (you, 're lacking, fortitude),
#   (None, batted, eyelash),
#   (what, 's kept, us),
#   (President Barack Obama, was supposed, to save),
#   (you, to meet, needs),
#   (we, start, looking),
#   (we, 've reduced, beliefs),
#   (politics, replace, community),
#   (that, justifies, intolerance),
#   (It, 's become, buzzword),
#   (we, can't throw, it),
#   (one, goes, hour),
#   (it, 's used, to justify),
#   (that, was never going, realized),
#   (that, rationalizes, behavior),
#   (we, build, community),
#   (evolution, has made, bets),
#   (that, sees, politics),
#   (he, describes, this),
#   (we, seek, Republican),
#   (politics, has surpassed, sports),
#   (we, judge, other),
#   (We, 're spending, more),
#   ('s, teach, engagement),
#   (We, can continue, to blame),
#   (teams, may build, loyalty),
#   (Most, couldn't name, one),
#   ('s, teach, to make),
#   (Trump, wasn't elected, do),
#   (tribalism, helped, success),
#   (We, Know, It),
#   (That, can lead, some),
#   (it, feels, avoid),
#   (you, name, it),
#   (He, must reflect, selves),
#   ('s, teach, them),
#   (people, run, municipalities),
#   (teams, may build, enthusiasm),
#   (Trump, wasn't elected, to mirror),
#   (you, might not know, it),
#   (we, ignored, backyards),
#   (election, amped, cult),
#   (It, infects, aspect),
#   (we, unwind, obsession),
#   (we, seek, Democrat),
#   (part, is demystifying, persona),
#   (that, justifies, exclusion),
#   (it, feels, discuss),
#   (He, recalls, -style debate),
#   (what, 's kept, alive),
#   (they, pit, American),
#   (people, run, schools),
#   (politics, be overriding, morals),
#   (politics, has surpassed, religion),
#   (she, must reflect, selves),
#   (what, has helped, motivate),
#   (We, will switch, compass),
#   (we, hope, to become),
#   (we, weed, friends)],
#  [(safari, took, turn),
#   (collision, damaged, cars),
#   (park, has urged, be),
#   (We, are approaching, season),
#   (African Police, are investigating, incident),
#   (collision, killed, giraffe),
#   (vehicle, held, visitors),
#   (park, has urged, visitors),
#   (that, hit, giraffe)],
#  [(I, gave, you),
#   (I, didn't want, to),
#   (She, meets, Tom),
#   (I, gave, heart),
#   (movies, surprise, you),
#   (Director Paul Feig, told, THR),
#   (Emma Thompson, to write, script),
#   (She, wrote, script),
#   (which, stars, Clarke),
#   (movies, surprise, things),
#   (that, affects, you),
#   (ending, helped, hook),
#   (who, is having, bit),
#   (he, had approached, Michael),
#   (Clarke, plays, Kate),
#   (Livingstone, told, THR),
#   (who, takes, her),
#   (Emma Thompson, didn't want, to),
#   (that, happens, Christmas),
#   (who, saved, Kate),
#   (which, stars, Golding),
#   (she, said, Let)],
#  [(which, led, to accuse),
#   (Ukraine, raises, concerns),
#   (she, suggests, solution),
#   (Taylor, expanded, testimony),
#   (he, heard, them),
#   (investigators, to fill, gaps),
#   (I, never heard, this),
#   (I, shrank, it),
#   (House phone call, doesn't show, pressure),
#   (He, refused, to speculate),
#   (that, explain, accusations),
#   (Taylor, managed, to share),
#   (Taylor, joined, Kent),
#   (senators, use, ballot),
#   (House, votes, to impeach),
#   (• White House, may release, transcript),
#   (House staffers, are refusing, to cooperate),
#   (all, going, to say),
#   (which, led, him),
#   (Republicans, shrug, impeachment hearings),
#   (Taylor, brought, conviction),
#   (Taylor, didn't try, to embellish),
#   (It, would take, to side),
#   (Taylor, raises, concerns),
#   (Diplomat Bill Taylor, played, role),
#   (timeline, had gotten, to follow),
#   (who, overheard, Trump),
#   (Leader Mitch McConnell, wouldn't allow, it),
#   (he, doesn't recall, it),
#   (we, 're going, have),
#   (President, has invited, to interfere),
#   (It, would take, handful),
#   (we, got, to impeach),
#   (Sondland, delivers, ultimatum),
#   (Taylor, brought, life),
#   (Democrats, want, to impeach),
#   (Ukrainians, would undertake, investigations),
#   (this, becomes, story),
#   (senators, could vote, minds),
#   (President, has invited, powers),
#   (aide, had overheard, Trump),
#   (President, tries, to change)],
#  [(machine, tabulates, receipt),
#   (Beshear, to assume, governorship),
#   (machine, tabulates, votes),
#   (they, have certified, results),
#   (General Assembly, authorize, board),
#   (counties, certified, vote),
#   ('s, take, it),
#   (campaign, may request, recanvass),
#   (he, is considering, action),
#   (Bevin, want, to pursue),
#   (office, expects, to make),
#   (machine, tabulates, prints),
#   (board, would make, recommendation),
#   (Gov. Matt Bevin, requested, that),
#   (Bevin, told, CNN),
#   (Representatives, are allowed, be),
#   (Bevin, told, WKYT),
#   (him, trailing, Beshear)],
#  [(I, cannot attribute, reasons),
#   (he, realizes, hurricanes),
#   (years, have brought, flooding),
#   (years, have brought, hurricanes),
#   (Carper, told, him),
#   (he, doesn't know, reasons),
#   (activities, are releasing, amounts),
#   (which, is trapping, heat),
#   (years, have brought, wildfires),
#   (nominee, made, comments)],
#  [(they, need, to break),
#   (Boyce O'Brien, decried, GOP),
#   (Washington, painted, picture),
#   (who, devoted, lives),
#   (it, raised, pressure),
#   (I, know, nothing),
#   (we, need, to find),
#   (who, face, reelection races),
#   (Trump, abused, power),
#   (forces, assaulted, allies),
#   (differences, allowed, debate),
#   (I, don't recall, it),
#   (President, can condition, performance),
#   (that, needed, million),
#   (Democrats, posed, question),
#   (Trump, asked, Sondland),
#   (lawmakers, contemplate, to deal),
#   (allies, underscored, task),
#   (who, defended, him),
#   (detail, deals, blow),
#   (race, becomes, errand),
#   (hearings, won't shake, support),
#   (that, had caused, damage),
#   (that, took, place),
#   (colleague, provided, testimony),
#   (Trump, hijacked, policy interests),
#   (President, can condition, aid),
#   (Democrats, built, foundation),
#   (Trump, cares, more),
#   (that, marked, distinction),
#   (I, know, gentleman),
#   (testimony, poked, holes),
#   (that, could convince, public),
#   (that, sees, interests),
#   (Trump, demanded, dirt),
#   (who, heard, call),
#   (Taylor, reminded, lawmakers),
#   (Rep. Devin Nunes, branded, witnesses),
#   (scheme, ignored, desperation),
#   (he, tried, get),
#   (I, heard, it),
#   (President, heaped, praise),
#   (Taylor, provided, testimony),
#   (that, could change, winds),
#   (that, raised, security concerns),
#   (he, told, Lah),
#   (Trump, told, reporters),
#   (President Trump, is trying, do),
#   (who, struggled, to establish),
#   (I, recognize, Party),
#   (President, can condition, meetings),
#   (disclosures, painted, picture),
#   (Democrats, will need, do),
#   (US diplomat, revealed, call)],
#  [(Michael Rehaag, told, CNN),
#   (payment, was estimated, be),
#   (influencer, ordered, to repay),
#   (who, is facing, charges),
#   (She, used, to advertise),
#   (She, used, media platform),
#   (Rehaag, told, CNN)],
#  [(companies, turned, snacks),
#   (taste, replicates, shape),
#   (companies, turned, Donettes),
#   (companies, turned, Bun),
#   (Post, is partnering, to turn),
#   (Gores Group, bought, majority stake),
#   (New York, gripped, States),
#   (Twinkies shortage, gripped, States),
#   (company, conducted, consumer tests),
#   (taste, replicates, taste)],
#  [(I, got, ta embrace),
#   (guests, included, chief),
#   (it, 's worked, for),
#   (Washington, threw, book party),
#   (Kushner, acknowledged, hitting),
#   (Ivanka Trump, threw, book party),
#   (You, cannot turn, genes),
#   (Kushner, played, host),
#   (Jared Kushner, threw, book party),
#   (which, appeared, be),
#   (Kushner, acknowledged, Triggered),
#   (I, got, go),
#   (three, wearing, suits),
#   (guests, included, members)],
#  [(people, choose, expose),
#   (most, had avoided, doing),
#   (they, were making, predictions),
#   (People, misjudge, emotions),
#   (you, may have avoided, it),
#   (they, expected, going),
#   (liberals, watched, speeches),
#   (majority, experienced, emotions),
#   (conservatives, watched, speeches),
#   (Americans, could begin, to bridge),
#   (they, expected, to feel),
#   (We, asked, report),
#   (We, asked, voters),
#   (We, asked, to watch),
#   (we, collected, arguments),
#   (we, used, to recruit),
#   (listening, turned, be),
#   (they, expected, going),
#   (President Donald Trump, give, address),
#   (they, ended, agreeing),
#   (it, meant, avoiding),
#   (forecasts, reduced, exposure),
#   (We, asked, them),
#   (that, contradicts, beliefs),
#   (democracy, requires, to expose),
#   (who, watches, News),
#   (We, asked, to predict),
#   (research, suggests, outlook),
#   (you, encounter, headline),
#   (Clinton voters, found, content),
#   (scientists, aiming, to understand),
#   (It, provided, window),
#   (Individuals, tend, to avoid),
#   (they, tend, to avoid),
#   (we, used, platform),
#   (we, saw, this),
#   (majority, experienced, ones),
#   (thirds, preferred, earning),
#   (we, conducted, study),
#   (people, form, echo chambers),
#   (we, found, pattern),
#   (they, expect, to agree),
#   (citizens, reiterate, positions),
#   (that, teaching, people),
#   (democracy, requires, us),
#   (what, drives, division)],
#  [(Horvat, told, CNN),
#   (Dorian, brought, tornadoes),
#   (Horvat, told, CNN),
#   (park, is trying, get),
#   (what, seems, be),
#   (it, made, landfall),
#   (superintendent, told, him),
#   (Dorian, brought, winds),
#   (Dorian, brought, rain)],
#  [(Taylor, delivered, opening statement),
#   (appeal, will sway, people),
#   (Rep. Mark Meadows, told, Fox),
#   (answer, will affect, future),
#   (House Intelligence Committee, opened, impeachment hearings),
#   (Sondland, called, Trump),
#   (adviser Tom Bossert, summed, it),
#   (it, tends, have),
#   (that, balances, powers),
#   (Taylor, recounted, episode),
#   (allies, abused, office),
#   (He, dismissed, investigation),
#   (I, monitored, stakes),
#   (that, affirms, view),
#   (country, announced, investigation),
#   (Kent, sought, to emphasize),
#   (Russia expert Fiona Hill, said, same),
#   (House Republicans, value, Jordan),
#   (Trump, cares, more),
#   (I, doubt, it),
#   (President Donald Trump, abused, office),
#   (goal, mentioned, Founders),
#   (he, began, speaking),
#   (He, called, finale),
#   (It, seems, unlikely),
#   (Devin Nunes, turns, it),
#   (He, called, Chamber),
#   (he, hears, it),
#   (he, mentioned, Founders),
#   (whistleblower, was known, have),
#   (Jim Jordan, showcases, style),
#   (Congress, had begun, to ask),
#   (House Republicans, value, ability),
#   (Jordan, asked, Taylor),
#   (Schiff, tried, to ground),
#   (He, called, hearings),
#   (President, defend, Constitution),
#   (Republicans, had put, signs),
#   (He, derided, sham),
#   (#Snoozefest, tweeted, Trump),
#   (Nunes, pushed, conspiracy theory),
#   (they, added, him),
#   (Taylor aide, asked, Sondland),
#   (I, 've seen, prayer chains),
#   (Ukraine, played, role),
#   (He, called, proceedings),
#   (Nunes, detailed, conspiracy theory),
#   (that, debunked, theory),
#   (Taylor, laid, timeline),
#   (Partisans, will take, side),
#   (Ukraine, making, statement),
#   (Russia, annexed, Crimea),
#   (He, described, door testimony),
#   (I, thought, to try),
#   (President, brought, conspiracy theory),
#   (we, become, monarchy),
#   (Rep. Devin Nunes, sought, to go)],
#  [(it, doesn't cause, him),
#   (tail, catapulted, him),
#   (He, seems, healthy),
#   (that, hasn't stopped, fans),
#   (spokesperson, told, CNN),
#   (they, want, to monitor),
#   (organization, received, adoption applications),
#   (that, resembles, tusk),
#   (face tail, does not bother, Narwhal),
#   (Vets, took, ray scans),
#   (which, took, him),
#   (he, got, meds),
#   (spokesperson, told, CNN),
#   (who, has been named, Smurf),
#   (it, doesn't cause, pain),
#   (they, are seeing, dogs),
#   (what, appears, be),
#   (He, seems, other)],
#  [(lawmakers, scrambling, to defend),
#   (defense team, pushed, conspiracy theory),
#   (he, had been working, phones),
#   (he, got, thanks),
#   (I, would sum, everything),
#   (inquiry, needs, to stop),
#   (Kent, shed, light),
#   (banner, said, RPT),
#   (Carlson, mocked, news outlets),
#   (graphic, alleged, MELTDOWN),
#   (websites, hyped, destroying),
#   (you, didn't see, case),
#   (GOP lawmaker, told, Ingraham),
#   (Mark Levin, called, Schiff),
#   (banners, summed, p.m. hour),
#   (Taylor, shed, light),
#   (Carlson, wrapped, hour),
#   (websites, hyped, clips),
#   (process, will hurt, Dems),
#   (you, were watching, hearing),
#   (I, wanted, to know),
#   (he, accused, witnesses),
#   (others, made, jokes),
#   (Carlson, seemed, reluctant),
#   (who, are resisting, policies),
#   (Mark Levin, called, boob),
#   (Laura Ingraham, criticized, Democrats),
#   (Dobbs segment, is sparking, outrage),
#   (Ingraham, welcomed, correspondent),
#   (Which, brings, me),
#   (NEW EVIDENCE, TIES, TRUMP),
#   (Dem aide, told, Post),
#   (Trish Regan, ran, segment),
#   (it, did not prove, point),
#   (who, told, him),
#   (websites, hyped, eviscerating),
#   (billionaire George Soros, controls, part),
#   (defenders, dismissed, hearings),
#   (president, loved, watching),
#   (President Trump, was hearing, one),
#   (banner, said, DEMS),
#   (that, generated, focus),
#   (beg Americans, to turn, TV),
#   (Grisham, called, joke),
#   (Grisham, called, it),
#   (I, decided, to write),
#   (I, decided, to mute)],
#  [(kids, made, splash),
#   (comment, earned, laugh),
#   (singer, brought, children),
#   (Momoa, faced, questions),
#   (Aquaman, knows, Ariel),
#   (I, 'm gon, na teach),
#   (Momoa, be seen, See)],
#  [(that, feature, content),
#   (Warner Bros., used, this),
#   (It, may contain, depictions),
#   (Director Tim Burton, chose, to not include),
#   (They, may depict, some),
#   (characters, put, circus tents),
#   (cartoons, do not represent, society),
#   (He, omitted, scene),
#   (Dumbo, featured, character),
#   (that, feature, prejudices)],
#  [(landmark cathedral, suffered, fire),
#   (Villeneuve, said, view),
#   (Philippe, has expressed, interest),
#   (President Emmanuel Macron, plans, have),
#   (I, have asked, Villeneuve),
#   (Minister Édouard Philippe, announced, competition),
#   (some, have criticized, line),
#   (she, favors, restoration)],
#  [(I, 'm going, to bring),
#   (it, feels, be),
#   (it, confirmed, power),
#   (she, became, female),
#   (I, feel, love),
#   (return, puts, her),
#   (awards, will take, take),
#   (Keys, told, Billboard),
#   (I, felt, it),
#   (Alicia Keys, is hosting, Awards),
#   (ya, gon, na top)],
#  [(company, has hired, to assist),
#   (Trump property, has harmed, Washington hotels),
#   (we, have received, interest),
#   (statement, did not list, profit figures),
#   (Donald Trump, is profiting, role),
#   (Street Journal, reported, sale),
#   (that, benefits, Trump family),
#   (President, has reported, earning),
#   (President Trump, isn't making, profit),
#   (agency, ignored, Constitution),
#   (People, are objecting, making),
#   (I, will be following, marketing attempt),
#   (Trump property, has harmed, businesses),
#   (company, has hired, JLL),
#   (court, revived, lawsuit),
#   (President, is violating, Emoluments Clauses),
#   (he, transferred, assets),
#   (Trump Organization, is considering, selling),
#   (Trump Organization, won, contract),
#   (House Transportation Committee, issued, subpoena),
#   (we, opened, doors),
#   (lawsuits, have been filed, accusing),
#   (Trump, took, office)],
#  [(he, began, clearing),
#   (protesters, barricaded, themselves),
#   (We, have had, warnings),
#   (state media, warning, protesters),
#   (protests, have taken, turn),
#   (protesters, hurling, bricks),
#   (government supporters, hurling, bricks),
#   (escalation, raised, questions),
#   (they, had evacuated, students),
#   (level, has reached, heights),
#   (country, will never accept, situation),
#   (what, is believed, be),
#   (protesters, built, barricades),
#   (you, are going, have),
#   (We, warn, protesters),
#   (who, are coerced, be),
#   (television channel, issued, editorial),
#   (Police, fired, canisters),
#   (government, unveiled, range),
#   (protesters, to cross, it),
#   (Adam Ni, told, CNN),
#   (you, can make, call),
#   (schools, have suspended, instance),
#   (We, have had, persuasion),
#   (police, confronted, protesters),
#   (MTR, continued, to suspend),
#   (schools, have suspended, classes),
#   (students, have been asked, to leave),
#   (We, have had, talking),
#   (who, have taken, footbridge),
#   (protesters, seek, to breach)],
#  [(Underwood, has had, banner year),
#   (Brooks, bested, to take),
#   (She, blows, me),
#   (few, wanted, to see),
#   (Brooks, bested, prompting),
#   (you, 're going, to continue),
#   (post, highlighted, tour),
#   (Brooks, bested, Urban),
#   (Underwood, deserved, award),
#   (Underwood, garnered, profile support),
#   (Brooks, bested, Stapleton),
#   (Association Awards, was supposed, be),
#   (Miranda Lambert, posted, explanation),
#   (Brooks, bested, her),
#   (Brooks, bested, Church),
#   (tweet, went, to say)],
#  [(it, could gain, traction),
#   (GOP lawmakers, used, to poke),
#   (Mulvaney, has defied, subpoena),
#   (urgency, increases, to hear),
#   (GOP lawmakers, described, testimony),
#   (he, abused, powers),
#   (who, overheard, Trump),
#   (Trump, telling, US diplomats),
#   (He, called, nonsubstantive),
#   (Trump, cares, more),
#   (He, referenced, GPS),
#   (who, used, time),
#   (asked, will provide, door testimony),
#   (They, repeated, many),
#   (Taylor, told, lawmakers),
#   (he, was fighting, corruption),
#   (Trump, to withhold, assistance),
#   (witnesses, are relaying, information),
#   (aide, asked, Sondland),
#   (Republicans, landed, punches),
#   (he, pressed, to investigate),
#   (he, had said, that),
#   (daylong affair, gave, plenty),
#   (who, used, to make),
#   (Mulvaney, told, said),
#   (daylong affair, gave, parties),
#   (Trump, mentioned, investigations),
#   (he, told, lawmakers),
#   (staff lawyers, led, questioning),
#   (there, 's going, be),
#   (He, called, short),
#   (which, would give, boost),
#   (He, called, it),
#   (Democrats, might struggle, to make),
#   (he, had never seen, example),
#   (Democrats, extracted, answers),
#   (Democrats, launched, impeachment inquiry),
#   (aide, had overheard, conversation),
#   (Trump, trying, to dig),
#   (GOP lawmakers, used, time),
#   (He, referenced, Russia dossier),
#   (which, prompt, questions),
#   (Taylor, told, lawmakers),
#   (Trump, has levied, accusations),
#   (which, would give, campaign),
#   (he, pressed, Zelensky),
#   (Trump, voiced, desire),
#   (asking, will provide, door testimony),
#   (he, abused, to seek),
#   (approach, puzzled, witnesses),
#   (they, start, drafting),
#   (GOP lawmakers, used, to point),
#   (conversations, will face, scrutiny),
#   (players, scheduled, to tell),
#   (Mulvaney, told, reporters),
#   (Daniel Goldman, sought, to build),
#   (Mulvaney, told, get)],
#  [(protesters, hurling, bricks),
#   (who, suffered, head injury),
#   (he, began, clearing),
#   (violence, was jeopardizing, country),
#   (We, will continue, to support),
#   (government supporters, hurling, bricks),
#   (it, challenging, line),
#   (President, condemned, violence),
#   (escalation, raised, questions),
#   (what, is believed, be),
#   (level, has reached, heights)],
#  [(we, spend, watching),
#   (parents, should be helping, kids),
#   (son, forget, concept),
#   (parents, want, to express),
#   (concept, fits, universe),
#   (Conversations, force, to think),
#   (I, don't appreciate, way),
#   (they, define, it),
#   (I, cooking, dinner),
#   (being, affects, us),
#   (we, spend, minutes),
#   (I, could have shown, time metrics),
#   (screen time, meant, dragging),
#   (They, want, to know),
#   (we, spent, looking),
#   (all, play, role),
#   (we, use, screens),
#   (kids, tend, be),
#   (we, 've begun, to spend),
#   (parents, stop, thinking),
#   (they, are using, screens),
#   (experience, tells, me),
#   (I, 've begun, to doubt),
#   (we, should be probing, nature),
#   (Shapiro, reminded, me),
#   (many, to see, screen),
#   (We, won't pit, activities),
#   (he, getting, taste),
#   (I, didn't think, much),
#   (it, began, to be applied),
#   (I, decided, to replace),
#   (we, keep, cookbooks),
#   (I, don't like, way),
#   (They, want, explanations),
#   (he, 's taken, interest),
#   (I, don't want, to burn),
#   (I, could have shown, him),
#   (adults, tend, to view),
#   (people, present, you),
#   (we, 've scapegoated, screen),
#   (you, are going, to see),
#   (categories, will require, subcategories),
#   (he, gets, exercise),
#   (screen time, meant, watching),
#   (thing, fits, universe),
#   (Conversations, force, us),
#   (academic, tells, me),
#   (many, are designed, be),
#   (son, internalized, equation),
#   (them, to develop, autonomy),
#   (She, suggests, voyage),
#   (I, don't like, stigma)],
#  [(which, flattened, thousands),
#   (president, rejected, accusations),
#   (flood, launched, plan),
#   (who, posted, videos),
#   (It, was preferred, to guarantee),
#   (it, rejected, measures),
#   (council chamber, started, to take),
#   (mayor, blamed, climate change),
#   (councilors, were debating, budget),
#   (Ciambetti, mentioned, million),
#   (that, will leave, mark),
#   (Forza Italia parties, rejected, amendments),
#   (It, was preferred, to stay),
#   (that, spent, million)],
#  [(she, making, joke),
#   (candidate, received, %),
#   (he, accepted, favors),
#   (Smith, called, criticism),
#   (her, having, string),
#   (that, do not represent, Mississippi),
#   (who, won, Mississippi),
#   (Smith, appeared, to say),
#   (he, accepted, gifts),
#   (he, will challenge, her),
#   (I, 'm running, be),
#   (people, can't find, job),
#   (one, invited, her)],
#  [(Court justices, take, DACA),
#   (Anderson Cooper, hosts, streaming),
#   (who, authored, study),
#   (Scientist, discovers, strain),
#   (We, 've got, answers),
#   (who, rescued, passenger),
#   (videos, show, tensions),
#   (Ross Garber, answers, questions)],
#  [(police, want, anyone),
#   (Brown, was driving, RV),
#   (Authorities, received, call),
#   (Brown, seen, wearing),
#   (Brown, was believed, be),
#   (police, to shut, schools),
#   (Anyone, should use, caution),
#   (who, sees, him),
#   (Brown, deserted, post),
#   (Brown, is considered, dangerous),
#   (He, knows, to move),
#   (he, was driving, Car),
#   (Carolina authorities, have charged, Brown),
#   (students, attend, school),
#   (US Marshals Service, is offering, reward)],
#  [(Trump, carries, business),
#   (who, had accepted, emoluments),
#   (he, could keep, it),
#   (Trump, is supposed, to be representing),
#   (appeals court, has rejected, emoluments lawsuit),
#   (states, have been paying, sums),
#   (he, researched, issue),
#   (he, gave, money),
#   (visit, helped, stop),
#   (It, has been updated, to note),
#   (that, houses, blocks),
#   (government, continues, to deny),
#   (Department, adopted, arguments),
#   (that, houses, building Trump leases),
#   (President Barack Obama, won, Prize),
#   (Trump, has guarded, privacy),
#   (President Donald Trump, had violated, Clause),
#   (job, had been enriching, himself),
#   (he, followed, rules),
#   (Trump, gave, operations),
#   (government, wants, to spend),
#   (he, took, business),
#   (who, has studied, issue),
#   (it, turns, Constitution guards),
#   (Charles Pinckney, urged, necessity),
#   (Who, runs, Organization),
#   (that, upends, years),
#   (it, would send, statement),
#   (kingdom, buys, arms),
#   (kingdom, buys, equipment),
#   (he, became, President),
#   (That, makes, sense),
#   (That, was going, to create),
#   (he, didn't give, ownership stake),
#   (Trump, has violated, emoluments clause),
#   (firm, put, groups),
#   (Some, have undergone, government review),
#   (Benjamin Franklin, was given, snuff box),
#   (they, would continue, to pursue),
#   (that, would strip, citizenship),
#   (appeals court, dismissed, challenge),
#   (Trump, to not take, emoluments),
#   (he, offered, representation),
#   (Trump Organization, could be forced, to disclose),
#   (governments, seem, to be spending)],
#  [(collection, included, dinosaur bones),
#   (that, contain, color pigments),
#   (that, may have represented, patterning),
#   (scientists, found, evidence),
#   (researchers, have found, evidence),
#   (Researchers, found, traces),
#   (team, examined, collection),
#   (dinosaurs, keep, warm),
#   (Researchers, found, cells),
#   (collection, included, feathers),
#   (dinosaurs, used, feathers)],
#  [(who, had grown, believing),
#   (novel, debunks, myths),
#   (that, includes, girls),
#   (I, attend, mother),
#   (that, had built, life),
#   (they, 're trying, to figure),
#   (Trump, instituted, Americans),
#   (people, would judge, us),
#   (I, opened, word document),
#   (I, started, identifying),
#   (Years, has produced, tension),
#   (I, stopped, hiding),
#   (I, know, lyrics),
#   (friend, told, me),
#   (thousands, stormed, Kennedy airport),
#   (I, don't wear, hijab),
#   (I, choose, to eat),
#   (I, began, writing),
#   (People, will treat, you),
#   (who, wants, to be accepted),
#   (lifestyle, disqualified, me),
#   (I, dread, reaction),
#   (who, is exploring, religion),
#   (thousands, stormed, airports),
#   (I, choose, not to wear),
#   (Trump, instituted, travel ban),
#   (mom, didn't feel, having),
#   (that, includes, Muslims),
#   (I, attend, mosque),
#   (President Donald Trump, issued, order),
#   (I, don't get told, go),
#   (I, support, policies),
#   (I, 've enjoyed, bottle),
#   (I, adore, religion),
#   (I, 've formed, bonds),
#   (I, eat, bacon),
#   (I, hadn't done, anything),
#   (they, can trust, me)],
#  [(they, had sent, to),
#   (Trump administration, had placed, to),
#   (process, took, place),
#   (Office, is declining, to open),
#   (White House, has offered, accounts),
#   (it, would appear, to have hindered),
#   (he, was attempting, to lift),
#   (President, attempted, to use),
#   (Laura Cooper, told, lawmakers),
#   (what, triggered, release),
#   (Volker, had told, her),
#   (House officials, been made, aware),
#   (it, is conducting, review),
#   (administration, had violated, law),
#   (what, triggered, Trump),
#   (Government Accountability Office, initiated, review),
#   (Trump administration, violated, appropriations law),
#   (Sen. Chris Van Hollen, asked, US comptroller),
#   (Democrats, expressed, disappointment),
#   (Trump administration, had placed, hold),
#   (Department Office, has declined, to investigate),
#   (office, pursue, review),
#   (they, would launch, investigations),
#   (Administration officials, have tried, to pin),
#   (Ukrainians, deliver, statement),
#   (impeachment inquiry, taking, place),
#   (who, had requested, review),
#   (what, triggered, change),
#   (President, released, aid),
#   (they, had sent, letter)],
#  [(Caleb Sharpe, opens, fire),
#   (Williams, kills, classmates),
#   (Bartley, is found, guilty),
#   (Morrison, shoots, Keyes),
#   (He, kills, himself),
#   (Woodham, is serving, life sentences),
#   (He, is serving, life),
#   (Dimitrios Pagourtzis, opens, injuring),
#   (Roger Needham, kills, student),
#   (18, shoots, student),
#   (Barbaro, kills, himself),
#   (Farmer Andrew Kehoe, sets, explosions),
#   (Jeff Weise, kills, adult),
#   (He, kills, himself),
#   (Morrison, kills, himself),
#   (appeals court, tosses, life sentence),
#   (who, had bullied, him),
#   (Butler, kills, himself),
#   (He, takes, life),
#   (SWAT teams, enter, school),
#   (James Wilson, kills, Bradley),
#   (Dubose, is found, guilty),
#   (Duane Morrison, takes, students),
#   (Osmanson, is sent, to),
#   (Williams, kills, old),
#   (Nikolas Cruz, opens, fire),
#   (Christian, attends, school),
#   (Kenneth Bartley Jr., opens, fire),
#   (drifter Patrick Purdy, uses, to kill),
#   (Toby Sincino, kills, teacher),
#   (bullet, kills, student),
#   (Williams, kills, old),
#   (Harless, serves, eight),
#   (Michael Carneal, opens, fire),
#   (Woodham, is serving, years),
#   (Bartley, accepts, plea bargain),
#   (Dylan Klebold, kill, teacher),
#   (James Sheets, brings, revolver),
#   (James Wilson, kills, Thomas),
#   (who, invade, classroom),
#   (student T.J. Lane, opens, fire),
#   (He, takes, life),
#   (student, opens, fire),
#   (He, is found, guilty),
#   (student Anthony Barbaro, kills, school janitor),
#   (Brenda Spencer, opens, fire),
#   (He, kills, students),
#   (Nathan Faris, shoots, Perrin),
#   (He, takes, life),
#   (Dimitrios Pagourtzis, opens, killing),
#   (Truvia, found, unfit),
#   (Kearbey, spends, years),
#   (drifter Patrick Purdy, uses, AK-47),
#   (male, opens, fire),
#   (suspect, activated, fire alarm),
#   (Jamie Rouse, kills, business teacher),
#   (student Jose Reyes, takes, handgun),
#   (He, earns, D),
#   (Barry Loukaitis, takes, rifle),
#   (police, believe, be),
#   (Rouse, is serving, life sentence),
#   (Jamie Rouse, kills, student),
#   (Investigating, find, Lanza),
#   (David Black, injures, student),
#   (He, is sentenced, to serve),
#   (Robert Butler Jr., opens, fire),
#   (Evan Ramsey, uses, to kill),
#   (student Jason Smith, kills, student),
#   (Convict Paul Orgeron, explodes, suitcase),
#   (shooter Darrick Evans, is given, sentence),
#   (who, had bullied, him),
#   (Jesus Rodriguez, stabs, Rivera),
#   (Siler, receives, years),
#   (Anderson, kills, himself),
#   (shooting, leaves, one),
#   (Doris Young, take, school),
#   (gunmen, kill, Blocker),
#   (Jeff Weise, kills, grandfather),
#   (Evan Ramsey, uses, shotgun),
#   (McCoy, serves, years),
#   (student Anthony Barbaro, kills, passers),
#   (He, serving, term),
#   (Freshman Jaylen Fryberg, shoots, people),
#   (Roberts, kills, himself),
#   (Karl Pierson, opens, fire),
#   (David, take, school),
#   (Dylan Klebold, kill, students),
#   (She, injures, people),
#   (David Young, shot, wife)],
#  [(Schiff, accomplished, task),
#   (Taylor, explained, backdoor channel),
#   (abuse charge, provides, impeachment theory),
#   (diplomats Taylor, started, to look flustered),
#   (delay, meant, death),
#   (Ukraine allegations, fail, to resonate),
#   (Republicans, favor, enforcement),
#   (Republicans, muddied, water),
#   (Steele Dossier, raised, head),
#   (he, was beginning, investigations),
#   (They, posed, questions),
#   (Schiff, proceeded, to swear),
#   (Prosecutors, like, to start),
#   (allies, defending, homeland),
#   (Kent, started, to look flustered),
#   (diplomats Taylor, started, confused),
#   (which, haunted, half),
#   (rules, permitted, to pontificate),
#   (Prosecutors, like, finish),
#   (questions, were designed, to remind),
#   (Harvard Law grad, executed, part),
#   (Richard Nixon, throwing, dollars),
#   (questions, require, evidence),
#   (it, helps, case),
#   (none, wanted, president),
#   (President, abused, power),
#   (prosecutor, executed, part),
#   (courtroom, would overrule, questions),
#   (actions, may violate, requirement),
#   (rules, permitted, Republicans),
#   (Trump, can beat, Biden),
#   (fathers, fought, War),
#   (Mr. Schiff, followed, rule),
#   (All, can beat, Biden),
#   (Kent, started, confused),
#   (It, causing, death),
#   (delay, could telegraph, lack),
#   (they, knew, nothing),
#   (case, began, to fade),
#   (He, brushed, assortment),
#   (Courts, prohibit, witness speculation)],
#  [(Patrick, missed, deadlines),
#   (she, ruled, run),
#   (you, want, to know),
#   (filing deadlines, appear, to have forced),
#   (Clinton, told, BBC radio),
#   (Clinton, told, Radio),
#   (admirers, have tried, to coax),
#   (I, 've got, do),
#   (he, entered, race),
#   (I, 've got, grandkids),
#   (you, 've got, to talk),
#   (public, can make, decision),
#   (Bloomberg, join, field),
#   (I, tell, you),
#   (who, could face, disadvantage),
#   (heavyweights, have dangled, possibility),
#   (Crooked Hillary Clinton, should run, steal),
#   (which, has prompted, much),
#   (team, filed, paperwork),
#   (I, 'd like, do),
#   (Patrick, join, field),
#   (Bloomberg, plans, to skip),
#   (I, would fix, it),
#   (we, 're going, do),
#   (I, 'm running, mine),
#   (he, decide, to run),
#   (none, could claim, runner status),
#   (Biden, held, lead),
#   (Massachusetts Gov. Deval Patrick, weighed, entry),
#   (He, 's running, campaign),
#   (I, 've got, daughters),
#   (both, have excited, generation),
#   (adviser, told, CNN),
#   (Bloomberg, told, reporters),
#   (they, miss, chance),
#   (Bloomberg, told, gaggle),
#   (party, has not settled, debate),
#   (University poll, showed, Bend),
#   (she, left, door ajar),
#   (Mayor Michael Bloomberg, made, run),
#   (I, 've known, him),
#   (University poll, showed, Indiana)],
#  [(who, can beat, Trump),
#   (he, hoped, to convince),
#   (primary, takes, place),
#   (who, represents, Ohio),
#   (congressman, did not walk, comments),
#   (I, love, guy),
#   (who, dropped, bid),
#   (Ryan, touted, himself),
#   (he, got, touch),
#   (candidate Rep. Tim Ryan, endorsed, bid),
#   (I, 'm going, do),
#   (Democrats, need, candidate),
#   (Ryan, expressed, misgivings),
#   (him, become, nominee),
#   (I, 'm going, to support),
#   (who, can beat, Trump),
#   (We, 've got, to beat),
#   (who, knows, to talk),
#   (Biden, received, support),
#   (endorsement, could prove, be),
#   (campaign, failed, to gain)],
#  [(President, deserved, to speak),
#   (Trump, were seeking, to leverage),
#   (those, were seeking, to leverage),
#   (Democrats, used, restate),
#   (aide, had overheard, Ambassador),
#   (Democrats, used, question time),
#   (it, meant, something),
#   (he, seen, sort),
#   (Ukraine, got, aid),
#   (that, swallows, descriptions),
#   (President, deserved, to be impeached),
#   (He, told, Republicans),
#   (Sondland, had told, aide),
#   (Democrats, used, to allow)],
#  [(I, conveyed, message),
#   (Quigley, told, CNN),
#   (who, hold, majority),
#   (hearing, moved, ball),
#   (I, conveyed, to),
#   (Rep. Raja Krishnamoorthi, told, reporters),
#   (None, asked, questions),
#   (I, told, Morrison),
#   (Rep. Adam Schiff, using, time),
#   (member, had overheard, Trump),
#   (ambassador, repeat, details),
#   (it, ended, being),
#   (Jordan, laid, case),
#   (President, dismissed, testimony),
#   (Identity, read, one),
#   (hearing, dismissed, importance),
#   (ally, laid, case),
#   (you, got, understanding),
#   (he, knew, nothing),
#   (Rep. Elise Stefanik, summed, GOP argument),
#   (opponents, will use, anything),
#   (opponents, will use, get),
#   (Ambassador Sondland, told, Trump),
#   (reactions, illustrate, divide),
#   (many, were paying, attention),
#   (that, prove, nothing),
#   (staffer, asked, Sondland),
#   (committee, moved, to depose),
#   (Jordan, mocked, lines),
#   (seating, pushed, observers),
#   (people, watched, proceedings),
#   (Rep. Jim Jordan, led, questioning),
#   (battle lines, had not moved, inch),
#   (Hammers, home, message),
#   (person, can claim, listening),
#   (anyone, change, mind),
#   (Republicans, were left, wondering),
#   (you, told, me),
#   (they, hear, story),
#   (call, took, place),
#   (it, not going, to change),
#   (member, could hear, Trump),
#   (Mr. Morrison, told, Taylor),
#   (Republicans, didn't try, to contest),
#   (handful, interrupted, proceedings),
#   (House Republican aide, told, CNN),
#   (Sondland, told, staffer),
#   (people, having, conversations),
#   (Ukraine, got, aid),
#   (Rep. Peter Welch, told, reporters),
#   (they, make, circus),
#   (that, ties, President),
#   (that, showed, engagement),
#   (President, 's going, be)],
#  [(suspects, are seen, walking),
#   (Atre, seen, getting),
#   (They, identified, body),
#   (We, need, community),
#   (suspects, were seen, walking)],
#  [(he, ruled, bid),
#   (Patrick, had upped, involvement),
#   (Patrick, told, WBUR),
#   (Patrick, entered, sector),
#   (Patrick, has missed, deadline),
#   (he, has made, decision),
#   (he, seeks, nomination),
#   (he, would be entering, race),
#   (he, was going, to jump),
#   (He, cited, it),
#   (Patrick, defended, work),
#   (Massachusetts Gov. Deval Patrick, is telling, allies),
#   (Patrick, had built, team),
#   (frontrunner Democrats, have cast, interests),
#   (Massachusetts Gov. Deval Patrick, is telling, friends),
#   (I, 've left, conscience),
#   (that, became, liability),
#   (I, 've never taken, job),
#   (he, could make, minute entry),
#   (Patrick, told, friends),
#   (he, planned, bid),
#   (he, wanted, to put),
#   (Patrick, has missed, to appear)],
#  [(CDC, started, collecting),
#   (1, used, tobacco product),
#   (That, represents, drop),
#   (US adults, used, tobacco product)],
#  [(he, follows, me),
#   (star, praised, husband),
#   (she, will be taking, step),
#   (Jameson, 's going, to start),
#   (she, will celebrate, years)],
#  [(it, represents, time),
#   (everything, is going, to be withheld),
#   (Congress, had directed, to be sent),
#   (Trump, asks, Sondland),
#   (whistleblower complaint, is made, public),
#   (Volker, advise, leadership),
#   (General Michael Atkinson, notifies, Nunes),
#   (York Times, publishes, report),
#   (aide, overhears, phone call),
#   (meeting, featured, House),
#   (Sondland, advise, leadership),
#   (Ukraine, needs, aid),
#   (Ambassador, characterized, request),
#   (Ukraine, raises, concerns),
#   (Sondland, recalls, telling),
#   (They, discuss, topics),
#   (General Michael Atkinson, notifies, Schiff),
#   (White House, lifted, hold),
#   (Ukraine, needs, US),
#   (which, had placed, him),
#   (Trump, wants, force),
#   (who, played, President),
#   (Trump, brings, investigations),
#   (document, trigger, impeachment inquiry),
#   (Speaker Nancy Pelosi, announces, impeachment inquiry),
#   (which, inhibited, interaction),
#   (suggestion, alarmed, Bolton),
#   (House Office, put, hold aid),
#   (meeting, featured, officials),
#   (President Donald Trump, used, US tax dollars),
#   (call, triggers, concerns),
#   (Taylor, raises, concerns),
#   (Taylor, raises, concerns),
#   (Giuliani, meets, official),
#   (which, does not mention, corruption investigations),
#   (Zelensky, wins, landslide victory),
#   (members, were requiring, quo),
#   (meeting, featured, Department officials),
#   (Zelensky, seeks, meeting),
#   (Sondland, delivers, ultimatum),
#   (committees, request, information),
#   (story, has been updated, reflect),
#   (Ukrainians, to investigate, arrangement),
#   (House committees, launch, investigation),
#   (Trump, can congratulate, Zelensky),
#   (Trump, wants, to put),
#   (Taylor, tells, Zelensky)],
#  [(one, seems, to share),
#   (impeachment, become, exercise),
#   (Trump, pressured, Ukraine),
#   (he, 's going, to say),
#   (he, is found, guilty),
#   (we, need, to find),
#   (It, doesn't pass, sniff test),
#   (I, say, that),
#   (it, hurts, feelings),
#   (retelling, will move, needle),
#   (hearings, would lay, facts),
#   (supporter Kent Jeffers, highlighted, depth),
#   (Wisconsin voter, called, it),
#   (who, watched, hearings),
#   (who, was keeping, eye),
#   (We, need, people),
#   (nothing, is going, to change),
#   (Randy Burl, told, wife),
#   (it, having, effect),
#   (they, 're giving, me),
#   (You, 're not going, to change),
#   (they, 're giving, endorsement),
#   (who, could vote, Democrat),
#   (impeachment, would change, minds),
#   (They, 're going, to turn),
#   (disclosures, will move, needle),
#   (people, would pay, attention),
#   (opposition, is going, to say),
#   (Trump, pressured, to investigate),
#   (it, 's going, to change),
#   (he, started, acting),
#   (this, will turn, tide),
#   (he, started, sounding),
#   (who, watches, soap opera),
#   (who, could vote, Republican),
#   (who, voted, GOP),
#   (what, started, to happen),
#   (It, remains, question),
#   (people, are never going, to see),
#   (independents, compromise, part),
#   (he, is found, guilty),
#   (who, feel, remorse),
#   (they, are going, to put),
#   (They, chose, reformer)],
#  [],
#  [(Washington hotel, has done, business),
#   (page, promotes, benefits),
#   (Amazon, could add, room nights),
#   (he, did not sell, assets),
#   (materials, offer, projections),
#   (People, are objecting, making),
#   (it, didn't take, advantage),
#   (Trump, created, trust),
#   (Trump, became, President),
#   (which, forbids, President),
#   (president, loves, to hate),
#   (hotel, is estimated, have),
#   (Prime Minister, booked, room),
#   (it, provide, performance data),
#   (buyer, won't own, land),
#   (he, leaves, office),
#   (refusal, has cost, it),
#   (renovation, are going, to command),
#   (Others, have raised, concerns),
#   (CEO, owns, Post),
#   (refusal, has cost, million),
#   (who, may be motivated, to curry),
#   (it, has become, magnet),
#   (it, turned, millions),
#   (company, is projecting, % jump),
#   (person, told, Journal),
#   (investor pitch, began, circulating),
#   (it, includes, numbers),
#   (he, sought, to benefit),
#   (counterpart, is trying, extract),
#   (arrangement, raises, conflicts),
#   (counterpart, is trying, to influence),
#   (location, are going, to command),
#   (Trump Organization, poured, millions),
#   (Hospitality, projects, occupancy rate),
#   (Trump, is not permitted, to sell),
#   (hotel, made, million),
#   (Trump, won, election),
#   (JLL Hotels, projects, occupancy rate),
#   (company, is hoping, get),
#   (pitch, does not include, figures),
#   (it, donated, 340,000),
#   (it, was exploring, sale),
#   (Trump, has violated, emoluments clause),
#   (sacrifices, include, turning),
#   (Trump Organization, has put, investor brochure),
#   (They, anticipating, boost)]]
