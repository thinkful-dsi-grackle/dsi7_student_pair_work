# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# For this assignment we will be using the fashion MNIST dataset.
# As stated in the original [Github repository](https://github.com/zalandoresearch/fashion-mnist):
# >Fashion-MNIST is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. We intend Fashion-MNIST to serve as a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits.
#
# One of the easiest ways to load the dataset is by using tf.keras. Our dataset will consist of 3 dimensional numpy arrays with shapes : (samples, rows, columns). In order to use the data with libraries that require 2 dimensional arrays with shapes (samples, features) we will reshape each sample by flattening each image. Instead of having an array of shape (28, 28) for each image we will now have a vector of length 784 (28x28=784).
#
# Note that below we only load the trainigng samples which we will use to perform dimensionality reduction.

# %%
(X_train, y_train), (_, _) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 3us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# We keep the class names in the following list and we also create another list named `y_train_labels` which contains the the labels for each sample. We will use these both as labels for our plots.

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

class_dict = dict(enumerate(class_names))

y_train_labels = np.vectorize(class_dict.get)(y_train)

# %% [markdown]
# We also define a function that will print a grid 5x5 of photos from the provided subset.

# %%
def plot_images(X, y):
    plt.figure(figsize=(10, 10))
    for i in range(25):
        plt.subplot(5, 5, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(X[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[y[i]])
    plt.show()

# %%
plot_images(X_train, y_train)

# %% [markdown]
# We can use images in python (and other programming languages of course) as arrays/matrices. In python a byte image of 28x28 will be represented by a numpy array of shape (28,28) with each pixel/cell having a value in the range [0, 255] with 0 being black and 255 white. The values between represent shades of gray. On the same note if we had an RBG image with colors, the same array would be a 3-dimensional numpy array of shape (28, 28, 3) where each pixel is represented by three values in the range [0, 255] for each color (Red, Green, Blue).
#
# We have seen feature scaling in the past. In order to be able to use our images with methods that are scale sensitive we divide all values by 255, thus bringing everything in the [0, 1] range.

# %%
X_train = X_train/255

# %% [markdown]
# Scikit learn methods require 2-dimensional datasets (number_of_rows, number_of_features). We tranform each image from 28 x 28 pixels to a flat array of 784 length. To find the number of features we multiply the last two dimensions.

# %%
number_of_features = X_train.shape[1] * X_train.shape[2]
X_train_reshaped = X_train.reshape(-1, number_of_features)

# %% [markdown]
# When we plot images we will require to reshape them back to 28x28 images.
#
# Also we select just a subset (1000) of our data samples and perform our exercises on this one in order to speed up execution, as our purpose is to showcase this. For more accurate/better results, we would need to do this on the whole dataset.

# %%
X_train_sub = X_train_reshaped[:1000]
y_train_labels_sub = y_train_labels[:1000]

# %%
from sklearn.decomposition import PCA
# Run PCA and keep the first two components
pca = PCA(n_components=2)
pca_ = pca.fit_transform(X_train_sub)

# %%
components = pd.DataFrame(pca_)

# %%
# Plot reduced data in two dimensions using seaborn scatterplot
import plotly.express as px
fig = px.scatter(components, x=0, y=1, color=y_train_labels_sub, title='PCA components 2')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c1041f1c-3c67-415e-9d83-dbdc2e504cb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1041f1c-3c67-415e-9d83-dbdc2e504cb4")) {
#                     Plotly.newPlot(
#                         'c1041f1c-3c67-415e-9d83-dbdc2e504cb4',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "color=
335914, 4.086355241409055, 3.1090418426704667, 5.676734247171383, 3.0200793296218293, 4.326160780396667, 2.1829603803359356, 2.5973635136823123, 3.9470868822258214, 1.6962232249408626, 3.342835081391373, 3.7412140514442753, 5.657561359159112, 5.90474167907551, 4.468150809953657, 3.457453258879485, 3.7770718658927653, 5.280493308903589, 4.972804012956622, 3.0591801391794293, 5.417589463650107, 5.486000842997565, 4.36514261817494, 5.130154049232795, 3.615846422565436, 0.9229670889326939, 5.755709616637052, 5.953578642829061, 5.623004541920045, 1.637199782296243, 5.932600798721917, 5.87695881609 ...

# %% [markdown]
# We can now inverse transform the reduced data. This means that we transform it back to the original space by using only the number of components we run PCA on (2 in our case). This will let us understand what dimensionality reduction really means. We keep a subset of these latent features that maximize the explained variance. With these plots we get an idea of what "maximum explained variance" actually means. We get images that vaguely look like our initial articles, but without the details.

# %%
inversed = pca.inverse_transform(components).reshape(-1, 28, 28)

# %%
plot_images(inversed, y_train)

# %% [markdown]
# Create t-SNE models with different amounts of perplexity (try between single and triple digits?) and plot their reduced features.

# %%
from sklearn.manifold import TSNE

tnse1 = TSNE(n_components=2, perplexity=1, n_iter=1000, verbose=1)
tnse_1 = pd.DataFrame(tnse1.fit_transform(X_train_sub))

tnse99 = TSNE(n_components=2, perplexity=99, n_iter=1000, verbose=1)
tnse_99 = pd.DataFrame(tnse99.fit_transform(X_train_sub))

tnse500 = TSNE(n_components=2, perplexity=500, n_iter=1000, verbose=1)
tnse_500 = pd.DataFrame(tnse500.fit_transform(X_train_sub))

    # Run TSNE for each of these perplexity values and transform X_train_sub
    
    
    # Plot reduced features in two dimensions using seaborn scatterplot
# Out:
# [t-SNE] Computing 4 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.066s...
# [t-SNE] Computed neighbors for 1000 samples in 1.804s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 0.470223
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.132950
# [t-SNE] KL divergence after 1000 iterations: 0.936397
# [t-SNE] Computing 298 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.072s...
# [t-SNE] Computed neighbors for 1000 samples in 2.042s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 3.340749
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.412323
# [t-SNE] KL divergence after 1000 iterations: 0.469911
# [t-SNE] Computing 999 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.001s...
# [t-SNE] Computed neighbors for 1000 samples in 0.221s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 5.857237
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 37.463276
# [t-SNE] KL divergence after 800 iterations: 0.131351

# %%
fig = px.scatter(tnse_1, x=0, y=1, color=y_train_labels_sub, title='TNSE perplexity 1')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9210e8c6-af25-44c1-90ed-87fe24460c78" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9210e8c6-af25-44c1-90ed-87fe24460c78")) {
#                     Plotly.newPlot(
#                         '9210e8c6-af25-44c1-90ed-87fe24460c78',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "color=Ankle boot<br>0=%{x}<br>1=%{y}", "legendgroup": "color=Ankle boot", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "color=
509], "xaxis": "x", "y": [1.1919363737106323, 2.598658800125122, 0.5898473858833313, 0.2972121238708496, 2.3637900352478027, 1.5246999263763428, 2.0621354579925537, 2.374735116958618, -0.11550235003232956, 0.523781955242157, -7.682014256715775e-05, 0.24836808443069458, 0.006081553176045418, 1.2386647462844849, 2.1758477687835693, -0.6446166038513184, 2.1004838943481445, -0.7155635952949524, 0.5520181655883789, 1.0254651308059692, 0.20784039795398712, -0.16088207066059113, 1.2424758672714233, 0.7528545260429382, 1.6630364656448364, -1.1731817722320557, 2.227663278579712, 0.0976548045873642, -1.1812101602554321, 1.503595232963562, 0.782240629196167, 1.9441872835159302, 0.9922047257423401, 1.0306785106658936, 0.2939017117023468, 1.2411741018295288, 2.3651320934295654, 0.4362466633319855, 1.5672729015350342, 0.002388001885265112, 1.3891195058822632, 0.7551389932632446, 0.6561494469642639, 0.43811556696891785, 0.6780364513397217, 0.05131092295050621, -0.7509683966636658, 0.37467634677886963, -0.007326177787035704, 1.5765079259872437, 0.29956111311912537, 1.425765037536621, 0.16087375581264496, 1.653754711151123, 0.7259660959243774, 0.6296746134757996, 1.5247448682785034, 1.4802212715148926, 2.120558738708496, 1.929359793663025, 0.9176359176635742, 0.3102506995201111, 0.5673415660858154, 2.159342050552368, 1.581343173980713, 1.990983009338379, 1.0070799589157104, 0.3985285460948944, 0.5190761089324951, 1.7141679525375366, -0.5162143111228943, 1.4240455627441406, 0.22239898145198822, 1.1826480627059937, 1.7490510940551758, 0.42185139656066895, 1.025338888168335, 1.7728556394577026, 0.10638146847486496, 0.2958625257015228, 0.30801987648010254, 0.743272900 ...

# %%
#!pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.6/dist-packages (0.4.6)
# Requirement already satisfied: numba!=0.47,>=0.46 in /usr/local/lib/python3.6/dist-packages (from umap-learn) (0.48.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.6/dist-packages (from umap-learn) (1.18.5)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.6/dist-packages (from umap-learn) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.6/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba!=0.47,>=0.46->umap-learn) (50.3.2)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba!=0.47,>=0.46->umap-learn) (0.31.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20->umap-learn) (0.17.0)

# %% [markdown]
# Create UMAP models with different numbers of neighbors (try between single and triple digits again) and plot their reduced features.

# %%
umap2 = umap.UMAP(n_neighbors=2)
umap2_ = pd.DataFrame(umap2.fit_transform(X_train_sub))

# %%
import umap
  # Run UMAP for each of these n_neighbors values and transform X_train_sub
umap3 = umap.UMAP(n_neighbors=3)
umap3_ = pd.DataFrame(umap3.fit_transform(X_train_sub))   

umap99 = umap.UMAP(n_neighbors=99)
umap99_ = pd.DataFrame(umap99.fit_transform(X_train_sub))   
    
umap500 = umap.UMAP(n_neighbors=500)
umap500_ = pd.DataFrame(umap500.fit_transform(X_train_sub))   

    # Plot reduced features in two dimensions using seaborn scatterplot

# %%
fig = px.scatter(umap2_, x=0, y=1, color=y_train_labels_sub, title='UMAP neighbors 2')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a9b20aae-e8e1-45bf-80c2-336297c24487" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("