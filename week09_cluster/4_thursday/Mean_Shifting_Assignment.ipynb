# %% [markdown]
# ## Day 49 Lecture 2 Assignment
#
# In this assignment, we will apply mean shift clustering to a dataset containing the results of a survey on financial wellbeing.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# This dataset contains the results of a survey on a financial wellbeing conducted by the US Consumer Finance Protection Bureau that were published in October 2017. This dataset has a large number of columns, most of which correspond to specific questions on the survey. These codebook for translating the column names to questions can be found here:
#
# https://s3.amazonaws.com/files.consumerfinance.gov/f/documents/cfpb_nfwbs-puf-codebook.pdf
#
# Load the dataset.

# %%
# answer goes here
df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Clustering/financial_wellbeing.csv')

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6394 entries, 0 to 6393
# Columns: 217 entries, PUF_ID to finalwt
# dtypes: float64(2), int64(215)
# memory usage: 10.6 MB
#    PUF_ID  sample  fpl  SWB_1  ...  PPT1317  PPT18OV  PCTLT200FPL   finalwt
# 0   10350       2    3      5  ...        0        1            0  0.367292
# 1    7740       1    3      6  ...        0        2            0  1.327561
# 2   13699       1    3      4  ...        1        2            1  0.835156
# 3    7267       1    3      6  ...        0        1            0  1.410871
# 4    7375       1    3      4  ...        0        4            1  4.260668
#
# [5 rows x 217 columns]

# %% [markdown]
# While the survey questions have the potential for interesting cluster analysis, we will stick to the "score" columns to avoid clustering in an unreasonably high-dimensional space. The columns we are interested in all have "score" in their names; identify and isolate these columns. (There should be 4 in total.)

# %%
# answer goes here
X = df.filter(like='score', axis=1)

X.head()
# Out:
#    FWBscore  FSscore  LMscore  KHscore
# 0        55       44        3    1.267
# 1        51       43        3   -0.570
# 2        49       42        3   -0.188
# 3        49       42        2   -1.485
# 4        49       42        1   -1.900

# %% [markdown]
# Standardize the features in your dataset using scikit-learn's StandardScaler, which will set the mean of each feature to 0 and the variance to 1.

# %%
# answer goes here
scale = StandardScaler()
X_scale = pd.DataFrame(scale.fit_transform(X), columns=X.columns)
X_scale.head()
# Out:
#    FWBscore   FSscore   LMscore   KHscore
# 0 -0.073062 -0.530906  0.653830  1.624716
# 1 -0.355677 -0.609920  0.653830 -0.629626
# 2 -0.496984 -0.688935  0.653830 -0.160841
# 3 -0.496984 -0.688935 -0.670399 -1.752502
# 4 -0.496984 -0.688935 -1.994628 -2.261785

# %% [markdown]
# Run mean shift clustering on the scores in the survey dataset using the default bandwidth. Then answer the following by printing or typing as appropriate:
#
# - How many clusters are produced?
# - What are the cluster centers?
# - How many responses are assigned to each cluster?
# - Are these results reasonable? If not, what changes should we make?

# %%
# answer goes here
ms = MeanShift()

df["cluster"] = ms.fit_predict(X_scale)

# %%
print("How many clusters are there: ", len(df.cluster.value_counts()))
# Out:
# How many clusters are there:  2

# %%
print("How many responses are assigned to each cluster?")
df.cluster.value_counts()
# Out:
# How many responses are assigned to each cluster?
# 0    6326
# 1      68
# Name: cluster, dtype: int64

# %%
centers = pd.DataFrame(ms.cluster_centers_,columns=X.columns)
centers_inverse = pd.DataFrame(scale.inverse_transform(centers), columns=X.columns)
print("Cluster Centers:")
centers_inverse.style.background_gradient()
# Out:
# Cluster Centers:
# <style  type="text/css" >
# #T_02e5154c_2aa4_11eb_809f_0242ac1c0002row0_col0,#T_02e5154c_2aa4_11eb_809f_0242ac1c0002row0_col1,#T_02e5154c_2aa4_11eb_809f_0242ac1c0002row0_col2,#T_02e5154c_2aa4_11eb_809f_0242ac1c0002row0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_02e5154c_2aa4_11eb_809f_0242ac1c0002row1_col0,#T_02e5154c_2aa4_11eb_809f_0242ac1c0002row1_col1,#T_02e5154c_2aa4_11eb_809f_0242ac1c0002row1_col2,#T_02e5154c_2aa4_11eb_809f_0242ac1c0002row1_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_02e5154c_2aa4_11eb_809f_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FWBscore</th>        <th class="col_heading level0 col1" >FSscore</th>        <th class="col_heading level0 col2" >LMscore</th>        <th class="col_heading level0 col3" >KHscore</th>    </tr></thead><tbody>
# ...

# %% [markdown]
# Try changing the appropriate parameters of the mean shift algorithm to achieve a better clustering result. Answer all of the same questions from the previous clustering step.

# %%
# answer goes here
ms = MeanShift(bandwidth=1.4)

df["clusters_optimal"] = ms.fit_predict(X_scale)

# %%
print("How many clusters are there: ", len(df.clusters_optimal.value_counts()))
# Out:
# How many clusters are there:  12

# %%
print("How many responses are assigned to each cluster?")
df.clusters_optimal.value_counts()
# Out:
# How many responses are assigned to each cluster?
# 0     3988
# 1     2100
# 10      91
# 5       51
# 9       43
# 11      41
# 8       21
# 6       19
# 4       19
# 2       12
# 3        8
# 7        1
# Name: clusters_optimal, dtype: int64

# %%
centers = pd.DataFrame(ms.cluster_centers_,columns=X.columns)
centers_inverse = pd.DataFrame(scale.inverse_transform(centers), columns=X.columns)
print("Optimal Cluster Centers:")
centers_inverse.style.background_gradient()
# Out:
# Optimal Cluster Centers:
# <style  type="text/css" >
# #T_11c171e4_2ab0_11eb_809f_0242ac1c0002row0_col0,#T_11c171e4_2ab0_11eb_809f_0242ac1c0002row9_col0{
#             background-color:  #328dbf;
#             color:  #000000;
#         }#T_11c171e4_2ab0_11eb_809f_0242ac1c0002row0_col1{
#             background-color:  #4295c3;
#             color:  #000000;
#         }#T_11c171e4_2ab0_11eb_809f_0242ac1c0002row0_col2{
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }#T_11c171e4_2ab0_11eb_809f_0242ac1c0002row0_col3{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_11c171e4_2ab0_11eb_809f_0242ac1c0002row1_col0{
#             background-color:  #549cc7;
#             color:  #000000;
#         }#T_11c171e4_2ab0_11eb_809f_0242ac1c0002row1_col1{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_11c171e4_2ab0_11eb_809f_0242ac1c0002row1_col2{
# ...

# %% [markdown]
# I tried a range of bandwiths from 0-10. It was very difficult to find the sweet spot for the bandwith. Some bandwith between 1.2-1.4 seems best, but the dataset has 2 really dense groups. So other bandwiths seems to group it around 0-2 groups or with dozens of groups. It was difficult to find a suitable bandwith.
