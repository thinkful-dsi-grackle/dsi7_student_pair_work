# %% [markdown]
# ## Day 49 Lecture 2 Assignment
#
# In this assignment, we will apply mean shift clustering to a dataset containing the results of a survey on financial wellbeing.

# %% [markdown]
# # IMPORTS

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# This dataset contains the results of a survey on a financial wellbeing conducted by the US Consumer Finance Protection Bureau that were published in October 2017. This dataset has a large number of columns, most of which correspond to specific questions on the survey. These codebook for translating the column names to questions can be found here:
#
# https://s3.amazonaws.com/files.consumerfinance.gov/f/documents/cfpb_nfwbs-puf-codebook.pdf
#
# Load the dataset.

# %% [markdown]
# # LOAD THE DATA

# %%
# answer goes here
data = 'https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Clustering/financial_wellbeing.csv'
df = pd.read_csv(data)

# %%
col = list(df.columns)

# %% [markdown]
# While the survey questions have the potential for interesting cluster analysis, we will stick to the "score" columns to avoid clustering in an unreasonably high-dimensional space. The columns we are interested in all have "score" in their names; identify and isolate these columns. (There should be 4 in total.)

# %% [markdown]
# # PROCESS THE DATA

# %%
# answer goes here
score = df.filter(like='score', axis=1)
score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6394 entries, 0 to 6393
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FWBscore  6394 non-null   int64
#  1   FSscore   6394 non-null   int64
#  2   LMscore   6394 non-null   int64
#  3   KHscore   6394 non-null   float64
# dtypes: float64(1), int64(3)
# memory usage: 199.9 KB

# %%
score.describe()
# Out:
#           FWBscore      FSscore      LMscore      KHscore
# count  6394.000000  6394.000000  6394.000000  6394.000000
# mean     56.034094    50.719112     2.506256    -0.056935
# std      14.154676    12.656921     0.755215     0.814936
# min      -4.000000    -1.000000     0.000000    -2.053000
# 25%      48.000000    42.000000     2.000000    -0.570000
# 50%      56.000000    50.000000     3.000000    -0.188000
# 75%      65.000000    57.000000     3.000000     0.712000
# max      95.000000    85.000000     3.000000     1.267000

# %% [markdown]
# Standardize the features in your dataset using scikit-learn's StandardScaler, which will set the mean of each feature to 0 and the variance to 1.

# %%
# answer goes here
scale = StandardScaler()
scaled = pd.DataFrame(scale.fit_transform(score), columns=score.columns)

# %% [markdown]
# Run mean shift clustering on the scores in the survey dataset using the default bandwidth. Then answer the following by printing or typing as appropriate:
#
# - How many clusters are produced?
# - What are the cluster centers?
# - How many responses are assigned to each cluster?
# - Are these results reasonable? If not, what changes should we make?

# %% [markdown]
# # BANDWIDTH DEFAULT

# %%
# answer goes here
msh = MeanShift()
msh.fit(scaled)
# Out:
# MeanShift(bandwidth=None, bin_seeding=False, cluster_all=True, max_iter=300,
#           min_bin_freq=1, n_jobs=None, seeds=None)

# %%
score['msh_cluster'] = msh.fit_predict(scaled)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print('The number of clusters produced is:', len(list(score.msh_cluster.value_counts())))
# Out:
# The number of clusters produced is: 2

# %%
msh_clus = pd.DataFrame(msh.cluster_centers_, columns=scaled.columns)
msh_inverse = pd.DataFrame(scale.inverse_transform(msh_clus), columns=scaled.columns)
unscaled = msh_inverse.style.background_gradient()

# %%
print('The cluster centers are: \n')
unscaled
# Out:
# The cluster centers are:
# <style  type="text/css" >
# #T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row0_col0,#T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row0_col1,#T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row0_col2,#T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row1_col0,#T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row1_col1,#T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row1_col2,#T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row1_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FWBscore</th>        <th class="col_heading level0 col1" >FSscore</th>        <th class="col_heading level0 col2" >LMscore</th>        <th class="col_heading level0 col3" >KHscore</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row0_col0" class="data row0 col0" >57.437953</td>
#                         <td id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row0_col1" class="data row0 col1" >50.121439</td>
#                         <td id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row0_col2" class="data row0 col2" >2.814341</td>
#                         <td id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row0_col3" class="data row0 col3" >0.217414</td>
#             </tr>
#             <tr>
#                         <th id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row1_col0" class="data row1 col0" >-1.000000</td>
#                         <td id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row1_col1" class="data row1 col1" >-1.000000</td>
#                         <td id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row1_col2" class="data row1 col2" >0.250000</td>
#                         <td id="T_33cc530a_2aa4_11eb_b4fb_0242ac1c0002row1_col3" class="data row1 col3" >-1.826000</td>
#             </tr>
#     </tbody></table>

# %%
print('The cluster values are: \n')
score.msh_cluster.value_counts()
# Out:
# The cluster values are:
# 0    6326
# 1      68
# Name: msh_cluster, dtype: int64

# %% [markdown]
# Try changing the appropriate parameters of the mean shift algorithm to achieve a better clustering result. Answer all of the same questions from the previous clustering step.

# %% [markdown]
# # BANDWIDTH 1

# %%
# answer goes here
msh1 = MeanShift(bandwidth=1)
msh1.fit(score)
score['msh_band1'] = msh1.fit_predict(scaled)

print('The number of clusters produced is:', len(list(score.msh_band1.value_counts())))
# Out:
# The number of clusters produced is: 41
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
msh_clus1 = pd.DataFrame(msh1.cluster_centers_, columns=scaled.columns)
msh_inverse1 = pd.DataFrame(scale.inverse_transform(msh_clus1), columns=scaled.columns)
unscaled1 = msh_inverse1.style.background_gradient()

print('The cluster centers are: \n')
unscaled1
# Out:
# The cluster centers are:
# <style  type="text/css" >
# #T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row0_col0,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row32_col0{
#             background-color:  #328dbf;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row0_col1{
#             background-color:  #4295c3;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row0_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row13_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row14_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row15_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row16_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row22_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row23_col0,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row23_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row24_col0,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row25_col0,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row25_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row26_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row27_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row28_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row30_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row32_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row34_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row0_col3{
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row1_col0{
#             background-color:  #549cc7;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row1_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row2_col0{
#             background-color:  #62a2cb;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row1_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row4_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row7_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row9_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row16_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row17_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row24_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row25_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row29_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row32_col2{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row1_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row10_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row35_col0{
#             background-color:  #93b5d6;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row2_col1{
#             background-color:  #75a9cf;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row2_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row5_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row6_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row8_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row10_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row26_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row31_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row36_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row39_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row40_col2{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row2_col3{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row3_col0,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row3_col1{
#             background-color:  #67a4cc;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row3_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row11_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row12_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row18_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row18_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row19_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row19_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row20_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row20_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row20_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row21_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row23_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row23_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row33_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row34_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row35_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row37_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row38_col2,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row39_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row40_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row3_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row21_col3{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row4_col0,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row28_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row36_col3{
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row4_col1{
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row4_col3{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row5_col0,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row33_col0{
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row5_col1{
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row5_col3{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row6_col0{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row6_col1{
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row6_col3{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row7_col0{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row7_col1{
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row7_col3{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row8_col0{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row8_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row12_col1{
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row8_col3,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row33_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row35_col1{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row9_col0{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row9_col1{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row9_col3{
#             background-color:  #1077b4;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row10_col0{
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row10_col1,#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row22_col3{
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row11_col0{
#             background-color:  #2d8abd;
#             color:  #000000;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row11_col1{
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }#T_e7fd32f4_2aa4_11eb_b4fb_0242ac1c0002row11_col3{
#             backgro

# %%
print('The cluster values are: \n')
score.msh_band1.value_counts()
# Out:
# The cluster values are:
# 0     3215
# 1     1353
# 2      441
# 4      229
# 9      132
# 7      130
# 25     119
# 16     117
# 15     100
# 3       85
# 5       74
# 17      63
# 14      54
# 6       39
# 13      30
# 10      25
# 11      24
# 24      19
# 32      18
# 8       14
# 22      13
# 35      12
# 36      12
# 37      11
# 27      11
# 34      10
# 38       6
# 30       5
# 40       5
# 12       5
# 33       4
# 29       4
# 18       3
# 20       2
# 31       2
# 21       2
# 19       2
# 23       1
# 28       1
# 26       1
# 39       1
# Name: msh_band1, dtype: int64

# %% [markdown]
# # BANDWIDTH 5

# %%
# answer goes here
msh5 = MeanShift(bandwidth=5)
msh5.fit(score)
score['msh_band5'] = msh5.fit_predict(scaled)

print('The number of clusters produced is:', len(list(score.msh_band5.value_counts())))
# Out:
# The number of clusters produced is: 1
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
msh_clus5 = pd.DataFrame(msh5.cluster_centers_, columns=scaled.columns)
msh_inverse5 = pd.DataFrame(scale.inverse_transform(msh_clus5), columns=scaled.columns)
unscaled5 = msh_inverse5.style.background_gradient()

print('The cluster centers are: \n')
unscaled5
# Out:
# The cluster centers are:
# <style  type="text/css" >
# #T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002row0_col0,#T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002row0_col1,#T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002row0_col2,#T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002row0_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FWBscore</th>        <th class="col_heading level0 col1" >FSscore</th>        <th class="col_heading level0 col2" >LMscore</th>        <th class="col_heading level0 col3" >KHscore</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002row0_col0" class="data row0 col0" >56.062960</td>
#                         <td id="T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002row0_col1" class="data row0 col1" >50.776821</td>
#                         <td id="T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002row0_col2" class="data row0 col2" >2.509632</td>
#                         <td id="T_4c21b192_2aa5_11eb_b4fb_0242ac1c0002row0_col3" class="data row0 col3" >-0.054264</td>
#             </tr>
#     </tbody></table>

# %%
print('The cluster values are: \n')
score.msh_band5.value_counts()
# Out:
# The cluster values are:
# 0    6394
# Name: msh_band5, dtype: int64

# %%
# answer goes here
msh2 = MeanShift(bandwidth=2)
msh2.fit(score)
score['msh_band2'] = msh2.fit_predict(scaled)

print('The number of clusters produced is:', len(list(score.msh_band2.value_counts())))
# Out:
# The number of clusters produced is: 2
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
msh_clus2 = pd.DataFrame(msh2.cluster_centers_, columns=scaled.columns)
msh_inverse2 = pd.DataFrame(scale.inverse_transform(msh_clus2), columns=scaled.columns)
unscaled2 = msh_inverse2.style.background_gradient()

print('The cluster centers are: \n')
unscaled2
# Out:
# The cluster centers are:
# <style  type="text/css" >
# #T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row0_col0,#T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row0_col1,#T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row0_col2,#T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row0_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row1_col0,#T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row1_col1,#T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row1_col2,#T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row1_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FWBscore</th>        <th class="col_heading level0 col1" >FSscore</th>        <th class="col_heading level0 col2" >LMscore</th>        <th class="col_heading level0 col3" >KHscore</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row0_col0" class="data row0 col0" >57.421547</td>
#                         <td id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row0_col1" class="data row0 col1" >50.105086</td>
#                         <td id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row0_col2" class="data row0 col2" >2.812967</td>
#                         <td id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row0_col3" class="data row0 col3" >0.215943</td>
#             </tr>
#             <tr>
#                         <th id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row1_col0" class="data row1 col0" >-1.000000</td>
#                         <td id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row1_col1" class="data row1 col1" >-1.000000</td>
#                         <td id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row1_col2" class="data row1 col2" >0.250000</td>
#                         <td id="T_d2741596_2aa5_11eb_b4fb_0242ac1c0002row1_col3" class="data row1 col3" >-1.826000</td>
#             </tr>
#     </tbody></table>

# %%
print('The cluster values are: \n')
score.msh_band2.value_counts()
# Out:
# The cluster values are:
# 0    6326
# 1      68
# Name: msh_band2, dtype: int64

# %% [markdown]
# # BANDWIDTH .5

# %%
# answer goes here
msh_5 = MeanShift(bandwidth=.5)
msh_5.fit(score)
score['msh_band_5'] = msh_5.fit_predict(scaled)

print('The number of clusters produced is:', len(list(score.msh_band_5.value_counts())))
# Out:
# The number of clusters produced is: 424
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
msh_clus_5 = pd.DataFrame(msh_5.cluster_centers_, columns=scaled.columns)
msh_inverse_5 = pd.DataFrame(scale.inverse_transform(msh_clus_5), columns=scaled.columns)
unscaled_5 = msh_inverse_5.style.background_gradient()

print('The cluster centers are: \n')
unscaled_5
# Out:
# The cluster centers are:
# <style  type="text/css" >
# #T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row0_col0,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row9_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row19_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row24_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row26_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row33_col0,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row71_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row81_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row82_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row87_col0,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row119_col0,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row318_col0,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row319_col0{
#             background-color:  #2987bc;
#             color:  #000000;
#         }#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row0_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row105_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row121_col0,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row237_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row373_col1{
#             background-color:  #358fc0;
#             color:  #000000;
#         }#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row0_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row1_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row2_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row3_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row4_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row4_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row5_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row9_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row16_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row19_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row22_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row22_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row24_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row25_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row27_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row30_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row35_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row36_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row38_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row39_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row40_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row42_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row42_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row45_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row49_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row51_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row52_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row53_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row54_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row55_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row55_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row58_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row60_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row61_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row61_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row64_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row66_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row69_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row72_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row72_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row73_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row74_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row75_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row75_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row76_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row77_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row79_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row84_col0,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row84_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row84_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row85_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row86_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row88_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row91_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row91_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row92_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row94_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row99_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row101_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row107_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row108_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row113_col0,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row113_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row113_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row114_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row114_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row115_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row116_col1,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row117_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row121_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row122_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row123_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row123_col3,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row125_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row126_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row128_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row131_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row140_col0,#T_66c2f6ea_2aa6_11eb_b4fb_0242ac1c0002row140_col2,#T_66c2f6ea_2aa6_11eb_b4fb_0 ...

# %%
print('The cluster values are: \n')
score.msh_band_5.value_counts()
# Out:
# The cluster values are:
# 2      484
# 0      480
# 4      342
# 1      320
# 3      273
#       ...
# 389      1
# 385      1
# 381      1
# 377      1
# 421      1
# Name: msh_band_5, Length: 424, dtype: int64

# %% [markdown]
# # BANDWIDTH 1.5

# %%
# answer goes here
msh1_5 = MeanShift(bandwidth=1.5)
msh1_5.fit(score)
score['msh_band1_5'] = msh1_5.fit_predict(scaled)

print('The number of clusters produced is:', len(list(score.msh_band1_5.value_counts())))
# Out:
# The number of clusters produced is: 8
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
msh_clus1_5 = pd.DataFrame(msh1_5.cluster_centers_, columns=scaled.columns)
msh_inverse1_5 = pd.DataFrame(scale.inverse_transform(msh_clus1_5), columns=scaled.columns)
unscaled1_5 = msh_inverse1_5.style.background_gradient()

print('The cluster centers are: \n')
unscaled1_5
# Out:
# The cluster centers are:
# <style  type="text/css" >
# #T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row0_col0{
#             background-color:  #3790c0;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row0_col1{
#             background-color:  #4295c3;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row0_col2{
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row0_col3{
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row1_col0{
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row1_col1{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row1_col2{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row1_col3{
#             background-color:  #79abd0;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row2_col0{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row2_col1{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row2_col2,#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row3_col0,#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row3_col1,#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row5_col2,#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row5_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row2_col3{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row3_col2,#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row3_col3{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row4_col0{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row4_col1{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row4_col2{
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row4_col3{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row5_col0,#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row5_col1,#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row6_col2,#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row6_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row6_col0{
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row6_col1{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row7_col0{
#             background-color:  #2d8abd;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row7_col1{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row7_col2{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row7_col3{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }</style><table id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FWBscore</th>        <th class="col_heading level0 col1" >FSscore</th>        <th class="col_heading level0 col2" >LMscore</th>        <th class="col_heading level0 col3" >KHscore</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row0_col0" class="data row0 col0" >58.683315</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row0_col1" class="data row0 col1" >50.565689</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row0_col2" class="data row0 col2" >2.943902</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row0_col3" class="data row0 col3" >0.378775</td>
#             </tr>
#             <tr>
#                         <th id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row1_col0" class="data row1 col0" >51.626538</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row1_col1" class="data row1 col1" >45.594903</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row1_col2" class="data row1 col2" >1.792619</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row1_col3" class="data row1 col3" >-0.705463</td>
#             </tr>
#             <tr>
#                         <th id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row2_col0" class="data row2 col0" >54.500000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row2_col1" class="data row2 col1" >6.833333</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row2_col3" class="data row2 col3" >-1.958333</td>
#             </tr>
#             <tr>
#                         <th id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row3_col0" class="data row3 col0" >-1.000000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row3_col1" class="data row3 col1" >-1.000000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row3_col2" class="data row3 col2" >0.250000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row3_col3" class="data row3 col3" >-1.826000</td>
#             </tr>
#             <tr>
#                         <th id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row4_col0" class="data row4 col0" >70.000000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row4_col1" class="data row4 col1" >11.000000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row4_col2" class="data row4 col2" >2.500000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row4_col3" class="data row4 col3" >-1.599000</td>
#             </tr>
#             <tr>
#                         <th id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row5_col0" class="data row5 col0" >95.000000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row5_col1" class="data row5 col1" >85.000000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row5_col2" class="data row5 col2" >0.000000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row5_col3" class="data row5 col3" >-2.053000</td>
#             </tr>
#             <tr>
#                         <th id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_0242ac1c0002row6_col0" class="data row6 col0" >80.000000</td>
#                         <td id="T_d613a06c_2aa6_11eb_b4fb_

# %%
print('The cluster values are: \n')
score.msh_band1_5.value_counts()
# Out:
# The cluster values are:
# 0    4096
# 1    2156
# 5      50
# 4      24
# 2      23
# 7      22
# 6      12
# 3      11
# Name: msh_band1_5, dtype: int64

# %% [markdown]
# # BANDWIDTH 1.75

# %%
# answer goes here
msh1_75 = MeanShift(bandwidth=1.75)
msh1_75.fit(score)
score['msh_band1_75'] = msh1_75.fit_predict(scaled)

print('The number of clusters produced is:', len(list(score.msh_band1_75.value_counts())))
# Out:
# The number of clusters produced is: 4
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
msh_clus1_75 = pd.DataFrame(msh1_75.cluster_centers_, columns=scaled.columns)
msh_inverse1_75 = pd.DataFrame(scale.inverse_transform(msh_clus1_75), columns=scaled.columns)
unscaled1_75 = msh_inverse1_75.style.background_gradient()

print('The cluster centers are: \n')
unscaled1_75
# Out:
# The cluster centers are:
# <style  type="text/css" >
# #T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row0_col0{
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row0_col1,#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row3_col0,#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row3_col2,#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row3_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row0_col2{
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row0_col3{
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row1_col0{
#             background-color:  #2081b9;
#             color:  #000000;
#         }#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row1_col1{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row1_col2,#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row1_col3,#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row2_col0,#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row2_col1{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row2_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row2_col3{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row3_col1{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }</style><table id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FWBscore</th>        <th class="col_heading level0 col1" >FSscore</th>        <th class="col_heading level0 col2" >LMscore</th>        <th class="col_heading level0 col3" >KHscore</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row0_col0" class="data row0 col0" >57.850949</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row0_col1" class="data row0 col1" >50.041371</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row0_col2" class="data row0 col2" >2.857183</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row0_col3" class="data row0 col3" >0.282810</td>
#             </tr>
#             <tr>
#                         <th id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row1_col0" class="data row1 col0" >54.222222</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row1_col1" class="data row1 col1" >11.333333</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row1_col2" class="data row1 col2" >0.111111</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row1_col3" class="data row1 col3" >-1.851222</td>
#             </tr>
#             <tr>
#                         <th id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row2_col0" class="data row2 col0" >-1.000000</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row2_col1" class="data row2 col1" >-1.000000</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row2_col2" class="data row2 col2" >0.250000</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row2_col3" class="data row2 col3" >-1.826000</td>
#             </tr>
#             <tr>
#                         <th id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row3_col0" class="data row3 col0" >80.000000</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row3_col1" class="data row3 col1" >10.000000</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row3_col2" class="data row3 col2" >3.000000</td>
#                         <td id="T_db22dd7e_2aa7_11eb_b4fb_0242ac1c0002row3_col3" class="data row3 col3" >0.712000</td>
#             </tr>
#     </tbody></table>

# %%
print('The cluster values are: \n')
score.msh_band1_75.value_counts()
# Out:
# The cluster values are:
# 0    5954
# 1     405
# 3      18
# 2      17
# Name: msh_band1_75, dtype: int64

# %% [markdown]
# # BANDWIDTH 1.25

# %%
# answer goes here
msh1_25 = MeanShift(bandwidth=1.25)
msh1_25.fit(score)
score['msh_band1_25'] = msh1_25.fit_predict(scaled)

print('The number of clusters produced is:', len(list(score.msh_band1_25.value_counts())))
# Out:
# The number of clusters produced is: 23
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
msh_clus1_25 = pd.DataFrame(msh1_25.cluster_centers_, columns=scaled.columns)
msh_inverse1_25 = pd.DataFrame(scale.inverse_transform(msh_clus1_25), columns=scaled.columns)
unscaled1_25 = msh_inverse1_25.style.background_gradient()

print('The cluster centers are: \n')
unscaled1_25
# Out:
# The cluster centers are:
# <style  type="text/css" >
# #T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row0_col0,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row18_col0{
#             background-color:  #328dbf;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row0_col1{
#             background-color:  #4094c3;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row0_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row8_col3,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row12_col0,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row12_col1,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row13_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row14_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row16_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row18_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row0_col3{
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row1_col0,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row22_col1{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row1_col1{
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row1_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row8_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row15_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row18_col2{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row1_col3{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row2_col0,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row3_col1{
#             background-color:  #62a2cb;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row2_col1{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row2_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row4_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row5_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row17_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row21_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row22_col2{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row2_col3{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row3_col0{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row3_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row6_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row7_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row9_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row9_col3,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row10_col1,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row10_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row11_col1,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row11_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row11_col3,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row12_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row12_col3,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row19_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row20_col2,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row21_col1,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row22_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row3_col3{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row4_col0,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row13_col3,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row19_col3,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row22_col3{
#             background-color:  #89b1d4;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row4_col1,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row14_col0{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row4_col3{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row5_col0{
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row5_col1{
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row5_col3{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row6_col0{
#             background-color:  #3991c1;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row6_col1{
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row6_col3{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row7_col0{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row7_col1{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row7_col3{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row8_col0{
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row8_col1{
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row9_col0{
#             background-color:  #2081b9;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row9_col1{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row10_col0,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row21_col0{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row10_col3{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row11_col0,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row20_col1{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row13_col0{
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row13_col1{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row14_col1,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row16_col1{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row14_col3{
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row15_col0,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row16_col0{
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row15_col1{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row15_col3,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row17_col1{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row16_col3,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row17_col3,#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row21_col3{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row17_col0{
#             background-color:  #2987bc;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row18_col1{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_c37a2000_2aa8_11eb_b4fb_0242ac1c0002row19_col0{
#             background-color:  #93b5d6;
#             color:  #000000;
#         }#T_c37a20

# %%
print('The cluster values are: \n')
score.msh_band1_25.value_counts()
# Out:
# The cluster values are:
# 0     3411
# 1     1664
# 2      466
# 8      310
# 5      138
# 4      127
# 3       96
# 18      39
# 22      24
# 19      19
# 16      17
# 13      16
# 6       15
# 20      15
# 17      10
# 7        6
# 21       6
# 15       4
# 9        3
# 10       3
# 11       3
# 14       1
# 12       1
# Name: msh_band1_25, dtype: int64

# %% [markdown]
# # BANDWIDTH CLUSTER COMPARE

# %%
print('The number of clusters produced by bandwidth=none is: ', len(list(score.msh_cluster.value_counts())))
print('The number of clusters produced by bandwidth=1 is:    ', len(list(score.msh_band1.value_counts())))
print('The number of clusters produced by bandwidth=5 is:    ', len(list(score.msh_band5.value_counts())))
print('The number of clusters produced by bandwidth=2 is:    ', len(list(score.msh_band2.value_counts())))
print('The number of clusters produced by bandwidth=.5 is:   ', len(list(score.msh_band_5.value_counts())))
print('The number of clusters produced by bandwidth=1.5 is:  ', len(list(score.msh_band1_5.value_counts())))
print('The number of clusters produced by bandwidth=1.75 is: ', len(list(score.msh_band1_75.value_counts())))
print('The number of clusters produced by bandwidth=1.25 is: ', len(list(score.msh_band1_25.value_counts())))
# Out:
# The number of clusters produced by bandwidth=none is:  2
# The number of clusters produced by bandwidth=1 is:     41
# The number of clusters produced by bandwidth=5 is:     1
# The number of clusters produced by bandwidth=2 is:     2
# The number of clusters produced by bandwidth=.5 is:    424
# The number of clusters produced by bandwidth=1.5 is:   8
# The number of clusters produced by bandwidth=1.75 is:  4
# The number of clusters produced by bandwidth=1.25 is:  23

# %% [markdown]
# # Conclusions

# %% [markdown]
# The ideal value for bandwidth really depends on the number of clusters desired. Somewhere between 1.25 and 1.5 is the ideal number of clusters. Above 2 and the model behaves worse than default. Below 1 and the amount of clusters becomes a bit unruly.
