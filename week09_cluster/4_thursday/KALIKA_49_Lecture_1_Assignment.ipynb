# %% [markdown]
# ## Day 49 Lecture 1 Assignment
#
# In this assignment, we will apply GMM (Gaussian Mixture Modeling) clustering to a dataset containing player-season statistics for NBA players from the past four years.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.special import entr

# %% [markdown]
# This dataset contains player-season statistics for NBA players from the past four years. Each row in this dataset represents a player's per-game averages for a single season.
#
# This dataset contains the following variables:
#
# - Seas: season ('2019' = 2018-2019 season, '2018' = 2017-2018 season, etc.)
# - Player: player name
# - Pos: position
# - Age: age
# - Tm: team
# - G: games played
# - GS: games started
# - MP: minutes played
# - FG: field goals
# - FGA: field goals attempted
# - FG%: field goal percentage
# - 3P: 3 pointers
# - 3PA: 3 pointers attempted
# - 3P%: 3 point percentage
# - 2P: 2 pointers
# - 2PA: 2 pointers attempted
# - 2P%: 2 point percentage
# - eFG%: effective field goal percentage
# - FT: free throws
# - FTA: free throws attempted
# - FT%: free throw percentage
# - ORB: offensive rebound
# - DRB: defensive rebound
# - TRB: total rebounds
# - AST: assists
# - STL: steals
# - BLK: blocks
# - TOV: turnovers
# - PF: personal fouls
# - PTS: points
#
# Load the dataset.

# %%
def get_df(url):
  df = pd.read_csv(url)
  return df

# %%
# answer goes here
# answer goes here
NBA_df = get_df('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Clustering/nba_player_seasons.csv')
NBA_df.head()
# Out:
#    Seas        Player Pos  Age   Tm   G  GS  ...  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2019  Álex Abrines  SG   25  OKC  31   2  ...  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2019    Quincy Acy  PF   28  PHO  10   0  ...  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  2019  Jaylen Adams  PG   22  ATL  34   1  ...  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  2019  Steven Adams   C   25  OKC  80  80  ...  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  2019   Bam Adebayo   C   21  MIA  82  28  ...  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %% [markdown]
# The goal is to cluster these player-seasons to identify potential player "archetypes".
# The pre-processing steps will be identical to what we previously did for K-means.
#
# Begin by removing players whose season did not meet one of the following criteria:
# 1. Started at least 20 games
# 2. Averaged at least 10 minutes per game

# %%
# answer goes here
gb = NBA_df.groupby(by='Player')['MP'].mean()
players =  gb[gb >= 10].index

NBA = NBA_df[(NBA_df['Player'].isin(players)) & (NBA_df['GS'] >= 20)]
NBA.head()
# Out:
#     Seas             Player Pos  Age   Tm   G  ...  AST  STL  BLK  TOV   PF   PTS
# 3   2019       Steven Adams   C   25  OKC  80  ...  1.6  1.5  1.0  1.7  2.6  13.9
# 4   2019        Bam Adebayo   C   21  MIA  82  ...  2.2  0.9  0.8  1.5  2.5   8.9
# 7   2019  LaMarcus Aldridge   C   33  SAS  81  ...  2.4  0.5  1.3  1.8  2.2  21.3
# 10  2019      Jarrett Allen   C   20  BRK  80  ...  1.4  0.5  1.5  1.3  2.3  10.9
# 12  2019    Al-Farouq Aminu  PF   28  POR  81  ...  1.3  0.8  0.4  0.9  1.8   9.4
#
# [5 rows x 30 columns]

# %% [markdown]
# Choose a subset of numeric columns that is interesting to you from an "archetypal" standpoint.
#
# We will choose the following basic statistics: **points, total rebounds, assists, steals, blocks**, and **turnovers**, but you should feel free to choose other reasonable feature sets if you like. Be careful not to include too many dimensions (curse of dimensionality).

# %%
# answer goes here

# answer goes here
cols = ['PTS', 'TRB', 'AST', 'STL', 'BLK', 'TOV']
NBA = NBA[cols]
NBA.head()
# Out:
#      PTS  TRB  AST  STL  BLK  TOV
# 3   13.9  9.5  1.6  1.5  1.0  1.7
# 4    8.9  7.3  2.2  0.9  0.8  1.5
# 7   21.3  9.2  2.4  0.5  1.3  1.8
# 10  10.9  8.4  1.4  0.5  1.5  1.3
# 12   9.4  7.5  1.3  0.8  0.4  0.9

# %% [markdown]
# Standardize the features in your dataset using scikit-learn's StandardScaler, which will set the mean of each feature to 0 and the variance to 1.

# %%
# answer goes here
# answer goes here
scale = StandardScaler()
X_std = scale.fit_transform(NBA)

# %% [markdown]
# Run both K-Means and Gaussian mixtures modeling twice, once with 3 cluster and once with 7 clusters. Print out the resulting means for all 4 scenarios (KM+3, GMM+3, KM+7, GMM+7). When printing the means, transform the scaled versions back into their corresponding unscaled values.
#
# What "archetypes" do you see? Are the archetypes identified by GMM similar to those identified by K-Means? How do the means of GMM differ from those of K-Means?

# %%
# answer goes here
# Defining the k-means
KNBA= KMeans(n_clusters=3)

# Fit model
KNBA.fit(X_std)
KNBA_df = pd.DataFrame(scale.inverse_transform(KNBA.cluster_centers_), columns=['points', 'total rebounds', 'assists', 'steals', 'blocks', 'turnovers'])
KNBA_df.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col0{
#             background-color:  #abbfdc;
#             color:  #000000;
#         }#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col1,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col4,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col0,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col2,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col3,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col2,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col3,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col0,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col1,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col4,#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col5{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col1{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col4{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col2{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col3{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }</style><table id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >points</th>        <th class="col_heading level0 col1" >total rebounds</th>        <th class="col_heading level0 col2" >assists</th>        <th class="col_heading level0 col3" >steals</th>        <th class="col_heading level0 col4" >blocks</th>        <th class="col_heading level0 col5" >turnovers</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col0" class="data row0 col0" >13.735359</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col1" class="data row0 col1" >8.605525</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col2" class="data row0 col2" >1.914917</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col3" class="data row0 col3" >0.777348</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col4" class="data row0 col4" >1.230387</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row0_col5" class="data row0 col5" >1.668508</td>
#             </tr>
#             <tr>
#                         <th id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col0" class="data row1 col0" >19.491620</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col1" class="data row1 col1" >5.293855</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col2" class="data row1 col2" >5.934078</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col3" class="data row1 col3" >1.354190</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col4" class="data row1 col4" >0.486034</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row1_col5" class="data row1 col5" >2.797765</td>
#             </tr>
#             <tr>
#                         <th id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col0" class="data row2 col0" >10.490787</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col1" class="data row2 col1" >3.945393</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col2" class="data row2 col2" >2.060000</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col3" class="data row2 col3" >0.803371</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col4" class="data row2 col4" >0.374607</td>
#                         <td id="T_b081fbbc_2a85_11eb_a42e_0242ac1c0002row2_col5" class="data row2 col5" >1.233034</td>
#             </tr>
#     </tbody></table>

# %%
# answer goes here
# Defining the k-means
KNBA= KMeans(n_clusters=7)

# Fit model
KNBA.fit(X_std)
KNBA_df = pd.DataFrame(scale.inverse_transform(KNBA.cluster_centers_), columns=['points', 'total rebounds', 'assists', 'steals', 'blocks', 'turnovers'])
KNBA_df.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col0{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col1{
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col3,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row5_col4{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col4{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col5,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col4{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col0{
#             background-color:  #2c89bd;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col1{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col2{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col3{
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col4{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col5{
#             background-color:  #569dc8;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col0{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col1{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col2{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col3{
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col5{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row3_col0{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row3_col1{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row3_col2{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row3_col3,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row3_col5{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row3_col4,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row5_col0,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row5_col1,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row5_col2,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row5_col3,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row5_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row4_col0,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row4_col2,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row4_col3,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row4_col5,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row6_col1,#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row6_col4{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row4_col1{
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row4_col4{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row6_col0{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row6_col2{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row6_col3{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row6_col5{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }</style><table id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >points</th>        <th class="col_heading level0 col1" >total rebounds</th>        <th class="col_heading level0 col2" >assists</th>        <th class="col_heading level0 col3" >steals</th>        <th class="col_heading level0 col4" >blocks</th>        <th class="col_heading level0 col5" >turnovers</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col0" class="data row0 col0" >11.523810</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col1" class="data row0 col1" >7.321769</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col2" class="data row0 col2" >1.674150</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col3" class="data row0 col3" >0.652381</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col4" class="data row0 col4" >0.938776</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row0_col5" class="data row0 col5" >1.395238</td>
#             </tr>
#             <tr>
#                         <th id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col0" class="data row1 col0" >18.717742</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col1" class="data row1 col1" >4.824194</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col2" class="data row1 col2" >5.788710</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col3" class="data row1 col3" >1.342742</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col4" class="data row1 col4" >0.408871</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row1_col5" class="data row1 col5" >2.650000</td>
#             </tr>
#             <tr>
#                         <th id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col0" class="data row2 col0" >11.410345</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col1" class="data row2 col1" >4.978161</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col2" class="data row2 col2" >2.085057</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col3" class="data row2 col3" >1.364368</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col4" class="data row2 col4" >0.511494</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row2_col5" class="data row2 col5" >1.294253</td>
#             </tr>
#             <tr>
#                         <th id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row3_col0" class="data row3 col0" >14.150000</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row3_col1" class="data row3 col1" >3.680460</td>
#                         <td id="T_ba8852e6_2a85_11eb_a42e_0242ac1c0002row3_col2" class="data row3 col2" >3.198851</td>

# %%
# answer goes here
# Defining the agglomerative clustering
gmm_cluster = GaussianMixture(n_components=3, random_state=123)

# Fit model
clusters = gmm_cluster.fit_predict(X_std)

# Fit model
gmm_df = pd.DataFrame(scale.inverse_transform(gmm_cluster.means_), columns=['points', 'total rebounds', 'assists', 'steals', 'blocks', 'turnovers'])
gmm_df.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col0,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col2,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col3,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col5,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col1,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col4{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col1{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col4{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col0,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col1,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col2,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col3,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col4,#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col0{
#             background-color:  #2a88bc;
#             color:  #000000;
#         }#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col2{
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col3{
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }#T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col5{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }</style><table id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >points</th>        <th class="col_heading level0 col1" >total rebounds</th>        <th class="col_heading level0 col2" >assists</th>        <th class="col_heading level0 col3" >steals</th>        <th class="col_heading level0 col4" >blocks</th>        <th class="col_heading level0 col5" >turnovers</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col0" class="data row0 col0" >10.049039</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col1" class="data row0 col1" >5.334392</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col2" class="data row0 col2" >1.451168</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col3" class="data row0 col3" >0.678767</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col4" class="data row0 col4" >0.585622</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row0_col5" class="data row0 col5" >1.132344</td>
#             </tr>
#             <tr>
#                         <th id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col0" class="data row1 col0" >17.008143</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col1" class="data row1 col1" >8.379988</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col2" class="data row1 col2" >4.257382</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col3" class="data row1 col3" >1.086338</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col4" class="data row1 col4" >1.173810</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row1_col5" class="data row1 col5" >2.445213</td>
#             </tr>
#             <tr>
#                         <th id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col0" class="data row2 col0" >14.594656</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col1" class="data row2 col1" >3.762327</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col2" class="data row2 col2" >3.678398</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col3" class="data row2 col3" >1.083023</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col4" class="data row2 col4" >0.317294</td>
#                         <td id="T_5b5023c0_2a86_11eb_a42e_0242ac1c0002row2_col5" class="data row2 col5" >1.860359</td>
#             </tr>
#     </tbody></table>

# %%
# answer goes here
# Defining the agglomerative clustering
gmm_cluster = GaussianMixture(n_components=7, random_state=123)

# Fit model
clusters = gmm_cluster.fit_predict(X_std)

# Fit model
gmm_df = pd.DataFrame(scale.inverse_transform(gmm_cluster.means_), columns=['points', 'total rebounds', 'assists', 'steals', 'blocks', 'turnovers'])
gmm_df.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col0,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col2,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col3,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row5_col1,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row5_col4,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row5_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col1{
#             background-color:  #94b6d7;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col4{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col5{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col0,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col2,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col5,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col3,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row4_col1,#T_622366d0_2a86_11eb_a42e_0242ac1c0002row4_col4{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col1{
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col3{
#             background-color:  #157ab5;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col4{
#             background-color:  #2c89bd;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col0{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col1{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col2{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col4{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col5{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row3_col0{
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row3_col1{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row3_col2{
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row3_col3{
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row3_col4{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row3_col5{
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row4_col0{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row4_col2{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row4_col3{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row4_col5{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row5_col0{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row5_col2{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row5_col3{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row6_col0{
#             background-color:  #4295c3;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row6_col1{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row6_col2{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row6_col3{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row6_col4{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_622366d0_2a86_11eb_a42e_0242ac1c0002row6_col5{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }</style><table id="T_622366d0_2a86_11eb_a42e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >points</th>        <th class="col_heading level0 col1" >total rebounds</th>        <th class="col_heading level0 col2" >assists</th>        <th class="col_heading level0 col3" >steals</th>        <th class="col_heading level0 col4" >blocks</th>        <th class="col_heading level0 col5" >turnovers</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_622366d0_2a86_11eb_a42e_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col0" class="data row0 col0" >8.314251</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col1" class="data row0 col1" >5.624617</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col2" class="data row0 col2" >1.268487</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col3" class="data row0 col3" >0.698495</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col4" class="data row0 col4" >0.773196</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row0_col5" class="data row0 col5" >1.067766</td>
#             </tr>
#             <tr>
#                         <th id="T_622366d0_2a86_11eb_a42e_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col0" class="data row1 col0" >18.224436</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col1" class="data row1 col1" >7.778196</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col2" class="data row1 col2" >5.332440</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col3" class="data row1 col3" >1.108604</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col4" class="data row1 col4" >0.979940</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row1_col5" class="data row1 col5" >2.762853</td>
#             </tr>
#             <tr>
#                         <th id="T_622366d0_2a86_11eb_a42e_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col0" class="data row2 col0" >11.496538</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col1" class="data row2 col1" >4.595601</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col2" class="data row2 col2" >2.669830</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col3" class="data row2 col3" >1.278338</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col4" class="data row2 col4" >0.471027</td>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row2_col5" class="data row2 col5" >1.511002</td>
#             </tr>
#             <tr>
#                         <th id="T_622366d0_2a86_11eb_a42e_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_622366d0_2a86_11eb_a42e_0242ac1c0002row3_col0" class="data row3 col0" >16.823074</td>

# %% [markdown]
# Interesting. I see the same archetypes as before, except there's a different in understanding the "team player" aspect of things. That is, in gaussian; I see that the players with most scores are grouped together as also being the ones that are contributing in all those other aspects.

# %% [markdown]
# Predict the likelihood of each player belonging to one of the 3 clusters using the GMM model. Then, calculate the entropy for each set of predicted probabilities.
#
# We will use entropy as a measure of how confident we are in the predicted class label. If we had no confidence in our prediction, we would assign 33% probability to each class, while if we were totally confident, we would assign 100% to one class. Entropy would be at a maximum in the "no confidence" scenario and a minimum in the "full confidence" scenario, which makes it a reasonable way to quantify our uncertainty in our prediction. There are certainly other methods as well; feel free to experiment with them if desired.
#
# Which five predicted labels are we least confident about? Which five are we most confident about? Print out the associated details (season, player name, stats, etc.) from those players.

# %%
# answer goes here

# answer goes here
# Defining the agglomerative clustering
gmm_cluster = GaussianMixture(n_components=3, random_state=123)

# Fit model
gmm_cluster.fit_predict(X_std)
clusters = gmm_cluster.predict_proba(X_std)

gmm_df = pd.concat([pd.DataFrame(clusters), NBA_df], join='inner', axis=1)
gmm_df
# Out:
#                 0         1             2  Seas  ...  BLK  TOV   PF   PTS
# 0    5.393271e-01  0.460667  6.229032e-06  2019  ...  0.2  0.5  1.7   5.3
# 1    9.563940e-01  0.043587  1.920420e-05  2019  ...  0.4  0.4  2.4   1.7
# 2    2.929699e-01  0.707030  1.043125e-13  2019  ...  0.1  0.8  1.3   3.2
# 3    8.761998e-01  0.123800  2.603168e-17  2019  ...  1.0  1.7  2.6  13.9
# 4    9.965320e-01  0.003458  9.625118e-06  2019  ...  0.8  1.5  2.5   8.9
# ..            ...       ...           ...   ...  ...  ...  ...  ...   ...
# 800  7.527314e-20  0.006723  9.932775e-01  2018  ...  0.5  1.7  2.6  14.1
# 801  1.076958e-01  0.000387  8.919168e-01  2018  ...  0.2  0.9  1.2   7.6
# 802  9.860148e-01  0.013984  1.099454e-06  2018  ...  0.4  0.7  1.9   9.2
# 803  7.312385e-01  0.268067  6.949682e-04  2018  ...  0.1  0.7  0.6   6.3
# 804  9.971108e-01  0.002876  1.319681e-05  2018  ...  0.7  0.4  1.6   5.4
#
# [805 rows x 33 columns]

# %% [markdown]
# The bulk of the confidence lies in the first class.

# %%
#Most Confident would be a probability > 66%
gmm_df.nlargest(5, 1)
# Out:
#                 0    1             2  Seas  ...  BLK  TOV   PF  PTS
# 246  1.056428e-21  1.0  1.520940e-21  2019  ...  0.0  0.3  0.0  0.0
# 259  1.002022e-17  1.0  2.619291e-19  2019  ...  0.1  0.3  0.4  4.7
# 454  1.202867e-17  1.0  6.702939e-36  2019  ...  0.3  1.0  1.7  6.7
# 6    4.471822e-15  1.0  6.351628e-20  2019  ...  0.0  0.3  0.6  1.0
# 405  3.892082e-15  1.0  1.521039e-17  2019  ...  0.9  0.6  1.6  5.5
#
# [5 rows x 33 columns]

# %%
#Least Confident would be a probablity < 33%
gmm_df.nsmallest(5, 1)
# Out:
#             0         1         2  Seas        Player  ...  STL  BLK  TOV   PF   PTS
# 668  0.846636  0.000028  0.153336  2018    Larry Drew  ...  0.0  0.0  0.3  0.6   1.7
# 63   0.874534  0.000030  0.125435  2019  Tony Bradley  ...  0.7  0.7  1.0  2.0   5.7
# 762  0.857479  0.000033  0.142489  2018   Serge Ibaka  ...  0.4  1.3  1.2  2.8  12.6
# 533  0.897747  0.000039  0.102214  2018   Bam Adebayo  ...  0.5  0.6  1.0  2.0   6.9
# 59   0.797911  0.000041  0.202048  2019   Isaac Bonga  ...  0.4  0.2  0.3  0.4   0.9
#
# [5 rows x 33 columns]
