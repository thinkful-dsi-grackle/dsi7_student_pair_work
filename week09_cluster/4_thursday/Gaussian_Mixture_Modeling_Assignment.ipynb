# %% [markdown]
# ## Day 49 Lecture 1 Assignment
#
# In this assignment, we will apply GMM (Gaussian Mixture Modeling) clustering to a dataset containing player-season statistics for NBA players from the past four years.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.special import entr

# %% [markdown]
# This dataset contains player-season statistics for NBA players from the past four years. Each row in this dataset represents a player's per-game averages for a single season.
#
# This dataset contains the following variables:
#
# - Seas: season ('2019' = 2018-2019 season, '2018' = 2017-2018 season, etc.)
# - Player: player name
# - Pos: position
# - Age: age
# - Tm: team
# - G: games played
# - GS: games started
# - MP: minutes played
# - FG: field goals
# - FGA: field goals attempted
# - FG%: field goal percentage
# - 3P: 3 pointers
# - 3PA: 3 pointers attempted
# - 3P%: 3 point percentage
# - 2P: 2 pointers
# - 2PA: 2 pointers attempted
# - 2P%: 2 point percentage
# - eFG%: effective field goal percentage
# - FT: free throws
# - FTA: free throws attempted
# - FT%: free throw percentage
# - ORB: offensive rebound
# - DRB: defensive rebound
# - TRB: total rebounds
# - AST: assists
# - STL: steals
# - BLK: blocks
# - TOV: turnovers
# - PF: personal fouls
# - PTS: points
#
# Load the dataset.

# %%
# answer goes here
df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Clustering/nba_player_seasons.csv')

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2141 entries, 0 to 2140
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Seas    2141 non-null   int64
#  1   Player  2141 non-null   object
#  2   Pos     2141 non-null   object
#  3   Age     2141 non-null   int64
#  4   Tm      2141 non-null   object
#  5   G       2141 non-null   int64
#  6   GS      2141 non-null   int64
#  7   MP      2141 non-null   float64
#  8   FG      2141 non-null   float64
#  9   FGA     2141 non-null   float64
#  10  FG%     2131 non-null   float64
#  11  3P      2141 non-null   float64
#  12  3PA     2141 non-null   float64
#  13  3P%     1967 non-null   float64
#  14  2P      2141 non-null   float64
#  15  2PA     2141 non-null   float64
#  16  2P%     2110 non-null   float64
#  17  eFG%    2131 non-null   float64
#  18  FT      2141 non-null   float64
#  19  FTA     2141 non-null   float64
#  20  FT%     2037 non-null   float64
#  21  ORB     2141 non-null   float64
#  22  DRB     2141 non-null   float64
#  23  TRB     2141 non-null   float64
#  24  AST     2141 non-null   float64
#  25  STL     2141 non-null   float64
#  26  BLK     2141 non-null   float64
#  27  TOV     2141 non-null   float64
#  28  PF      2141 non-null   float64
#  29  PTS     2141 non-null   float64
# dtypes: float64(23), int64(4), object(3)
# memory usage: 501.9+ KB
#    Seas        Player Pos  Age   Tm   G  GS  ...  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2019  Álex Abrines  SG   25  OKC  31   2  ...  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2019    Quincy Acy  PF   28  PHO  10   0  ...  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  2019  Jaylen Adams  PG   22  ATL  34   1  ...  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  2019  Steven Adams   C   25  OKC  80  80  ...  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  2019   Bam Adebayo   C   21  MIA  82  28  ...  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %% [markdown]
# The goal is to cluster these player-seasons to identify potential player "archetypes".
# The pre-processing steps will be identical to what we previously did for K-means.
#
# Begin by removing players whose season did not meet one of the following criteria:
# 1. Started at least 20 games
# 2. Averaged at least 10 minutes per game

# %%
# answer goes here
nba = df.loc[(df['GS'] >= 20) & (df['MP'] >= 10)]

nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804 entries, 3 to 2139
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Seas    804 non-null    int64
#  1   Player  804 non-null    object
#  2   Pos     804 non-null    object
#  3   Age     804 non-null    int64
#  4   Tm      804 non-null    object
#  5   G       804 non-null    int64
#  6   GS      804 non-null    int64
#  7   MP      804 non-null    float64
#  8   FG      804 non-null    float64
#  9   FGA     804 non-null    float64
#  10  FG%     804 non-null    float64
#  11  3P      804 non-null    float64
#  12  3PA     804 non-null    float64
#  13  3P%     771 non-null    float64
#  14  2P      804 non-null    float64
#  15  2PA     804 non-null    float64
#  16  2P%     804 non-null    float64
#  17  eFG%    804 non-null    float64
#  18  FT      804 non-null    float64
#  19  FTA     804 non-null    float64
#  20  FT%     804 non-null    float64
#  21  ORB     804 non-null    float64
#  22  DRB     804 non-null    float64
#  23  TRB     804 non-null    float64
#  24  AST     804 non-null    float64
#  25  STL     804 non-null    float64
#  26  BLK     804 non-null    float64
#  27  TOV     804 non-null    float64
#  28  PF      804 non-null    float64
#  29  PTS     804 non-null    float64
# dtypes: float64(23), int64(4), object(3)
# memory usage: 194.7+ KB

# %% [markdown]
# Choose a subset of numeric columns that is interesting to you from an "archetypal" standpoint.
#
# We will choose the following basic statistics: **points, total rebounds, assists, steals, blocks**, and **turnovers**, but you should feel free to choose other reasonable feature sets if you like. Be careful not to include too many dimensions (curse of dimensionality).

# %%
# answer goes here
X = nba.loc[:,['PTS','TRB','AST','STL','BLK','TOV']]

X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804 entries, 3 to 2139
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PTS     804 non-null    float64
#  1   TRB     804 non-null    float64
#  2   AST     804 non-null    float64
#  3   STL     804 non-null    float64
#  4   BLK     804 non-null    float64
#  5   TOV     804 non-null    float64
# dtypes: float64(6)
# memory usage: 44.0 KB

# %% [markdown]
# Standardize the features in your dataset using scikit-learn's StandardScaler, which will set the mean of each feature to 0 and the variance to 1.

# %%
# answer goes here
scale = StandardScaler()
X_scale = pd.DataFrame(scale.fit_transform(X), columns=X.columns)

# %% [markdown]
# Run both K-Means and Gaussian mixtures modeling twice, once with 3 cluster and once with 7 clusters. Print out the resulting means for all 4 scenarios (KM+3, GMM+3, KM+7, GMM+7). When printing the means, transform the scaled versions back into their corresponding unscaled values.
#
# What "archetypes" do you see? Are the archetypes identified by GMM similar to those identified by K-Means? How do the means of GMM differ from those of K-Means?

# %%
# kmeans 3 cluster
kmeans = KMeans(n_clusters=3)

kmeans.fit_predict(X_scale)

centers = pd.DataFrame(kmeans.cluster_centers_,columns=X.columns)

centers_inverse = pd.DataFrame(scale.inverse_transform(centers), columns=X.columns)
kmeans_3_cluster = centers_inverse.style.background_gradient()
centers_inverse.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col0,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col1,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col4,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col5,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col2,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col2{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col3{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col0{
#             background-color:  #abbfdc;
#             color:  #000000;
#         }#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col1,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col4,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col0,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col2,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col3,#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col5{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col1{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col4{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }</style><table id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PTS</th>        <th class="col_heading level0 col1" >TRB</th>        <th class="col_heading level0 col2" >AST</th>        <th class="col_heading level0 col3" >STL</th>        <th class="col_heading level0 col4" >BLK</th>        <th class="col_heading level0 col5" >TOV</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col0" class="data row0 col0" >10.505405</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col1" class="data row0 col1" >3.949775</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col2" class="data row0 col2" >2.063739</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col3" class="data row0 col3" >0.804730</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col4" class="data row0 col4" >0.374324</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row0_col5" class="data row0 col5" >1.235135</td>
#             </tr>
#             <tr>
#                         <th id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col0" class="data row1 col0" >13.735359</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col1" class="data row1 col1" >8.605525</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col2" class="data row1 col2" >1.914917</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col3" class="data row1 col3" >0.777348</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col4" class="data row1 col4" >1.230387</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row1_col5" class="data row1 col5" >1.668508</td>
#             </tr>
#             <tr>
#                         <th id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col0" class="data row2 col0" >19.491620</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col1" class="data row2 col1" >5.293855</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col2" class="data row2 col2" >5.934078</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col3" class="data row2 col3" >1.354190</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col4" class="data row2 col4" >0.486034</td>
#                         <td id="T_88ef89ec_2aae_11eb_b055_0242ac1c0002row2_col5" class="data row2 col5" >2.797765</td>
#             </tr>
#     </tbody></table>

# %%
#gmm 3 cluster
gmm3 = GaussianMixture(n_components=3)
gmm3.fit(X_scale)

gmm_centers = pd.DataFrame(gmm3.means_, columns=X_scale.columns)
gmm_centers_inverse = pd.DataFrame(scale.inverse_transform(gmm_centers), columns=X_scale.columns)
gmm_centers_inverse.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col0,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col2,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col5,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col3,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col1,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col4{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col1{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col3{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col4{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col0{
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col1,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col4,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col0,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col2,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col3,#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col2{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col5{
#             background-color:  #2d8abd;
#             color:  #000000;
#         }</style><table id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PTS</th>        <th class="col_heading level0 col1" >TRB</th>        <th class="col_heading level0 col2" >AST</th>        <th class="col_heading level0 col3" >STL</th>        <th class="col_heading level0 col4" >BLK</th>        <th class="col_heading level0 col5" >TOV</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col0" class="data row0 col0" >10.228179</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col1" class="data row0 col1" >4.504354</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col2" class="data row0 col2" >1.579742</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col3" class="data row0 col3" >0.779853</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col4" class="data row0 col4" >0.433706</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row0_col5" class="data row0 col5" >1.107959</td>
#             </tr>
#             <tr>
#                         <th id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col0" class="data row1 col0" >14.550186</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col1" class="data row1 col1" >8.524727</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col2" class="data row1 col2" >2.279152</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col3" class="data row1 col3" >0.777242</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col4" class="data row1 col4" >1.230885</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row1_col5" class="data row1 col5" >1.842771</td>
#             </tr>
#             <tr>
#                         <th id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col0" class="data row2 col0" >15.895675</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col1" class="data row2 col1" >4.173718</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col2" class="data row2 col2" >4.807518</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col3" class="data row2 col3" >1.176113</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col4" class="data row2 col4" >0.370977</td>
#                         <td id="T_88fc8f52_2aae_11eb_b055_0242ac1c0002row2_col5" class="data row2 col5" >2.244243</td>
#             </tr>
#     </tbody></table>

# %%
#k means 7 cluster
kmeans = KMeans(n_clusters=7)

kmeans.fit_predict(X_scale)

centers = pd.DataFrame(kmeans.cluster_centers_,columns=X.columns)

centers_inverse = pd.DataFrame(scale.inverse_transform(centers), columns=X.columns)
kmeans_7_cluster = centers_inverse.style.background_gradient()
centers_inverse.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col0{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col1{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col2{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col3{
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col4{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col5{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col0{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col1{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col3{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col4{
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col5{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col0,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col2,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col3,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col5,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row5_col1,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row5_col4{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col1{
#             background-color:  #197db7;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col4{
#             background-color:  #abbfdc;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row3_col0{
#             background-color:  #2d8abd;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row3_col1{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row3_col2{
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row3_col3{
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row3_col4{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row3_col5{
#             background-color:  #509ac6;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row4_col0{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row4_col1{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row4_col2{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row4_col3{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row4_col4,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row6_col0,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row6_col1,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row6_col2,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row6_col3,#T_8913a19c_2aae_11eb_b055_0242ac1c0002row6_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row4_col5{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row5_col0{
#             background-color:  #4295c3;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row5_col2{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row5_col3{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row5_col5{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_8913a19c_2aae_11eb_b055_0242ac1c0002row6_col4{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }</style><table id="T_8913a19c_2aae_11eb_b055_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PTS</th>        <th class="col_heading level0 col1" >TRB</th>        <th class="col_heading level0 col2" >AST</th>        <th class="col_heading level0 col3" >STL</th>        <th class="col_heading level0 col4" >BLK</th>        <th class="col_heading level0 col5" >TOV</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8913a19c_2aae_11eb_b055_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col0" class="data row0 col0" >11.285714</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col1" class="data row0 col1" >4.885714</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col2" class="data row0 col2" >2.130769</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col3" class="data row0 col3" >1.354945</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col4" class="data row0 col4" >0.498901</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row0_col5" class="data row0 col5" >1.300000</td>
#             </tr>
#             <tr>
#                         <th id="T_8913a19c_2aae_11eb_b055_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col0" class="data row1 col0" >11.526490</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col1" class="data row1 col1" >7.282119</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col2" class="data row1 col2" >1.688079</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col3" class="data row1 col3" >0.655629</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col4" class="data row1 col4" >0.936424</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row1_col5" class="data row1 col5" >1.394040</td>
#             </tr>
#             <tr>
#                         <th id="T_8913a19c_2aae_11eb_b055_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col0" class="data row2 col0" >24.603226</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col1" class="data row2 col1" >8.374194</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col2" class="data row2 col2" >7.803226</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col3" class="data row2 col3" >1.603226</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col4" class="data row2 col4" >0.809677</td>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row2_col5" class="data row2 col5" >3.941935</td>
#             </tr>
#             <tr>
#                         <th id="T_8913a19c_2aae_11eb_b055_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8913a19c_2aae_11eb_b055_0242ac1c0002row3_col0" class="data row3 col0" >18.556452</td>
#                         <td id="T_8913a19c_2aae_

# %%
#gmm 7 cluster
gmm7 = GaussianMixture(n_components=7)
gmm7.fit(X_scale)

gmm_centers = pd.DataFrame(gmm7.means_, columns=X_scale.columns)
gmm_centers_inverse = pd.DataFrame(scale.inverse_transform(gmm_centers), columns=X_scale.columns)
gmm_centers_inverse.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col0{
#             background-color:  #3790c0;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col1,#T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col4,#T_892292ba_2aae_11eb_b055_0242ac1c0002row4_col0,#T_892292ba_2aae_11eb_b055_0242ac1c0002row4_col2,#T_892292ba_2aae_11eb_b055_0242ac1c0002row4_col5,#T_892292ba_2aae_11eb_b055_0242ac1c0002row6_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col2,#T_892292ba_2aae_11eb_b055_0242ac1c0002row5_col0{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col3,#T_892292ba_2aae_11eb_b055_0242ac1c0002row3_col2{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col5{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col0{
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col1{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col2{
#             background-color:  #2484ba;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col3{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col4{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col5{
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col0,#T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col1,#T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col2,#T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col3,#T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col5,#T_892292ba_2aae_11eb_b055_0242ac1c0002row3_col4{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col4{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row3_col0{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row3_col1{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row3_col3{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row3_col5{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row4_col1{
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row4_col3{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row4_col4{
#             background-color:  #569dc8;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row5_col1{
#             background-color:  #549cc7;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row5_col2{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row5_col3{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row5_col4{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row5_col5{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row6_col0{
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row6_col1{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row6_col2{
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row6_col4{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_892292ba_2aae_11eb_b055_0242ac1c0002row6_col5{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }</style><table id="T_892292ba_2aae_11eb_b055_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PTS</th>        <th class="col_heading level0 col1" >TRB</th>        <th class="col_heading level0 col2" >AST</th>        <th class="col_heading level0 col3" >STL</th>        <th class="col_heading level0 col4" >BLK</th>        <th class="col_heading level0 col5" >TOV</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_892292ba_2aae_11eb_b055_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col0" class="data row0 col0" >16.530193</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col1" class="data row0 col1" >9.282297</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col2" class="data row0 col2" >2.923970</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col3" class="data row0 col3" >0.896829</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col4" class="data row0 col4" >1.359077</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row0_col5" class="data row0 col5" >2.120127</td>
#             </tr>
#             <tr>
#                         <th id="T_892292ba_2aae_11eb_b055_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col0" class="data row1 col0" >17.983791</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col1" class="data row1 col1" >3.939510</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col2" class="data row1 col2" >5.635105</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col3" class="data row1 col3" >1.134762</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col4" class="data row1 col4" >0.300336</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row1_col5" class="data row1 col5" >2.542821</td>
#             </tr>
#             <tr>
#                         <th id="T_892292ba_2aae_11eb_b055_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col0" class="data row2 col0" >7.971222</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col1" class="data row2 col1" >3.468278</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col2" class="data row2 col2" >1.338104</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col3" class="data row2 col3" >0.625561</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col4" class="data row2 col4" >0.348648</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row2_col5" class="data row2 col5" >0.883253</td>
#             </tr>
#             <tr>
#                         <th id="T_892292ba_2aae_11eb_b055_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row3_col0" class="data row3 col0" >13.010276</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row3_col1" class="data row3 col1" >3.713215</td>
#                         <td id="T_892292ba_2aae_11eb_b055_0242ac1c0002row3_col2" class="

# %% [markdown]
# Overall the archetypes seem pretty similiar between K-Means and GMM. You do see more differences between groups with 7 clusters vs 3 clusters. However, in the 3 cluster's points category K-means has a much higher number than GMM. This is a result of the particlur centroid for this cluster having a much higher value than the cluster mean. K-means uses a particular data point as the centroid where as GMM uses the mean of the entire cluster. So we will see some differences if the K-Means centroid differs much from the acutal cluster mean.

# %% [markdown]
# Predict the likelihood of each player belonging to one of the 3 clusters using the GMM model. Then, calculate the entropy for each set of predicted probabilities.
#
# We will use entropy as a measure of how confident we are in the predicted class label. If we had no confidence in our prediction, we would assign 33% probability to each class, while if we were totally confident, we would assign 100% to one class. Entropy would be at a maximum in the "no confidence" scenario and a minimum in the "full confidence" scenario, which makes it a reasonable way to quantify our uncertainty in our prediction. There are certainly other methods as well; feel free to experiment with them if desired.
#
# Which five predicted labels are we least confident about? Which five are we most confident about? Print out the associated details (season, player name, stats, etc.) from those players.

# %%
# answer goes here
X = df[['PTS','TRB','AST','STL','BLK','TOV']]
X_scale = pd.DataFrame(scale.fit_transform(X), columns=X.columns)

gmm3 = GaussianMixture(n_components=3)
gmm3.fit(X_scale)

X["cluster"] = gmm3.fit_predict(X_scale)

probs = pd.DataFrame(gmm3.predict_proba(X_scale))
entropy = entr(probs)
entropy['entropy'] = entropy[0] + entropy[1] + entropy[2]
entropy['entropy']

X_probs = pd.concat([X, entropy], axis=1)
X_probs.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     PTS  TRB  AST  STL  BLK  ...  cluster         0         1         2   entropy
# 0   5.3  1.5  0.6  0.5  0.2  ...        1  0.013432  0.021482  0.076853  0.111766
# 1   1.7  2.5  0.8  0.1  0.4  ...        1  0.039700  0.011703  0.019749  0.071152
# 2   3.2  1.8  1.9  0.4  0.1  ...        2  0.076065  0.353825  0.344508  0.774398
# 3  13.9  9.5  1.6  1.5  1.0  ...        0  0.000006  0.000066  0.000011  0.000083
# 4   8.9  7.3  2.2  0.9  0.8  ...        0  0.016600  0.067754  0.001930  0.086283
#
# [5 rows x 11 columns]

# %%
# least amount of confidence in predicited labels
X_probs.sort_values(by='entropy', ascending=False).head()
# Out:
#        PTS  TRB  AST  STL  BLK  ...  cluster         0         1         2   entropy
# 1590   3.8  3.1  1.0  0.7  0.0  ...        0  0.364940  0.350629  0.365090  1.080659
# 915   11.8  4.5  1.2  1.0  0.4  ...        2  0.366379  0.347070  0.365156  1.078605
# 2058   5.8  3.8  1.7  1.0  0.4  ...        2  0.324037  0.367581  0.365148  1.056766
# 1445  14.0  4.6  2.0  0.7  0.3  ...        2  0.352862  0.344786  0.350498  1.048145
# 1816   4.5  3.4  1.0  0.9  0.2  ...        1  0.324016  0.355583  0.365798  1.045397
#
# [5 rows x 11 columns]

# %%
# most amount of confidence in predicited labels
X_probs.sort_values(by='entropy', ascending=True).head()
# Out:
#        PTS   TRB  AST  STL  ...    0              1              2        entropy
# 1580   6.0  10.0  1.0  0.0  ... -0.0  2.332941e-250  7.804590e-261  2.332941e-250
# 2117  14.2  11.8  0.4  0.6  ... -0.0   6.561753e-67   3.896346e-85   6.561753e-67
# 1578   4.0   5.5  0.5  0.0  ... -0.0   1.667081e-57   9.516034e-65   1.667081e-57
# 484   13.3   7.2  1.6  0.8  ... -0.0   2.118958e-37   3.204021e-43   2.118961e-37
# 940   22.7   6.6  1.2  0.8  ... -0.0   7.389275e-41   2.587124e-31   2.587124e-31
#
# [5 rows x 11 columns]
