# %% [markdown]
# ## Keras and TensorFlow
#
# In this assignment, we will learn about Keras and TensorFlow. We will create a neural network and measure the model's performance.

# %%
import numpy as np
import pandas as pd

# %%
cancer = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/breast_cancer.csv')

# %%
cancer.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# We'll start with some data cleaning. First remove the id column since we have no use for it. Then check for missing data and remove all rows containing missing data.

# %%
# Answer below:
cancer = cancer.drop('id', axis=1).dropna()
cancer
# Out:
#     diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0           M        17.99  ...          0.4601                  0.11890
# 1           M        20.57  ...          0.2750                  0.08902
# 2           M        19.69  ...          0.3613                  0.08758
# 3           M        11.42  ...          0.6638                  0.17300
# 4           M        20.29  ...          0.2364                  0.07678
# ..        ...          ...  ...             ...                      ...
# 564         M        21.56  ...          0.2060                  0.07115
# 565         M        20.13  ...          0.2572                  0.06637
# 566         M        16.60  ...          0.2218                  0.07820
# 567         M        20.60  ...          0.4087                  0.12400
# 568         B         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %% [markdown]
# The diagnosis columnn is our target variable. How many possible values are in this variable?

# %%
# Answer below:
cancer.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# Create one or multiple dummy variables for this column and store this encoded data in a numpy array called `target`

# %%
# Answer below:
cancer['target'] = pd.get_dummies(cancer.diagnosis, drop_first=True)
cancer['target'].value_counts()
# Out:
# 0    357
# 1    212
# Name: target, dtype: int64

# %% [markdown]
# When looking at the columm names, you may have noticed that for each attribute we have a mean of the attribute, a standard error, and a worst value. Let's create a list of column names for only the means columns. Use this list to create a new dataframe containing only the means columns.

# %%
# Answer below:
means = cancer[['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean']]
means
# Out:
#      radius_mean  texture_mean  ...  symmetry_mean  fractal_dimension_mean
# 0          17.99         10.38  ...         0.2419                 0.07871
# 1          20.57         17.77  ...         0.1812                 0.05667
# 2          19.69         21.25  ...         0.2069                 0.05999
# 3          11.42         20.38  ...         0.2597                 0.09744
# 4          20.29         14.34  ...         0.1809                 0.05883
# ..           ...           ...  ...            ...                     ...
# 564        21.56         22.39  ...         0.1726                 0.05623
# 565        20.13         28.25  ...         0.1752                 0.05533
# 566        16.60         28.08  ...         0.1590                 0.05648
# 567        20.60         29.33  ...         0.2397                 0.07016
# 568         7.76         24.54  ...         0.1587                 0.05884
#
# [569 rows x 10 columns]

# %% [markdown]
# Split the data into train and test samples. The test sample should contain 20% of the data.

# %%
# Answer below:
y = cancer.target
X = means
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Now we'll use the minmax scaler to ensure that all columns have values between zero and 1. Apply this transformations for all columns to be used in the prediction.

# %%
# Answer below:
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
X_train_scale = scale.fit_transform(X_train)
X_test_scale = scale.transform(X_test)

# %% [markdown]
# Now we can proceed with our model. In the cell below, import the `Sequential`, and `Dense` functions.

# %%
# Answer below:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# create a model that takes the training data and predicts the target variable. The model will have 3 layers. The input layer should be of unit size 12 and the hidden layer will be of size 10. The output layer size will be determined by the size of the target variable. Use the sigmoid activation function for the last layer

# %%
X_train_scale.shape
# Out:
# (455, 10)

# %%
# Answer below
model = Sequential()
model.add(Dense(12, input_shape=X_train.shape, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_31 (Dense)             (None, 455, 12)           132
# _________________________________________________________________
# dense_32 (Dense)             (None, 455, 10)           130
# _________________________________________________________________
# dense_33 (Dense)             (None, 455, 1)            11
# =================================================================
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile and fit the model. Use the adam optimizer and the binary crossentropy loss function. Train the model for 200 epochs with a batch size of 80. Make sure touse the test data into the model as well.

# %%
# Answer below:
model.compile(optimizer='Adam', loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train_scale, y_train, batch_size=80, epochs=200,verbose=1)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Model was constructed with shape (None, 455, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 455, 10), dtype=tf.float32, name='dense_31_input'), name='dense_31_input', description="created by layer 'dense_31_input'"), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 455, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 455, 10), dtype=tf.float32, name='dense_31_input'), name='dense_31_input', description="created by layer 'dense_31_input'"), but it was called on an input with incompatible shape (None, 10).
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7326 - accuracy: 0.6394
# Epoch 2/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7273 - accuracy: 0.6340
# Epoch 3/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7182 - accuracy: 0.6352
# Epoch 4/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7080 - accuracy: 0.6317
# Epoch 5/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7067 - accuracy: 0.6188
# Epoch 6/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7010 - accuracy: 0.6186
# Epoch 7/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6827 - accuracy: 0.6456
# Epoch 8/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.6134
# Epoch 9/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6699 - accuracy: 0.6439
# Epoch 10/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6754 - accuracy: 0.6154
# Epoch 11/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6703 - accuracy: 0.6141
# Epoch 12/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6604 - accuracy: 0.6255
# Epoch 13/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6533 - accuracy: 0.6240
# Epoch 14/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6443 - accuracy: 0.6314
# Epoch 15/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.6413
# Epoch 16/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6393 - accuracy: 0.6108
# Epoch 17/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6352 - accuracy: 0.6077
# Epoch 18/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6263 - accuracy: 0.6111
# Epoch 19/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6193 - accuracy: 0.6126
# Epoch 20/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6078 - accuracy: 0.6293
# Epoch 21/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5975 - accuracy: 0.6338
# Epoch 22/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6143 - accuracy: 0.5852
# Epoch 23/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5988 - accuracy: 0.6093
# Epoch 24/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5875 - accuracy: 0.6155
# Epoch 25/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5819 - accuracy: 0.6147
# Epoch 26/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5655 - accuracy: 0.6316
# Epoch 27/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5701 - accuracy: 0.6060
# Epoch 28/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5431 - accuracy: 0.6511
# Epoch 29/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5321 - accuracy: 0.6495
# Epoch 30/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5348 - accuracy: 0.6521
# Epoch 31/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5262 - accuracy: 0.7222
# Epoch 32/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5163 - accuracy: 0.7665
# Epoch 33/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5111 - accuracy: 0.7868
# Epoch 34/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5128 - accuracy: 0.7925
# Epoch 35/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5025 - accuracy: 0.7977
# Epoch 36/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.8096
# Epoch 37/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4811 - accuracy: 0.8261
# Epoch 38/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4675 - accuracy: 0.8346
# Epoch 39/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.8691
# Epoch 40/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.8685
# Epoch 41/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4409 - accuracy: 0.8655
# Epoch 42/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4361 - accuracy: 0.8665
# Epoch 43/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4295 - accuracy: 0.8675
# Epoch 44/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8743
# Epoch 45/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4063 - accuracy: 0.8765
# Epoch 46/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4048 - accuracy: 0.8773
# Epoch 47/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3836 - accuracy: 0.8825
# Epoch 48/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8840
# Epoch 49/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3677 - accuracy: 0.8938
# Epoch 50/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3607 - accuracy: 0.9005
# Epoch 51/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3365 - accuracy: 0.9032
# Epoch 52/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.8914
# Epoch 53/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8998
# Epoch 54/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8986
# Epoch 55/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3255 - accuracy: 0.8963
# Epoch 56/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3216 - accuracy: 0.8987
# Epoch 57/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.8865
# Epoch 58/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2883 - accuracy: 0.9098
# Epoch 59/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2962 - accuracy: 0.9086
# Epoch 60/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2927 - accuracy: 0.9112
# Epoch 61/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2730 - accuracy: 0.9210
# Epoch 62/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2924 - accuracy: 0.9015
# Epoch 63/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2732 - accuracy: 0.9139
# Epoch 64/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2548 - accuracy: 0.9174
# Epoch 65/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2659 - accuracy: 0.9046
# Epoch 66/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2644 - accuracy: 0.9041
# Epoch 67/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2653 - accuracy: 0.9041
# Epoch 68/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2661 - accuracy: 0.9186
# Epoch 69/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.9225
# Epoch 70/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2407 - accuracy: 0.9221
# Epoch 71/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9275
# Epoch 72/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2382 - accuracy: 0.9126
# Epoch 73/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2345 - accuracy: 0.9208
# Epoch 74/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2299 - accuracy: 0.9149
# Epoch 75/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2153 - accuracy: 0.9212
# Epoch 76/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2372 - accuracy: 0.9146
# Epoch 77/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2263 - accuracy: 0.9156
# Epoch 78/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2179 - accuracy: 0.9197
# Epoch 79/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2208 - accuracy: 0.9119
# Epoch 80/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2071 - accuracy: 0.9241
# Epoch 81/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2043 - accuracy: 0.9360
# Epoch 82/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2042 - accuracy: 0.9167
# Epoch 83/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1938 - accuracy: 0.9234
# Epoch 84/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1806 - accuracy: 0.9342
# Epoch 85/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2129 - accuracy: 0.9133
# Epoch 86/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1909 - accuracy: 0.9236
# Epoch 87/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2084 - accuracy: 0.9136
# Epoch 88/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2068 - accuracy: 0.9191
# Epoch 89/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2140 - accuracy: 0.9046
# Epoch 90/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2079 - accuracy: 0.9198
# Epoch 91/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1990 - accuracy: 0.9100
# Epoch 92/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1892 - accuracy: 0.9199
# Epoch 93/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1741 - accuracy: 0.9308
# Epoch 94/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2118 - accuracy: 0.9088
# Epoch 95/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1933 - accuracy: 0.9129
# Epoch 96/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2001 - accuracy: 0.9163
# Epoch 97/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2015 - accuracy: 0.9100
# Epoch 98/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1853 - accuracy: 0.9280
# Epoch 99/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1899 - accuracy: 0.9176
# Epoch 100/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1853 - accuracy: 0.9212
# Epoch 101/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1732 - accuracy: 0.9354
# Epoch 102/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1911 - accuracy: 0.9186
# Epoch 103/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1799 - accuracy: 0.9213
# Epoch 104/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1911 - accuracy: 0.9242
# Epoch 105/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1997 - accuracy: 0.9035
# Epoch 106/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1765 - accuracy: 0.9241
# Epoch 107/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1652 - accuracy: 0.9357
# Epoch 108/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1728 - accuracy: 0.9300
# Epoch 109/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1639 - accuracy: 0.9308
# Epoch 110/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1860 - accuracy: 0.9149
# Epoch 111/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1721 - accuracy: 0.9218
# Epoch 112/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1827 - accuracy: 0.9231
# Epoch 113/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1719 - accuracy: 0.9349
# Epoch 114/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1648 - accuracy: 0.9283
# Epoch 115/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1681 - accuracy: 0.9285
# Epoch 116/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1814 - accuracy: 0.9228
# Epoch 117/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1739 - accuracy: 0.9185
# Epoch 118/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1779 - accuracy: 0.9215
# Epoch 119/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1672 - accuracy: 0.9294
# Epoch 120/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1575 - accuracy: 0.9277
# Epoch 121/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1574 - accuracy: 0.9269
# Epoch 122/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1835 - accuracy: 0.9186
# Epoch 123/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.9412
# Epoch 124/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1660 - accuracy: 0.9238
# Epoch 125/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1556 - accuracy: 0.9336
# Epoch 126/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1739 - accuracy: 0.9174
# Epoch 127/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1742 - accuracy: 0.9209
# Epoch 128/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1640 - accuracy: 0.9258
# Epoch 129/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1587 - accuracy: 0.9302
# Epoch 130/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1727 - accuracy: 0.9208
# Epoch 131/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1765 - accuracy: 0.9132
# Epoch 132/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1525 - accuracy: 0.9237
# Epoch 133/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1700 - accuracy: 0.9285
# Epoch 134/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1576 - accuracy: 0.9365
# Epoch 135/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1866 - accuracy: 0.9145
# Epoch 136/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1714 - accuracy: 0.9221
# Epoch 137/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1591 - accuracy: 0.9349
# Epoch 138/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1716 - accuracy: 0.9161
# Epoch 139/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1527 - accuracy: 0.9403
# Epoch 140/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1921 - accuracy: 0.9173
# Epoch 141/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1484 - accuracy: 0.9288
# Epoch 142/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1562 - accuracy: 0.9337
# Epoch 143/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1654 - accuracy: 0.9316
# Epoch 144/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1467 - accuracy: 0.9387
# Epoch 145/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1430 - accuracy: 0.9418
# Epoch 146/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1692 - accuracy: 0.9209
# Epoch 147/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1629 - accuracy: 0.9273
# Epoch 148/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1634 - accuracy: 0.9194
# Epoch 149/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1604 - accuracy: 0.9417
# Epoch 150/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1426 - accuracy: 0.9358
# Epoch 151/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 0.9303
# Epoch 152/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1664 - accuracy: 0.9341
# Epoch 153/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1555 - accuracy: 0.9294
# Epoch 154/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1580 - accuracy: 0.9291
# Epoch 155/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1456 - accuracy: 0.9399
# Epoch 156/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1524 - accuracy: 0.9360
# Epoch 157/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1427 - accuracy: 0.9251
# Epoch 158/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1423 - accuracy: 0.9324
# Epoch 159/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1314 - accuracy: 0.9448
# Epoch 160/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1371 - accuracy: 0.9391
# Epoch 161/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1448 - accuracy: 0.9433
# Epoch 162/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1703 - accuracy: 0.9338
# Epoch 163/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1627 - accuracy: 0.9330
# Epoch 164/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1391 - accuracy: 0.9410
# Epoch 165/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1415 - accuracy: 0.9410
# Epoch 166/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1486 - accuracy: 0.9318
# Epoch 167/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9255
# Epoch 168/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1656 - accuracy: 0.9349
# Epoch 169/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1656 - accuracy: 0.9257
# Epoch 170/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1635 - accuracy: 0.9320
# Epoch 171/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1511 - accuracy: 0.9415
# Epoch 172/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1582 - accuracy: 0.9408
# Epoch 173/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1432 - accuracy: 0.9505
# Epoch 174/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1605 - accuracy: 0.9295
# Epoch 175/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1623 - accuracy: 0.9369
# Epoch 176/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1398 - accuracy: 0.9372
# Epoch 177/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1604 - accuracy: 0.9371
# Epoch 178/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1510 - accuracy: 0.9366
# Epoch 179/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9539
# Epoch 180/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1345 - accuracy: 0.9447
# Epoch 181/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1314 - accuracy: 0.9541
# Epoch 182/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1691 - accuracy: 0.9314
# Epoch 183/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9517
# Epoch 184/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1396 - accuracy: 0.9467
# Epoch 185/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9467
# Epoch 186/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1423 - accuracy: 0.9442
# Epoch 187/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1439 - accuracy: 0.9377
# Epoch 188/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1452 - accuracy: 0.9466
# Epoch 189/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1589 - accuracy: 0.9220
# Epoch 190/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1381 - accuracy: 0.9442
# Epoch 191/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1477 - accuracy: 0.9449
# Epoch 192/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9554
# Epoch 193/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1440 - accuracy: 0.9395
# Epoch 194/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9397
# Epoch 195/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1436 - accuracy: 0.9380
# Epoch 196/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1453 - accuracy: 0.9496
# Epoch 197/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1513 - accuracy: 0.9399
# Epoch 198/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1369 - accuracy: 0.9404
# Epoch 199/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1570 - accuracy: 0.9395
# Epoch 200/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1372 - accuracy: 0.9435

# %% [markdown]
# Report the accuracy of the test sample.

# %%
# Answer below:
score = model.evaluate(X_test_scale,y_test,verbose=0)
print('Test Score: ', score[0])
print('Test Accuracy: ', score[1])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 455, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 455, 10), dtype=tf.float32, name='dense_31_input'), name='dense_31_input', description="created by layer 'dense_31_input'"), but it was called on an input with incompatible shape (None, 10).
# Test Score:  0.2177049219608307
# Test Accuracy:  0.9035087823867798
