# %% [markdown]
# ## Keras and TensorFlow
#
# In this assignment, we will learn about Keras and TensorFlow. We will create a neural network and measure the model's performance.

# %%
import numpy as np
import pandas as pd

# %%
cancer = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/breast_cancer.csv')

# %%
cancer.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# We'll start with some data cleaning. First remove the id column since we have no use for it. Then check for missing data and remove all rows containing missing data.

# %%
# Answer below:
cancer.drop("id", axis=1, inplace=True)

# %%
cancer.dropna(inplace=True)

# %%
cancer.isnull().mean()
# Out:
# diagnosis                  0.0
# radius_mean                0.0
# texture_mean               0.0
# perimeter_mean             0.0
# area_mean                  0.0
# smoothness_mean            0.0
# compactness_mean           0.0
# concavity_mean             0.0
# concave points_mean        0.0
# symmetry_mean              0.0
# fractal_dimension_mean     0.0
# radius_se                  0.0
# texture_se                 0.0
# perimeter_se               0.0
# area_se                    0.0
# smoothness_se              0.0
# compactness_se             0.0
# concavity_se               0.0
# concave points_se          0.0
# symmetry_se                0.0
# fractal_dimension_se       0.0
# radius_worst               0.0
# texture_worst              0.0
# perimeter_worst            0.0
# area_worst                 0.0
# smoothness_worst           0.0
# compactness_worst          0.0
# concavity_worst            0.0
# concave points_worst       0.0
# symmetry_worst             0.0
# fractal_dimension_worst    0.0
# dtype: float64

# %% [markdown]
# The diagnosis columnn is our target variable. How many possible values are in this variable?

# %%
# Answer below:
cancer.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# There are two possible values for *diagnosis*

# %% [markdown]
# Create one or multiple dummy variables for this column and store this encoded data in a numpy array called `target`

# %%
# Answer below:
cancer['target'] = cancer.diagnosis.map({'M':1, 'B':0})
cancer.head(20)
# Out:
#    diagnosis  radius_mean  ...  fractal_dimension_worst  target
# 0          M        17.99  ...                  0.11890       1
# 1          M        20.57  ...                  0.08902       1
# 2          M        19.69  ...                  0.08758       1
# 3          M        11.42  ...                  0.17300       1
# 4          M        20.29  ...                  0.07678       1
# 5          M        12.45  ...                  0.12440       1
# 6          M        18.25  ...                  0.08368       1
# 7          M        13.71  ...                  0.11510       1
# 8          M        13.00  ...                  0.10720       1
# 9          M        12.46  ...                  0.20750       1
# 10         M        16.02  ...                  0.08452       1
# 11         M        15.78  ...                  0.10480       1
# 12         M        19.17  ...                  0.10230       1
# 13         M        15.85  ...                  0.06287       1
# 14         M        13.73  ...                  0.14310       1
# 15         M        14.54  ...                  0.13410       1
# 16         M        14.68  ...                  0.08216       1
# 17         M        16.13  ...                  0.11420       1
# 18         M        19.81  ...                  0.07615       1
# 19         B        13.54  ...                  0.07259       0
#
# [20 rows x 32 columns]

# %% [markdown]
# When looking at the columm names, you may have noticed that for each attribute we have a mean of the attribute, a standard error, and a worst value. Let's create a list of column names for only the means columns. Use this list to create a new dataframe containing only the means columns.

# %%
# Answer below:
mean_cols = cancer.filter(like="_mean")

# %%
mean_cols.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_mean  fractal_dimension_mean
# 0        17.99         10.38  ...         0.2419                 0.07871
# 1        20.57         17.77  ...         0.1812                 0.05667
# 2        19.69         21.25  ...         0.2069                 0.05999
# 3        11.42         20.38  ...         0.2597                 0.09744
# 4        20.29         14.34  ...         0.1809                 0.05883
#
# [5 rows x 10 columns]

# %% [markdown]
# Split the data into train and test samples. The test sample should contain 20% of the data.

# %%
# Answer below
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(mean_cols, cancer.target, test_size=0.2)

# %% [markdown]
# Now we'll use the minmax scaler to ensure that all columns have values between zero and 1. Apply this transformations for all columns to be used in the prediction.

# %%
# Answer below:
from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler()
X_train_ = mmscaler.fit_transform(X_train)
X_test_ = mmscaler.transform(X_test)

# %% [markdown]
# Now we can proceed with our model. In the cell below, import the `Sequential`, and `Dense` functions.

# %%
# Answer below:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# create a model that takes the training data and predicts the target variable. The model will have 3 layers. The input layer should be of unit size 12 and the hidden layer will be of size 10. The output layer size will be determined by the size of the target variable. Use the sigmoid activation function for the last layer

# %%
X_train_.shape
# Out:
# (455, 10)

# %%
# Answer below
model = Sequential()
# input layer
model.add(Dense(12, input_shape=X_train_.shape, activation="relu"))
# hidden layer
model.add(Dense(6, activation="relu"))
# output layer
model.add(Dense(1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 455, 12)           132
# _________________________________________________________________
# dense_13 (Dense)             (None, 455, 6)            78
# _________________________________________________________________
# dense_14 (Dense)             (None, 455, 1)            7
# =================================================================
# Total params: 217
# Trainable params: 217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile and fit the model. Use the adam optimizer and the binary crossentropy loss function. Train the model for 200 epochs with a batch size of 80. Make sure touse the test data into the model as well.

# %%
# Answer below:
model.compile(optimizer="Adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.fit(X_train_, y_train, batch_size=80, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Model was constructed with shape (None, 455, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 455, 10), dtype=tf.float32, name='dense_12_input'), name='dense_12_input', description="created by layer 'dense_12_input'"), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 455, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 455, 10), dtype=tf.float32, name='dense_12_input'), name='dense_12_input', description="created by layer 'dense_12_input'"), but it was called on an input with incompatible shape (None, 10).
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.6258
# Epoch 2/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6744 - accuracy: 0.6417
# Epoch 3/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6646 - accuracy: 0.6633
# Epoch 4/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6638 - accuracy: 0.6697
# Epoch 5/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6511 - accuracy: 0.7207
# Epoch 6/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6389 - accuracy: 0.7462
# Epoch 7/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6299 - accuracy: 0.7647
# Epoch 8/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6203 - accuracy: 0.7653
# Epoch 9/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6153 - accuracy: 0.7735
# Epoch 10/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6072 - accuracy: 0.7930
# Epoch 11/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5864 - accuracy: 0.8207
# Epoch 12/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5786 - accuracy: 0.8278
# Epoch 13/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5663 - accuracy: 0.8131
# Epoch 14/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5512 - accuracy: 0.8312
# Epoch 15/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5420 - accuracy: 0.8300
# Epoch 16/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5302 - accuracy: 0.8400
# Epoch 17/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5206 - accuracy: 0.8509
# Epoch 18/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5133 - accuracy: 0.8303
# Epoch 19/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5015 - accuracy: 0.8381
# Epoch 20/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4808 - accuracy: 0.8611
# Epoch 21/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4693 - accuracy: 0.8623
# Epoch 22/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4496 - accuracy: 0.8780
# Epoch 23/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4468 - accuracy: 0.8567
# Epoch 24/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4227 - accuracy: 0.8893
# Epoch 25/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4126 - accuracy: 0.8715
# Epoch 26/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8767
# Epoch 27/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8745
# Epoch 28/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3820 - accuracy: 0.8748
# Epoch 29/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8730
# Epoch 30/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3568 - accuracy: 0.8685
# Epoch 31/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8871
# Epoch 32/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3565 - accuracy: 0.8695
# Epoch 33/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3210 - accuracy: 0.8918
# Epoch 34/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3274 - accuracy: 0.8816
# Epoch 35/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3058 - accuracy: 0.8907
# Epoch 36/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2894 - accuracy: 0.8960
# Epoch 37/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3028 - accuracy: 0.8790
# Epoch 38/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2851 - accuracy: 0.8965
# Epoch 39/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2821 - accuracy: 0.8934
# Epoch 40/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2613 - accuracy: 0.9086
# Epoch 41/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8924
# Epoch 42/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2630 - accuracy: 0.8962
# Epoch 43/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2527 - accuracy: 0.8965
# Epoch 44/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2532 - accuracy: 0.9019
# Epoch 45/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2419 - accuracy: 0.9133
# Epoch 46/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2363 - accuracy: 0.9166
# Epoch 47/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2139 - accuracy: 0.9220
# Epoch 48/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2149 - accuracy: 0.9215
# Epoch 49/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2215 - accuracy: 0.9074
# Epoch 50/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2462 - accuracy: 0.8965
# Epoch 51/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2075 - accuracy: 0.9240
# Epoch 52/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2201 - accuracy: 0.9099
# Epoch 53/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2047 - accuracy: 0.9217
# Epoch 54/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.9215
# Epoch 55/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2089 - accuracy: 0.9183
# Epoch 56/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 0.9203
# Epoch 57/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2102 - accuracy: 0.9191
# Epoch 58/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1898 - accuracy: 0.9281
# Epoch 59/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1869 - accuracy: 0.9340
# Epoch 60/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1847 - accuracy: 0.9281
# Epoch 61/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1919 - accuracy: 0.9201
# Epoch 62/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1974 - accuracy: 0.9198
# Epoch 63/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1978 - accuracy: 0.9108
# Epoch 64/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1769 - accuracy: 0.9409
# Epoch 65/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1783 - accuracy: 0.9390
# Epoch 66/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1717 - accuracy: 0.9323
# Epoch 67/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1843 - accuracy: 0.9214
# Epoch 68/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1729 - accuracy: 0.9292
# Epoch 69/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1666 - accuracy: 0.9373
# Epoch 70/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1907 - accuracy: 0.9154
# Epoch 71/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1678 - accuracy: 0.9330
# Epoch 72/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1800 - accuracy: 0.9290
# Epoch 73/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1571 - accuracy: 0.9371
# Epoch 74/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9238
# Epoch 75/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.9285
# Epoch 76/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1566 - accuracy: 0.9427
# Epoch 77/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1822 - accuracy: 0.9240
# Epoch 78/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1633 - accuracy: 0.9351
# Epoch 79/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1625 - accuracy: 0.9364
# Epoch 80/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9205
# Epoch 81/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1610 - accuracy: 0.9279
# Epoch 82/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1765 - accuracy: 0.9164
# Epoch 83/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1586 - accuracy: 0.9381
# Epoch 84/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1541 - accuracy: 0.9349
# Epoch 85/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1650 - accuracy: 0.9386
# Epoch 86/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1632 - accuracy: 0.9295
# Epoch 87/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1616 - accuracy: 0.9361
# Epoch 88/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1816 - accuracy: 0.9156
# Epoch 89/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9374
# Epoch 90/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.9428
# Epoch 91/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1479 - accuracy: 0.9438
# Epoch 92/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1728 - accuracy: 0.9292
# Epoch 93/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1631 - accuracy: 0.9337
# Epoch 94/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1484 - accuracy: 0.9394
# Epoch 95/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1467 - accuracy: 0.9402
# Epoch 96/200
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1635 - accuracy: 0.9302
# Epoch 97/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1648 - accuracy: 0.9243
# Epoch 98/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1541 - accuracy: 0.9359
# Epoch 99/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9342
# Epoch 100/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1383 - accuracy: 0.9453
# Epoch 101/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.9356
# Epoch 102/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1469 - accuracy: 0.9354
# Epoch 103/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1386 - accuracy: 0.9449
# Epoch 104/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1616 - accuracy: 0.9414
# Epoch 105/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1501 - accuracy: 0.9442
# Epoch 106/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1673 - accuracy: 0.9269
# Epoch 107/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1675 - accuracy: 0.9332
# Epoch 108/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1563 - accuracy: 0.9346
# Epoch 109/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1585 - accuracy: 0.9353
# Epoch 110/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1610 - accuracy: 0.9376
# Epoch 111/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1413 - accuracy: 0.9494
# Epoch 112/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1551 - accuracy: 0.9278
# Epoch 113/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1427 - accuracy: 0.9390
# Epoch 114/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1667 - accuracy: 0.9272
# Epoch 115/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9442
# Epoch 116/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1582 - accuracy: 0.9309
# Epoch 117/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1577 - accuracy: 0.9298
# Epoch 118/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9256
# Epoch 119/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1497 - accuracy: 0.9417
# Epoch 120/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1627 - accuracy: 0.9264
# Epoch 121/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1238 - accuracy: 0.9462
# Epoch 122/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1495 - accuracy: 0.9304
# Epoch 123/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1284 - accuracy: 0.9472
# Epoch 124/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1652 - accuracy: 0.9407
# Epoch 125/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1461 - accuracy: 0.9350
# Epoch 126/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1455 - accuracy: 0.9271
# Epoch 127/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1399 - accuracy: 0.9464
# Epoch 128/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1482 - accuracy: 0.9433
# Epoch 129/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1427 - accuracy: 0.9340
# Epoch 130/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9332
# Epoch 131/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1192 - accuracy: 0.9607
# Epoch 132/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1438 - accuracy: 0.9431
# Epoch 133/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.9352
# Epoch 134/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 0.9348
# Epoch 135/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1322 - accuracy: 0.9414
# Epoch 136/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1363 - accuracy: 0.9375
# Epoch 137/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1437 - accuracy: 0.9344
# Epoch 138/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1369 - accuracy: 0.9414
# Epoch 139/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1297 - accuracy: 0.9504
# Epoch 140/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1393 - accuracy: 0.9459
# Epoch 141/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1288 - accuracy: 0.9505
# Epoch 142/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1450 - accuracy: 0.9424
# Epoch 143/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1348 - accuracy: 0.9419
# Epoch 144/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1389 - accuracy: 0.9465
# Epoch 145/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1447 - accuracy: 0.9432
# Epoch 146/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1422 - accuracy: 0.9380
# Epoch 147/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1406 - accuracy: 0.9357
# Epoch 148/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1566 - accuracy: 0.9330
# Epoch 149/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1403 - accuracy: 0.9375
# Epoch 150/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1502 - accuracy: 0.9266
# Epoch 151/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1327 - accuracy: 0.9472
# Epoch 152/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9589
# Epoch 153/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1460 - accuracy: 0.9404
# Epoch 154/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.9500
# Epoch 155/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1378 - accuracy: 0.9475
# Epoch 156/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.9547
# Epoch 157/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1231 - accuracy: 0.9490
# Epoch 158/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1546 - accuracy: 0.9307
# Epoch 159/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9413
# Epoch 160/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1347 - accuracy: 0.9411
# Epoch 161/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1662 - accuracy: 0.9337
# Epoch 162/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1627 - accuracy: 0.9330
# Epoch 163/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1377 - accuracy: 0.9438
# Epoch 164/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1706 - accuracy: 0.9248
# Epoch 165/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9537
# Epoch 166/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1279 - accuracy: 0.9524
# Epoch 167/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1471 - accuracy: 0.9435
# Epoch 168/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1212 - accuracy: 0.9552
# Epoch 169/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1608 - accuracy: 0.9358
# Epoch 170/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 0.9417
# Epoch 171/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1544 - accuracy: 0.9407
# Epoch 172/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1502 - accuracy: 0.9403
# Epoch 173/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1298 - accuracy: 0.9480
# Epoch 174/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1416 - accuracy: 0.9407
# Epoch 175/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9541
# Epoch 176/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1181 - accuracy: 0.9542
# Epoch 177/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1441 - accuracy: 0.9446
# Epoch 178/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1347 - accuracy: 0.9454
# Epoch 179/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1372 - accuracy: 0.9447
# Epoch 180/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1271 - accuracy: 0.9479
# Epoch 181/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1361 - accuracy: 0.9421
# Epoch 182/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9485
# Epoch 183/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1310 - accuracy: 0.9414
# Epoch 184/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.9416
# Epoch 185/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1290 - accuracy: 0.9539
# Epoch 186/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1305 - accuracy: 0.9498
# Epoch 187/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1386 - accuracy: 0.9514
# Epoch 188/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 0.9466
# Epoch 189/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1234 - accuracy: 0.9538
# Epoch 190/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9530
# Epoch 191/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1203 - accuracy: 0.9567
# Epoch 192/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1481 - accuracy: 0.9494
# Epoch 193/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1422 - accuracy: 0.9382
# Epoch 194/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9529
# Epoch 195/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1436 - accuracy: 0.9348
# Epoch 196/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1394 - accuracy: 0.9463
# Epoch 197/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1350 - accuracy: 0.9415
# Epoch 198/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1278 - accuracy: 0.9491
# Epoch 199/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1396 - accuracy: 0.9451
# Epoch 200/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1298 - accuracy: 0.9465

# %% [markdown]
# Report the accuracy of the test sample.

# %%
# Answer below:
accuracy = model.evaluate(X_test_, y_test, verbose=0)
print(f"Scaled Test Accuracy: {accuracy[1]}")
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 455, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 455, 10), dtype=tf.float32, name='dense_12_input'), name='dense_12_input', description="created by layer 'dense_12_input'"), but it was called on an input with incompatible shape (None, 10).
# Scaled Test Accuracy: 0.9210526347160339
