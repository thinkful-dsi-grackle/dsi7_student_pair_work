# %% [markdown]
# ## Day 22 Lecture 1 Assignment
#
# In this assignment, we will do some EDA to uncover basic patterns in our datasets. We will be using both the FIFA ratings dataset and the Chicago traffic crash dataset.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
crash_data = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/traffic_crashes_chicago.csv')
soccer_data = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/fifa_ratings.csv')

# %%
soccer_data.head()
# Out:
#        ID               Name  Overall  ...  Marking  StandingTackle  SlidingTackle
# 0  158023           L. Messi       94  ...       33              28             26
# 1   20801  Cristiano Ronaldo       94  ...       28              31             23
# 2  190871          Neymar Jr       92  ...       27              24             33
# 3  192985       K. De Bruyne       91  ...       68              58             51
# 4  183277          E. Hazard       91  ...       34              27             22
#
# [5 rows x 32 columns]

# %%
crash_data.head()
# Out:
#       RD_NO       CRASH_DATE  ...  INJURIES_NO_INDICATION INJURIES_UNKNOWN
# 0  JC334993   7/4/2019 22:33  ...                     NaN              NaN
# 1  JC370822  7/30/2019 10:22  ...                     NaN              NaN
# 2  JC387098  8/10/2019 17:00  ...                     NaN              NaN
# 3  JC395195  8/16/2019 16:53  ...                     1.0              0.0
# 4  JC396604  8/17/2019 16:04  ...                     1.0              0.0
#
# [5 rows x 41 columns]

# %% [markdown]
# We will start with the FIFA dataset, which consists entirely of numeric features (we will ignore the player ID and name). Create a histogram of each numeric column in the dataset. What do you notice about the distributions of scores? Are there any particular distributions that jump out?

# %%
# answer goes here
#Most of the histograms are normally distributed except 'Interceptions','Marking', 'StandingTackles', and 'SlidingTackles'


plt.hist(soccer_data['Overall'])
# Out:
# 'Marking'

# %%
plt.hist(soccer_data['Crossing'])
# Out:
# (array([  34.,  604., 1455., 1739., 2290., 3888., 3721., 1885.,  461.,
#           45.]),
#  array([11. , 19.2, 27.4, 35.6, 43.8, 52. , 60.2, 68.4, 76.6, 84.8, 93. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data['Finishing'])
# Out:
# (array([ 286., 1474., 2172., 1818., 2356., 3024., 3360., 1326.,  278.,
#           28.]),
#  array([10. , 18.5, 27. , 35.5, 44. , 52.5, 61. , 69.5, 78. , 86.5, 95. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[5]])
# Out:
# (array([  20.,  132.,  816., 2200., 3280., 4273., 3362., 1669.,  339.,
#           31.]),
#  array([15. , 22.9, 30.8, 38.7, 46.6, 54.5, 62.4, 70.3, 78.2, 86.1, 94. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[6]])
# Out:
# (array([  23.,  144.,  369., 1011., 2156., 4245., 5401., 2231.,  491.,
#           51.]),
#  array([20. , 27.3, 34.6, 41.9, 49.2, 56.5, 63.8, 71.1, 78.4, 85.7, 93. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[7]])
# Out:
# (array([ 121., 1083., 2404., 2620., 2897., 2720., 2439., 1337.,  427.,
#           74.]),
#  array([10., 18., 26., 34., 42., 50., 58., 66., 74., 82., 90.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[8]])
# Out:
# (array([  83.,  423.,  630., 1107., 2157., 4248., 5102., 1965.,  375.,
#           32.]),
#  array([14. , 22.3, 30.6, 38.9, 47.2, 55.5, 63.8, 72.1, 80.4, 88.7, 97. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[9]])
# Out:
# (array([  57.,  838., 2042., 2713., 2738., 2822., 2955., 1410.,  494.,
#           53.]),
#  array([11. , 19.3, 27.6, 35.9, 44.2, 52.5, 60.8, 69.1, 77.4, 85.7, 94. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[10]])
# Out:
# (array([  71., 1033., 3528., 3276., 2386., 2430., 1871., 1245.,  257.,
#           25.]),
#  array([10. , 18.4, 26.8, 35.2, 43.6, 52. , 60.4, 68.8, 77.2, 85.6, 94. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[11]])
# Out:
# (array([ 225.,  744., 1300., 1729., 2830., 4503., 3176., 1384.,  209.,
#           22.]),
#  array([19. , 26.4, 33.8, 41.2, 48.6, 56. , 63.4, 70.8, 78.2, 85.6, 93. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[12]])
# Out:
# (array([ 135.,  251.,  623., 1399., 3141., 5053., 3769., 1420.,  295.,
#           36.]),
#  array([25. , 32.1, 39.2, 46.3, 53.4, 60.5, 67.6, 74.7, 81.8, 88.9, 96. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[13]])
# Out:
# (array([   8.,  251.,  354.,  624., 1773., 3487., 4236., 3683., 1355.,
#          351.]),
#  array([20. , 27.7, 35.4, 43.1, 50.8, 58.5, 66.2, 73.9, 81.6, 89.3, 97. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[14 ]])
# Out:
# (array([ 109.,  280.,  353.,  928., 1804., 3708., 4245., 3002., 1283.,
#          410.]),
#  array([25. , 32.1, 39.2, 46.3, 53.4, 60.5, 67.6, 74.7, 81.8, 88.9, 96. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[15]])
# Out:
# (array([  60.,  336.,  512., 1189., 2112., 3267., 4386., 2714., 1145.,
#          401.]),
#  array([23. , 30.3, 37.6, 44.9, 52.2, 59.5, 66.8, 74.1, 81.4, 88.7, 96. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[16]])
# Out:
# (array([1.000e+00, 2.000e+01, 2.580e+02, 1.202e+03, 3.893e+03, 5.067e+03,
#         4.077e+03, 1.312e+03, 2.750e+02, 1.700e+01]),
#  array([21. , 28.5, 36. , 43.5, 51. , 58.5, 66. , 73.5, 81. , 88.5, 96. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[17]])
# Out:
# (array([  27.,  349.,  497.,  861., 1877., 3794., 3971., 3238., 1093.,
#          415.]),
#  array([22. , 29.4, 36.8, 44.2, 51.6, 59. , 66.4, 73.8, 81.2, 88.6, 96. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[18]])
# Out:
# (array([  68.,  322.,  876., 1510., 2287., 3605., 4024., 2607.,  772.,
#           51.]),
#  array([14. , 22.1, 30.2, 38.3, 46.4, 54.5, 62.6, 70.7, 78.8, 86.9, 95. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[19]])
# Out:
# (array([ 243.,  311.,  594., 1188., 2802., 3848., 3534., 2327.,  975.,
#          300.]),
#  array([28. , 34.7, 41.4, 48.1, 54.8, 61.5, 68.2, 74.9, 81.6, 88.3, 95. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[20]])
# Out:
# (array([ 124.,  203.,  383., 1347., 2357., 3961., 4066., 2429.,  969.,
#          283.]),
#  array([27. , 33.9, 40.8, 47.7, 54.6, 61.5, 68.4, 75.3, 82.2, 89.1, 96. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[21]])
# Out:
# (array([ 171.,  436.,  744., 1131., 2358., 4000., 3606., 2442.,  936.,
#          298.]),
#  array([25. , 32.2, 39.4, 46.6, 53.8, 61. , 68.2, 75.4, 82.6, 89.8, 97. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[22]])
# Out:
# (array([ 296., 1284., 1525., 2059., 2336., 3300., 3502., 1488.,  296.,
#           36.]),
#  array([11. , 19.3, 27.6, 35.9, 44.2, 52.5, 60.8, 69.1, 77.4, 85.7, 94. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[23]])
# Out:
# (array([  15.,  364., 1064., 1527., 2127., 3551., 3505., 2696., 1062.,
#          211.]),
#  array([13. , 21.2, 29.4, 37.6, 45.8, 54. , 62.2, 70.4, 78.6, 86.8, 95. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[24]])
soccer_data.columns[24]
# Out:
# 'Interceptions'

# %%
plt.hist(soccer_data[soccer_data.columns[25]])
# Out:
# (array([  84.,  939., 1231., 1348., 2348., 4162., 3728., 1908.,  334.,
#           40.]),
#  array([11. , 19.4, 27.8, 36.2, 44.6, 53. , 61.4, 69.8, 78.2, 86.6, 95. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[26]])
# Out:
# (array([  33.,  304., 1251., 1667., 2886., 4287., 3530., 1744.,  373.,
#           47.]),
#  array([12. , 20.2, 28.4, 36.6, 44.8, 53. , 61.2, 69.4, 77.6, 85.8, 94. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[27]])
# Out:
# (array([  38.,  180., 1278., 2913., 3484., 3333., 3005., 1482.,  355.,
#           54.]),
#  array([12., 20., 28., 36., 44., 52., 60., 68., 76., 84., 92.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[28]])
# Out:
# (array([2.000e+00, 8.300e+01, 1.010e+03, 2.200e+03, 3.426e+03, 4.820e+03,
#         3.036e+03, 1.300e+03, 2.260e+02, 1.900e+01]),
#  array([22. , 29.4, 36.8, 44.2, 51.6, 59. , 66.4, 73.8, 81.2, 88.6, 96. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(soccer_data[soccer_data.columns[29]])
soccer_data.columns[29]
# Out:
# 'Marking'

# %%
plt.hist(soccer_data[soccer_data.columns[30]])
soccer_data.columns[30]
# Out:
# 'StandingTackle'

# %%
plt.hist(soccer_data[soccer_data.columns[31]])
soccer_data.columns[31]
# Out:
# 'SlidingTackle'

# %% [markdown]
# Next, generate pairplots between the Overall rating and the other numeric features (i.e. Overall-Crossing, Overall-Finishing....Overall-SlidingTackle). Are the results what you would expect, visually speaking? What are the strongest correlations that jump out?
#
# This dataset has many columns, so it may help to split up the pairwise scatterplots across two or three visuals. In addition, the scatterplots will probably be too crowded to be informative if the full dataset is used, so using a sample of the rows is advisable as well.

# %%
# answer goes here
# We expect the individual numeric features to increase as the overall rating increases. Most of the plots show this relationship. 
# The one that stood out the most would be Finishing vs. Overall. The overall vs. slidingtackle did not show this trend. 

over_70 = soccer_data[soccer_data['Overall'] > 70]

import seaborn as sns
sns.scatterplot(over_70['Overall'], over_70['Finishing'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(over_70['Overall'], over_70['Crossing'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(over_70['Overall'], over_70['SlidingTackle'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Plot a correlation matrix between all of the numeric columns. A heatmap is an effective way to do so. Which pairs of features stand out as having exceptionally strong correlations, both positive and/or negative?

# %%
# answer goes here
heatmap = sns.heatmap(soccer_data.iloc[:,2:25].corr(), annot=True)
plt.rcParams['figure.figsize'] = (20, 15)
plt.show()

# %% [markdown]
# Finally, create a pairplot using the numeric features in the dataset (i.e. scatterplots between pairs of features, rather than between Overall and the other features). Are the graphs visually consistent with what you would expect from the correlation heatmap?
#
# Note: there are too many numeric features to realistically generate a pairplot between all of them, so choose a subset. Choosing a fixed number of consecutive columns is fine (e.g. 10 through 20); you can also use the results of the correlation heatmap to guide your choices of columns. As with the previous exercise, using a sample of rows is recommended.

# %%
# Yes! +0.85 corr vs. -0.6 corr
sns.scatterplot(soccer_data['Dribbling'],soccer_data['BallControl'])
plt.rcParams['figure.figsize'] = (8, 6)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(soccer_data['Balance'],soccer_data['Strength'])
plt.rcParams['figure.figsize'] = (8, 6)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# For the Chicago traffic crash data, we will consider the "DAMAGE" column to be the response of interest, and the other columns to be potential features. Most of the features are categorical, so we can use contingency table to identify potentially strong associations between categorical features and our categorical response.
#
# Select one or two categorical variables that you suspect will have a strong relationship with the dollar amount of damages associated with a crash (we will choose TRAFFICWAY_TYPE), and print out the associated contigency table in two different forms:
#
# - Raw data counts
# - Percentage of total (i.e. the percentage of "OVER \$1500" for each level of a categorical variable)
#
# Are there any particular categories within a particular feature that are strongly associated with higher damages? Are there any caveats to keep in mind with some of the more extreme values in the contingency table?

# %%
# The trafficway type of 'Not Divided' has a lot more accident counts comparing to other types. Highest percentage of over $1,500 within each
# category is the 'Not Reported' trafficway. 
data_crosstab = pd.crosstab(crash_data['DAMAGE'], 
                            crash_data['TRAFFICWAY_TYPE'],  
                               margins = False) 
data_crosstab
# Out:
# TRAFFICWAY_TYPE  ALLEY  ...  Y-INTERSECTION
# DAMAGE                  ...
# $500 OR LESS      1052  ...              20
# $501 - $1,500     1737  ...              37
# OVER $1,500       3104  ...             106
#
# [3 rows x 20 columns]

# %%
pd_crosstab_x = pd.crosstab(crash_data['DAMAGE'], 
                            crash_data['TRAFFICWAY_TYPE']).apply(lambda x: x/x.sum()*100, axis=0)
pd_crosstab_x
# Out:
# TRAFFICWAY_TYPE      ALLEY  ...  Y-INTERSECTION
# DAMAGE                      ...
# $500 OR LESS     17.851688  ...       12.269939
# $501 - $1,500    29.475649  ...       22.699387
# OVER $1,500      52.672662  ...       65.030675
#
# [3 rows x 20 columns]

# %%
pd_crosstab_y = pd.crosstab(crash_data['DAMAGE'], 
                            crash_data['TRAFFICWAY_TYPE']).apply(lambda x: x/x.sum()*100, axis=1)
pd_crosstab_y
# Out:
# TRAFFICWAY_TYPE     ALLEY  ...  Y-INTERSECTION
# DAMAGE                     ...
# $500 OR LESS     2.100975  ...        0.039942
# $501 - $1,500    1.542738  ...        0.032862
# OVER $1,500      1.478651  ...        0.050495
#
# [3 rows x 20 columns]
