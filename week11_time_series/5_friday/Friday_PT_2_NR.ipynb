# %%
#Time Series Classification and Clustering

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.cluster import KMeans

# %%
#import

df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Time%20Series%20Analysis/Time%20Series%20-%20Day%205/WMT_data.csv')

# %%
df.shape
# Out:
# (1259, 7)

# %%
df['date'] = pd.to_datetime(df['date'])
df.columns = ['Date', 'Open', 'High', 'Low', 'Observed', 'Volume', 'Ticker']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1259 non-null   datetime64[ns]
#  1   Open      1259 non-null   float64
#  2   High      1259 non-null   float64
#  3   Low       1259 non-null   float64
#  4   Observed  1259 non-null   float64
#  5   Volume    1259 non-null   int64
#  6   Ticker    1259 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 69.0+ KB

# %%
df.set_index('Date')['Observed'].plot(kind='line', figsize=(20,10))

# %%
#Transform the data to be able to predict minor direction changes in the stock's price, given 180 days of history.

# %%
df['Returns'] = df['Observed'].pct_change()
df.head()
# Out:
#         Date   Open   High     Low  Observed   Volume Ticker   Returns
# 0 2013-02-08  71.20  71.64  71.070     71.48  5906823    WMT       NaN
# 1 2013-02-11  71.25  71.51  70.530     71.40  6202534    WMT -0.001119
# 2 2013-02-12  71.49  71.66  71.100     71.40  4761910    WMT  0.000000
# 3 2013-02-13  71.29  71.70  71.210     71.39  3969807    WMT -0.000140
# 4 2013-02-14  71.10  71.23  70.755     70.82  6820952    WMT -0.007984

# %%
df['Returns'].plot()

# %%
df['MA_5'] = df['Observed'].rolling(5).mean()

df['Trend'] = 'None'
df.loc[(df['MA_5'] < df['Observed']), 'Trend'] = 'Negative'
df.loc[(df['MA_5'] > df['Observed']), 'Trend'] = 'Positive'
df['Change'] = df['Trend'].eq(df['Trend'].shift())
df.tail()
# Out:
#            Date    Open    High     Low  ...   Returns     MA_5     Trend  Change
# 1254 2018-02-01  105.96  106.56  105.18  ... -0.010131  107.558  Positive    True
# 1255 2018-02-02  105.15  106.47  104.15  ... -0.009856  106.776  Positive    True
# 1256 2018-02-05  103.40  104.61   97.09  ... -0.042018  104.884  Positive    True
# 1257 2018-02-06   97.64  101.08   97.25  ...  0.008093  103.518  Positive    True
# 1258 2018-02-07  100.50  104.59  100.01  ...  0.019326  102.768  Negative   False
#
# [5 rows x 11 columns]

# %%
df['Binary'] = 0
df.loc[(df['Change']==False) & (df['Trend'] != 'None'), 'Binary'] = 1

df.dropna(inplace=True)
df.head()
# Out:
#         Date   Open   High     Low  ...    MA_5     Trend Change  Binary
# 4 2013-02-14  71.10  71.23  70.755  ...  71.298  Positive  False       1
# 5 2013-02-15  69.54  70.00  68.130  ...  70.862  Positive   True       0
# 6 2013-02-19  69.19  69.45  68.540  ...  70.334  Positive   True       0
# 7 2013-02-20  68.72  69.85  68.300  ...  69.896  Positive   True       0
# 8 2013-02-21  70.00  71.47  69.720  ...  69.670  Negative  False       1
#
# [5 rows x 12 columns]

# %%
transformed = df[['Date', 'Returns', 'Binary']]

history = 180
future = 0

shifts = [x + future for x in list(range(1, history + 1))]

for shift in shifts:
    transformed['t-' + str(shift)] = transformed['Returns'].shift(shift)

transformed.dropna(inplace=True)
transformed.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#           Date   Returns  Binary  ...     t-178     t-179     t-180
# 184 2013-10-31 -0.002080       1  ... -0.007792 -0.021463 -0.007984
# 185 2013-11-01  0.004169       1  ...  0.006545 -0.007792 -0.021463
# 186 2013-11-04  0.003374       0  ...  0.015171  0.006545 -0.007792
# 187 2013-11-05  0.001164       0  ...  0.001993  0.015171  0.006545
# 188 2013-11-06  0.009558       0  ...  0.000568  0.001993  0.015171
#
# [5 rows x 183 columns]

# %%
#Train a Logistic Regression classification model on the transformed data.

x = transformed.drop(['Date', 'Returns', 'Binary'], axis=1)
y = transformed['Binary']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, shuffle=False)

# %%
model = LogisticRegression(class_weight='balanced')
model.fit(x_train, y_train)
predictions = model.predict(x_test)

# %%
#Run a classification report and evaluate the performance of the classifier.

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.63      0.70       161
#            1       0.30      0.46      0.36        54
#
#     accuracy                           0.59       215
#    macro avg       0.54      0.55      0.53       215
# weighted avg       0.66      0.59      0.61       215

# %%
#Transform the data again to have 10 days of history for clustering.

transformed = df[['Date', 'Returns', 'Binary']]

history = 10
future = 0

shifts = [x + future for x in list(range(1, history + 1))]

for shift in shifts:
    transformed['t-' + str(shift)] = transformed['Returns'].shift(shift)

transformed.dropna(inplace=True)

x = transformed.drop(['Date', 'Returns', 'Binary'], axis=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
#Train a K Means clustering model on the data.
#Try different values for K and see how the summary changes.


def kmeans(df, clusters=2):
    model = KMeans(n_clusters=clusters)
    clusters = model.fit_predict(df)
    results = df.copy()
    results['Cluster'] = clusters
    
    cluster_size = results.groupby(['Cluster']).size().reset_index()
    cluster_size.columns = ['Cluster', 'Count']
    cluster_means = results.groupby(['Cluster'], as_index=False).mean()
    summary = pd.merge(cluster_size, cluster_means, on='Cluster')
    
    return results, summary

#2 clusters
results_2, summary_2 = kmeans(x, clusters=2)
summary_2
# Out:
#    Cluster  Count       t-1       t-2  ...       t-7       t-8       t-9      t-10
# 0        0    588 -0.002792 -0.001880  ...  0.004136  0.001633 -0.001714 -0.001500
# 1        1    657  0.003132  0.002316  ... -0.002881 -0.000669  0.002268  0.002053
#
# [2 rows x 12 columns]

# %%
results_5, summary_5 = kmeans(x, clusters=5)
summary_5
# Out:
#    Cluster  Count       t-1       t-2  ...       t-7       t-8       t-9      t-10
# 0        0    261  0.002907  0.003070  ...  0.008265  0.002440 -0.000069 -0.000669
# 1        1    242  0.006303 -0.002441  ... -0.006956  0.004433  0.003124  0.007275
# 2        2    240 -0.001343  0.001139  ...  0.000320  0.001210 -0.005538 -0.004798
# 3        3    295  0.000042  0.006294  ... -0.000212 -0.005683  0.000028  0.001939
# 4        4    207 -0.007526 -0.009299  ...  0.000244  0.000951  0.005144 -0.002610
#
# [5 rows x 12 columns]

# %%
results_10, summary_10 = kmeans(x, clusters=10)
summary_10
# Out:
#    Cluster  Count       t-1       t-2  ...       t-7       t-8       t-9      t-10
# 0        0    141 -0.000056  0.008885  ...  0.000421  0.002268 -0.000777 -0.009594
# 1        1     90 -0.001671  0.010188  ...  0.001382 -0.013338  0.002845  0.002262
# 2        2    133 -0.008023 -0.004162  ... -0.003170  0.000552  0.012169  0.001161
# 3        3    132 -0.002745 -0.007263  ...  0.002932  0.001362 -0.000694  0.000123
# 4        4     91 -0.007778 -0.000452  ... -0.002879 -0.002253 -0.015095  0.001505
# 5        5    165  0.002570  0.000106  ...  0.011495 -0.001192  0.000109  0.000640
# 6        6    103  0.014330 -0.003891  ... -0.008349  0.001370  0.000174  0.000570
# 7        7    115  0.002364  0.000835  ... -0.002571 -0.001664 -0.000640  0.015234
# 8        8    128  0.003845 -0.002484  ... -0.000009 -0.002056  0.002139 -0.002115
# 9        9    147  0.000324  0.002754  ... -0.000601  0.012671 -0.000366 -0.002297
#
# [10 rows x 12 columns]

# %%
#Visualize the summary of the clustering results as a heatmap.

plt.figure(figsize=(20,10))
sns.heatmap(summary_5.drop(columns=['Cluster', 'Count']), cmap='Reds', linewidths=0.01)
