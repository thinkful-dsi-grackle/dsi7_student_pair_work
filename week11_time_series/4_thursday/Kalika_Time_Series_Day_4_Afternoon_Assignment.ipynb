# %% [markdown]
# # Time Series Forecasting Assignment

# %%
import pandas as pd
import plotly.express as px
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from fbprophet import Prophet

# %% [markdown]
# ### Import the Microsoft stock price data set (MSFT_data.csv) into a Pandas dataframe.

# %%
df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Time%20Series%20Analysis/Time%20Series%20-%20Day%204/MSFT_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   object
#  1   open    1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   close   1259 non-null   float64
#  5   volume  1259 non-null   int64
#  6   Name    1259 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 69.0+ KB

# %%
ms = df[['date', 'close']].copy()
ms.head()
# Out:
#          date  close
# 0  2013-02-08  27.55
# 1  2013-02-11  27.86
# 2  2013-02-12  27.88
# 3  2013-02-13  28.03
# 4  2013-02-14  28.04

# %%
ms.date = pd.to_datetime(ms.date)

# %%
ms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   datetime64[ns]
#  1   close   1259 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 19.8 KB

# %% [markdown]
# ### Generate a line chart showing the observed values (closing prices).

# %%
def iline(df, x, y, groups=None, title=''):
    fig = px.line(df, x=x, y=y, color=groups, title=title, 
                  template='none')
    fig.show()

# %%
def chart(df, vars, title='Model Comparison'):
   
   vars = list(vars)
   vars.append('close')
   chart = pd.melt(df, id_vars='date', value_vars=vars, 
                 var_name='Variable', value_name='Value')

   iline(chart, 'date', 'Value', groups='Variable', title=title)

# %%
chart(ms, '', 'Closing Prices over Time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f51f7a85-8850-46df-ba36-b35feefe9b6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f51f7a85-8850-46df-ba36-b35feefe9b6c")) {
#                     Plotly.newPlot(
#                         'f51f7a85-8850-46df-ba36-b35feefe9b6c',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Variable=close<br>date=%{x}<br>Value=%{y}", "legendgroup": "Variable=close", "line": {"color": "#1F77B4", "dash": "solid"}, "mode": "lines", "name": "Variable=close", "showlegend": true, "type": "scattergl", "x": ["2013-02-08T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-02-13T00:00:00", "2013-02-14T00:00:00", "2013-02-15T00:00:00", "2013-02-19T00:00:00", "2013-02-20T00:00:00", "2013-02-21T00:00:00", "2013-02-22T00:00:00", "2013-02-25T00:00:00", "2013-02-26T00:00:00", "2013-02-27T00:00:00", "2013-02-28T00:00:00", "2013-03-01T00:00:00", "2013-03-04T00:00:00", "2013-03-05T00:00:00", "2013-03-06T00:00:00", "2013-03-07T00:00:00", "2013-03-08T00:00:00", "2013-03-11T00:00:00", "2013-03-12T00:00:00", "2013-03-13T00:00:00", "2013-03-14T00:00:00", "2013-03-15T00:00:00", "2013-03-18T00:00:00", "2013-03-19T00:00:00", "2013-03-20T00:00:00", "2013-03-21T00:00:00", "2013-03-22T00:00:00", "2013-03-25T00:00:00", "2013-03-26T00:00:00", "2013-03-27T00:00:00", "2013-03-28T00:00:00", "2013-04-01T00:00:00", "2013-04-02T00:00:00", "2013-04-03T00:00:00", "2013-04-04T00:00:00", "2013-04-05T00:00:00", "2013-04-08T00:00:00", "2013-04-09T00:00:00", "2013-04-10T00:00:00", "2013-04-11T00:00:00", "2013-04-12T00:00:00", "2013-04-15T00:00:00", "2013-04-16T00:00:00", "2013-04-17T00:00:00", "2013-04-18T00:00:00", "2013-04-19T00:00:00", "2013-04-22T00:00:00", "2013-04-23T00:00:00", "2013-04-24T00:00:00", "2013-04-25T00:00:00", "2013-04-26T00:00:00", "2013-04-29T00:00:00", "2013-04-30T00:00:00", "2013-05-01T00:00:00", "2013-05-02T00:00:00", "2013-05-03T00:00:00", "2013-05-06T00:00:00", "2013-05-07T00:00:00", "2013-05-08T00:00:00", "2013-05-09T00:00:00", "2013-05-10T00:00:00", "2013-05-13T00:00:00", "2013-05-14T00:00:00", "2013-05-15T00:00:00", "2013-05-16T00:00:00", "2013-05-17T00:00:00", "2013-05-20T00:00:00", "2013-05-21T00:00:00", "2013-05-22T00:00:00", "2013-05-23T00:00:00", "2013-05-24T00:00:00", "2013-05-28T00:00:00", "2013-05-29T00:00:00", "2013-05-30T00:00:00", "2013-05-31T00:00:00", "2013-06-03T00:00:00", "2013-06-04T00:00:00", "2013-06-05T00:00:00", "2013-06-06T00:00:00", "2013-06-07T00:00:00", "2013-06-10T00:00:00", "2013-06-11T00:00:00", "2013-06-12T00:00:00", "2013-06-13T00:00:00", "2013-06-14T00:00:00", "2013-06-17T00:00:00", "2013-06-18T00:00:00", "2013-06-19T00:00:00", "2013-06-20T00:00:00", "2013-06-21T00:00:00", "2013-06-24T00:00:00", "2013-06-25T00:00:00", "2013-06-26T00:00:00", "2013-06-27T00:00:00", "2013-06-28T00:00:00", "2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013- ...

# %% [markdown]
# ### Decompose the time series and check it for stationarity. If the data is not stationary, difference the observations and store the results in a new Diff column.

# %%
series = ms.set_index('date')
#frequency is 252, we're looking at finance.
decomposition = sm.tsa.seasonal_decompose(series, model='additive', freq=252)


ms['trend'] = decomposition.trend.reset_index().close
ms['seasonality'] = decomposition.seasonal.reset_index().close
ms['residuals'] = decomposition.resid.reset_index().close

# %%
ms.describe()
# Out:
#              close        trend  seasonality    residuals
# count  1259.000000  1007.000000  1259.000000  1007.000000
# mean     51.063081    49.919506     0.001300    -0.200148
# std      14.852117    10.170233     1.329931     1.789639
# min      27.370000    33.443516    -2.576283    -6.586172
# 25%      40.310000    43.316300    -0.917716    -1.343388
# 50%      47.520000    47.470635    -0.365645    -0.125781
# 75%      59.730000    56.347579     0.549321     1.035761
# max      95.010000    74.683016     3.336350     4.118625

# %%
chart(ms, ['trend', 'seasonality', 'residuals'], 'Decomposition Analysis')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="54b1bea9-bcf5-4974-9098-86fb0ff073cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54b1bea9-bcf5-4974-9098-86fb0ff073cc")) {
#                     Plotly.newPlot(
#                         '54b1bea9-bcf5-4974-9098-86fb0ff073cc',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Variable=trend<br>date=%{x}<br>Value=%{y}", "legendgroup": "Variable=trend", "line": {"color": "#1F77B4", "dash": "solid"}, "mode": "lines", "name": "Variable=trend", "showlegend": true, "type": "scattergl", "x": ["2013-02-08T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-02-13T00:00:00", "2013-02-14T00:00:00", "2013-02-15T00:00:00", "2013-02-19T00:00:00", "2013-02-20T00:00:00", "2013-02-21T00:00:00", "2013-02-22T00:00:00", "2013-02-25T00:00:00", "2013-02-26T00:00:00", "2013-02-27T00:00:00", "2013-02-28T00:00:00", "2013-03-01T00:00:00", "2013-03-04T00:00:00", "2013-03-05T00:00:00", "2013-03-06T00:00:00", "2013-03-07T00:00:00", "2013-03-08T00:00:00", "2013-03-11T00:00:00", "2013-03-12T00:00:00", "2013-03-13T00:00:00", "2013-03-14T00:00:00", "2013-03-15T00:00:00", "2013-03-18T00:00:00", "2013-03-19T00:00:00", "2013-03-20T00:00:00", "2013-03-21T00:00:00", "2013-03-22T00:00:00", "2013-03-25T00:00:00", "2013-03-26T00:00:00", "2013-03-27T00:00:00", "2013-03-28T00:00:00", "2013-04-01T00:00:00", "2013-04-02T00:00:00", "2013-04-03T00:00:00", "2013-04-04T00:00:00", "2013-04-05T00:00:00", "2013-04-08T00:00:00", "2013-04-09T00:00:00", "2013-04-10T00:00:00", "2013-04-11T00:00:00", "2013-04-12T00:00:00", "2013-04-15T00:00:00", "2013-04-16T00:00:00", "2013-04-17T00:00:00", "2013-04-18T00:00:00", "2013-04-19T00:00:00", "2013-04-22T00:00:00", "2013-04-23T00:00:00", "2013-04-24T00:00:00", "2013-04-25T00:00:00", "2013-04-26T00:00:00", "2013-04-29T00:00:00", "2013-04-30T00:00:00", "2013-05-01T00:00:00", "2013-05-02T00:00:00", "2013-05-03T00:00:00", "2013-05-06T00:00:00", "2013-05-07T00:00:00", "2013-05-08T00:00:00", "2013-05-09T00:00:00", "2013-05-10T00:00:00", "2013-05-13T00:00:00", "2013-05-14T00:00:00", "2013-05-15T00:00:00", "2013-05-16T00:00:00", "2013-05-17T00:00:00", "2013-05-20T00:00:00", "2013-05-21T00:00:00", "2013-05-22T00:00:00", "2013-05-23T00:00:00", "2013-05-24T00:00:00", "2013-05-28T00:00:00", "2013-05-29T00:00:00", "2013-05-30T00:00:00", "2013-05-31T00:00:00", "2013-06-03T00:00:00", "2013-06-04T00:00:00", "2013-06-05T00:00:00", "2013-06-06T00:00:00", "2013-06-07T00:00:00", "2013-06-10T00:00:00", "2013-06-11T00:00:00", "2013-06-12T00:00:00", "2013-06-13T00:00:00", "2013-06-14T00:00:00", "2013-06-17T00:00:00", "2013-06-18T00:00:00", "2013-06-19T00:00:00", "2013-06-20T00:00:00", "2013-06-21T00:00:00", "2013-06-24T00:00:00", "2013-06-25T00:00:00", "2013-06-26T00:00:00", "2013-06-27T00:00:00", "2013-06-28T00:00:00", "2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013- ...

# %%
#augmented dickey fuller - we know it's not stationary.
adf_test = sm.tsa.stattools.adfuller(ms['close'])
results = pd.Series(adf_test[0:4], 
                    index=['ADF Test Statistic',
                            'P-Value', 
                            '# Lags Used',
                            '# Observations Used'])
for key, value in adf_test[4].items():
  results[f'Critical Value {key}'] = value
results
# Out:
# ADF Test Statistic        0.415655
# P-Value                   0.982071
# # Lags Used               0.000000
# # Observations Used    1258.000000
# Critical Value 1%        -3.435559
# Critical Value 5%        -2.863840
# Critical Value 10%       -2.567995
# dtype: float64

# %%
ms['diff'] = ms['close'] - ms['close'].shift()
ms['diff'].fillna(0, inplace=True)

# %% [markdown]
# ### Forecast the time series 60 days into the future using double and triple exponential smoothing models.

# %%
model = sm.tsa.ExponentialSmoothing(ms['close'], trend='additive').fit()
double_exp = model.forecast(60)

# %%
model = sm.tsa.ExponentialSmoothing(ms['close'], trend='additive', 
                                    seasonal='additive', 
                                    seasonal_periods=4).fit()

triple_exp = model.forecast(60)

# %% [markdown]
# ### Forecast the time series 60 days into the future using ARMA, ARIMA, and SARIMA models.

# %%
def forecast(data, field, model, periods):
    model_results = model.forecast(periods)[0]
    current_value = data[field].iloc[-1]
    forecasts = []
    
    for result in model_results:
        forecast = current_value + result
        forecasts.append(forecast)
        current_value = forecast
    
    forecasts = pd.Series(forecasts)
    forecasts.index = [x + periods 
                       for x in list(data[field].tail(periods).index)]
    
    return forecasts

# %%
#a shift column will help with future modeling arrangements. Adding it here, should've done it sooner; probably.
ms['shift'] = ms['close'].shift(1).fillna(method='bfill')

# %%
model = ARMA(ms['diff'], order=(2, 1)).fit()
arma_forecasts = forecast(ms, 'close', model, 60)
arma_forecasts.head(20)
# Out:
# 1259    89.711841
# 1260    89.801678
# 1261    89.887137
# 1262    89.968672
# 1263    90.046715
# 1264    90.121648
# 1265    90.193812
# 1266    90.263509
# 1267    90.331012
# 1268    90.396559
# 1269    90.460366
# 1270    90.522623
# 1271    90.583500
# 1272    90.643148
# 1273    90.701703
# 1274    90.759282
# 1275    90.815995
# 1276    90.871935
# 1277    90.927187
# 1278    90.981827
# dtype: float64

# %%
model = ARIMA(ms['diff'], order=(1, 1, 1)).fit()
arima_forecasts = forecast(ms, 'close', model, 60)
arima_forecasts.head(20)
# Out:
# 1259    89.754431
# 1260    89.839348
# 1261    89.926225
# 1262    90.013099
# 1263    90.100032
# 1264    90.187022
# 1265    90.274070
# 1266    90.361175
# 1267    90.448337
# 1268    90.535557
# 1269    90.622834
# 1270    90.710168
# 1271    90.797559
# 1272    90.885008
# 1273    90.972514
# 1274    91.060077
# 1275    91.147698
# 1276    91.235376
# 1277    91.323111
# 1278    91.410904
# dtype: float64

# %%
model = SARIMAX(ms['close'], order=(2, 1, 1), 
                seasonal_order=(1, 1, 1, 1)).fit()

sarima_forecasts = model.forecast(60)
sarima_forecasts.head(20)
# Out:
# 1259    89.714712
# 1260    89.793799
# 1261    89.874259
# 1262    89.955747
# 1263    90.038219
# 1264    90.121633
# 1265    90.205948
# 1266    90.291124
# 1267    90.377124
# 1268    90.463911
# 1269    90.551452
# 1270    90.639713
# 1271    90.728663
# 1272    90.818271
# 1273    90.908510
# 1274    90.999350
# 1275    91.090767
# 1276    91.182735
# 1277    91.275230
# 1278    91.368228
# dtype: float64

# %% [markdown]
# ### Forecast the time series 60 days into the future using the Facebook Prophet model.

# %%
series = ms[['date', 'close']]
series.columns = ['ds', 'y']
series
# Out:
#              ds      y
# 0    2013-02-08  27.55
# 1    2013-02-11  27.86
# 2    2013-02-12  27.88
# 3    2013-02-13  28.03
# 4    2013-02-14  28.04
# ...         ...    ...
# 1254 2018-02-01  94.26
# 1255 2018-02-02  91.78
# 1256 2018-02-05  88.00
# 1257 2018-02-06  91.33
# 1258 2018-02-07  89.61
#
# [1259 rows x 2 columns]

# %%
model = Prophet()
model.fit(series)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(60)
future.tail(61)
# Out:
#              ds
# 1258 2018-02-07
# 1259 2018-02-08
# 1260 2018-02-09
# 1261 2018-02-10
# 1262 2018-02-11
# ...         ...
# 1314 2018-04-04
# 1315 2018-04-05
# 1316 2018-04-06
# 1317 2018-04-07
# 1318 2018-04-08
#
# [61 rows x 1 columns]

# %%
results = model.predict(future)
results.tail()
# Out:
#              ds      trend  ...  multiplicative_terms_upper       yhat
# 1314 2018-04-04  91.948867  ...                         0.0  91.682917
# 1315 2018-04-05  92.019629  ...                         0.0  91.683326
# 1316 2018-04-06  92.090391  ...                         0.0  91.832418
# 1317 2018-04-07  92.161153  ...                         0.0  92.773285
# 1318 2018-04-08  92.231915  ...                         0.0  92.819962
#
# [5 rows x 19 columns]

# %%
# take the last 30 rows
prophet_forecasts = results.iloc[-60:]['yhat']
prophet_forecasts.head()
# Out:
# 1259    88.695185
# 1260    88.837582
# 1261    89.772343
# 1262    89.812578
# 1263    88.907186
# Name: yhat, dtype: float64

# %% [markdown]
# ### Combine the observed values and all the forecasts into a single data frame and generate a line chart to visually compare the different models.

# %%
future_dates = pd.DataFrame({'date': pd.date_range(start=ms.date.iloc[-1], periods=61, 
                                                   freq='D', closed='right')})

fcast_df = pd.concat([pd.DataFrame(ms['date']), future_dates], ignore_index=True)
fcast_df = fcast_df.merge(ms[['date', 'close']], on='date', how='left')
fcast_df
# Out:
#            date  close
# 0    2013-02-08  27.55
# 1    2013-02-11  27.86
# 2    2013-02-12  27.88
# 3    2013-02-13  28.03
# 4    2013-02-14  28.04
# ...         ...    ...
# 1314 2018-04-04    NaN
# 1315 2018-04-05    NaN
# 1316 2018-04-06    NaN
# 1317 2018-04-07    NaN
# 1318 2018-04-08    NaN
#
# [1319 rows x 2 columns]

# %%
fcast_df['Double_Exp_Smooth'] = double_exp
fcast_df['Triple_Exp_Smooth'] = triple_exp
fcast_df['ARMA'] = arma_forecasts
fcast_df['ARIMA'] = arima_forecasts
fcast_df['SARIMA'] = sarima_forecasts
fcast_df['Prophet'] = prophet_forecasts

# %%
fcast_df
# Out:
#            date  close  Double_Exp_Smooth  ...      ARIMA     SARIMA    Prophet
# 0    2013-02-08  27.55                NaN  ...        NaN        NaN        NaN
# 1    2013-02-11  27.86                NaN  ...        NaN        NaN        NaN
# 2    2013-02-12  27.88                NaN  ...        NaN        NaN        NaN
# 3    2013-02-13  28.03                NaN  ...        NaN        NaN        NaN
# 4    2013-02-14  28.04                NaN  ...        NaN        NaN        NaN
# ...         ...    ...                ...  ...        ...        ...        ...
# 1314 2018-04-04    NaN          92.430657  ...  94.609600  94.920107  91.682917
# 1315 2018-04-05    NaN          92.480026  ...  94.699513  95.022020  91.683326
# 1316 2018-04-06    NaN          92.529395  ...  94.789483  95.124026  91.832418
# 1317 2018-04-07    NaN          92.578763  ...  94.879510  95.226119  92.773285
# 1318 2018-04-08    NaN          92.628132  ...  94.969595  95.328297  92.819962
#
# [1319 rows x 8 columns]

# %%
fcast_df.columns[2:]
# Out:
# Index(['Double_Exp_Smooth', 'Triple_Exp_Smooth', 'ARMA', 'ARIMA', 'SARIMA',
#        'Prophet'],
#       dtype='object')

# %%
chart(fcast_df, ['Double_Exp_Smooth', 'Triple_Exp_Smooth', 'ARMA', 'ARIMA', 'SARIMA',
       'Prophet'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2202aab2-60da-4c52-8be8-7b26122083fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2202aab2-60da-4c52-8be8-7b26122083fb")) {
#                     Plotly.newPlot(
#                         '2202aab2-60da-4c52-8be8-7b26122083fb',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Variable=Double_Exp_Smooth<br>date=%{x}<br>Value=%{y}", "legendgroup": "Variable=Double_Exp_Smooth", "line": {"color": "#1F77B4", "dash": "solid"}, "mode": "lines", "name": "Variable=Double_Exp_Smooth", "showlegend": true, "type": "scattergl", "x": ["2013-02-08T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-02-13T00:00:00", "2013-02-14T00:00:00", "2013-02-15T00:00:00", "2013-02-19T00:00:00", "2013-02-20T00:00:00", "2013-02-21T00:00:00", "2013-02-22T00:00:00", "2013-02-25T00:00:00", "2013-02-26T00:00:00", "2013-02-27T00:00:00", "2013-02-28T00:00:00", "2013-03-01T00:00:00", "2013-03-04T00:00:00", "2013-03-05T00:00:00", "2013-03-06T00:00:00", "2013-03-07T00:00:00", "2013-03-08T00:00:00", "2013-03-11T00:00:00", "2013-03-12T00:00:00", "2013-03-13T00:00:00", "2013-03-14T00:00:00", "2013-03-15T00:00:00", "2013-03-18T00:00:00", "2013-03-19T00:00:00", "2013-03-20T00:00:00", "2013-03-21T00:00:00", "2013-03-22T00:00:00", "2013-03-25T00:00:00", "2013-03-26T00:00:00", "2013-03-27T00:00:00", "2013-03-28T00:00:00", "2013-04-01T00:00:00", "2013-04-02T00:00:00", "2013-04-03T00:00:00", "2013-04-04T00:00:00", "2013-04-05T00:00:00", "2013-04-08T00:00:00", "2013-04-09T00:00:00", "2013-04-10T00:00:00", "2013-04-11T00:00:00", "2013-04-12T00:00:00", "2013-04-15T00:00:00", "2013-04-16T00:00:00", "2013-04-17T00:00:00", "2013-04-18T00:00:00", "2013-04-19T00:00:00", "2013-04-22T00:00:00", "